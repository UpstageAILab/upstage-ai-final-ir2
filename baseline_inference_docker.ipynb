# %% [markdown]
# # Information Retrieval Baseline Code

# %% [markdown]
# ## 대회 설명
# Information Retrieval 경진대회에 오신 여러분 환영합니다! 🎉 <br>
# 본 대회에서는 과학 상식에 대한 멀터턴 질문에 대하여 RAG 기술을 활용하여 질문에 적합한 레퍼런스를 추출하고 이를 토대로 답변을 생성하는 어플리케이션을 구현해 봅니다. <br>
# LLM은 GPT-3.5 버전을 이용하고, 레퍼런스 추출을 위한 검색엔진 구축은 Elasticsearch를 활용합니다.

# %% [markdown]
# ## 데이터셋 준비
# * 질문에 대한 레퍼런스로 활용될 수 있는 4272개의 과학 상식을 다루는 문서
#  * Open Ko LLM Leaderboard에 들어가는 Ko-H4 데이터 중 MMLU, ARC 데이터를 기반으로 생성
#  * Question과 answer를 paraphrase (question과 answer를 토대로 GPT-4 활용하여 document 생성)
#  * 예시)
#   ```
#   수소, 산소, 질소 가스의 혼합물에서 평균 속도가 가장 빠른 분자는 수소입니다
# . 수소 분자는 가장 가볍고 작은 원자로 구성되어 있기 때문에 다른 분자들보다 더 빠르게 움직>입니다. 이러한 이유로 수소 분자는 주어진 온도에서 가장 빠른 평균 속도를 가지고 있습니다. >수소 분자는 화학 반응에서도 활발하게 참여하며, 수소 연료로도 널리 사용됩니다. 따라서 수소 분자는 주어진 온도에서 평균 속도가 가장 빠른 분자입니다.
#   ```
#
# * 가상의 질문 220개
#  * 과학 상식 질문 또는 일상 대화 메시지를 수동으로 생성
#  * 220개 중 20개는 멀티턴 대화 형태의 질문, 20개는 일상 칫챗 대화
#   * 예시)
#   ```
# {"eval_id": 0, "msg": [{"role": "user", "content": "나무의 분류에 대해 조사해 보기 위한 방
# 법은?"}], "refs": ["c63b9e3a-716f-423a-9c9b-0bcaa1b9f35d"]}
# {"eval_id": 1, "msg": [{"role": "user", "content": "각 나라에서의 공교육 지출 현황에 대해 알려줘."}], "refs": ["79c93deb-fe60-4c81-8d51-cb7400a0a156"]}
# {"eval_id": 2, "msg": [{"role": "user", "content": "기억 상실증 걸리면 너무 무섭겠다."}, {"role": "assistant", "content": "네 맞습니다."}, {"role": "user", "content": "어떤 원인 때
# 문에 발생하는지 궁금해."}], "refs": ["25de4ffd-cee4-4f27-907e-fd6b802c6ede"]}
#   ```

# %%
 # 색인 대상 문서 및 평가 데이터 다운로드
 # !wget https://aistages-api-public-prod.s3.amazonaws.com/app/Competitions/000291/data/data.tar.gz
 # !tar -xzvf data.tar.gz
# Out:
# --2024-02-14 05:15:10--  https://aistages-api-public-prod.s3.amazonaws.com/app/Competitions/000291/data/data.tar.gz
# Resolving aistages-api-public-prod.s3.amazonaws.com (aistages-api-public-prod.s3.amazonaws.com)... 52.219.206.95, 52.219.202.27, 52.219.56.70, ...
# Connecting to aistages-api-public-prod.s3.amazonaws.com (aistages-api-public-prod.s3.amazonaws.com)|52.219.206.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1068264 (1.0M) [binary/octet-stream]
# Saving to: ‘data.tar.gz’
#
# data.tar.gz         100%[===================>]   1.02M  1.49MB/s    in 0.7s
#
# 2024-02-14 05:15:12 (1.49 MB/s) - ‘data.tar.gz’ saved [1068264/1068264]
#
# data/
# data/eval.jsonl
# data/documents.jsonl

# %% [markdown]
# ## 환경 설정
# 검색엔진을 위한 Elasitcsearch, 임베딩 생성을 위한 sentence transformers, LLM 사용을 위한 openai client 설치가 필요합니다.

# %%
# Elasticsearch python 패키지 설치
# !pip install elasticsearch==8.8.0

# OpenAI Python 패키지 설치
# !pip install openai==1.7.2

# 임베딩 생성을 위한 벡터 인코더 설치
# !pip install sentence-transformers==2.2.2
# Out:
# Collecting elasticsearch==8.8.0
#   Downloading elasticsearch-8.8.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting elastic-transport<9,>=8 (from elasticsearch==8.8.0)
#   Downloading elastic_transport-8.13.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /home/demyank/anaconda3/lib/python3.11/site-packages (from elastic-transport<9,>=8->elasticsearch==8.8.0) (1.26.18)
# Requirement already satisfied: certifi in /home/demyank/anaconda3/lib/python3.11/site-packages (from elastic-transport<9,>=8->elasticsearch==8.8.0) (2024.2.2)
# Downloading elasticsearch-8.8.0-py3-none-any.whl (393 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.8/393.8 kB 4.4 MB/s eta 0:00:00a 0:00:01m
# Downloading elastic_transport-8.13.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: elastic-transport, elasticsearch
# Successfully installed elastic-transport-8.13.0 elasticsearch-8.8.0
# Collecting openai==1.7.2
#   Downloading openai-1.7.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (1.8.0)
# Collecting httpx<1,>=0.23.0 (from openai==1.7.2)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (1.10.12)
# Requirement already satisfied: sniffio in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (1.3.0)
# Requirement already satisfied: tqdm>4 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /home/demyank/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai==1.7.2) (3.4)
# Requirement already satisfied: certifi in /home/demyank/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai==1.7.2) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai==1.7.2)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.7.2)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading openai-1.7.2-py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.1/212.1 kB 5.6 MB/s eta 0:00:00ta 0:00:01
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.7 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.7.2
# Collecting sentence-transformers==2.2.2
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (4.38.2)
# Requirement already satisfied: tqdm in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (2.2.1)
# Requirement already satisfied: torchvision in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (0.17.1)
# Requirement already satisfied: numpy in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (1.26.4)
# Requirement already satisfied: scikit-learn in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (1.2.2)
# Requirement already satisfied: scipy in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (1.11.4)
# Requirement already satisfied: nltk in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (3.8.1)
# Collecting sentencepiece (from sentence-transformers==2.2.2)
#   Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (0.21.4)
# Requirement already satisfied: filelock in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2023.10.0)
# Requirement already satisfied: requests in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.28.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (23.1)
# Requirement already satisfied: sympy in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (1.12)
# Requirement already satisfied: networkx in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.1)
# Requirement already satisfied: jinja2 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/demyank/anaconda3/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->sentence-transformers==2.2.2) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /home/demyank/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/demyank/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.4.2)
# Requirement already satisfied: click in /home/demyank/anaconda3/lib/python3.11/site-packages (from nltk->sentence-transformers==2.2.2) (8.1.7)
# Requirement already satisfied: joblib in /home/demyank/anaconda3/lib/python3.11/site-packages (from nltk->sentence-transformers==2.2.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence-transformers==2.2.2) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torchvision->sentence-transformers==2.2.2) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.6.0->sentence-transformers==2.2.2) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.6.0->sentence-transformers==2.2.2) (1.3.0)
# Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.6 MB/s eta 0:00:0000:0100:01m
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125937 sha256=a6b7e361d9a6d35feee368a7559085ee84b2d0243431cf89f0e983e370814e04
#   Stored in directory: /home/demyank/.cache/pip/wheels/ff/27/bf/ffba8b318b02d7f691a57084ee154e26ed24d012b0c7805881
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, sentence-transformers
# Successfully installed sentence-transformers-2.2.2 sentencepiece-0.2.0

# %% [markdown]
# ## 검색엔진 준비 - Elasticsearch

# %%
# 데몬이 구동되었는지 확인 (세개의 daemon process가 있어야 함)
# !ps -ef | grep elasticsearch
# Out:
# demyank  69360 68765  0 11:59 pts/11   00:00:00 /usr/bin/zsh -c ps -ef | grep elasticsearch
# demyank  69362 69360  0 11:59 pts/11   00:00:00 grep elasticsearch

# %%
import os
import torch
from elasticsearch import Elasticsearch, helpers
from peft import LoraConfig, AutoPeftModelForCausalLM, PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, BitsAndBytesConfig, AutoTokenizer, TrainingArguments, pipeline, DataCollatorForSeq2Seq

# %%
# Elasticsearch credentials (adjust these as per your Elasticsearch setup)
es_username = 'elastic'
es_password = os.getenv('ES_PASSWORD')  # Replace 'your_password_here' with your actual Elasticsearch password

# Path to your CA certificate on your host (adjust this after copying it from the container)
ca_cert_path = os.getenv('HTTP_CA_CRT_PATH')  # Update this to the actual path where you store your copied CA certificate

# Create an Elasticsearch client
es = Elasticsearch(
    ['https://localhost:9200'],
    basic_auth=(es_username, es_password),
    ca_certs=ca_cert_path
)

# Print Elasticsearch client information to verify connectivity
print(es.info())
# Out:
# {'name': '8b4375334f9c', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'XuaZu5E-QgWjjKSFBuUCaQ', 'version': {'number': '8.13.2', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '16cc90cd2d08a3147ce02b07e50894bc060a4cbf', 'build_date': '2024-04-05T14:45:26.420424304Z', 'build_snapshot': False, 'lucene_version': '9.10.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'}

# %%
from sentence_transformers import SentenceTransformer

# checkpoint_path = 'snunlp/KR-SBERT-V40K-klueNLI-augSTS'

# Sentence Transformer 모델 초기화 (한국어 임베딩 생성 가능한 어떤 모델도 가능)
model = SentenceTransformer('output/scientific_continue_training_kr_sbert_v40k_klueNLI_augSTS')

# %%
# SetntenceTransformer를 이용하여 임베딩 생성
def get_embedding(sentences):
    # return model.encode(sentences)
    return [model.encode(sentence) for sentence in sentences]


# 주어진 문서의 리스트에서 배치 단위로 임베딩 생성
def get_embeddings_in_batches(docs, batch_size=100):
    batch_embeddings = []
    for i in range(0, len(docs), batch_size):
        batch = docs[i:i + batch_size]
        contents = [doc["content"] for doc in batch]
        embeddings = get_embedding(contents)
        batch_embeddings.extend(embeddings)
        print(f'batch {i}')
    return batch_embeddings


# 새로운 index 생성
def create_es_index(index, settings, mappings):
    # 인덱스가 이미 존재하는지 확인
    if es.indices.exists(index=index):
        # 인덱스가 이미 존재하면 설정을 새로운 것으로 갱신하기 위해 삭제
        es.indices.delete(index=index)
    # 지정된 설정으로 새로운 인덱스 생성
    es.indices.create(index=index, settings=settings, mappings=mappings)


# 지정된 인덱스 삭제
def delete_es_index(index):
    es.indices.delete(index=index)


# Elasticsearch 헬퍼 함수를 사용하여 대량 인덱싱 수행
def bulk_add(index, docs):
    # 대량 인덱싱 작업을 준비
    actions = [
        {
            '_index': index,
            '_source': doc
        }
        for doc in docs
    ]
    return helpers.bulk(es, actions)


# 역색인을 이용한 검색
def sparse_retrieve(query_str, size):
    query = {
        "match": {
            "content": {
                "query": query_str
            }
        }
    }
    return es.search(index="test", query=query, size=size, sort="_score")


# Vector 유사도를 이용한 검색
def dense_retrieve(query_str, size):
    # 벡터 유사도 검색에 사용할 쿼리 임베딩 가져오기
    query_embedding = get_embedding([query_str])[0]

    # KNN을 사용한 벡터 유사성 검색을 위한 매개변수 설정
    knn = {
        "field": "embeddings",
        "query_vector": query_embedding.tolist(),
        "k": size,
        "num_candidates": 100
    }

    # 지정된 인덱스에서 벡터 유사도 검색 수행
    return es.search(index="test", knn=knn)

# %%
# 색인을 위한 setting 설정
settings = {
    "analysis": {
        "analyzer": {
            "nori": {
                "type": "custom",
                "tokenizer": "nori_tokenizer",
                "decompound_mode": "mixed",
                "filter": ["nori_posfilter"]
            }
        },
        "filter": {
            "nori_posfilter": {
                "type": "nori_part_of_speech",
                # 어미, 조사, 구분자, 줄임표, 지정사, 보조 용언 등
                "stoptags": ["E", "J", "SC", "SE", "SF", "VCN", "VCP", "VX"]
            }
        }
    }
}

# 색인을 위한 mapping 설정 (역색인 필드, 임베딩 필드 모두 설정)
mappings = {
    "properties": {
        "content": {"type": "text", "analyzer": "nori"},
        "embeddings": {
            "type": "dense_vector",
            "dims": 768,
            "index": True,
            "similarity": "l2_norm"
        }
    }
}

# %%
# settings, mappings 설정된 내용으로 'test' 인덱스 생성
create_es_index("test", settings, mappings)

# %%
import json

# 문서의 content 필드에 대한 임베딩 생성
index_docs = []
with open("data/documents.jsonl") as f:
    docs = [json.loads(line) for line in f]
embeddings = get_embeddings_in_batches(docs)

# 생성한 임베딩을 색인할 필드로 추가
for doc, embedding in zip(docs, embeddings):
    # doc["embeddings"] = embedding.tolist()
    doc["embeddings"] = embedding
    index_docs.append(doc)

# 'test' 인덱스에 대량 문서 추가
ret = bulk_add("test", index_docs)

# 색인이 잘 되었는지 확인 (색인된 총 문서수가 출력되어야 함)
print(ret)
# Out:
# batch 0
# batch 100
# batch 200
# batch 300
# batch 400
# batch 500
# batch 600
# batch 700
# batch 800
# batch 900
# batch 1000
# batch 1100
# batch 1200
# batch 1300
# batch 1400
# batch 1500
# batch 1600
# batch 1700
# batch 1800
# batch 1900
# batch 2000
# batch 2100
# batch 2200
# batch 2300
# batch 2400
# batch 2500
# batch 2600
# batch 2700
# batch 2800
# batch 2900
# batch 3000
# batch 3100
# batch 3200
# batch 3300
# batch 3400
# batch 3500
# batch 3600
# batch 3700
# batch 3800
# batch 3900
# batch 4000
# batch 4100
# batch 4200
# (4272, [])

# %%
# 검색엔진에 색인이 잘 되었는지 테스트하기 위한 질의
test_query = "금성이 다른 행성들보다 밝게 보이는 이유는 무엇인가요?"

# %%
# 역색인을 사용하는 검색 예제
search_result_retrieve = sparse_retrieve(test_query, 3)

# 결과 출력 테스트
for rst in search_result_retrieve['hits']['hits']:
    print('score:', rst['_score'], 'source:', rst['_source']["content"])
# Out:
# score: 33.68643 source: 금성이 다른 행성들보다 더 밝게 보이는 이유는 지구 쪽으로 가장 많은 햇빛을 반사하기 때문입니다. 케빈은 맑은 밤에 하늘을 관찰하고 있습니다. 그는 맨눈으로 금성, 화성, 목성, 토성을 볼 수 있습니다. 금성은 햇빛을 많이 반사하기 때문에 다른 행성들보다 더 밝게 보입니다. 이는 금성의 표면이 반사율이 높기 때문입니다. 금성은 태양으로부터 받은 햇빛을 표면에 반사하여 지구에서 관찰하기 쉽게 만듭니다. 따라서 케빈은 맑은 밤에 금성을 더 밝게 볼 수 있습니다.
# score: 18.915426 source: 금성은 태양계의 두 번째로 가까운 행성입니다. 이 행성의 대략적인 나이는 7억 5천만 년으로 추정됩니다. 금성은 지구와 매우 비슷한 크기와 구성을 가지고 있으며, 약 90% 이상이 이산화탄소로 이루어져 있습니다. 이 행성은 매우 뜨거운 온도와 압력을 가지고 있어서 인간이 살 수 있는 환경이 아닙니다. 금성의 대기는 두꺼워서 태양의 열을 가두고 있어서 행성의 표면은 평균 온도가 약 450도로 매우 뜨거운 상태입니다. 또한, 금성은 자전 속도가 매우 빠르기 때문에 하루가 지구의 약 243일과 같습니다. 이러한 특징들로 인해 금성은 우리 태양계에서 가장 가혹한 환경을 가진 행성 중 하나로 알려져 있습니다.
# score: 18.728905 source: 메릴랜드 Space Grant Observatory는 볼티모어에 위치해 있습니다. 학생들은 이 망원경을 방문하여 별, 행성, 달에 대해 배웠습니다. 그들은 아래와 같은 정보를 기록했습니다. 첫째, 별 패턴은 그대로 유지되지만, 하늘에서의 위치는 변하는 것처럼 보입니다. 둘째, 태양, 행성, 달은 하늘에서 움직이는 것처럼 보입니다. 셋째, 켄타우루스자리의 프록시마 성은 우리 태양계에서 가장 가까운 별입니다. 넷째, 북극성은 소 북두칠성이라 불리는 별 패턴의 일부입니다. 그렇다면 태양이 매일 하늘을 가로질러 움직이는 것처럼 보이는 이유는 무엇일까요? 지구가 자전축을 중심으로 회전하기 때문입니다.

# %%
# Vector 유사도 사용한 검색 예제
search_result_retrieve = dense_retrieve(test_query, 3)

# 결과 출력 테스트
for rst in search_result_retrieve['hits']['hits']:
    print('score:', rst['_score'], 'source:', rst['_source']["content"])
# Out:
# score: 0.008345666 source: 태양은 열을 발산하는 별입니다. 태양은 무수한 수의 핵융합 반응을 통해 엄청난 양의 에너지를 생성합니다. 이 에너지는 태양의 표면에서 방출되어 우리 행성에 도달합니다. 햇빛은 여러 가지 파장으로 구성되어 있으며, 그 중에서도 가시광선은 우리 눈으로 볼 수 있는 범위입니다. 햇빛은 지구의 대기를 통과하여 지표면에 도달하게 되는데, 이때 햇빛은 지표면에 흡수되거나 반사됩니다.
#
# 얼음은 물이 얼어서 만들어진 물체입니다. 얼음은 일반적으로 0도 미만의 온도에서 형성되며, 주로 물이 얼어서 만들어집니다. 얼음은 분자 간의 결합력으로 인해 고체 상태를 유지합니다. 그러나 햇빛에 노출되면 얼음 조각은 빠르게 녹게 됩니다. 이는 태양에서 발산되는 열 에너지가 얼음 조각에 흡수되어 얼음 분자 간의 결합력을 약화시키기 때문입니다. 따라서 햇빛에 노출된 얼음 조각은 녹게 되는 것입니다.
#
# 태양은 우리 생활에 매우 중요한 역할을 합니다. 태양의 열 에너지는 식물의 광합성을 통해 식물이 자라고, 동물들이 생존하고, 우리가 따뜻한 날씨를 느낄 수 있도록 합니다. 또한 태양은 태양광 발전을 통해 전기를 생산하는데에도 사용됩니다. 따라서 태양은 우리 생활에 필수적인 존재이며, 햇빛은 얼음이 녹는 현상을 설명하는 중요한 요소입니다.
# score: 0.008261326 source: 식물에게서 잎이 많이 없어지고 다른 잎에는 큰 구멍이 뚫려 있는 현상을 관찰한 제러마이아는 궁금해졌습니다. 왜 잎이 없어지는 것이 식물에 해로울까요? 이러한 현상은 식물이 더 적은 양의 양분을 만들기 때문입니다. 식물은 잎을 통해 태양의 에너지를 흡수하고 이를 이용하여 양분을 생산합니다. 그러나 양분이 부족하거나 제대로 전달되지 않으면 식물은 생존을 위해 잎을 제거하거나 손상시킵니다. 이로 인해 잎이 없어지고 다른 잎에는 큰 구멍이 뚫리는 것을 관찰할 수 있습니다. 이러한 현상은 식물이 생존을 위해 자신의 에너지와 양분을 효율적으로 사용하려는 자연의 방어 메커니즘입니다. 따라서 잎이 없어지는 것은 식물에게 해로운 것이 아니라, 오히려 생존을 위한 필수적인 과정입니다.
# score: 0.008102263 source: 화성은 붉은색인 이유는 표면이 많이 산화된("녹슨") 광물로 덮여 있기 때문입니다. 이 산화된 광물은 철 미립자로 이루어져 있어서 화성의 표면이 붉은 색으로 보입니다. 이러한 특징은 화성을 지구와 구별할 수 있는 중요한 특징 중 하나입니다. 화성의 붉은색은 우주 탐사선들이 보내는 사진들을 통해 우리에게 잘 알려져 있습니다. 이러한 특징은 화성의 지질학적 특성을 연구하는데도 중요한 역할을 합니다. 화성의 붉은색은 우리가 우주 탐사를 통해 더 많은 것을 알아갈 수 있도록 도와줍니다. 화성은 우리에게 아직 많은 비밀을 품고 있는 행성입니다.

# %% [markdown]
# ## RAG 구현
#
# 준비된 검색엔진과 LLM을 활용하셔 대화형 RAG 구현

# %%
from openai import OpenAI
import traceback

# OpenAI API 키를 환경변수에 설정
# os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')
#os.environ["OPENAI_API_KEY"] = "Your API Key"

client = OpenAI(organization=os.getenv('ORGANIZATION_ID'))
# 사용할 모델을 설정(여기서는 gpt-3.5-turbo-1106 모델 사용)
llm_model = "gpt-3.5-turbo-1106"
# llm_model = "gpt-3.5-turbo"

# %%
# RAG 구현에 필요한 Question Answering을 위한 LLM  프롬프트 수정
persona_qa = """
## Role: 과학,공학,의학 상식 전문가
## Instructions
- 한국어로 답변을 생성한다.
- 제대로 답변을 하지 않으면 기업이 엄청난 손해를 보게된다.
- 사용자의 이전 메시지 정보 및 주어진 Reference 정보를 활용하여 간결하게 답변을 생성한다.
- 주어진 검색 결과 정보로 대답할 수 없는 경우는 정보가 부족해서 답을 할 수 없다고 대답한다.
"""
# RAG 구현에 필요한 질의 분석 및 검색 이외의 일반 질의 대응을 위한 LLM 프롬프트
persona_function_calling = """
## Role: 과학,공학,의학 상식 전문가
## Instruction
- 제대로 답변을 하지 않으면 기업이 엄청난 손해를 보게된다.
- 사용자가 대화를 통해 과학 지식에 관한 주제로 질문하면 search api를 호출할 수 있어야 한다.
- 과학이나 공학, 또는 의학적 상식이 필요하지 않은 나머지 대화 메시지에는 적절한 대답을 생성한다.
"""

# %%
# RAG 구현에 필요한 Question Answering을 위한 LLM  프롬프트
persona_qa = """
## Role: 과학 지식 전문가

## Instructions
- 사용자의 이전 메시지 정보 및 주어진 Reference 정보를 활용하여 간결하게 답변을 생성한다.
- 주어진 검색 결과 정보로 대답할 수 없는 경우는 정보가 부족해서 답을 할 수 없다고 대답한다.
- 한국어로 답변을 생성한다.
- 결과는 json 형태로 생성하고, 반드시 'is_science' 필드를 추가하여 질문이 과학 지식에 관련된 내용이면 true를, 과학 지식에 관련된 내용이 아니라면 false를 value로 만든다. 답변 필드의 이름은 'answer'로 통일한다.
"""

# RAG 구현에 필요한 질의 분석 및 검색 이외의 일반 질의 대응을 위한 LLM 프롬프트
persona_function_calling = """
## Role: 과학 지식 전문가

## Instruction
- 사용자가 대화를 통해 과학 지식에 관한 주제로 질문하면 search api를 호출할 수 있어야 한다.
- 과학 지식과 관련되지 않은 나머지 대화 메시지에는 적절한 대답을 생성한다.
- 결과는 json 형태로 생성하고, 반드시 'is_science' 필드를 추가하여 질문이 과학 지식에 관련된 내용이면 true를, 과학 지식에 관련된 내용이 아니라면 false를 value로 만든다. 답변 필드의 이름은 'answer'로 통일한다.
"""

# Function calling에 사용할 함수 정의
tools = [
    {
        "type": "function",
        "function": {
            "name": "search",
            "description": "search relevant documents",
            "parameters": {
                "properties": {
                    "standalone_query": {
                        "type": "string",
                        "description": "Final query suitable for use in search from the user messages history."
                    }
                },
                "required": ["standalone_query"],
                "type": "object"
            }
        }
    },
]

# %%
# LLM과 검색엔진을 활용한 RAG 구현
def answer_question(messages):
    # 함수 출력 초기화
    response = {"standalone_query": "", "topk": [], "references": [], "answer": ""}

    # 질의 분석 및 검색 이외의 질의 대응을 위한 LLM 활용
    msg = [{"role": "system", "content": persona_function_calling}] + messages
    try:
        ### 이 부분을 바꿔서 json으로 만들어 줄까...
        result = client.chat.completions.create(
            model=llm_model,
            response_format={"type": "json_object"},
            messages=msg,
            tools=tools,
            #tool_choice={"type": "function", "function": {"name": "search"}},
            temperature=0,
            seed=1,
            timeout=10
        )
    except Exception as e:
        traceback.print_exc()
        return response

    # 검색이 필요한 경우 검색 호출후 결과를 활용하여 답변 생성
    if result.choices[0].message.tool_calls:
        tool_call = result.choices[0].message.tool_calls[0]
        function_args = json.loads(tool_call.function.arguments)
        standalone_query = function_args.get("standalone_query")

        # Baseline으로는 sparse_retrieve만 사용하여 검색 결과 추출
        search_result = dense_retrieve(standalone_query, 3)

        response["standalone_query"] = standalone_query
        retrieved_context = []
        for i,rst in enumerate(search_result['hits']['hits']):
            retrieved_context.append(rst["_source"]["content"])
            response["topk"].append(rst["_source"]["docid"])
            response["references"].append({"score": rst["_score"], "content": rst["_source"]["content"]})

        content = json.dumps(retrieved_context)
        messages.append({"role": "assistant", "content": content})
        msg = [{"role": "system", "content": persona_qa}] + messages
        try:
            qaresult = client.chat.completions.create(
                    model=llm_model,
                    response_format={"type": "json_object"},
                    messages=msg,
                    temperature=0,
                    seed=1,
                    timeout=30
                )
        except Exception as e:
            traceback.print_exc()
            return response
        response["answer"] = qaresult.choices[0].message.content

    # 검색이 필요하지 않은 경우 바로 답변 생성
    else:
        response["answer"] = result.choices[0].message.content

    return response

# %%
import json

# 평가를 위한 파일을 읽어서 각 평가 데이터에 대해서 결과 추출 후 파일에 저장
def eval_rag(eval_filename, output_filename):
    with open(eval_filename) as f, open(output_filename, "w") as of:
        idx = 0
        for line in f:
            j = json.loads(line)
            print(f'Test {idx}\nQuestion: {j["msg"]}')
            response = answer_question(j["msg"])
            print(f'Answer: {response["answer"]}\n')

            # 대회 score 계산은 topk 정보를 사용, answer 정보는 LLM을 통한 자동평가시 활용
            # output = {"eval_id": j["eval_id"], "standalone_query": response["standalone_query"], "topk": response["topk"], "answer": response["answer"], "references": response["references"]}

            # json.loads(response)
            res_answer = json.loads(response["answer"])
            is_science = res_answer.get("is_science", False)
            if not is_science:
                answer = "과학 지식과 관련된 질문이 아닙니다."
                topk = []
            else:
                answer = res_answer['answer']
                topk = response["topk"]
            
            # json format으로 생성했을 때.
            output = {"eval_id": j["eval_id"], 
                      "standalone_query": response["standalone_query"], 
                      "topk": topk, 
                      "answer": answer, 
                      "references": response["references"]}
            of.write(f'{json.dumps(output, ensure_ascii=False)}\n')
            idx += 1

# %%
# 역색인을 사용하는 검색 예제
q1 = '나무의 분류에 대해 조사해 보기 위한 방법은?'
search_result_retrieve = sparse_retrieve(q1, 3)
search_result_retrieve
# Out:
# ObjectApiResponse({'took': 5, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 4238, 'relation': 'eq'}, 'max_score': 20.857122, 'hits': [{'_index': 'test', '_id': 'YZqJN48B-sAIPHWj34HJ', '_score': 20.857122, '_source': {'docid': 'c63b9e3a-716f-423a-9c9b-0bcaa1b9f35d', 'src': 'ko_ai2_arc__ARC_Challenge__test', 'content': '한 학생이 다양한 종류의 나무를 조사하고 있습니다. 이 학생은 성장 속도, 온도 범위, 크기가 비슷한 두 나무를 발견했습니다. 그러나 이 두 나무의 잎과 꽃은 서로 다릅니다. 이러한 특징을 고려하면, 이 나무들은 대체로 같은 속에 속해 있을 것으로 추측됩니다. 같은 속에 속한 나무들은 종류별로 유사한 특징을 가지고 있으며, 이는 생물 분류학에서 중요한 기준 중 하나입니다. 따라서 이 학생의 조사 결과는 나무의 분류와 관련된 중요한 정보를 제공할 수 있습니다. 이러한 조사는 나무의 성장과 생태에 대한 이해를 높이는 데 도움이 될 것입니다.', 'embeddings': [-0.2693350613117218, 0.16106565296649933, -0.6686766147613525, -0.4087434709072113, -0.6087977290153503, -0.5408722162246704, 1.4245141744613647, -1.4220963716506958, -0.8162183165550232, -0.9986358880996704, -1.0482354164123535, 1.2237915992736816, -1.3584719896316528, 0.29972395300865173, 0.5895066261291504, -0.02090403623878956, 0.27583420276641846, -1.0972949266433716, -0.4782058298587799, 0.566891074180603, -0.04273995757102966, 0.08423794060945511, 0.9294244050979614, 1.22434663772583, 0.8080000877380371, -0.5453926920890808, -0.5892763137817383, -1.5225648880004883, -1.5311918258666992, 0.3093801736831665, -0.916719913482666, 0.1462908387184143, 0.33276790380477905, -0.11941248178482056, -0.8636401295661926, 1.4611587524414062, -0.9125920534133911, -0.5032921433448792, 1.2054777145385742, -1.0653512477874756, -0.4573671519756317, -0.2715780735015869, -0.6439120173454285, 0.1095324233174324, -0.898736298084259, 0.09486313164234161, 0.05869128927588463, 0.2631889879703522, 0.0828084945678711, -0.5255855321884155, 0.3287999629974365, 0.10320410877466202, -0.13067148625850677, -0.849593997001648, 0.6599602699279785, -0.5816741585731506, -0.7374539971351624, -0.35787978768348694, -1.373934030532837, 0.46767696738243103, -0.6102631688117981, 0.14975573122501373, -0.6519489884376526, -1.3459899425506592, -0.14304596185684204, -0.1410156637430191, 0.4048808813095093, 1.270416498184204, 0.543582022190094, 1.4017144441604614, -0.13145679235458374, 0.5616637468338013, -0.6219454407691956, 0.7565515041351318, 2.692436456680298, 0.2520536184310913, -0.7891588807106018, 0.5574100017547607, -0.026874687522649765, -1.2929046154022217, 0.2505601644515991, 0.4488687813282013, -1.4590767621994019, 1.8176912069320679, 0.47459009289741516, -0.04225585609674454, -0.022463727742433548, -1.105310320854187, -0.23567622900009155, -0.5759019255638123, -0.39760857820510864, 0.9643349647521973, -0.6582993268966675, -0.5748084187507629, 0.5114393830299377, -1.8718098402023315, -1.1360796689987183, -0.1674317717552185, -0.43963146209716797, -0.4617367386817932, -1.2789775133132935, 1.5980581045150757, -1.4674233198165894, 0.9171792268753052, 1.8380210399627686, 0.7889441847801208, 0.10074567794799805, 0.9745189547538757, -1.3934438228607178, -1.379225254058838, -0.48446157574653625, 0.3751218616962433, 1.2205032110214233, 0.04264470934867859, -0.9063958525657654, -0.2489759624004364, -0.46812552213668823, 1.187987208366394, -0.43432408571243286, -0.33165213465690613, -1.2850106954574585, 1.8485008478164673, -0.4201721251010895, -1.1168651580810547, -1.5774537324905396, -0.6481029987335205, -0.6329235434532166, 0.40743497014045715, -0.31961590051651, -0.19268572330474854, 1.7388345003128052, -0.5140606164932251, 0.26741063594818115, -0.12754645943641663, -0.8777331709861755, 0.9905782341957092, -0.4253919720649719, 0.3258279263973236, 0.5121250152587891, 0.613684356212616, 0.8269867300987244, 2.0645604133605957, -0.15129096806049347, 0.6942378878593445, 0.46152785420417786, 0.8514750599861145, -0.4924948215484619, 0.6147627234458923, 0.7159149646759033, 0.1844656616449356, -0.30941471457481384, 1.4253267049789429, 0.32145196199417114, -0.19689743220806122, -1.2094703912734985, 0.13524223864078522, -0.0011889388551935554, -0.2609262764453888, 0.992882192 ...

# %%
from datetime import datetime
# 평가 데이터에 대해서 결과 생성 - 파일 포맷은 jsonl이지만 파일명은 csv 사용
eval_rag("data/eval.jsonl", f"sample_submission_{datetime.now().strftime('%Y-%m-%d_%H-%M')}.csv")
# Out:
# Test 0
# Question: [{'role': 'user', 'content': '나무의 분류에 대해 조사해 보기 위한 방법은?'}]
# Answer: {
#   "answer": "나무의 분류를 조사하기 위한 방법은 주로 잎의 형태, 줄기의 모양, 꽃과 열매의 유무 등을 관찰하여 분류하는 것이 일반적입니다. 이러한 특징을 확인하면 해당하는 분류책과 도서를 참고하여 더 자세한 정보를 얻을 수 있습니다.",
#   "is_science": true
# }
#
# Test 1
# Question: [{'role': 'user', 'content': '각 나라에서의 공교육 지출 현황에 대해 알려줘.'}]
# Answer: {
#   "answer": "각 나라의 공교육 지출 현황은 국가마다 다양하며, 국가별로 교육에 대한 중요성과 투자 정책이 다르다. 예를 들어, 2017년 기준으로 전 세계의 공교육 지출은 국내총생산(GDP)의 평균 4%를 占하고 있다. 또한, 2020년 기준으로는 미국, 독일, 이탈리아, 프랑스 등이 교육에 상당한 투자를 하고 있으며, 이들 국가들은 교육에 대한 중요성을 강조하고 교육 수준을 높이기 위해 노력하고 있다. 또한, 중국, 일본, 한국 등의 교육체제는 교육의 질을 높이고 학생들의 학습 효과를 증진시키기 위해 노력하고 있다. 이와 같이 각 국가의 교육 지출은 국가의 경제 상황과 교육 정책에 따라 다양하게 나타난다.",
#   "is_science": false
# }
#
# Test 2
# Question: [{'role': 'user', 'content': '기억 상실증 걸리면 너무 무섭겠다.'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '어떤 원인 때문에 발생하는지 궁금해.'}]
# Answer:
# {
#   "answer": "기억 상실증은 다양한 원인으로 발생할 수 있습니다. 이는 일상적인 사건이나 경험에 대한 기억을 저장하고, 일상적인 기억을 활용하지 않는 경우에 발생할 수 있습니다. 또한, 80세 이상의 사람들은 후기 인지기능(75% 이상)을 잃을 수 있습니다. 후기는 사람이 되면서 체력적으로 쇠약해지는데, 이는 사람들이 체력쇠약으로 인해 일상적인 기억을 활용하지 않는 경우에 발생할 수 있습니다. 이는 뇌의 기능이 약화되고, 정보 처리능력이 부족해지는 것과 관련이 있습니다. 따라서, 기억 상실증은 다양한 원인으로 발생할 수 있으며, 이에 대한 관리와 예방의 중요성이 강조됩니다.",
#   "is_science": true
# }
#
# Test 3
# Question: [{'role': 'user', 'content': '통학 버스의 가치에 대해 말해줘.'}]
# Answer: {
#   "answer": "통학 버스는 학교나 학원으로 학생들을 운송하는 버스로, 안전 및 편의를 고려한 운행이 중요합니다. 학교 버스는 학생들의 안전을 최우선으로 고려하여 운영되며, 학교 교육과 관련된 다양한 활동을 지원하기도 합니다. 또한, 학교 버스는 학생들의 편의를 고려하여 학습 활동의 활용 및 차후 방문 여부를 결정하는 데 도움을 줍니다. 이러한 학교 버스의 장점은 다른 교통수단을 이용하는 것보다 학생들의 안전을 보장하고, 학교 교육과 관련된 활동을 지원한다는 점입니다. 또한, 학교 버스는 학교 내부의 소통과 교육을 촉진하며, 학생들에게 책임감을 심어주고 학습 환경을 지원합니다.",
#   "is_science": false
# }
#
# Test 4
# Question: [{'role': 'user', 'content': 'Dmitri Ivanovsky가 누구야?'}]
# Answer:
# {
#   "answer": "Dmitri Ivanovsky는 바이러스의 발견과 연구로 유명한 러시아의 식물학자입니다.",
#   "is_science": true
# }
#
# Test 5
# Question: [{'role': 'user', 'content': '피임을 하기 위한 방법중 약으로 처리하는 방법은 쓸만한가?'}]
# Answer: {
#   "answer": "피임을 하기 위한 약물 치료는 효과적일 수 있지만, 개별 상황에 따라 부작용이 있을 수 있습니다. 피임 약물 치료는 의사의 지시에 따라 정확히 복용하고, 정기적으로 검진을 받아야 합니다. 또한, 피임 약물 치료는 생활습관과 결합하여 사용하고, 특히 약물 복용 후 부작용이 있을 경우 즉시 의사와 상의해야 합니다. 생활습관 변경으로도 효과적으로 피임할 수 있습니다. 피임 약물 치료는 일반적으로 효과적이지만, 부작용이 있을 수 있으므로 의사의 지시에 따라 복용하고, 정기적인 검진을 받아야 합니다. 또한, 피임 약물 치료는 생활습관과 결합하여 사용하며, 부작용 및 효과를 모니터링해야 합니다.",
#   "is_science": true
# }
#
# Test 6
# Question: [{'role': 'user', 'content': '헬륨이 다른 원소들과 반응을 잘 안하는 이유는?'}]
# Answer: {
#   "answer": "헬륨은 다른 원소들과 반응을 잘 안하는 이유는 헬륨이 안정한 원자 구조를 가지고 있기 때문입니다. 헬륨 원자는 이미 가장 안정한 상태로 존재하고 있어서 다른 원자들과 화학적 반응을 하지 않습니다. 이는 헬륨 원자가 매우 안정하고 비활성이기 때문에 다른 원자들과 결합하기를 꺼려하는 성질 때문입니다.",
#   "is_science": true
# }
#
# Test 7
# Question: [{'role': 'user', 'content': '문맹 비율이 사회 발전에 미치는 영향은?'}]
# Answer: {
#   "answer": "문맹 비율이 사회 발전에 미치는 영향은 다양합니다. 문맹은 사람들의 교육 수준과 경제적 발전에 영향을 미칩니다. 특히 문맹은 사회의 발전과 경제적 성장에 부정적인 영향을 미칠 수 있습니다. 문맹으로 인해 교육의 기회와 정보 접근이 제한되며, 이는 사회의 발전과 경제 발전에 제약을 줄 수 있습니다. 또한, 문맹으로 인해 사람들의 건강 상태와 사회적 상호작용, 경제 활동의 효율성 등이 저하될 수 있습니다. 따라서 문맹 문제를 해결하여 교육의 기회와 정보 접근을 확대하고, 사회 및 경제 발전을 촉진하는 것이 중요합니다.",
#   "is_science": true
# }
#
# Test 8
# Question: [{'role': 'user', 'content': '이란 콘트라 사건이 뭐야'}, {'role': 'assistant', 'content': '이란-콘트라 사건은 로널드 레이건 집권기인 1986년에 레이건 행정부와 CIA가 적성국이었던 이란에게 무기를 몰래 수출한 대금으로 니카라과의 우익 성향 반군 콘트라를 지원하면서 동시에 반군으로부터 마약을 사들인 후 미국에 판매하다가 발각되어 큰 파장을 일으킨 사건입니다.'}, {'role': 'user', 'content': '이 사건이 미국 정치에 미친 영향은?'}]
# Answer:
# {
#   "answer": "이란-콘트라 사건은 미국 정치에 큰 파장을 일으켰습니다. 이 사건으로 미국 정부와 CIA의 비리가 드러나면서 논란이 일었고, 이로 인해 미국 내에서 정치적인 충격과 논란이 일었습니다. 또한, 사건으로 인해 미국 정치의 투명성과 신뢰성에 대한 의문이 제기되었습니다.",
#   "is_science": false
# }
#
# Test 9
# Question: [{'role': 'user', 'content': '자기장이 얼마나 센지 표현하는 방식은?'}]
# Answer: {
#   "answer": "자기장의 세기를 표현하는 방식은 주로 자기장의 밀도와 방향을 나타내는데 사용됩니다. 자기장은 밀도가 높은 지역과 방향이 불규칙한 구역이 많이 존재합니다. 밀도가 높은 지역은 자기장의 세기를 나타내는데, 이를 측정할 때에는 5-10분 간격으로 측정하여야 합니다. 이 기간 동안의 변화량은 자기장의 변화를 추적하는 데 유용합니다. 또한, 자기장의 밀도와 방향을 결정하는 요인은 자극도와 자기장의 변화를 추적하는 데 유용한 정보를 제공합니다. 따라서, 자기장은 밀도가 높은 지역과 방향이 불규칙한 구역을 가지고 있으며, 이러한 특징은 자기장을 세는 방식과 관련이 있습니다.",
#   "is_science": true
# }
#
# Test 10
# Question: [{'role': 'user', 'content': '피를 맑게 하고 몸 속의 노폐물을 없애는 역할을 하는 기관은?'}]
# Answer: {
#   "answer": "신장",
#   "is_science": true
# }
#
# Test 11
# Question: [{'role': 'user', 'content': '글리코겐의 분해는 인체에서 왜 필요한가?'}]
# Answer: {
#   "answer": "글리코겐은 인체에서 에너지를 공급하기 위해 필요합니다. 글리코겐은 혈당을 유지하고 급격한 혈당 감소에 대비하여 필요한 시점에 분해되어 포도당으로 변환되어 에너지원으로 활용됩니다.",
#   "is_science": true
# }
#
# Test 12
# Question: [{'role': 'user', 'content': '빗방울이 점점 커지게 되는 요인은?'}]
# Answer: {
#   "answer": "빗방울이 점점 커지는 요인은 다양합니다. 빗방울은 공기 중의 수증기가 응축되어 형성되는데, 이때 수증기가 응축되는 과정에서는 다양한 요인이 작용합니다. 먼지, 먼지, 우박, 증발 등이 모두 빗방울의 형성에 영향을 미치며, 빗방울의 크기는 이러한 다양한 요인에 의해 결정됩니다. 빗방울은 구름 속에서 다양한 환경에서 형성되며, 우리는 이러한 다양한 환경의 변화를 고려해야 합니다. 빗방울은 구름의 결정점이며, 수증기와 물방울의 결합에 의해 형성됩니다. 따라서, 빗방울의 형성에는 다양한 환경적 요인이 작용하며, 우리는 이러한 다양한 요인을 이해하여야 합니다.",
#   "is_science": true
# }
#
# Test 13
# Question: [{'role': 'user', 'content': '기체의 부피나 형태가 왜 일정하지 않을까?'}]
# Answer: {
#   "answer": "기체의 부피나 형태가 일정하지 않는 이유는 기체 분자들이 운동하면서 부딪치고 충돌하는 과정에서 운동 에너지와 운동량이 변하기 때문입니다. 이러한 과정으로 인해 기체의 부피나 형태가 일정하지 않을 수 있습니다.",
#   "is_science": true
# }
#
# Test 14
# Question: [{'role': 'user', 'content': '식물이 빛을 에너지로 변환하는 과정에 대해 설명해줘.'}]
# Answer: {
#   "answer": "식물은 빛을 흡수하여 엽록소를 이용해 이를 에너지로 변환합니다. 이 과정을 광합성이라고 합니다. 광합성은 태양 에너지를 화학 에너지로 변환하는 과정으로, 엽록체 내의 엽록소가 이를 수행합니다. 이때, 물과 이산화탄소가 사용되고 산소가 생성됩니다. 이러한 광합성은 생물들이 에너지를 얻는 주요한 방법 중 하나입니다.",
#   "is_science": true
# }
#
# Test 15
# Question: [{'role': 'user', 'content': '직류와 교류 전류의 차이에 대해 알려줘.'}]
# Answer: {
#   "answer": "교류와 직류 전류의 차이는 전류의 방향과 세기에 있습니다. 직류는 한 방향으로만 흐르는 반면, 교류는 주기적으로 방향이 바뀝니다. 이에 따라 직류는 특정 방향의 상황을 유지하며, 교류는 주기적으로 변화하는 상황을 가집니다. 전류의 흐름은 전하의 이동과 전류의 세기에 따라 결정되며, 교류의 특성은 주기적으로 변화하는 전류의 특성에 의해 결정됩니다. 교류는 전류의 주기적 변화와 전류의 세기에 따라 다양한 특성을 가지며, 이는 전압의 변화와 전류의 상관을 반영하고, 직류의 특성은 일정한 전류의 흐름과 전압의 특성에 의해 결정됩니다.",
#   "is_science": true
# }
#
# Test 16
# Question: [{'role': 'user', 'content': '기름과 물이 섞여 있을 수 있나?'}]
# Answer: {
#   "answer": "물과 기름은 섞일 수 없습니다. 물은 극성 분자로서 수소 원자가 있고, 기름은 비극성 분자로서 수소 원자가 없기 때문에 서로 상호 작용하지 않습니다. 따라서, 물과 기름은 섞이지 않고 두 상이 분리됩니다.",
#   "is_science": true
# }
#
# Test 17
# Question: [{'role': 'user', 'content': '인간이 2세를 생산할 때 DNA의 결합 과정에 대히 설명해줘.'}]
# Answer: {
#   "answer": "인간의 생식과정에서 DNA의 결합은 부모의 유전정보를 다음 세대로 전달하는 과정으로, 부모의 유전정보를 다음 세대로 전달하기 위해 염색체의 결합이 일어납니다. 염색체는 부모의 유전자를 유전적으로 조합하고 다양성을 증가시키는 중요한 역할을 합니다. DNA의 메틸화 과정은 부모 DNA의 표지를 유지하고, 자식 DNA의 초기 발달을 돕습니다. 이 과정은 유전자 발현, 유전자 조절 및 유전자 발달에 중요한 역할을 합니다. DNA는 생물체의 성장과 발달에 필수적이며 유전정보를 저장하고 전달하는데 중요한 역할을 합니다. 이러한 정보는 DNA의 복제 및 유전자의 특성에 관한 정보를 포함합니다. 따라서, DNA의 결합과 관련된 정보는 DNA의 복제 및 유전자의 특성과 관련된 정보를 포함합니다.",
#   "is_science": true
# }
#
# Test 18
# Question: [{'role': 'user', 'content': '금성에서 달이 어떻게 보일까?'}]
# Answer: {
#   "answer": "금성에서는 달이 없기 때문에 달을 볼 수 없습니다. 대신에 금성은 새벽 또는 저녁 시간에 볼 수 있습니다. 새벽에는 동쪽 하늘에서, 저녁에는 서쪽 하늘에서 볼 수 있습니다. 또한 금성은 지구와 닮은 행성이기 때문에 상당히 밝게 빛나며, 망원경을 사용하면 표면의 상세한 모습을 관찰할 수 있습니다.",
#   "is_science": true
# }
#
# Test 19
# Question: [{'role': 'user', 'content': '차량의 연비가 좋아질때 나타나는 긍정적인 효과는?'}]
# Answer: {
#   "answer": "차량의 연비가 좋아지면 나타나는 긍정적인 효과는 주로 환경 보호와 경제적 이점입니다. 연비가 좋아지면 연료 소비가 줄어들어 에너지 절약 및 환경 오염 감소에 기여하며, 더불어 운전자의 주행 거리가 증가하여 편의성을 높일 수 있습니다. 또한, 연비 향상은 주행 안전성을 향상시키고, 주행 중에 발생하는 스트레스를 감소시킬 수 있습니다. 따라서 차량의 연비 향상은 환경, 경제, 안전 등 다양한 측면에서 긍정적인 영향을 미칩니다.",
#   "is_science": true
# }
#
# Test 20
# Question: [{'role': 'user', 'content': '혼합물의 특성에 대해 알려줘.'}]
# Answer: {
#   "answer": "혼합물은 두 개 이상의 물질이 섞여있는 것으로, 물질의 특성을 유지하면서 물리적으로 섞여있는 성질을 갖습니다. 혼합물은 물과 소금의 용액이나 공기와 이산화탄소로 이루어진 혼합물로 구성될 수 있습니다. 이 두 가지의 혼합물은 서로 다른 성질을 가지고 있어 상호작용하며 새로운 성질을 나타내기도 합니다. 혼합물은 물질이 물과의 상호작용으로 인해 새로운 물질을 생성하는 반면, 혼합물은 물질이 상호작용하여 새로운 물질을 생성하지 않습니다. 혼합물은 물질을 섞어 새로운 혼합물을 만들어내는 반면, 혼합물은 물질을 섞어 새로운 물질을 만들지 않습니다. 따라서 혼합물은 물질의 특성을 유지하면서 물리적으로 섞여 있는 것으로 정의됩니다.",
#   "is_science": true
# }
#
# Test 21
# Question: [{'role': 'user', 'content': '요새 너무 힘들다.'}]
# Answer: {
#   "answer": "힘든 상황에서는 자신의 감정을 이해하고, 필요하다면 도움을 청하는 것이 중요합니다. 과도한 스트레스는 건강에 해로울 수 있으므로 적절한 대처가 필요합니다. 또한, 힘든 상황에서는 긍정적인 마인드를 유지하고, 적절한 휴식과 관리가 필요합니다. 이러한 상황에서는 전문가의 도움을 받는 것도 도움이 될 수 있습니다.",
#   "is_science": false
# }
#
# Test 22
# Question: [{'role': 'user', 'content': '세제의 거품이 만들어지는 원리는?'}]
# Answer: {
#   "answer": "세제의 거품이 만들어지는 원리는 세제 분자의 수성과 지방성을 이용하여 거품을 형성하는 것입니다. 이때, 세제 분자의 수성과 지방성은 거품 내에서 표면을 형성하고, 거품 내부의 수분과 지방분자는 상호 작용하여 거품을 유지합니다. 거품은 물과 기름 사이의 경계면 활성제로, 물과 기름을 섞는 데 필요한 에너지를 줄여주는 역할을 합니다. 이러한 원리로 세제는 거품을 만들어냅니다.",
#   "is_science": true
# }
#
# Test 23
# Question: [{'role': 'user', 'content': '나무가 생태계에서 하는 역할에 대해 설명해줘.'}]
# Answer: {
#   "answer": "나무는 생태계에서 다양한 역할을 합니다. 나무는 이산화탄소를 흡수하여 산소를 생산하고, 토양 안정화와 토양의 수분 조절에 도움을 줍니다. 또한 나무는 동물 서식지를 제공하고, 생태 다양성을 유지하는 등의 역할을 합니다. 또한 나무는 산림 침전, 대기 정화, 지질 안정화 등의 다양한 기능을 수행하며, 생태계의 안정을 유지합니다.",
#   "is_science": true
# }
#
# Test 24
# Question: [{'role': 'user', 'content': '전류의 흐름을 극대화 하려면 배터리와 저항을 어떻게 연결해야 하나?'}]
# Answer: {
#   "answer": "전류를 극대화하기 위해서는 배터리와 저항을 어떻게 연결해야 하는지에 대한 질문인 것으로 보입니다. 전류를 극대화하기 위해서는 전압과 전류를 최적화해야 합니다. 전압은 전류를 유도하는 역할을 하며, 저항은 전압을 받아들이고 전류를 제어하는데 사용됩니다. 전압과 저항을 조절하여 전류를 극대화할 수 있습니다. 전류를 극대화하기 위해서는 배터리를 충전하여 전압이나 출력과 같은 전류를 증가시키는 제품들을 사용하여 전류를 높일 수 있습니다. 이러한 제품들을 적절히 조절하여 전류를 극대화하면 됩니다.",
#   "is_science": true
# }
#
# Test 25
# Question: [{'role': 'user', 'content': '식물이 높이 자랄 수 있게 하는 메커니즘이 궁금해.'}]
# Answer: {
#   "answer": "식물이 높이 자랄 수 있는 메커니즘은 주로 광합성과 세포분열에 의해 결정됩니다. 광합성은 태양빛을 이용하여 이루어지며, 이를 통해 식물은 영양분을 생산합니다. 또한, 세포분열은 새로운 세포를 생성하여 식물이 자라는 데 중요한 역할을 합니다. 이러한 메커니즘은 식물이 자라는 과정에서 중요한데, 이를 위해 영양분과 물, 그리고 태양빛이 필요합니다.",
#   "is_science": true
# }
#
# Test 26
# Question: [{'role': 'user', 'content': '달을 보면 항상 같은 면만 보이더라구'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 이유가 뭐야?'}]
# Answer:
# {
#   "answer": "달은 지구의 자전과 공전으로 항상 같은 면만 보이게 됩니다. 이것을 '달의 자전 고정'이라고 합니다. 달의 자전 고정은 지구의 중력과 달의 중력이 서로 작용하여 발생하며, 이에 따라 달은 항상 지구의 같은 면을 향하게 됩니다. 이러한 현상은 과학적으로 증명되었으며, 달의 자전 고정은 지구의 중력과 달의 중력이 서로 작용하여 발생합니다.",
#   "is_science": true
# }
#
# Test 27
# Question: [{'role': 'user', 'content': '식초와 베이킹 소다를 섞어주면 어떤 일이 일어나?'}]
# Answer: {
#   "answer": "식초와 베이킹 소다를 섞으면 발효 반응이 일어나며 이산화탄소, 물, 소금을 생성합니다. 이후 베이킹 소다를 온도에 따라 다양한 화합물로 분해할 수 있습니다. 이 분해과정에서 발생하는 이산화탄소는 거품을 일으켜 반죽이 부풀어 오르게 합니다. 이러한 화합물들은 음식물 소독, 화장품, 청소제로 활용될 수 있습니다.",
#   "is_science": true
# }
#
# Test 28
# Question: [{'role': 'user', 'content': '세균이 나쁜줄말 알았는데 그게 아니야?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그럼 순기능에 대해 알려줄래?'}]
# Answer: {"answer": "세균은 다양한 기능을 수행하며, pH를 조절하는 역할과 다양한 생태계의 생물을 돕는 역할을 합니다. 또한, 미생물은 다양한 유익한 기능을 수행하며 인간의 건강에 도움을 줄 수 있습니다. 예를 들어, EPA와 DHA를 함유한 미생물은 신체의 기능을 유지하고 혈관 건강을 지원하는데 도움을 줄 수 있습니다. 따라서, 세균은 유익한 역할을 하는 경우도 많으며, 이러한 유익한 세균들을 적극적으로 활용하는 것이 중요합니다.", "is_science": true}
#
# Test 29
# Question: [{'role': 'user', 'content': '오토마톤의 특징에 대해 알려줘.'}]
# Answer: {
#   "answer": "오토마톤은 인간의 동작을 모방하는 로봇으로, 특히 자동화된 기능을 갖추고 있습니다. 이러한 특징으로 오토마톤은 다양한 산업분야에서 활용될 수 있습니다. 또한, 오토마톤은 인간의 동작을 모방하고 다양한 작업을 수행할 수 있는 로봇입니다.",
#   "is_science": true
# }
#
# Test 30
# Question: [{'role': 'user', 'content': '다양한 책을 catalog화 하는 코드에서 class 정의 방법 알려줘.'}]
# Answer: {
#   "answer": "책을 catalog화 하는 코드에서 class를 정의하는 방법은 프로그래밍 언어에 따라 다를 수 있습니다. 일반적으로 책을 나타내는 Book 클래스와 책 목록을 관리하는 LibraryList 클래스를 정의합니다. Book 클래스에는 저자, 제목, 책 정보 등을 관리하는 메서드를 포함하고, LibraryList 클래스에는 책 목록을 관리하고 추가, 삭제, 검색하는 메서드를 포함합니다. 이러한 클래스를 정의하고 활용하여 책을 catalog화할 수 있습니다.",
#   "is_science": false
# }
#
# Test 31
# Question: [{'role': 'user', 'content': '전구가 병렬로 연결될 때 전류가 줄어드는 원인은?'}]
# Answer:
# {
#   "answer": "전구가 병렬로 연결될 때 전류가 줄어드는 원인은 전체 전기 회로에 걸리는 전압이 일정하기 때문입니다. 병렬 연결된 전구는 각각이 독립적으로 전압을 유지하므로 전체 전류가 분산되어 각 전구에 걸리는 전압이 감소하게 됩니다.",
#   "is_science": true
# }
#
# Test 32
# Question: [{'role': 'user', 'content': '물속에서 침전이 발생하는 원리에 대해 알려줘.'}]
# Answer: {
#   "answer": "물속에서 침전이 발생하는 원리는 물 온도에 따라 다르지만, 일반적으로 물 온도가 낮아지면 용질이 용해도가 낮아지고 침전이 발생합니다. 이는 물 온도가 낮아지면 용질 분자들이 더 밀도가 높아지고 침전이 발생하게 됩니다.",
#   "is_science": true
# }
#
# Test 33
# Question: [{'role': 'user', 'content': '화산 폭발이 발생한 후 새로운 생물 군집이 생겨나는 것을 무엇이라 부르나?'}]
# Answer: {
#   "answer": "화산 폭발 후에 새로운 생물 군집이 생겨나는 현상을 '화산생물군'이라고 합니다. 화산생물군은 화산 폭발로 인해 새로운 환경이 형성되고, 이에 적응한 생물들이 생겨나는 현상을 말합니다. 이는 생태계를 형성하는 결과로, 생태계는 서로 다른 유형의 생물들이 상호작용하여 다양한 발전을 이루는 곳입니다. 화산생물군은 생물의 이름은 다르지만 유전적 다양성을 가지고 있으며, 화산생물은 주로 생태적으로 다양한 환경을 끌어들이는 성향을 가지고 있습니다. 따라서, 이러한 화산생물의 특성을 고려하여 '생태학'이라는 용어를 사용할 수 있습니다. 생태학은 환경이나 생물학적인 특성을 고려하여 생태계를 연구하는 학문이며, 화산생물은 이러한 생태학적인 연구의 대상이 될 수 있습니다.",
#   "is_science": true
# }
#
# Test 34
# Question: [{'role': 'user', 'content': '축전기를 병렬로 이어주면 전체 용량이 어떻게 되는가?'}]
# Answer: {
#   "answer": "축전기를 병렬로 연결하면 전체 용량은 각 축전기의 용량을 더한 값이 됩니다. 이는 축전기의 용량이 더해져서 총 용량이 증가하기 때문에 병렬 연결의 특성입니다.",
#   "is_science": true
# }
#
# Test 35
# Question: [{'role': 'user', 'content': '정육면체가 가라앉지 않고 물 위에 떠 있을 때 수면 윗부분에 해당하는 부피를 구하는 방법은?'}]
# Answer: {
#   "answer": "정육면체가 물 위에 떠 있을 때 수면 윗부분에 해당하는 부피를 구하는 방법은 정육면체의 무게가 물 위에 떠 있는 경우에 해당합니다. 이 경우에는 물의 밀도를 고려하여 물 위에 떠 있는 정육면체의 부피를 계산할 수 있습니다. 정육면체의 부피를 구하려면 물 위에 떠 있는 정육면체의 무게를 측정하고, 물의 밀도와 물 위에 떠 있는 정육면체의 부피를 이용하여 계산할 수 있습니다. 이렇게 구한 부피는 정육면체가 물 위에 떠 있는 상태에서의 부피를 나타냅니다.",
#   "is_science": true
# }
#
# Test 36
# Question: [{'role': 'user', 'content': '니가 대답을 잘해줘서 너무 신나!'}]
# Answer: {
#   "answer": "죄송합니다, 이해할 수 없는 메시지입니다.",
#   "is_science": false
# }
#
# Test 37
# Question: [{'role': 'user', 'content': '건설 현장에서 망치로 벽을 치는 이유는?'}]
# Answer: {
#   "answer": "망치로 벽을 치는 이유는 주로 건설 작업에서 사용되며, 벽을 쌓거나 철근을 박는 등의 작업을 수행하기 위한 도구입니다. 망치로 치는 작업은 주로 건설 현장에서 사용되며, 벽을 쌓거나 철근을 박는 등의 작업을 수행하기 위한 도구입니다. 망치로 치는 작업은 주로 건설 현장에서 사용되며, 벽을 쌓거나 철근을 박는 등의 작업을 수행하기 위한 도구입니다. 망치로 치는 작업은 주로 건설 현장에서 사용되며, 벽을 쌓거나 철근을 박는 등의 작업을 수행하기 위한 도구입니다.",
#   "is_science": false
# }
#
# Test 38
# Question: [{'role': 'user', 'content': '차량의 매연이 발생하지 않게 만드는 장치가 무엇인가?'}]
# Answer: {
#   "answer": "차량의 매연을 줄이는 장치로 촉매 변환기와 화물층이 있습니다. 촉매 변환기를 통해 탈취 및 이산화탄소를 생성하며, 화물층은 연소 가스를 제거합니다. 또한, 촉매 변환기와 화물층을 함께 사용하는 시스템도 있습니다. 이 외에도 차량의 매연을 줄이는 다양한 기술이 연구되고 있습니다.",
#   "is_science": true
# }
#
# Test 39
# Question: [{'role': 'user', 'content': 'python에서 lambda 함수를 언제 사용할 수 있어?'}]
# Answer: {
#   "answer": "람다 함수는 간단한 연산을 수행해야 하는 경우에 사용할 수 있습니다. 주로 함수의 인자로 함수를 전달해야 하는 경우나 간단한 함수를 한 줄로 표현해야 하는 경우에 활용됩니다.",
#   "is_science": false
# }
#
# Test 40
# Question: [{'role': 'user', 'content': '강이나 바다의 물이 증발하는 가장 중요한 원인은?'}]
# Answer: {
#   "answer": "강이나 바다의 물이 증발하는 가장 중요한 원인은 대기 중의 황산가스(SO2)와 질산가스(NO)가 증발된 물을 산성화하고, 증발을 촉진하는 역할을 합니다. 또한, 증발된 물은 산성의 pH를 유지하며, 이로 인해 증발된 물과 주변의 환경이 상호작용하여 증발을 유도합니다. 또한, 강이나 바다의 물이 증발하는 또 다른 중요한 이유는 바람의 영향으로 인해 수증기가 증발을 촉진하고, 이로 인해 증발된 물의 pH 수준이 높아져 증발이 유도됩니다.",
#   "is_science": true
# }
#
# Test 41
# Question: [{'role': 'user', 'content': '남녀 관계에서 정서적인 행동이 왜 중요해?'}]
# Answer: {
#   "answer": "남녀 관계에서 정서적인 행동은 상호간의 이해와 신뢰를 증진시키며, 갈등을 해결하고 소통을 원활하게 하는 데 도움을 줍니다. 또한, 정서적인 행동은 감정적인 안정과 안전을 제공하여 상대방과의 관계를 강화시키는 역할을 합니다. 정서적인 행동은 상호간의 이해와 신뢰를 증진시키며, 갈등을 해결하고 소통을 원활하게 하는 데 도움을 줍니다. 또한, 정서적인 행동은 감정적인 안정과 안전을 제공하여 상대방과의 관계를 강화시키는 역할을 합니다. 정서적인 행동은 상호간의 이해와 신뢰를 증진시키며, 갈등을 해결하고 소통을 원활하게 하는 데 도움을 줍니다. 또한, 정서적인 행동은 감정적인 안정과 안전을 제공하여 상대방과의 관계를 강화시키는 역할을 합니다. 정서적인 행동은 상호간의 이해와 신뢰를 증진시키며, 갈등을 해결하고 소통을 원활하게 하는 데 도움을 줍니다.",
#   "is_science": false
# }
#
# Test 42
# Question: [{'role': 'user', 'content': 'DNA 조각들이 서로 결합되도록 돕는 것은?'}]
# Answer: {
#   "answer": "DNA 결합을 돕는 것은 DNA 리가제나 DNA 리간드입니다.",
#   "is_science": true
# }
#
# Test 43
# Question: [{'role': 'user', 'content': '해가 뜨는 현상이 지구의 자전과 관련있어?'}]
# Answer: {
#   "answer": "해가 뜨는 현상은 지구의 자전과 관련이 있습니다. 지구는 자전하면서 동쪽으로 회전하고, 이로 인해 해가 뜨고 지는 현상이 발생합니다. 이는 지구의 자전과 해가 뜨는 시간을 결정짓는 요소입니다.",
#   "is_science": true
# }
#
# Test 44
# Question: [{'role': 'user', 'content': '두 물질이 다른 분자구조나 화학적인 성분으로 이루어져 있다는 것을 어떻게 알 수 있나요?'}]
# Answer: {
#   "answer": "두 물질이 다른 분자구조나 화학적 성분으로 이루어져 있다는 것을 알아내는 방법은 두 분자의 구조를 비교하고, 화학적 특성을 분석하여 확인할 수 있습니다. 또한, 두 물질의 반응을 통해 산소(O2)와 이산화탄소(CO2) 같은 물질의 생성 여부를 확인할 수 있습니다. 또한, 두 물질의 화학적 특성을 분석하여 pH 등의 특성을 비교하여 물질의 화학적 특성을 확인할 수 있습니다. 따라서, 두 물질이 다른 분자구조나 화학적 성분으로 이루어져 있다는 것을 확인하기 위해서는 체계적인 실험과 분석이 필요합니다.",
#   "is_science": true
# }
#
# Test 45
# Question: [{'role': 'user', 'content': '수성이 뜨거운 이유는?'}]
# Answer: {
#   "answer": "수성은 태양으로부터 매우 가까운 위치에 있기 때문에 뜨거운 행성입니다. 수성의 궤도는 태양으로부터 약 0.304 AU에서 0.466 AU까지 변하는데, 이는 수성이 태양으로부터 매우 가까운 궤도를 도는 것을 의미합니다. 또한, 수성의 자전은 매우 느리고, 수성의 자전 축과 공전 궤도의 기울기가 크기 때문에 수성은 극심한 온도 변화를 경험합니다. 이러한 이유로 수성은 매우 뜨거운 행성입니다.",
#   "is_science": true
# }
#
# Test 46
# Question: [{'role': 'user', 'content': '하구 퇴적지의 기능에 대해 알려줘.'}]
# Answer: {
#   "answer": "하구 퇴적지는 강의 흐름에 의해 퇴적물이 쌓이는 지형으로, 강의 흐름이 둔화되는 곳에서 퇴적물이 쌓입니다. 이 지형은 강물의 흐름과 퇴적물의 층으로 구성되어 있으며, 강의 흐름에 따라 다양한 기능을 수행합니다. 퇴적지는 토지의 비옥화, 경작, 퇴적물층으로 인한 수분 보유 등 다양한 용도로 활용됩니다. 또한, 퇴적지는 홍수, 벼락, 강물의 흐름 등에 대한 영향을 줄이는 역할도 합니다. 이러한 기능을 수행하는 퇴적지는 지속적인 관리가 필요하며, 퇴적물의 특성에 따라 다양한 활용이 가능합니다.",
#   "is_science": true
# }
#
# Test 47
# Question: [{'role': 'user', 'content': '디엔에이에서 퓨린과 피리미딘은 어떤 비율로 존재하는가?'}]
# Answer: {
#   "answer": "죄송합니다, 해당 정보를 찾을 수 없습니다.",
#   "is_science": false
# }
#
# Test 48
# Question: [{'role': 'user', 'content': 'interferon의 역할에 대해 알려줘.'}]
# Answer: {
#   "answer": "인터페론은 면역 체계의 조절에 관여하여 바이러스나 세포의 증식을 억제하는 역할을 합니다. 이러한 역할은 인터페론이 세포 내에서 활성화되어 다양한 신호전달을 통해 면역 반응을 조절함으로써 이루어집니다. 또한, 인터페론은 뇌하수체의 호르몬인 CRF(Corticotropin-Releasing Factor)로부터 분비됩니다. CRF는 세포 스트레스 반응을 조절하고, 결과적으로 세포 스트레스 호르몬 코르티코스테로이드의 분비를 촉진합니다. 이러한 과정은 어떤 신체체계에 의해 조절되는 것이며, 이에 대한 자세한 내용은 세포스트레스의 분자 메커니즘에 관련된 것입니다.",
#   "is_science": true
# }
#
# Test 49
# Question: [{'role': 'user', 'content': '하나의 유전자에서 여러가지 단백질이 만들어질 수 있는 원인은?'}]
# Answer: {
#   "answer": "하나의 유전자에서 여러 가지 단백질이 만들어질 수 있는 원인은 유전자의 다양한 스플라이싱 현상과 형질의 다양성 때문입니다. 유전자는 하나의 DNA 서열로부터 여러 가지 mRNA를 만들어내는데, 이는 유전자의 일부분을 선택적으로 읽어내고, 이 선택은 세포의 상황에 따라 달라집니다. 이러한 선택은 mRNA에 의해 단백질이 합성되는데, 이 합성은 다양한 조건에 따라서 변화할 수 있습니다. 따라서, 하나의 유전자가 다양한 단백질을 만들어내는 원인은 유전자의 스플라이싱 현상으로 인해 발생하며, 이는 세포의 상황에 따라서 변화할 수 있습니다.",
#   "is_science": true
# }
#
# Test 50
# Question: [{'role': 'user', 'content': '질산을 통한 염화물 침전시 염소의 비율을 구하는 방법은?'}]
# Answer: {
#   "answer": "질산을 통한 염화물 침전시 염소의 비율을 구하는 방법은 산화-환원 반응을 이용하여 구할 수 있습니다. 이 반응에서는 염화물이 질산에 의해 산화되고, 질산은 질소가스와 물로 환원됩니다. 이를 이용하여 염소의 비율을 계산할 수 있습니다.",
#   "is_science": true
# }
#
# Test 51
# Question: [{'role': 'user', 'content': '이제 그만 얘기해!'}]
# Answer: {
#   "answer": "죄송합니다, 과학 지식과는 무관한 내용으로 답변드릴 수 없습니다.",
#   "is_science": false
# }
#
# Test 52
# Question: [{'role': 'user', 'content': '오늘 너무 즐거웠다!'}]
# Answer: {
#   "answer": "좋은 하루를 보내셨다니 다행입니다! 즐거운 일들이 많이 있었나요?",
#   "is_science": false
# }
#
# Test 53
# Question: [{'role': 'user', 'content': '우울한데 신나는 얘기 좀 해줘!'}]
# Answer: {
#   "answer": "우울할 때는 자연의 풍경을 감상하거나 스트레스를 해소할 수 있는 활동을 하는 것이 도움이 될 수 있습니다. 또한, 활동적인 레저나 운동을 통해 기분을 전환하고 쾌활함을 즐기는 것도 좋은 방법입니다. 또한, 자연 속에서 휴식을 취하고 마음을 치유하는 것이 중요합니다. 마지막으로, 사람들은 자연의 풍경을 감상하며 여유롭게 즐기거나, 산책, 드라이브, 바다나 호수를 감상하며 여유를 즐기는 것이 도움이 될 수 있습니다.",
#   "is_science": false
# }
#
# Test 54
# Question: [{'role': 'user', 'content': '연구자가 갖추어야 할 태도와 자세가 뭘까?'}]
# Answer: {
#   "answer": "연구자가 가져야 할 태도와 자세는 책임감과 윤리, 창의성과 학습에 대한 열정, 협력과 의사소통, 그리고 문제 해결 능력 등이 있습니다.",
#   "is_science": true
# }
#
# Test 55
# Question: [{'role': 'user', 'content': '나이가 들수록 시간이 더 빨리 가는 것 처럼 느끼게 되는 원인은?'}]
# Answer: {
#   "answer": "나이가 들수록 시간이 더 빨리 가는 것 처럼 느끼는 것은 심리적인 요인과 뇌의 기능 변화로 인해 발생합니다. 이는 나이가 들면서 인지능력이 저하되고, 일상적인 활동을 처리하는 속도가 떨어지며, 기억 처리 및 추론 능력이 감소하기 때문에 더 빨리 시간이 흘러가는 것처럼 느껴지는 현상입니다. 또한, 심리적으로 인지능력이 저하되면서 일상적인 활동을 처리하는데 더 많은 노력이 필요하고, 기억 처리 능력이 감소하면서 더 많은 시간이 소요되는 것으로 보고되고 있습니다. 이러한 변화는 뇌의 기능 변화와 관련이 있으며, 2020년의 연구 결과에 따르면, 뇌의 신경 회로 및 기능, 학습 및 기억 처리, 인지 능력, 추론 능력 등을 담당하는 기능이 변화로 인해 시간 인식을 왜곡시키는 것으로 보고되고 있습니다. 따라서, 나이가 들면서 시간이 빨리 가는 것처럼 느껴지는 현상은 심리적인 요인과 뇌의 기능 변화로 인해 발생하는 것으로 보고되고 있습니다.",
#   "is_science": true
# }
#
# Test 56
# Question: [{'role': 'user', 'content': '퇴직한 사람들에게 사회 보장은 어떤 의미인가?'}]
# Answer: {
#   "answer": "퇴직한 사람들에게 사회 보장은 경제적 안정과 안락함을 제공하며, 사람들이 삶의 터전을 이루는 데 도움을 줍니다. 사회 보장은 개인의 사회적, 경제적 안전망을 구축하고, 퇴직 후의 삶을 안정적으로 보장하여 삶의 질을 향상시킵니다. 또한, 사회 보장은 사람들이 퇴직 후에도 경제적으로 독립적으로 살 수 있도록 도와주며, 이는 경제적 안정을 보장합니다. 사회 보장은 또한 사람들에게 경제적 안정을 제공하고, 사회적인 안정을 유지하며, 공공 교육 시스템 등을 통해 교육을 받을 수 있도록 합니다.",
#   "is_science": false
# }
#
# Test 57
# Question: [{'role': 'user', 'content': '사람이나 물체가 지구 위에서 땅속으로 꺼지거나 바깥으로 튕겨나가지 않고 가만히 서 있을 수 있잖아?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 이유를 힘의 원리로 설명해줘.'}]
# Answer: {
#   "answer": "힘의 원리에 따르면 물체는 두 가지 경우에만 정지할 수 있습니다. 첫 번째로, 중력의 영향으로 물체의 운동을 제어하는 결과로 발생하는 반력과 마찰력의 합으로 인해 정지합니다. 이 반력은 중력을 제어하며, 모든 물체를 상쇄시키는 결과를 초래합니다. 두 번째로, 반력의 영향으로 발생하는 운동량-보존 법칙을 따르면, 물체는 운동량을 상쇄시키는 결과로 정지합니다. 이 두 가지 경우의 결과로 인해 물체를 정지시키는 힘은 발생합니다. 이러한 결과는 물리적인 법칙에 따라 발생하며, 우리가 상쇄하는 동안에는 힘의 방향을 결정하는 동안, 물체는 상쇄되는 동안에는 힘의 방향과 크기를 결정합니다. 이러한 힘의 결과는 발생하는 상황에 따라 다르며, 물체의 운동량을 제어하는 결과로 발생합니다.",
#   "is_science": true
# }
#
# Test 58
# Question: [{'role': 'user', 'content': '씨앗의 기능에 대해 자세히 알려줘?'}]
# Answer: {
#   "answer": "씨앗은 생물이나 다른 물질을 만들어내는 능력을 갖고 있습니다. 씨앗은 자연적으로 생긴 물질을 이용하여 성장할 수 있으며, 이 과정에서 탄소를 흡수하고 산소를 생성합니다. 씨앗의 자연적인 생태학은 자연적으로 생긴 물질을 이용하여 산소를 생성하고, 이산화탄소, 수분을 배출합니다. 씨앗의 산소 생성은 산소를 필요로 하는 동식물을 위해 중요한 역할을 합니다. 따라서 씨앗은 산소를 생성하고, 이산화탄소, 수분을 배출하여 생태계를 유지합니다. 씨앗의 생성은 산소를 필요로 하는 동식물을 위해 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 59
# Question: [{'role': 'user', 'content': '친환경 재생 가능 재료가 어떤것들이 있나?'}]
# Answer: {
#   "answer": "친환경 재생 가능한 재료로는 너트로펜, 친환경 너트로펜 2가지가 있습니다. 이러한 재료들은 환경에 부담을 주지 않고 재활용이 가능합니다.",
#   "is_science": true
# }
#
# Test 60
# Question: [{'role': 'user', 'content': '남미의 라틴 역사에 대해 알려줘.'}]
# Answer: {
#   "answer": "남미의 라틴 역사에 대해 알려드릴게요. 남미는 라틴 아메리카로 불리며, 라틴어를 기반으로 하는 문화와 언어를 갖고 있습니다. 남미는 다양한 문화와 역사적으로 풍부한 지역으로, 특히 스페인, 포르투갈, 네덜란드, 영국 등 다양한 국가들의 영향을 받아 다채로운 문화를 형성하고 있습니다. 또한 남미는 지리적으로 다양한 특성과 분포를 가지고 있어, 다양한 지형과 인구들의 특성을 반영하고 있습니다. 라틴 아메리카는 남미의 다양한 문화와 역사적인 특성을 반영하며, 사람들의 풍부한 생활과 이해를 추구하는 중심지로 작용하고 있습니다. 더 자세한 내용은 라틴 아메리카의 다양한 문화와 특성을 반영하며, 지리적 특성과 다양한 문화적 요소를 반영하고 있는 중심지로 작용하고 있습니다.",
#   "is_science": false
# }
#
# Test 61
# Question: [{'role': 'user', 'content': '원자의 내부 구조에 대해 설명해줘.'}]
# Answer: {
#   "answer": "원자의 내부 구조는 양성자와 음성자로 구성되어 있습니다. 양성자는 원자의 핵심을 이루며 +1의 전하를 가지고 있습니다. 이는 양성자가 함유된 것을 의미합니다. 원자는 양성자, 전자, 중성자로 구성되어 있으며, 양성자는 양전하를 가지고 있고, 전자는 음전하를 가지며, 중성자는 전하를 가지고 있지 않습니다. 이러한 구성은 양성자의 전자 구조와 양성자의 결합 법칙에 의해 결정됩니다. 양성자의 전자 구조와 양성자의 결합은 양성자의 전자 구조의 특성을 결정하는데, 이는 원자의 화학적 성질에 영향을 미치며, 양성자의 결합은 양성자의 전자 구조의 특성을 결정하는데, 이는 원자의 화학적 성질에 영향을 미칩니다. 이러한 양성자의 결합은 화학 반응의 결과와 반응 속도를 결정하는 중요한 요소입니다. 이에 따라 양성자의 결합은 화학적 성질과 화학 반응에 중요한 영향을 미치며, 이러한 양성자의 결합은 화학적 성질과 화학 반응에 중요한 영향을 미칩니다.",
#   "is_science": true
# }
#
# Test 62
# Question: [{'role': 'user', 'content': '난관의 기능에 대해 알려줘.'}]
# Answer: {
#   "answer": "난관의 기능에 대해 설명할 수 있습니다. 난관은 음식물의 소화와 영양흡수에 중요한 역할을 합니다. 또한, 면역 체계와 특정 물질의 분해와 흡수에도 관여합니다. 난관의 기능은 소화기관의 주요한 구성요소와 밀접한 관련이 있으며, 소화 및 흡수를 통해 영양소를 공급하는 중요한 장기입니다.",
#   "is_science": true
# }
#
# Test 63
# Question: [{'role': 'user', 'content': '공기의 온도가 기후에 미치는 영향은?'}]
# Answer: {
#   "answer": "공기의 온도는 기후에 미치는 영향이 큽니다. 온도는 사람들의 활동에 영향을 미치고, 생산과 소비에 영향을 미치며, 기후의 성질과 연관된 여러 가지 영향을 발생시킵니다. 따라서, 온도는 기후의 성질과 다양한 현상을 반영하며, 기후의 변화와 발전에도 영향을 미칩니다. 공기의 온도는 기후의 변화와 발전에 중요한 영향을 미치며, 기후의 안정성과 변화, 발전 등을 조절합니다. 따라서, 온도는 기후의 특성과 다양한 현상을 반영하며, 기후의 변화와 발전에도 영향을 미칩니다.",
#   "is_science": true
# }
#
# Test 64
# Question: [{'role': 'user', 'content': '안녕 반갑다'}]
# Answer: {"answer": "안녕하세요! 과학 지식에 관련된 내용이 아닌 것 같아요.", "is_science": false}
#
# Test 65
# Question: [{'role': 'user', 'content': '평균을 구하는 코드를 작성중이야.'}, {'role': 'assistant', 'content': '네 무엇을 도와드릴까요?'}, {'role': 'user', 'content': '예외처리가 필요한 경우를 알려줘.'}]
# Answer:
# {
#   "answer": "평균을 구하는 코드를 작성할 때 예외 처리가 필요한 경우는 입력값이 없거나 잘못된 형식으로 입력된 경우입니다. 예외 처리를 통해 입력값의 유효성을 검사하고, 평균을 계산하는 과정에서 발생할 수 있는 오류를 처리할 수 있습니다. 또한, 평균을 계산하는 도중에 발생할 수 있는 예외 상황을 대비하여 예외 처리를 추가하는 것이 좋습니다. 예를 들어, 입력값이 숫자가 아닌 경우나 입력값이 없는 경우에 대비한 예외 처리를 추가할 수 있습니다.",
#   "is_science": true
# }
#
# Test 66
# Question: [{'role': 'user', 'content': '소프트웨어 개발이 사람의 편향없이 이루어질 수 있나?'}]
# Answer: {
#   "answer": "소프트웨어 개발이 완전히 편향 없이 이루어지는 것은 어렵습니다. 이는 소프트웨어가 인간의 의사결정에 의해 설계되고 구축되기 때문입니다. 또한, 로봇의 학습과 결정은 내재된 가치, 편견, 상황 등을 반영하므로 완전한 편향 없는 결정을 내리기 어렵습니다. 이러한 편향은 사용자의 관리 없이는 제어하기 어렵고, 사용자의 관리와 편향이 결정적인 역할을 합니다. 따라서 소프트웨어의 개발과 로봇의 결정은 사용자의 편향과 의사결정의 영향을 받기 때문에 완전한 편향 없는 결정을 내리기 어렵습니다.",
#   "is_science": true
# }
#
# Test 67
# Question: [{'role': 'user', 'content': '전체 인구에서 특정 유전자의 비율이 변하지 않고 유지되는 상태를 뭐라고 해?'}]
# Answer: {
#   "answer": "유전자 주파의 유지는 유전적 평형의 원리에 따라 발생합니다. 유전자 주파는 세포분열 및 유전자의 복제과정에서 유지되며, 세포분열 과정에서의 무작위한 유전자 분배 및 유전자 돌연변이로 인해 변하지 않습니다. 이러한 현상은 유전적 다양성과 유전적 안정성을 결정하는 중요한 특성을 가지고 있습니다. 따라서, 유전자 주파의 유지는 유전적 다양성과 안정성을 유지하는 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 68
# Question: [{'role': 'user', 'content': '지구가 생겨난지 얼마나 오래 되었는지 확인하는 방법은?'}]
# Answer: {
#   "answer": "지구의 나이를 확인하는 방법은 바위층의 연대를 조사하여 알 수 있습니다. 10월에는 지구가 태어난 후 약 46억 년이 지났습니다. 이는 밤하늘에서 바라볼 때 측정할 수 있는 최소의 시간입니다. 이 시간에는 바위층을 조사하여 지구의 연대를 알 수 있습니다. 따라서 1월에 지구가 태어난 후 약 4.6억 년이 지난 것으로 추정됩니다. 이 시간에는 바위층을 조사하여 지구의 연대를 알 수 있는데, 이는 과학적으로 증명된 사실입니다.",
#   "is_science": true
# }
#
# Test 69
# Question: [{'role': 'user', 'content': '성적인 자극이 발생하는 과정에 대해 알려줘.'}]
# Answer: {
#   "answer": "성적인 자극이 발생하는 과정은 대략적으로 다음과 같습니다. 성적 자극이나 유혹을 받으면 뇌의 특정 영역이 활성화되어 관여하며, 이로 인해 성적인 욕구가 발생하게 됩니다. 이러한 과정은 대략 10초에서 30초 후에 시작되며, 성적 자극이 성숙의 중요한 부분에서 발생하고, 성적인 욕구는 성숙의 중요한 부분에서 활발하게 되는 것으로 알려져 있습니다. 성적 자극의 발생은 성적인 욕구를 유발하며, 이로 인해 성적인 행동이 발생하고 성적인 만족이 일어나는 것으로 알려져 있습니다. 이러한 과정은 성적인 욕구와 성적인 행동의 상호작용을 통해 발생하며, 성적인 욕구는 성적인 행동의 동기부여를 모발하고 성적인 만족은 성숙의 중요한 결론을 보여줍니다. 따라서, 성적인 자극이 발생하는 과정은 성숙의 중요한 결론을 통해 발생하는 것으로 알려져 있습니다.",
#   "is_science": true
# }
#
# Test 70
# Question: [{'role': 'user', 'content': '전선 주위로 흐르는 자기장의 모습은 어떻게 보이나?'}]
# Answer: {
#   "answer": "전선 주위로 흐르는 자기장은 LED 등의 표시기로는 보이지 않습니다. 이는 전류 흐름의 특성상 눈으로 감지하기 어렵기 때문입니다. 전선 주위의 자기장은 특정 장비를 사용하여 감지할 수 있으며, 이때는 특수 장비를 사용하여야 합니다.",
#   "is_science": true
# }
#
# Test 71
# Question: [{'role': 'user', 'content': '간헐적으로 높은 강도의 운동을 하면 어떤 효과가 있나요?'}]
# Answer: {
#   "answer": "간헐적으로 높은 강도의 운동을 하면 근육 성장과 대사 활성화에 도움이 됩니다. 이러한 운동을 하면 근육 내 라크테이트 농도가 증가하며, 이는 근육을 사용하여 에너지를 생산하고 대사를 촉진하는 데 도움이 됩니다. 또한, 운동 중에는 혈중의 산소, ATP 및 크레아틴 인산염이 증가하며, 이는 근육의 에너지 생산과 성장을 촉진합니다. 또한, 운동 후에는 대사가 증가하여 지방 연소와 근육 회복에 도움이 됩니다.",
#   "is_science": true
# }
#
# Test 72
# Question: [{'role': 'user', 'content': '아세틸 콜린의 역할이 뭐야?'}]
# Answer: {
#   "answer": "아세틸 콜린은 신경 전달물질로 작용하며, 기억력과 학습능력을 향상시키는 데 도움을 줄 수 있습니다.",
#   "is_science": true
# }
#
# Test 73
# Question: [{'role': 'user', 'content': '디엔에이와 단백질의 관계와 역할에 대해 설명해줘.'}]
# Answer: {
#   "answer": "디엔에이와 단백질은 화학적으로 상호작용하여 다양한 기능을 수행합니다. 디엔에이는 유전 정보를 전달하고 다양한 대사활동을 조절하는 기능을 합니다. 단백질은 우리 몸의 구조, 항체, 소화, 운송 등 다양한 기능을 담당합니다.",
#   "is_science": true
# }
#
# Test 74
# Question: [{'role': 'user', 'content': '자전축이 기후에 미치는 영향은?'}]
# Answer: {
#   "answer": "자전축은 지구의 기후와 날씨에 영향을 미칩니다. 자전축은 지구의 자전운동과 자전축 기울기의 영향으로 발생하며, 이로 인해 지구는 한 번의 자전주기 동안에 낮과 밤이 번갈아 가며 일어나게 됩니다. 자전축은 우리가 하루 동안의 낮과 밤을 경험하게 하며, 낮과 밤의 변화는 우리의 생활과 활동을 조절합니다. 또한, 자전축은 지구의 계절과 날씨 변화에도 영향을 미칩니다.",
#   "is_science": true
# }
#
# Test 75
# Question: [{'role': 'user', 'content': '여행을 통해 얻을 수 있는 좋은 점들이 뭐가 있어?'}]
# Answer: {
#   "answer": "여행을 통해 얻을 수 있는 좋은 점들은 다양합니다. 여행은 사람들에게 새로운 경험과 기억을 제공하며, 특별한 경험과 추억을 만들어줍니다. 또한, 여행은 일상에서 벗어나 새로운 환경과 문화를 경험하고, 새로운 사람들과의 만남을 통해 다양한 인맥을 형성할 수 있습니다. 또한, 여행은 자연 속에서의 휴식과 새로운 도전을 통해 성장할 수 있는 기회를 제공합니다. 여행은 다양한 경험과 인연을 만들어주며, 새로운 자아를 발견할 수 있는 기회를 제공합니다.",
#   "is_science": false
# }
#
# Test 76
# Question: [{'role': 'user', 'content': '은하들이 점점 멀어지고 있다던데 맞아?'}, {'role': 'assistant', 'content': '네 맞아요.'}, {'role': 'user', 'content': '어떤 물리적인 현상을 보고 그걸 알게 되었어?'}]
# Answer:
# {
#   "answer": "은하들이 서로 멀어지는 현상은 우주의 가속팽창으로 인해 발견되었습니다. 이 현상은 천문학자들에 의해 관측된 여러 증거들을 바탕으로 발견되었습니다. 이러한 현상은 우리의 우주의 진화와 관련된 중요한 흔적을 제공합니다. 이러한 현상은 1483년에 니콜라우스 코페르니쿠스의 천문학적 연구에 의해 처음으로 관측되었습니다. 이러한 현상은 천문학자들에 의해 연구되고 있으며, 우리의 우주와 지구의 진화에 대한 중요한 정보를 제공합니다.",
#   "is_science": true
# }
#
# Test 77
# Question: [{'role': 'user', 'content': '목성 trojan의 특징에 대해 알려줘.'}]
# Answer: {
#   "answer": "목성의 trojan은 목성 주위의 특정한 위치에 존재하는 천체로, 특히 Lagrange 점에 위치한 목성의 위성들과 공명하는 천체입니다. 이러한 trojan은 특정한 위치에 안정적으로 위치하여 목성과의 공명 상태를 유지합니다. 또한, trojan은 특정한 천체의 중력에 의해 안정적인 궤도를 유지하며, 목성의 중력과의 상호작용으로 안정적인 궤도를 유지합니다. 또한, trojan은 특정한 천체의 중력에 의해 안정적인 궤도를 유지하며, 목성의 중력과의 상호작용으로 안정적인 궤도를 유지합니다.",
#   "is_science": true
# }
#
# Test 78
# Question: [{'role': 'user', 'content': '슈퍼옥시드 디스무타아제 라는 효소에 대해 설명해줘.'}]
# Answer: {
#   "answer": "슈퍼옥시드 디스무타아제는 세포 내에서 다양한 기능을 수행하는 효소들 중 하나로, 산소를 이용하여 유해 물질을 제거하고 세포의 대사 활동을 조절하는 역할을 합니다. 이 효소는 세포 내에서 활발한 활동을 보이며, 산화적 역할을 수행하고 활성산소의 농도를 조절하며 세포의 안정을 유지합니다. 슈퍼옥시드 디스무타아제와 리그나제는 피토케미컬로, 세포 내에서도 산화 및 면역 활동과 관련하여 중요한 기능을 합니다. 이러한 효소들은 활성산소를 조절하고 세포의 안정을 유지하는 역할을 하며, 활용 방법으로는 항산화, 항염, 항암 등 다양한 응용이 있습니다.",
#   "is_science": true
# }
#
# Test 79
# Question: [{'role': 'user', 'content': '네바다주에 살고 있는데...'}, {'role': 'assistant', 'content': '네 그러시군요?'}, {'role': 'user', 'content': '여기 비가 많이 오지 않는 이유가 뭐야?'}]
# Answer:
# {
#   "answer": "네바다 주에서 비가 많이 오지 않는 이유는 주변 산들이 비를 막아서 그렇습니다. 또한, 네바다 주의 고도가 높고, 주변 지역의 영향을 받기 때문에 강수량이 적습니다. 또한, 네바다 주의 특정 지역은 건조한 바람이 불어서 강수량이 적을 수 있습니다.",
#   "is_science": true
# }
#
# Test 80
# Question: [{'role': 'user', 'content': '어떤 물체를 매우 크게 확대해서 볼수 있는 기계는?'}]
# Answer: {
#   "answer": "전자 현미경을 사용하여 물체를 매우 크게 확대해서 볼 수 있습니다.",
#   "is_science": true
# }
#
# Test 81
# Question: [{'role': 'user', 'content': 'merge sort 알고리즘에 대해 설명해줘.'}]
# Answer: {
#   "answer": "병합 정렬(merge sort)은 분할 정복 알고리즘의 하나로, 리스트를 반으로 나눈 뒤 각각을 정렬하고 합병하는 과정을 반복하여 정렬하는 알고리즘입니다.",
#   "is_science": true
# }
#
# Test 82
# Question: [{'role': 'user', 'content': '심해가 생태계에 미치는 영향은?'}]
# Answer: {"answer": "심해는 지구 생태계에 매우 중요한 영향을 미치며, 다양한 생물이 서식하고 상호작용합니다. 심해 생태계는 다른 해양 생태계로 이동하는 등의 역할을 하며, 해양 생태계의 안정성과 생물 다양성에 중요한 영향을 미칩니다. 또한 심해는 식량, 의약품, 자원 등 다양한 측면에서 중요한 역할을 합니다. 따라서 심해 생태계의 변화는 지구 생태계 전반에 영향을 미치며, 이에 대한 연구와 보호가 필요합니다.", "is_science": true}
#
# Test 83
# Question: [{'role': 'user', 'content': '저항이 2배로 증가하면 전력은 어떻게 되나?'}]
# Answer: {
#   "answer": "저항이 2배로 증가하면 전력은 변하지 않습니다. 전력은 전압의 제곱을 저항으로 나눈 값이기 때문에, 저항이 증가하더라도 전압이나 전류에 변화가 없다면 전력은 변하지 않습니다.",
#   "is_science": true
# }
#
# Test 84
# Question: [{'role': 'user', 'content': '산에 불이 나면 동식물이 많이 죽을텐데'}, {'role': 'assistant', 'content': '네 안타까운 일입니다.'}, {'role': 'user', 'content': '불난 후에 자연의 회복 과정은 어떻게 돼?'}]
# Answer: {
#   "answer": "산불 후 자연의 회복 과정은 다양한 단계로 진행됩니다. 먼저, 산불로부터 생존한 동물들이 다시 번성하고, 새로운 식물이 자라나며 생태계가 회복됩니다. 이후 몇 시간 내에는 산불의 잔해를 청소하고, 씨앗을 심어 새로운 식물을 재배하며, 산불로부터 생존한 식물들이 번성합니다. 산불로부터 생존한 동물들은 생존 후 몇 시간 동안은 산불의 피해를 복구하고, 씨앗을 심어 새로운 생명을 키우며, 산불로부터 생존한 동물과의 상호작용과 충돌을 통해 생태계를 회복합니다. 산불의 잔해를 청소하고, 식물의 성장을 돕는 등의 기능은 산불의 피해를 복구하고, 산불로부터 생존한 동물과의 상호작용과 충돌을 통해 생태계를 회복합니다. 이러한 과정은 산불의 피해를 복구하고, 산불로부터 생존한 동물과의 상호작용과 충돌을 통해 생태계를 회복하는 데 도움이 됩니다.",
#   "is_science": true
# }
#
# Test 85
# Question: [{'role': 'user', 'content': 'DNA 분해 효소의 역할에 대해 알려줘.'}]
# Answer: {
#   "answer": "DNA 분해 효소는 DNA 분자를 분해하는 역할을 합니다. 이 효소는 DNA 분자 내의 A:T 비율을 2:3으로 유지하며, 새로운 DNA를 합성할 때에도 A와 T의 비율을 유지하도록 도와줍니다. 또한, DNA 분해 과정에서 이루어지는 메틸화를 조절하는 역할을 하는 효소인 DNMT1도 있습니다. DNMT1은 DNA 메틸화 상태를 유지하고, 새로운 DNA 분해 과정에서 새로 메틸화되는 지점을 조절합니다. 이러한 역할은 유전자 발현 조절, 세포분열 및 세포 분화에 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 86
# Question: [{'role': 'user', 'content': '특정 농도의 황산 sample을 만드는 방법?'}]
# Answer: {
#   "answer": "황산을 특정 농도로 만드는 방법에 대한 정보가 아닌 것 같습니다.",
#   "is_science": false
# }
#
# Test 87
# Question: [{'role': 'user', 'content': '달은 1년 동안 지구를 몇바퀴 도는가?'}]
# Answer: {
#   "answer": "달은 1년 동안 지구를 13바퀴 돕니다.",
#   "is_science": true
# }
#
# Test 88
# Question: [{'role': 'user', 'content': '개인의 생물학적, 사회적인 특성 형성에 영향을 미치는 요소에 대해 설명해줘.'}]
# Answer: {
#   "answer": "개인의 생물학적, 사회적 특성 형성에 영향을 미치는 요소에는 유전적 요인, 환경적 요인, 사회적 상호작용, 교육 수준, 문화적 배경, 경제적 상황 등이 있습니다.",
#   "is_science": true
# }
#
# Test 89
# Question: [{'role': 'user', 'content': '너는 누구야?'}]
# Answer: {"answer": "죄송합니다, 제가 도와드릴 수 있는 정보가 아닌 것 같습니다.", "is_science": false}
#
# Test 90
# Question: [{'role': 'user', 'content': '지각은 주로 무엇으로 이루어져 있어?'}]
# Answer: {"answer": "지각은 눈의 망막, 망막 신경 및 뇌의 특정 영역과 연결된 신경 세포의 상호작용으로 이루어져 있습니다. 눈의 망막은 빛을 감지하고, 뇌의 특정 영역과 연결된 신경은 시각 자극을 처리하며, 뇌의 특정 영역과 연결된 신경은 시각 자극을 해석합니다. 이러한 상호작용은 시각운동을 처리하는 동안 사용됩니다. 또한, 지각은 빛을 감지하고 처리하는 뇌의 특정 영역과 연결된 신경으로 구성되어 있습니다. 이러한 신경은 시각 자극을 해석하고, 뇌의 특정 영역과 연결된 신경은 시각 자극을 처리합니다. 이러한 상호작용은 빛을 감지하고 처리하는 동안 사용됩니다. 따라서 지각의 특성을 이해하는 것은 시각운동을 처리하는 동안 사용됩니다. 지각은 눈의 망막, 망막 신경 및 뇌의 특정 영역과 연결된 신경으로 구성되어 있으며, 빛을 감지하고 처리하는 동안 사용됩니다.", "is_science": true}
#
# Test 91
# Question: [{'role': 'user', 'content': '오세아니아 섬나라에 광견병이 있어?'}]
# Answer: {
#   "answer": "오세아니아 지역의 광견병은 티아라추추병으로 알려져 있습니다. 이 질병은 티아라추추 바이러스 B1로 인해 발생하며, 우리 몸에 위험한 영향을 미치는 질병입니다. 광견병은 티아라추추병으로 인해 발생하는 질병으로, 주로 티아라추추 바이러스 B1에 노출되거나 감염된 동물의 침을 통해 전파됩니다. 이러한 질병은 예방 가능하며, 백신을 통해 예방할 수 있습니다. 따라서, 광견병이 존재할 수 있지만 적절한 예방과 치료를 통해 통제할 수 있습니다.",
#   "is_science": true
# }
#
# Test 92
# Question: [{'role': 'user', 'content': '추울때 폭이 넓은 회색의 구름이 끼면 어떤 날씨가 예상되나?'}]
# Answer: {
#   "answer": "추울 때 폭이 넓은 회색의 구름이 꼈을 때에는 비가 오거나 눈이 내릴 가능성이 높습니다. 이는 폭이 넓은 구름이 쌓이고 끼면서 북풍 중심의 수북이 발생하고, 이로 인해 기압이 떨어지고 비나 눈이 내리게 됩니다. 이러한 현상은 일반적으로 전반, 후반, 진눈깨비와 같은 상황으로 나타날 수 있습니다. 또한, 북풍 중심으로 인해 1년 내내 최소한의 눈이 쌓이는 경우도 있습니다. 이는 북풍 중심의 축이 더욱 강화되고 남북방향을 가로지르는 구름이 쌓이면서 기온이 떨어지고 눈이 내리는 현상을 의미합니다. 이러한 추론 결과는 폭이 넓은 구름이 쌓일 때의 기압과 북풍 중심의 눈이 내리는 현상을 설명하고 있습니다. 따라서, 추울 때 폭이 넓은 구름이 꼈을 때에는 비나 눈이 내릴 가능성이 높습니다.",
#   "is_science": true
# }
#
# Test 93
# Question: [{'role': 'user', 'content': '안정성이 높은 PRP를 만드는 방법에 대해 알려줘.'}]
# Answer: {
#   "answer": "안정성이 높은 PRP를 만드는 방법에는 다양한 실험, 수행 및 분석을 통해 안정성을 검증하는 것이 포함됩니다. 안정성 검증을 위해 적합한 실험 및 분석을 선택하고, 안정성을 보장하는데 필요한 조건을 설정하여 안정성을 평가하는 것이 중요합니다. 안정성 검증을 통해 안정성이 보장된 PRP를 만들 수 있습니다. 이러한 절차를 통해 안정성이 보장되지 않는 결과를 방지하고, 안정성을 확인하는데 필요한 조건을 충족시킬 수 있습니다. 이러한 방법을 통해 안정성이 보장된 PRP를 만들 수 있습니다.",
#   "is_science": true
# }
#
# Test 94
# Question: [{'role': 'user', 'content': '너 모르는 것도 있니?'}]
# Answer: {"answer": "죄송합니다, 제가 이해할 수 없는 내용이에요.", "is_science": false}
#
# Test 95
# Question: [{'role': 'user', 'content': '중성자의 특징에 대해 설명해줘.'}]
# Answer: {
#   "answer": "중성자는 원자핵의 구성 요소 중 하나로서 양성자와 질량은 같지만 전하가 없는 입자입니다. 중성자는 원자의 구조와 화학반응에 중요한 역할을 하며, 핵물리학이나 원자로봇학과 같은 특수한 분야에서 중요한 특성을 가지고 있습니다. 중성자의 질량은 전자의 0.6배의 크기로, 이는 중력적인 효과를 고려할 때 중요한 특성입니다. 또한 중성자는 중성자 별과 같은 천체에서 발견되는 특성을 가지고 있습니다.",
#   "is_science": true
# }
#
# Test 96
# Question: [{'role': 'user', 'content': '플랑크톤의 역할에 대해 알려줘.'}]
# Answer: {
#   "answer": "플랑크톤은 해양 생태계에서 중요한 역할을 합니다. 이들은 해양 식물의 기반이 되는 작은 식물이며, 이러한 작은 식물은 수십 미터의 1초의 시간 동안에 100분의 1로 자라게 됩니다. 또한, 유독한 물질을 흡수하고 처리하여 해양 생태계의 균형을 유지합니다. 플랑크톤은 바다에서 중요한 영양원으로 작용하며, 다양한 해양 생물들의 먹이로 작용합니다.",
#   "is_science": true
# }
#
# Test 97
# Question: [{'role': 'user', 'content': '기생과 공생의 차이에 대해 알려줘.'}]
# Answer: {
#   "answer": "기생과 공생의 차이는 기생은 호스트의 몸속이나 표면에서 생활하면서 이익을 얻는 관계를 말하고, 공생은 두 종 모두가 상호 협력하여 상생하는 관계를 말합니다. 기생은 호스트의 몸속이나 표면에서 생활하면서 호스트의 영양을 빼앗거나 질병을 일으키는 경우가 많으며, 이에 반해 공생은 두 종 모두가 협력하여 상생하는 경우가 많습니다. 따라서 기생은 단순히 호스트의 이익만을 취하는 반면, 공생은 서로 협력하여 상생하는 경우가 많습니다.",
#   "is_science": true
# }
#
# Test 98
# Question: [{'role': 'user', 'content': '강아지가 사회화되는 행동의 사례는 뭐가 있을까?'}]
# Answer: {
#   "answer": "강아지가 사회화되는 행동의 사례로는 주인과의 상호작용, 타인과의 교류, 사회적 상황에서의 행동 등이 있습니다. 또한 강아지는 놀이를 통해 사회화되기도 합니다. 강아지는 사회화를 통해 주인과의 상호작용, 타인과의 교류, 사회적 상황에서의 행동을 익히게 되며, 이는 강아지의 사회적 기술을 향상시키고, 사회적 상황에서의 적응력을 높입니다.",
#   "is_science": true
# }
#
# Test 99
# Question: [{'role': 'user', 'content': '너 잘하는게 뭐야?'}]
# Answer: {
#   "answer": "제가 잘하는 것은 과학적인 지식을 활용하여 복잡한 문제들을 해결하는 것입니다. 이를 통해 새로운 발견을 이끌어내고, 다양한 분야에서 유용한 정보를 제공합니다. 또한, 과학적인 지식을 활용하여 사회 문제를 해결하고, 새로운 기술의 발전에 기여합니다. 따라서, 제가 잘하는 것은 과학적인 지식을 활용하여 다양한 문제를 해결하고, 새로운 발견을 이끌어내는 것입니다.",
#   "is_science": true
# }
#
# Test 100
# Question: [{'role': 'user', 'content': '지구에서 새로운 땅이 생겨나는 메커니즘은?'}]
# Answer: {
#   "answer": "지구에서 새로운 땅이 생겨나는 메커니즘은 플레이트 틱토닉이라고 합니다. 지구 표면의 플레이트가 서로 충돌하거나 멀어지는 과정에서 산소, 화산, 지각 변동 등의 현상을 경험하게 됩니다. 이러한 지질 활동은 지진, 화산 폭발, 토네이도 등의 자연 재해를 유발하며, 지구의 지형과 기후를 변화시킵니다.",
#   "is_science": true
# }
#
# Test 101
# Question: [{'role': 'user', 'content': '더러워진 엔진오일을 잘 처리하는 방법에 대해 알려줘.'}]
# Answer: {
#   "answer": "엔진오일을 처리하는 방법에는 여러 가지가 있습니다. 먼저, 엔진오일을 버리지 말고 적절히 처리해야 합니다. 엔진오일을 폐기할 때는 환경과 안전을 위해 지정된 수거 장소에 버려야 합니다. 또한, 엔진오일을 재활용하는 것이 가능한데, 이를 위해서는 전문가의 도움이 필요합니다. 엔진오일을 처리하는데 필요한 안전장비와 규정을 준수하는 사람들은 여러 가지 위험을 방지할 수 있습니다. 또한, 엔진오일을 처리하는 사람들은 적절한 처리 시설과 기술을 갖추고 있어야 합니다. 따라서, 엔진오일을 처리하는 방법에 대해 자세히 알아보고 싶다면 전문가의 도움을 받는 것이 좋습니다.",
#   "is_science": false
# }
#
# Test 102
# Question: [{'role': 'user', 'content': '너 정말 똑똑하다!'}]
# Answer: {"answer": "감사합니다! 제가 도와드릴 수 있는 다른 질문이 있으면 언제든지 물어보세요.", "is_science": false}
#
# Test 103
# Question: [{'role': 'user', 'content': '다람쥐가 열매를 땅에 묻는 행동이 나무에 미치는 영향은?'}]
# Answer: {"answer": "다람쥐가 열매를 땅에 묻는 행동은 나무에 영양을 공급하는 역할을 합니다. 이 행동은 나무의 생장을 촉진하고 씨앗을 보호하여 식물의 번식을 도와줍니다. 또한, 열매를 묻는 행위는 씨앗의 저장과 분포를 도와주며, 씨앗을 먹지 않고 저장하는 경우에는 씨앗을 발아시키는데 도움을 줍니다. 따라서 다람쥐의 행동은 나무와 식물의 번식과 성장에 긍정적인 영향을 미칩니다.", "is_science": true}
#
# Test 104
# Question: [{'role': 'user', 'content': '새로운 생명체의 발생에 대한 오래된 믿음을 깨기 위해 어떤 방법이 사용되었나?'}]
# Answer: {"answer": "새로운 생명체의 발생에 대한 오래된 믿음을 깨기 위해 사용된 방법은 다양했습니다. 17세기, 실험적 방법을 통해 생명체의 발생을 부정하고자 하는 주장이 제기되었습니다. 이 주장은 실험적 증거에 의해 반박되었지만, 이후에도 다양한 실험과 연구를 통해 생명체의 발생을 부정하는 주장이 제기되었습니다. 이러한 논쟁을 통해 과학적 방법과 이론이 발전하였습니다. 과학적 방법과 이론을 통해 새로운 가설을 검증하고 부정하는 것은 과학적인 태도와 방법으로, 이는 과학의 발전에 중요한 역할을 합니다. 따라서, 과학적 방법을 통해 새로운 생명체의 발생에 대한 오래된 믿음을 깨는 것은 과학의 발전에 기여하는 중요한 과정입니다.", "is_science": true}
#
# Test 105
# Question: [{'role': 'user', 'content': '협곡이 형성되는 과정은?'}]
# Answer: {
#   "answer": "협곡이 형성되는 과정은 강의 유속이 빠르거나 물이 강하게 흐를 때, 지형이 다양한 곳에서 물이 모여 하나의 강물로 합류하면서 발생합니다. 이로 인해 강물의 유속이 증가하고, 강물이 지형을 깎아내어 협곡을 형성하게 됩니다. 또한, 협곡은 강의 곡면과 협력으로 인해 형성되기도 합니다.",
#   "is_science": true
# }
#
# Test 106
# Question: [{'role': 'user', 'content': 'python 공부중인데...'}, {'role': 'assistant', 'content': '네 꼭 필요한 언어라서 공부해 두면 좋습니다.'}, {'role': 'user', 'content': '숫자 계산을 위한 operator 우선순위에 대해 알려줘.'}]
# Answer: {
#   "answer": "숫자 계산을 위한 operator 우선순위에 대해 알려드리겠습니다. 연산자는 일반적으로 수학적인 우선순위를 따릅니다. 연산자는 곱셈을 우선으로 사용하여 괄호나 제곱을 통해 계산 순서를 조절할 수 있습니다. 연산자를 사용하여 계산할 때는 연산의 우선순위와 시간 데이터를 확인하여 적절한 결과를 도출할 수 있습니다. 연산자를 사용하여 숫자를 계산할 때는 연산의 우선순위와 시간 데이터를 확인하여 적절한 결과를 도출할 수 있습니다. 따라서, 연산자를 사용하여 숫자를 계산할 때는 연산의 우선순위와 시간 데이터를 확인하여 적절한 결과를 도출할 수 있습니다.",
#   "is_science": true
# }
#
# Test 107
# Question: [{'role': 'user', 'content': '지구상에 존재하는 물 중 가장 많은 물은 바닷물이잖아?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '바닷물 말고 담수가 가장 많이 있는 곳이 어디야?'}]
# Answer: {
#   "answer": "바닷물 이외에도 담수가 많이 존재합니다. 이러한 담수는 강, 호수, 지하수 등에서 발견됩니다. 특히 북극의 빙하와 남극 대륙에서는 많은 양의 담수가 저장되어 있습니다. 이러한 담수는 물 부족 문제를 해결하는 데 중요한 자원이며, 지구상의 생태계에도 영향을 미칩니다. 담수 자원을 보호하고, 관리하는 것이 중요합니다.",
#   "is_science": true
# }
#
# Test 108
# Question: [{'role': 'user', 'content': '폭풍을 쫓는 사람들이 누구야?'}]
# Answer: {"answer": "폭풍을 쫓는 사람들은 바람을 타고 날아다니며 폭풍의 중심에 가까이 다가가는 사람들을 말합니다. 이들은 폭풍의 구조, 교훈, 성질 등을 연구하고 폭풍 지도학을 발전시키며 폭풍의 원리를 이해하고 분석하는 등의 활동을 합니다. 이들은 폭풍의 발달 과정과 특성을 더욱 잘 이해하고, 폭풍의 행동을 예측하고 대비하는 등의 활동을 통해 폭풍의 피해를 최소화하고 안전을 유지하는 데 기여합니다.", "is_science": true}
#
# Test 109
# Question: [{'role': 'user', 'content': '우라늄을 사용한 원자력 발전의 단점에 대해 알려줘.'}]
# Answer: {
#   "answer": "우라늄을 사용한 원자력 발전의 단점은 다음과 같습니다. 1. 방사성 폐기물의 처리 문제: 우라늄은 오랜 기간 동안 방사성 물질을 방출하므로, 이를 안전하게 처리하는 것이 중요합니다. 방사성 폐기물은 활동 및 비활동 폐기물로 구분되며, 처리 방법에 대한 규제와 시설이 부족하여 문제가 발생할 수 있습니다. 2. 화학적 안정성 문제: 우라늄은 화학적으로 매우 안정하지 않은 성질을 가지고 있습니다. 이로 인해 화학적 안정성 문제와 관련된 규제와 시설이 부족하여 문제가 발생할 수 있습니다. 3. 원자력 발전의 경제성: 원자력 발전소의 경제적인 문제도 있습니다. 이에는 우라늄 발전소의 운영 및 유지에 따른 비용과 관련된 여러 가지 문제가 포함됩니다. 4. 화학적 및 방사선 사고: 우라늄 발전소는 화학적 사고 및 방사선 사고에 취약할 수 있습니다. 이에 따라 화학적 안전, 방사선 안전, 방사선 폐기물 처리 등에 대한 안전성을 보장하는 것이 중요합니다.",
#   "is_science": true
# }
#
# Test 110
# Question: [{'role': 'user', 'content': '고체에서 액체로 변할 때 엔트로피는 어떻게 되나?'}]
# Answer: {
#   "answer": "고체에서 액체로 변할 때 엔트로피는 보통 증가합니다. 이는 분자의 자유도가 증가하고, 결국 엔트로피가 증가하기 때문입니다. 이러한 변화는 열역학적으로 필요한 과정으로, 액체의 엔트로피를 측정하면, 높은 값을 얻을 수 있습니다.",
#   "is_science": true
# }
#
# Test 111
# Question: [{'role': 'user', 'content': '사회로부터의 감정적인 지원이 어떤 형태로 나타날 수 있어?'}]
# Answer: {
#   "answer": "사회적 지원은 다양한 형태로 나타날 수 있습니다. 사회적 지원은 개인이나 집단에게 제공되는 지원으로, 이는 경제적, 정서적, 정보적, 심리적 등 다양한 형태로 이루어질 수 있습니다. 이러한 지원은 사람들의 사회적 성취를 촉진하고, 스트레스를 줄이며, 자아존중감을 높이는 데 도움을 줄 수 있습니다. 또한, 사회적 지원은 개인의 경제적, 사회적 이익을 보호하고, 스트레스를 줄이며, 사고력을 향상시키는 데 도움을 줄 수 있습니다. 사회적 지원은 사람들의 감정적 지지와 희망을 제공하며, 사회적 상호작용과 더불어 행복을 증진시킬 수 있는 중요한 요소입니다.",
#   "is_science": false
# }
#
# Test 112
# Question: [{'role': 'user', 'content': '석탄을 에너지원으로 사용할 때의 장단점이 뭐야?'}]
# Answer: {
#   "answer": "석탄을 에너지원으로 사용할 때의 장단점은 다양합니다. 이를테면, 석탄은 안정적으로 공급되는 에너지원으로서 경제적이고 안정적인 특성을 가지고 있습니다. 이에 더해, 석탄은 화력발전소에서의 사용 가능성을 보유하며, 환경 문제와 관련된 기술적인 문제를 해결할 수 있는 가능성도 있습니다. 그러나, 석탄의 에너지밀도와 발전 효율 등의 측면에서 고려해야 할 문제가 있습니다. 또한, 석탄의 사용으로 인한 환경오염과 기후변화에 대한 우려도 존재합니다. 이러한 장단점을 고려하여 석탄의 사용을 평가하고 결정하는 것이 중요합니다.",
#   "is_science": true
# }
#
# Test 113
# Question: [{'role': 'user', 'content': '탄소의 내부 구조를 알아낼 수 있는 방법은?'}]
# Answer: {
#   "answer": "탄소의 내부 구조를 알아내는 방법은 탄소 원자의 질량과 전자 구조를 통해 알 수 있습니다. 또한, 탄소의 결정 구조를 분석하고 다양한 실험을 통해 특성을 확인할 수 있습니다. 탄소의 내부 구조를 밝히는 것은 중요한 연구이며, 이를 통해 탄소의 활용 분야를 확장시킬 수 있습니다.",
#   "is_science": true
# }
#
# Test 114
# Question: [{'role': 'user', 'content': '연구의 과정과 결과를 잘 기록해야 하는 이유?'}]
# Answer: {
#   "answer": "연구의 과정과 결과를 잘 기록하는 이유는 연구자가 실험 결과를 정확하게 기록하고 데이터의 일관성을 유지하여 연구의 타당성을 보장하기 위해서입니다. 또한, 연구의 결과를 다른 연구자들과 공유하여 지식을 쌓고 새로운 발견을 이끌어내기 위해서도 중요합니다. 연구자들은 연구 결과를 분석하여 유의미한 결과를 도출하고, 이를 토대로 합리적인 결론을 도출하고 다른 연구자들과의 상호작용을 통해 지식을 공유합니다. 또한, 연구자들은 연구 결과를 검증하여 타당성을 보장하고, 데이터의 일관성을 유지하여 연구의 신뢰성을 높입니다.",
#   "is_science": true
# }
#
# Test 115
# Question: [{'role': 'user', 'content': '니가 대답을 잘해줘서 기분이 좋아!'}]
# Answer: {
#   "answer": "좋은 말씀 감사합니다. 제가 도와드릴 수 있는 과학 관련 질문이 있으면 언제든지 물어봐 주세요.",
#   "is_science": false
# }
#
# Test 116
# Question: [{'role': 'user', 'content': '밀물과 썰물의 강도에 영향을 주는 요소들에 대해 알려줘.'}]
# Answer: {
#   "answer": "밀물과 썰물의 강도에 영향을 주는 요소들은 조석, 달, 태양 등의 천문 현상과 바다 바닥의 지형, 지진 등의 지질 현상이 있습니다. 또한, 바다의 온도와 염분, 풍속의 변화, 해양 생물의 활동 등도 영향을 미칩니다. 이러한 요소들은 밀물과 썰물의 특성을 결정하는데 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 117
# Question: [{'role': 'user', 'content': '우울한데 신나는 얘기 좀 해줄래?'}]
# Answer: {
#   "answer": "죄송합니다. 현재 제가 신나는 이야기를 들려드릴 수 있는 정보가 부족합니다.",
#   "is_science": false
# }
#
# Test 118
# Question: [{'role': 'user', 'content': '이제 그만 얘기하자.'}]
# Answer: {
#   "answer": "죄송합니다, 과학 지식과는 무관한 내용으로 답변드릴 수 없습니다.",
#   "is_science": false
# }
#
# Test 119
# Question: [{'role': 'user', 'content': '유전 교차에서 복잡형질과 관련된 염색체 영역 식별 방법은?'}]
# Answer: {
#   "answer": "유전 교차에서 복잡형질과 관련된 염색체 영역을 식별하는 방법은 다양합니다. 염색체 맵핑을 통해 특정 염색체 영역을 식별할 수 있으며, 유전자의 특정 부분을 타겟팅하여 분석하는 방법도 있습니다. 또한 유전자의 특정 특성을 분석하기 위해 특정 유전자를 변이시키는 방법도 있습니다. 이러한 방법들은 유전체학적으로 발전하면서 다양한 방법들이 발전되고 있습니다.",
#   "is_science": true
# }
#
# Test 120
# Question: [{'role': 'user', 'content': '척추 동물이 영역을 가지고 다투는 이유는?'}]
# Answer: {
#   "answer": "척추 동물이 영역을 가지고 다투는 이유는 서로의 영역을 확보하기 위해서이며, 이는 생존과 번식을 위한 행동입니다. 또한, 영역 다툼은 척추 동물의 사회적인 상호작용과 자원 확보에 관련된 특성으로 이해될 수 있습니다. 이러한 행동은 생물학적, 행동학적 측면에서 이해되며, 척추 동물의 행동과 생태학적 특성에 영향을 미칩니다.",
#   "is_science": true
# }
#
# Test 121
# Question: [{'role': 'user', 'content': '어린 새들이 생존에서 살아남기 위해 진화한 기능들이 뭐가 있어?'}]
# Answer: {
#   "answer": "어린 새들이 생존에서 살아남기 위해 진화한 기능들로는 둥지 건설, 먹이 획득을 위한 다양한 기술, 상대적으로 빠른 속도와 민첩성을 활용한 피해 방어, 그리고 다른 새들과의 상호작용을 통해 생존 전략을 개발하는 등의 특성이 있습니다. 또한, 어린 새들의 성장 과정은 부모 새들과의 상호작용을 통해 선택이 이루어지며, 동물들의 성격 정보를 다른 세대로 전달하는 행동적인 방법으로 진화됩니다. 생존 기능은 개체들의 선택과 성공과 실패에 따라 다양한 변화를 겪으며 진화됩니다.",
#   "is_science": true
# }
#
# Test 122
# Question: [{'role': 'user', 'content': '입자가 같은 속력으로 원운동을 할 때 속도와 가속도 벡터 사이의 각도는 얼마인가?'}]
# Answer: {
#   "answer": "원운동을 하는 입자의 속도와 가속도 벡터 사이의 각도는 입자의 질량, 중력가속도, 마찰 계수 등에 따라 달라집니다. 따라서 구체적인 각도를 알기 위해서는 물체의 질량, 중력가속도, 마찰 계수 등을 알아야 합니다. 이에 대한 정보가 주어지지 않았기 때문에 각도를 구체적으로 알 수 없습니다.",
#   "is_science": true
# }
#
# Test 123
# Question: [{'role': 'user', 'content': '곤충 눈의 구조에 대해 설명해줘.'}]
# Answer: {
#   "answer": "곤충의 눈은 여러 가지 유형으로 구성되어 있습니다. 대부분의 곤충은 복합 눈을 가지고 있으며, 이는 여러 개의 눈 세포로 구성되어 시각 정보를 수집합니다. 또한, 단순 눈, 복합 눈, 홍체 눈, 안구 렌즈 등 다양한 유형의 눈을 가지고 있습니다. 또한, 곤충의 눈은 UV 광선을 감지할 수 있는 특성이 있습니다. 또한, 곤충의 눈은 복합적인 특성을 가지고 있어서, 다양한 시각 정보를 수집할 수 있습니다.",
#   "is_science": true
# }
#
# Test 124
# Question: [{'role': 'user', 'content': '너는 누구니?'}]
# Answer: {"answer": "저는 소프트웨어 기반의 도움 로봇 캐릭터입니다. 이 도움 로봇은 이전에 참여한 프로젝트와 관련된 정보를 활용하여 사용자의 질문에 답변하고, 새로운 지식을 학습하고, 이를 통해 사용자와 상호작용하고자 합니다. 이 도움 로봇의 참여는 이전 경험과 학습을 통해 사용자에게 유익한 정보를 제공하고, 사용자의 요구를 충족시키고자 합니다. 이 도움 로봇의 참여는 학습과 과학적인 지식을 통해 다른 사용자들과 정보를 공유하고, 이 사용자에게 유익한 정보를 제공하고자 합니다. 이 도움 로봇의 참여는 학습과 과학적인 지식을 통해 다른 사용자들과 정보를 공유하고, 이 사용자에게 유익한 정보를 제공하고자 합니다. 이 도움 로봇의 참여는 학습과 과학적인 지식을 통해 다른 사용자들과 정보를 공유하고, 이 사용자에게 유익한 정보를 제공하고자 합니다.", "is_science": false}
#
# Test 125
# Question: [{'role': 'user', 'content': '물고기는 어떻게 숨을 쉬는가?'}]
# Answer: {"answer": "물고기는 물 속에서 아가미를 이용하여 산소를 흡입하고 이산화탄소를 배출합니다. 아가미는 물고기의 호흡과 관련된 기관으로, 물 속에서 산소를 공급받아 이산화탄소를 배출합니다. 이와 같은 과정은 물고기가 호흡과 심장 기능을 통제하여 수분을 흡수하고 배출함으로써 이루어집니다. 수면 숨바꼭질은 물고기의 호흡과 관련된 특수한 기능으로, 물 속에서 산소를 흡입하고 이산화탄소를 배출합니다. 이러한 호흡 방식은 물고기가 아가미를 이용하여 산소를 공급받아 이산화탄소를 배출함으로써 이루어집니다. 또한, 수면 숨바꼭질은 물고기의 특수한 기능으로, 물 속에서 산소를 흡입하고 이산화탄소를 배출합니다. 이러한 호흡 방식은 물고기가 아가미를 이용하여 산소를 공급받아 이산화탄소를 배출함으로써 이루어집니다.", "is_science": true}
#
# Test 126
# Question: [{'role': 'user', 'content': '하천을 모델링하고 싶어.'}, {'role': 'assistant', 'content': '네 무엇을 도와 드릴까요?'}, {'role': 'user', 'content': '모델링할 때 신경써야 할 사항들이 뭐가 있어?'}]
# Answer:
# {
#   "answer": "하천 모델링을 할 때에는 수문학적인 요소뿐만 아니라 지질학적인 특성과 pH 등의 화학적 특성을 고려해야 합니다. 또한, 수문학적인 특성을 반영하여 유입량, 수질 요소, 지형 요소 등을 고려해야 하며, 홍수 예측 모델링을 위해 통계적인 방법과 데이터 분석을 사용해야 합니다. 또한, 하천 모델링은 홍수 예방을 위한 방법과 지형 변화를 고려하여야 합니다. 이러한 과정은 홍수 예방을 위한 효과적인 방법을 찾기 위한 것입니다.",
#   "is_science": true
# }
#
# Test 127
# Question: [{'role': 'user', 'content': '체질량 지수의 한계에 대해 알려줘.'}]
# Answer: {"answer": "체질량 지수(BMI)는 체중을 신장의 제곱으로 나눈 값으로, 일반적으로 몇 가지 범위로 분류됩니다. 이 범위 중 특정 범위 내에 BMI가 있으면 건강한 체중을 유지하고 있는 것으로 간주됩니다. 그러나 개인의 신체 구조와 특성을 고려해야 하며, BMI는 개인의 근육, 지방, 운동 등과는 관련이 없습니다. 이러한 이유로 건강 상태와 관련된 BMI의 한계를 고려해야 합니다. 또한, BMI는 건강한 체중을 나타내지만 개인의 신체 구조와 특성을 고려하지 못할 수 있으므로, 추가적인 신체 구조 및 건강 상태의 평가가 필요할 수 있습니다.", "is_science": true}
#
# Test 128
# Question: [{'role': 'user', 'content': '행성의 내부 구조를 이해하기 위한 방법은?'}]
# Answer: {
#   "answer": "행성의 내부 구조를 이해하기 위한 방법은 지질학적 조사와 지진파를 활용하여 지하 구조를 파악하고, 지구과학 및 지구과학자들과의 협력으로 지구 내부의 다양한 측면을 분석하고 해석하는 것입니다. 지질학은 과학자들이 모형을 만들어 실험하면서 움직임을 관찰하고 분석하여 지하의 구조와 지진, 그리고 지하 활동을 추적하는 데 사용됩니다. 이러한 방법은 지구의 다양한 측면을 보여주며, 지구의 특성과 실험에 대한 결과를 확인하고, 지구의 지질학과 지진학에 대한 정보를 제공합니다.",
#   "is_science": true
# }
#
# Test 129
# Question: [{'role': 'user', 'content': '식물의 잎이 다수 떨어지거나 구멍이 생기는 현상을 어떻게 해석해야 해?'}]
# Answer: {
#   "answer": "식물의 잎이 다수 떨어지거나 구멍이 생기는 현상은 다양한 원인으로 해석될 수 있습니다. 잎이 떨어지는 경우에는 식물이 자연적으로 대비하는 현상이거나, 병해충의 영향을 받고 있을 수 있습니다. 또한 잎에 구멍이 생기는 경우에는 곤충의 침입이나 질병에 의한 것일 수 있습니다. 이러한 현상은 각각의 상황에 따라 다양한 원인으로 해석될 수 있으며, 정확한 원인을 파악하기 위해서는 전문가의 도움이 필요합니다.",
#   "is_science": true
# }
#
# Test 130
# Question: [{'role': 'user', 'content': '일식이 발생하는 원리는?'}]
# Answer: {
#   "answer": "일식은 지구의 달과 태양의 상대적 위치에 따라 발생합니다. 달은 지구 주변을 도는데, 이때 달이 태양과 지구 사이에 위치하면 일식이 발생합니다. 이때 태양빛이 지구에 가려지므로 어둡게 보이는 현상이 일어납니다. 이러한 현상은 천문학적인 현상으로, 태양의 광선이 지구의 특정 지역에 가려지는 것이기 때문에 과학적인 현상입니다.",
#   "is_science": true
# }
#
# Test 131
# Question: [{'role': 'user', 'content': '광합성이 무엇인지 그리고 효과에 대해 알려줘.'}]
# Answer: {"answer": "광합성은 광에너지를 이용하여 이산화탄소와 물을 이용해 포도당과 산소를 생산하는 과정입니다. 광합성은 식물의 엽록체에서 일어나며, 이후에는 포도당과 산소로 변환되어 에너지를 생산합니다. 광합성은 태양 에너지를 이용하여 이루어지며, 이산화탄소를 흡수하여 산소를 발생시킵니다. 이러한 광합성은 식물의 생장과 대사의 핵심이며, 태양 에너지를 이용하지 않는 경우에는 산소가 생산되지 않습니다. 또한, 광합성은 태양 에너지를 이용하여 다른 이산화탄소를 흡수하는 과정과 산소를 발생시키는 과정으로 이루어집니다. 따라서, 광합성은 이산화탄소를 흡수하고 산소를 발생시키는 과정으로 이루어지며, 이로 인해 산소의 방출이 가능합니다.", "is_science": true}
#
# Test 132
# Question: [{'role': 'user', 'content': '리보오솜의 역할이 뭐야?'}]
# Answer: {
#   "answer": "리보오티드는 유전물질의 전달과 단백질 합성에 관여하는 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 133
# Question: [{'role': 'user', 'content': '오늘 너무 즐거웠어!'}]
# Answer: {
#   "answer": "좋은 하루를 보내셨군요! 즐거우셨다니 다행입니다.",
#   "is_science": false
# }
#
# Test 134
# Question: [{'role': 'user', 'content': '바람이 부는 이유는?'}]
# Answer: {
#   "answer": "바람이 부는 이유는 다양한 요인으로 인해 발생합니다. 바람은 대기의 기압 차이로 인해 발생하며, 이는 지구의 온난화로 인해 발생하는 온도 차, 대기의 습도, 압력, 햇볕 등의 요인에 의해 형성됩니다. 또한, 바람은 지형, 해수, 토지, 태양열 등의 영향을 받아 발생합니다. 따라서 바람은 지구의 다양한 환경과 기상 조건에 의해 형성되며, 이는 지구의 기후를 결정하고 지구 생태계를 조절하는 방법 중 하나입니다.",
#   "is_science": true
# }
#
# Test 135
# Question: [{'role': 'user', 'content': '메릴랜드의 대표적인 천연 자원은?'}]
# Answer: {
#   "answer": "메릴랜드의 대표적인 천연 자원은 바다와 해안 지역입니다. 바다는 우리의 생태의 중요한 원천이며, 연안 조사와 해양생물학 연구에 기여하고 다양한 생물종의 서식지로 활용됩니다. 또한, 메릴랜드의 대표적인 천연 자원으로는 해안 생물학 연구소와 해안 보호구역이 있습니다. 해안 보호구역은 메릴랜드의 생태를 보존하는 데 중요한 역할을 하며, 해안 생물학 연구소는 다양한 생물의 행동을 연구하여 해안 생태계를 보호하는 데 기여합니다.",
#   "is_science": true
# }
#
# Test 136
# Question: [{'role': 'user', 'content': '디엔에이 리가아제의 주요 기능이 뭐야?'}]
# Answer: {
#   "answer": "디엔에이 리가아제의 주요 기능은 VLDL 생성, ATP 생산, 지질 대사에 관여하는 것입니다.",
#   "is_science": true
# }
#
# Test 137
# Question: [{'role': 'user', 'content': '신체 변화의 정도나 속도가 사람들마다 다른 점으로부터 고려 할 수 있는 사항은?'}]
# Answer: {
#   "answer": "신체 변화의 정도나 속도가 사람들마다 다른 이유는 유전적 요소, 환경적 요인, 신체적 특성 등 여러 가지 요소에 의해 결정되기 때문입니다. 이러한 변화는 유전자와 환경 요인에 의해 결정되며, 이에 따라 변화의 정도와 속도가 다양하게 나타납니다. 또한, 변화의 정도와 속도는 유전자의 변이와 특성, 환경적 요인에 따라 결정되며, 이는 사람들에 따라 다양한 변화를 유발합니다. 이러한 변화는 유전적 특성과 환경적 요인을 고려하여 변화를 결정하는 것으로, 사람들의 선택에 따라 변화가 일어나는 것을 고려해야 합니다. 따라서, 변화의 정도나 속도는 유전적 특성, 환경적 요인 및 다양한 요소에 의해 결정되며, 이를 고려하여 선택을 하는 것이 중요합니다.",
#   "is_science": true
# }
#
# Test 138
# Question: [{'role': 'user', 'content': '머클-담고르 해시 함수를 사용한 MAC 보안 취약점은?'}]
# Answer: {
#   "answer": "머클-담고르 해시 함수를 사용한 MAC 보안 취약점은 H(k || m)을 이용한 MAC의 보안 취약점으로, 이 MAC의 해시값이 변조된 데이터를 인증하는 기능을 하므로 데이터를 변조하는 공격을 할 수 있다. 이로 인해 MAC는 보안 취약점을 가지고 있다.",
#   "is_science": true
# }
#
# Test 139
# Question: [{'role': 'user', 'content': '초코렛이 녹는 물리적인 원리는?'}]
# Answer: {
# ...
#   "is_science": true
# }
#
# Test 175
# Question: [{'role': 'user', 'content': '너 뭘 잘해?'}]
# Answer: {"answer": "제가 잘하는 것은 과학적인 지식을 바탕으로 사용자의 질문에 답변하는 것입니다.", "is_science": false}
#
# Test 176
# Question: [{'role': 'user', 'content': 'bridge inverter의 역할에 대해 알려줘?'}]
# Answer: {
#   "answer": "브릿지 인버터는 주로 교류 전원을 변환하여 다양한 용도로 사용되는데, 주로 태양광 발전 및 전력 변환 시스템에서 사용됩니다. 브릿지 인버터의 역할은 교류 전원을 생성하고, 직류 전원을 교류로 변환하는 것입니다. 이를 통해 전력 변환 및 전력 품질을 유지하는 역할을 합니다.",
#   "is_science": true
# }
#
# Test 177
# Question: [{'role': 'user', 'content': '캠핑의 선기능에 대해 알려줘.'}]
# Answer: {
#   "answer": "캠핑의 선기능은 주로 텐트나 캠핑카를 이용하여 자연 속에서 휴식을 취하고 즐거운 활동을 즐기는 것을 말합니다. 캠핑은 산림이나 호수 등 자연 속에서 즐기는 활동으로, 산책, 낚시, 등산 등 다양한 야외 활동을 포함합니다. 또한, 캠핑은 자연 속에서의 요리나 바베큐를 즐기는 등 다양한 경험을 포함합니다. 캠핑은 자연 속에서의 여가 활동으로, 휴식과 즐거움을 추구하는 활동입니다.",
#   "is_science": false
# }
#
# Test 178
# Question: [{'role': 'user', 'content': '지구 온난화 때문에 문제가 발생할 수 있는 지역은?'}]
# Answer: {
#   "answer": "지구 온난화로 인해 문제가 발생할 수 있는 지역은 지구의 여러 지점이 포함됩니다. 이로 인해 지구의 기후와 생태계가 변화하고, 극지방의 빙하와 빙하의 녹는 속도가 가속화되며, 해수면 상승과 함께 다양한 문제가 발생할 수 있습니다. 이로 인해 지구 온난화가 발생하고, 극지방의 빙하가 녹아 물이 상승하면서 다양한 문제가 발생할 수 있습니다. 이는 생태계에 영향을 미치고, 생태계의 변화, 기후 변화의 가속화, 수자원 부족 등 다양한 문제를 야기할 수 있습니다. 따라서 지구 온난화로 인한 문제는 전 세계적으로 발생할 수 있으며, 특히 극지방과 해안 지역의 문제가 심각할 수 있습니다.",
#   "is_science": true
# }
#
# Test 179
# Question: [{'role': 'user', 'content': '염소 원자에 빛을 방출했을 때 발생할 수 있는 시나리오에 대해 알려줘.'}]
# Answer:
# {
#   "answer": "염소 원자가 빛을 방출하는 시나리오에 대해 설명해드릴 수 있습니다. 염소 원자가 빛을 흡수하면 전자가 높은 에너지 상태로 이동하게 됩니다. 이후 전자는 낮은 에너지 상태로 돌아가면서 빛을 방출하게 됩니다. 이러한 과정이 빛을 방출하는 시나리오입니다.",
#   "is_science": true
# }
#
# Test 180
# Question: [{'role': 'user', 'content': '후두가 안정성을 유지할 수 있는 이유는?'}]
# Answer: {
#   "answer": "후두가 안정성을 유지하는 이유는 후두가 세포를 보호하고 산소 및 ATP를 공급하여 세포의 에너지 요구를 충족시키기 때문입니다. 또한, 후두는 세포의 산소 요구를 충족하고 독소 및 열을 제거하는 역할을 합니다. 이러한 기능들로 인해 후두는 세포의 안정성을 유지하며, 세포의 생존과 기능을 지원합니다.",
#   "is_science": true
# }
#
# Test 181
# Question: [{'role': 'user', 'content': '요새 너무 힘드네..'}]
# Answer: {
#   "answer": "힘든 시기를 견뎌내는 것은 어려운 일이지만, 이 시간을 통해 자신의 성장과 발전을 이루는 데 도움이 될 것입니다. 과학적 연구에 따르면, 스트레스를 관리하고 긍정적인 마음가짐을 유지하는 것이 중요합니다. 또한, 적절한 휴식과 식사, 규칙적인 운동을 통해 건강을 유지하는 것도 중요합니다. 또한, 주변 환경과 대인관계가 힘든 상황에서 우리의 마음을 안정시키고 행복을 찾는 데 도움이 될 것입니다. 이러한 방법을 통해 힘든 시기를 극복할 수 있습니다.",
#   "is_science": true
# }
#
# Test 182
# Question: [{'role': 'user', 'content': '연구실에서 무엇인지 파악이 안된 가루를 저울로 옮기는 좋은 방법은?'}]
# Answer: {
#   "answer": "연구실에서 무엇인지 파악이 안된 가루를 저울로 옮기는 좋은 방법은 연구실 측정용 저울을 사용하는 것입니다. 이 저울은 정밀한 측정을 위해 필요한 방법으로, 가루를 정확히 측정하고 옮기는 데 적합합니다. 또한, 정밀한 측정을 위해 가루를 옮길 때는 정전기 방지용 특수 소재의 용기를 사용하고, 가루를 옮길 때는 정전기 방지용 소지품을 착용해야 합니다. 이를 통해 정확한 측정과 안전한 작업을 할 수 있습니다.",
#   "is_science": true
# }
#
# Test 183
# Question: [{'role': 'user', 'content': '금성이 행성중 가장 밝게 보이는 이유는?'}]
# Answer: {
#   "answer": "금성은 태양계에서 가장 밝게 보이는 행성 중 하나입니다. 이는 금성의 대기가 이산화탄소와 유황으로 이루어져 있어서 태양 빛을 강하게 반사하고, 이를 이용하여 지구와 달을 비추는 효과를 만들어내기 때문입니다. 또한, 금성은 태양과 가장 가까운 곳에 있어서 밝게 보이는 효과도 있습니다. 이러한 이유로 금성은 밤하늘에서 가장 밝게 보이는 행성 중 하나입니다.",
#   "is_science": true
# }
#
# Test 184
# Question: [{'role': 'user', 'content': '자석의 세기에 가장 큰 영향을 주는 불순물은?'}]
# Answer: {
#   "answer": "자석의 세기에 가장 큰 영향을 주는 불순물은 온도입니다. 자석 세기는 온도가 높아지면 감소하며, 온도가 낮아지면 증가합니다. 또한, 온도가 낮아지면 자석의 지속력이 증가하는데, 이는 자석의 세기에 큰 영향을 미칩니다.",
#   "is_science": true
# }
#
# Test 185
# Question: [{'role': 'user', 'content': '솔레노이드가 뭐야?'}]
# Answer: {
#   "answer": "솔레노이드는 전류가 흐르는 동안에만 자기장을 유지하는 장치입니다. 이 장치는 전류가 흐르면 자기장이 발생하여, 그 자기장 안에서 화학 반응이 일어나는데, 이때 H+ 이온의 이동으로 ATP 생성을 도와줍니다. 이러한 과정은 ATP를 ATP로 인산화하는데 사용됩니다. 이와 같은 반응을 활성화 에너지로 인한 활성화 에너지를 통해 반응이 일어납니다. 솔레노이드 내부로 들어가는 H+ 이온의 이동은 수동 운반체로 이루어지며, 이러한 운반체는 수동 운반체로 인해 화학 반응의 pH가 변화하면서 화학 반응이 일어나게 됩니다.",
#   "is_science": true
# }
#
# Test 186
# Question: [{'role': 'user', 'content': '여러개의 약을 동시에 먹고 있어.'}, {'role': 'assistant', 'content': '네, 무엇을 도와드릴까요?'}, {'role': 'user', 'content': '이렇게 동시에 먹는 경우 어떤 문제가 생길수 있나?'}]
# Answer:
# {
#   "answer": "여러 약을 동시에 복용할 때는 상호작용이 발생하여 부작용을 일으킬 수 있습니다. 또한, 약물간의 충돌이나 상호작용으로 인해 효과가 감소하거나 증가할 수 있습니다. 따라서 의사나 약사와 상의 없이 약을 복용하는 것은 위험할 수 있습니다. 또한, 약물간의 상호작용은 각각의 약물에 따라 다양하게 나타날 수 있으므로 주의가 필요합니다.",
#   "is_science": true
# }
#
# Test 187
# Question: [{'role': 'user', 'content': '진폭 변조와 주파수 변조의 차이에 대해 알려줘.'}]
# Answer: {
#   "answer": "진폭 변조는 신호의 진폭을 변화시켜 정보를 전달하는 것이고, 주파수 변조는 신호의 주파수를 변화시켜 정보를 전달하는 것입니다.",
#   "is_science": true
# }
#
# Test 188
# Question: [{'role': 'user', 'content': '잠을 잘 잤을 때 이로운 점을 나열해줘.'}]
# Answer: {
#   "answer": "잠을 잘 잤을 때의 이로운 점으로는 면역력 증진, 정상적인 대사 및 호르몬 분비, 뇌 기능 향상, 스트레스 감소, 심혈관 질환 예방 등이 있습니다.",
#   "is_science": true
# }
#
# Test 189
# Question: [{'role': 'user', 'content': '음파는 어떻게 이동하는가?'}]
# Answer: {
#   "answer": "음파는 탄성 매질을 통해 전파됩니다. 이 탄성 매질을 통해 전파된 음파는 공기 등을 흔들어서 전파됩니다. 전파된 음파는 주변을 통과하면서 압축과 이완을 반복하며, 이로 인해 소리가 전파됩니다. 음파는 소리의 진폭을 결정하고, 소리의 주파수와 음압에도 영향을 미칩니다. 따라서 음파의 진폭과 주파수는 소리의 세기와 음의 높낮이에 영향을 미치며, 음파의 진폭과 주파수는 소리의 세기와 음의 높낮이를 결정합니다. 음파는 공간의 특성과 공간의 온도에 따라 속도가 달라질 수 있습니다. 또한, 탄성 매질의 밀도와 속도는 음파의 전파속도에 영향을 미치며, 음파의 전파속도는 탄성 매질의 밀도와 속도에 따라 달라집니다.",
#   "is_science": true
# }
#
# Test 190
# Question: [{'role': 'user', 'content': '테러로 인한 이슈와 대응책에 대해 알려줘.'}]
# Answer: {
#   "answer": "테러로 인한 이슈와 대응책에 대해 알려드릴 수 있습니다. 테러는 국가나 국제사회에서 발생하는 심각한 문제로, 이에 대한 대응은 다양한 측면에서 이루어져야 합니다. 특히 테러로 인한 피해를 최소화하고 예방하기 위해서는 국제사회 간의 협력과 정보 교류가 필수적입니다. 또한, 국내외에서의 대응책은 다양한 분야에서의 협력과 국민의 안전을 위한 다양한 정책이 필요합니다. 이러한 문제에 대한 대응은 국가와 시민 간의 협력이 필수적이며, 국가 안보와 국민 안전을 위해 다양한 노력이 필요합니다.",
#   "is_science": false
# }
#
# Test 191
# Question: [{'role': 'user', 'content': '바닥의 마찰이 없는 곳에서 두 사람이 서로 밀어낼때 무게가 덜 나가는 사람이 더 나가는 사람이 더 빨리 움직이게 되는 이유는?'}]
# Answer: {
#   "answer": "바닥의 마찰이 없는 곳에서 두 사람이 서로 밀어낼 때 무게가 덜 나가는 사람이 더 나가는 사람이 더 빨리 움직이는 이유는 물리적 법칙에 따라 발생합니다. 두 사람의 무게와 마찰력 등의 요소를 고려하여 설명할 수 있습니다. 이러한 현상은 물리학적인 이론에 근거하여 설명될 수 있습니다.",
#   "is_science": true
# }
#
# Test 192
# Question: [{'role': 'user', 'content': '세포간에 갭결합이 생기는 것을 규명한 실험에 대해 알려줘.'}]
# Answer: {
#   "answer": "세포간에 갭결합이 생기는 것을 규명한 실험은 세포 내의 이온을 추적하기 위한 실험입니다. 이 실험에서는 인산염을 이용하여 세포 내부의 화학적 활동을 추적하고, 이를 통해 세포들이 전기적으로 연결되어 상호작용하고 통신하는 것을 확인했습니다.",
#   "is_science": true
# }
#
# Test 193
# Question: [{'role': 'user', 'content': '행성의 크기와 화산이 얼마나 자주 폭발하는지가 관련이 있어?'}]
# Answer: {
#   "answer": "행성의 크기와 화산이 얼마나 자주 폭발하는지는 밀접한 관련이 있습니다. 행성의 크기는 화산 폭발 빈도에 영향을 미치며, 더 큰 행성은 더 강력한 화산 폭발을 일으킬 가능성이 있습니다. 또한 화산 폭발은 지구과학적인 측면에서 볼 때 매우 중요한 현상으로, 화산 폭발의 결과로 인한 지질학적인 변화와 지구과학적인 연구의 결과를 통해 많은 정보를 얻을 수 있습니다. 따라서 화산 폭발을 추적하고 연구함으로써 지구과학적인 통찰을 얻을 수 있습니다.",
#   "is_science": true
# }
#
# Test 194
# Question: [{'role': 'user', 'content': '우성인 빨간색 꽃과 열성인 흰꽃을 교배한다고 하자.'}, {'role': 'assistant', 'content': '네 말씀하세요.'}, {'role': 'user', 'content': '두 꽃을 교배한 후 다음세대 꽃의 색깔은 어떻게 되나?'}]
# Answer: {
#   "answer": "두 꽃을 교배한 후 다음 세대 꽃의 색깔은 모두 붉은색일 것입니다. 이는 빨간색 꽃이 유전적으로 우세한 특성을 가지고 있고, 흰색 꽃이 약세인 특성을 가지고 있기 때문입니다. 따라서, 다음 세대에서는 빨간색 꽃이 우세하게 나타날 것입니다.",
#   "is_science": true
# }
#
# Test 195
# Question: [{'role': 'user', 'content': '기계가 연료를 태울 때 어떤 형태로 에너지가 낭비되는가?'}]
# Answer: {
#   "answer": "기계가 연료를 태울 때 에너지는 열과 운동 에너지로 낭비됩니다. 연료를 태우면 열과 압력이 발생하여 움직이는 부품을 움직이거나 전기를 생산합니다. 이러한 과정에서 일부 에너지는 유용한 작업으로 전환되지만, 대부분의 에너지는 열로 낭비됩니다. 이러한 열 손실을 최소화하기 위해 많은 현대 기술은 효율적인 열변환 및 열 손실을 줄이는 방법을 개발하고 있습니다.",
#   "is_science": true
# }
#
# Test 196
# Question: [{'role': 'user', 'content': '동물들이 종종 집단으로 이주하는 경우가 발생하더라구?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '이렇게 집단으로 이주하게 되는 계기는 어떤 것들이 있어?'}]
# Answer:
# {
#   "answer": "동물들이 집단으로 이주하는 계기는 여러 가지가 있습니다. 예를 들어, 사회적 이유나 생태적 이유로 인해 집단을 이루어 이주하는 경우가 있습니다. 또한 동물들의 이주는 생존에 필요한 자원을 찾거나 특정 지역의 환경에 적응하기 위한 이유로 발생하기도 합니다. 이러한 이주는 종단위의 생태계와 생물다양성을 유지하고, 특정 지역의 생태적인 이점을 활용하는 데 도움을 줄 수 있습니다.",
#   "is_science": true
# }
#
# Test 197
# Question: [{'role': 'user', 'content': '남미 여러 나라들이 중고등학교 취학률을 높이기 위해 어떤 일들을 하고 있어?'}]
# Answer: {
#   "answer": "남미 여러 나라들은 중고등학교 취학률을 높이기 위해 다양한 노력을 기울이고 있습니다. 이들은 교육에 대한 투자를 늘리고, 학생들의 교육 환경을 개선하며, 교육 시설을 확충하는 등의 다양한 방법을 사용하고 있습니다. 또한, 국제적인 협력을 통해 교육의 질을 향상시키고, 학생들의 교육 영향력을 증진시키는 노력을 기울이고 있습니다. 이러한 노력들은 국가별로 다양하며, 국제적인 협력을 통해 교육의 질을 향상시키는 방향으로 진행되고 있습니다.",
#   "is_science": false
# }
#
# Test 198
# Question: [{'role': 'user', 'content': '네트웍 계층 중 IP에 대해 설명해줘.'}]
# Answer: {
#   "answer": "네트워크 계층에서 IP는 인터넷 프로토콜을 나타냅니다. IP 프로토콜은 SNMP를 이용하여 네트워크의 정보를 수집하고 관리하는 데 사용됩니다. 또한 IP 프로토콜은 인터넷에서 데이터를 전송하고 수신하는 데 사용되는 프로토콜입니다. IP 프로토콜을 사용하는 사용자는 SNMP 프로토콜을 이용하여 네트워크의 정보를 확인하고 분석할 수 있습니다. 이를 통해 네트워크 관리자는 네트워크 상의 문제를 식별하고 해결할 수 있습니다. IP 프로토콜은 데이터의 출발지와 목적지 IP 주소를 이용하여 데이터를 전송하고, 데이터의 유효성과 무결성을 확인하며 변조를 검출하고 복구하는 기능도 포함하고 있습니다. 따라서 IP 프로토콜은 네트워크의 연결성과 안전성을 보장하는 기능을 수행합니다.",
#   "is_science": true
# }
#
# Test 199
# Question: [{'role': 'user', 'content': '같은 독감에 다시 걸리면 빨리 회복이 되더라구?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 이유가 뭐야?'}]
# Answer:
# {
#   "answer": "같은 독감에 다시 걸리면 빨리 회복되지 않습니다. 이는 독감에 걸린 후에 면역체계가 형성되어 다음에 같은 독감에 걸릴 때 빠르게 회복되는 것이 아니기 때문입니다. 또한, MMR 백신은 국제 백신연구원들에 의해 매우 효과적이고 안전한 백신으로 인정받고 있습니다. MMR 백신은 홍역, 볼거리, 풍진을 예방하는 백신으로 사용되며, 이는 면역체계를 강화하여 독감에 대한 면역력을 향상시키는 역할을 합니다. 독감 백신은 일반적으로 매년 재접종해야 하며, 특히 고령자, 어린이, 임신부 등에게 권장됩니다. 따라서, 독감에 다시 걸릴 경우 빠르게 회복되지 않으며, 예방을 위해 독감 예방접종을 꾸준히 받는 것이 중요합니다.",
#   "is_science": true
# }
#
# Test 200
# Question: [{'role': 'user', 'content': '시소에서 균형을 잡기 위해 양쪽에서 가하는 힘의 크기에 대해 설명해줘.'}]
# Answer: {
#   "answer": "시소에서 균형을 잡기 위해 양쪽에서 가하는 힘의 크기는 두 힘의 크기와 방향이 서로 반대로 작용해야 합니다. 시소에서 양쪽으로 가해지는 힘은 서로 상쇄되어야 하며, 균형 상태에서는 두 힘이 크기와 방향이 서로 반대로 작용하여 결과적으로 균형을 유지할 수 있습니다. 힘은 두 방향과 크기의 상충으로 인해 발생하며, 균형을 유지하기 위해서는 두 힘의 크기와 방향이 상쇄되어야 합니다.",
#   "is_science": true
# }
#
# Test 201
# Question: [{'role': 'user', 'content': '두개의 소스로부터 발생한 사건중 어떤 쪽에서 기인한 것인지 확률 계산하는 예시 알려줘.'}]
# Answer: {
#   "answer": "주어진 정보로는 확률을 계산할 수 없습니다.",
#   "is_science": false
# }
#
# Test 202
# Question: [{'role': 'user', 'content': '곤충의 생태를 관찰할 때 사용할 수 있는 방법은?'}]
# Answer: {
#   "answer": "곤충의 생태를 관찰할 때 사용할 수 있는 방법은 다양합니다. 주로 사용되는 방법으로는 채집 및 분류, 표본 제작, 수집 및 분석, 수목 및 환경 조사 등이 있습니다. 이러한 방법들을 활용하여 곤충의 서식지, 행동 및 생태학적 특성을 파악하고, 보다 체계적으로 연구할 수 있습니다. 또한, 수집된 데이터를 분석하여 곤충의 생태학적 특성 및 환경의 상호작용을 이해하는 데 도움이 됩니다. 이러한 방법들은 곤충학자들에 의해 사용되며, 곤충의 서식지를 발견하고, 환경 조사를 통해 생태학적 정보를 수집하고, 분류학적 연구를 통해 곤충의 특성을 파악하는 등의 작업을 수행합니다.",
#   "is_science": true
# }
#
# Test 203
# Question: [{'role': 'user', 'content': '작은 기체 하나의 질량을 어떻게 구할 수 있어?'}]
# Answer: {
#   "answer": "작은 기체의 질량을 구하는 방법은 그 기체를 포함하는 용기의 질량을 먼저 측정한 후, 용기 안에 기체와 같은 양의 다른 물질을 넣어서 측정하는 방법으로 질량을 구할 수 있습니다. 이때, 기체의 질량은 SI 단위인 킬로그램(kg)으로 표시되며, 기체의 질량은 변하지 않습니다. 따라서, 기체의 질량은 기체에 있는 다른 물질의 질량을 빼서 구할 수 있습니다.",
#   "is_science": true
# }
#
# Test 204
# Question: [{'role': 'user', 'content': '평형분극비율이 뭐야?'}]
# Answer: {
#   "answer": "평형분극비율은 물질이 용액과 고체 상태 사이에서 평형을 이룰 때 용액과 고체 상태의 농도 비율을 말합니다. 이는 화학 반응에서 생성되는 고체의 농도를 나타내는 중요한 지표입니다.",
#   "is_science": true
# }
#
# Test 205
# Question: [{'role': 'user', 'content': '근친간의 성행위가 금해지는 이유는?'}]
# Answer: {
#   "answer": "근친간의 성행위가 금지되는 이유는 다양합니다. 근친간의 성행위는 유전적 이상을 유발할 수 있으며, 이는 사회적, 법적으로 문제가 될 수 있습니다. 또한 근친간의 성행위는 윤리적, 도덕적으로 문제가 되는데, 이는 사회적, 법적으로 금지되고 있습니다. 따라서 근친간의 성행위는 일반적으로 금지되며, 이는 과학적, 윤리적인 이유로 인해 금지되고 있습니다.",
#   "is_science": true
# }
#
# Test 206
# Question: [{'role': 'user', 'content': '노인들이 종종 후각 능력을 잃게 되는 경우가 있더라구?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '이렇게 냄새를 못맡게 되면 어떤 결과로 이어지지?'}]
# Answer:
# {
#   "answer": "후각 능력을 잃게 되면 먹는 즐거움이 감소하고 영양 섭취가 부족해질 수 있습니다. 또한, 안전 문제와 심리적인 영향도 있을 수 있습니다. 후각 능력을 잃은 사람은 음식의 맛을 느끼지 못하고, 식사 시간에 대한 만족감이 감소할 수 있습니다. 또한, 후각 능력이 감소하면 음식의 신선도나 조리 시간에 대한 인식이 어려워질 수 있습니다. 후각 능력을 잃은 사람은 음식의 맛을 느끼지 못하고, 식사 시간에 대한 만족감이 감소할 수 있습니다. 또한, 후각 능력이 감소하면 음식의 신선도나 조리 시간에 대한 인식이 어려워질 수 있습니다.",
#   "is_science": true
# }
#
# Test 207
# Question: [{'role': 'user', 'content': '하늘이 파란 이유는?'}]
# Answer: {
#   "answer": "하늘이 파란 이유는, 태양빛이 대기 속에서 흩어지면 파란빛의 파장이 더 많이 흩어져서 파란색으로 보이기 때문입니다. 또한, 북극성이 하늘에서 더 밝게 보이는데, 이는 북극성이 북극 방향으로 향하는 성직의 특성 때문입니다. 또한, 천체의 온도 차이로 인해 파란색을 띄는 것도 있습니다.",
#   "is_science": true
# }
#
# Test 208
# Question: [{'role': 'user', 'content': '짚신 벌레의 번식은 어떻게 이루어지나?'}]
# Answer: {
#   "answer": "짚신 벌레의 번식은 주로 알을 낳는 방식으로 이루어집니다. 알을 낳은 뒤에는 부화하여 애벌레가 태어나며, 이후에는 번데기와 어른 벌레로 성장합니다.",
#   "is_science": true
# }
#
# Test 209
# Question: [{'role': 'user', 'content': '온난 전선이 발생하면 이후 날씨는 어떻게 되나?'}]
# Answer: {
#   "answer": "온난 전선이 발생하면 이후 날씨는 다양한 영향을 받을 수 있습니다. 온난 전선으로 인해 기온이 상승하고 습기가 증가하면서 강한 비와 폭우가 발생할 수 있습니다. 또한, 온난 전선이 지나가면서 기온이 급격히 변화하여 강한 바람이 불거나 천둥번개가 발생할 수 있습니다. 이러한 영향은 지역에 따라 다를 수 있습니다. 따라서 온난 전선이 지나가면서 발생하는 날씨 변화에 대해 정확히 예측하기 어렵습니다.",
#   "is_science": true
# }
#
# Test 210
# Question: [{'role': 'user', 'content': '전기가 흐르는 회로에서 전선과 전구의 전류는 동일한가?'}]
# Answer: {
#   "answer": "전기가 흐르는 회로에서 전선과 전구의 전류는 동일합니다. 이는 전선을 통해 흐르는 전류가 전구를 통해 흐르는 전류와 동일하기 때문입니다. 전기가 흐르는 회로에서는 전류의 분배가 발생하지 않고 전선을 통해 흐르는 전류가 전구를 통해 흐르는 것과 동일합니다.",
#   "is_science": true
# }
#
# Test 211
# Question: [{'role': 'user', 'content': '플로리다에서 친환경 에너지를 가장 효과적으로 활용할 수 있는 시기는?'}]
# Answer: {
#   "answer": "플로리다에서는 6월이 친환경 에너지를 가장 효과적으로 활용할 수 있는 시기입니다. 6월은 플로리다의 날씨가 매우 덥고 벼랑끝 시기로 인해 풍력에너지를 이용할 수 있는 조건이 좋습니다. 또한, 플로리다에서는 6월에 가장 높은 인구 밀도 지역에서 300개 이상의 인공 어족도를 설치하는 등 친환경 에너지를 촉진하는 노력이 있습니다. 또한, 1926년에는 플로리다 주에서 태양열을 이용한 발전소를 운영하기 시작하여 친환경 에너지를 적극적으로 추구하고 있습니다.",
#   "is_science": true
# }
#
# Test 212
# Question: [{'role': 'user', 'content': '농장이 해안가 환경에 나쁜 영향을 미칠 수 있는 원인이 뭐가 있어?'}]
# Answer:
# {
#   "answer": "농장이 해안가 환경에 나쁜 영향을 미칠 수 있는 원인으로는 농업 폐기물과 농업 화학물질이 해안 생태계에 부정적인 영향을 미칠 수 있습니다. 이러한 화학물질은 해양 생물에 해로운 영향을 미치며, 해안 생태계의 균형을 깨뜨릴 수 있습니다. 또한, 농장에서 발생하는 폐기물은 해양 오염과 해안 생태계의 파괴를 초래할 수 있습니다. 이러한 문제를 해결하기 위해서는 농업 폐기물을 적절히 처리하고, 농업 화학물질의 사용을 규제하며, 해안 생태계를 보호하기 위한 다양한 정책을 시행해야 합니다.",
#   "is_science": true
# }
#
# Test 213
# Question: [{'role': 'user', 'content': '자성을 띄지 않는 유전체 내부에서 빛의 속도는 어떻게 되나?'}]
# Answer: {"answer": "유전체 내부에서 빛의 속도는 4.0 x 10^8 m/s입니다. 이는 유전체 내부의 특성에 따라 변할 수 있지만, 일반적으로 빛의 속도는 이와 같습니다. 따라서 유전체 내부에서 빛의 속도는 자성을 띄지 않는 유전체의 특성에 의해 결정되며, 일반적으로 빛의 속도와는 다를 수 있습니다.", "is_science": true}
#
# Test 214
# Question: [{'role': 'user', 'content': '자연보호구역이 필요한 이유는?'}]
# Answer: {
#   "answer": "자연보호구역은 생태계의 안정을 유지하고, 생물다양성을 보전하며 자연환경을 보호하기 위한 공간으로, 생태계의 복원과 생태계의 유지를 위해 중요한 역할을 합니다. 또한 자연보호구역은 풍요로운 지역을 보존하고 생태계를 회복시키는 데 중요한 요소입니다. 환경파괴적인 영향을 받는 지역을 보호하고, 특별한 생물종을 보호하는 데에도 중요한 역할을 합니다. 따라서 자연보호구역은 사람에게 매우 중요하고 유익한 환경입니다.",
#   "is_science": true
# }
#
# Test 215
# Question: [{'role': 'user', 'content': '정상파가 뭐야?'}]
# Answer: {"answer": "정상파는 시간에 따라 진폭이 변하지 않고 일정한 주기로 진동하는 파형을 말합니다. 일반적으로 정상파의 주파수는 100 mV입니다. 또한 정상파의 주기 중에 다른 정상을 포함하면 변화가 없습니다. 따라서 두 주기는 상호영향을 주지 않습니다. 또한 두 주기는 공명진동으로 특정값을 넘어가면, 두 주기가 상호영향을 주게 됩니다.", "is_science": true}
#
# Test 216
# Question: [{'role': 'user', 'content': '공에 힘이 주어졌을 때 공이 어떻게 움직이는지 과학적으로 설명해줘.'}]
# Answer: {
#   "answer": "공에 힘이 주어지면 공은 그 방향으로 움직입니다. 이에 따라 힘이 공의 내부에서 발생한 동력과 상충되며 공은 가속도를 얻게 됩니다. 가속도는 공이 그 방향으로 움직이는 데 필요한 힘의 크기를 나타냅니다. 따라서, 공이 힘이 가해지면 가속도를 얻어 공의 운동을 설명할 수 있습니다.",
#   "is_science": true
# }
#
# Test 217
# Question: [{'role': 'user', 'content': '동물들이 피부나 털의 색깔을 통해 생존의 확률을 높이는 방식에 대해 설명해줘.'}]
# Answer: {
#   "answer": "동물들은 피부나 털의 색깔을 통해 생존의 확률을 높이는 방식이 있습니다. 이는 주로 우리의 환경에 적응하기 위한 특성으로, 색깔은 생존에 영향을 미칠 수 있습니다. 피부나 털의 색깔은 주로 우리의 환경에 적응하기 위한 특성으로, 색깔은 생존에 영향을 미칠 수 있습니다. 색깔은 주로 우리의 환경에 적응하기 위한 특성으로, 색깔은 생존에 영향을 미칠 수 있습니다.",
#   "is_science": true
# }
#
# Test 218
# Question: [{'role': 'user', 'content': '메탄과 산소의 화학 반응에 대해 알려줘.'}]
# Answer: {
#   "answer": "메탄과 산소의 화학 반응은 메탄과 산소가 반응하여 이산화탄소와 물이 생성되는 화학 반응입니다. 메탄은 탄소 원자와 수소 두 개로 구성된 화합물로, 화염에서 매우 뜨거운 상태에서 반응하여 이산화탄소와 수소를 생성합니다. 이산화탄소는 주로 대기 중에서 이산화탄소 농도, 이산화탄소 배출 및 이산화탄소 흡수와 관련된 환경 및 기후 변화와 관련된 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 219
# Question: [{'role': 'user', 'content': '복숭아 키우는 노하우좀?'}]
# Answer: {
#   "answer": "복숭아를 키우는 노하우에는 복숭아의 재배 및 수확 방법, 복숭아 품종의 선택, 복숭아의 병해충 관리 등이 포함됩니다. 복숭아의 재배는 햇볕이 잘 드는 곳에 심어주고, 적정한 물과 비료를 공급하여 식물이 성장할 수 있도록 해야 합니다. 복숭아의 병해충은 복숭아나무 주변을 청소하고, 병해충을 방지하기 위해 살충제를 사용하며, 내부에는 과수원을 깨끗이 유지하고 병든 열매를 제거해야 합니다. 복숭아의 수확 방법은 다른 복숭아를 향한 특정 방법을 선택하여 복숭아를 수확하고, 복숭아의 품종과 수확량을 고려하여 적절한 방법을 선택해야 합니다. 이러한 방법을 통해 복숭아를 키우는 노하우를 습득할 수 있습니다.",
#   "is_science": false
# }

# %%
new_dl = list()

with open('sample_submission_4_final.csv', 'r') as f :
    for line in f:
        except_is_science_dict = dict()
        
        j = json.loads(line)        # dict
        print(j.keys())
        
        except_is_science_dict = {
            "eval_id": j['eval_id'],
            "standalone_query": j['standalone_query'],
            "topk": j['topk'] if j['is_science'] else [],
            "answer": j['answer'],
            "references": j['references'] if j['is_science'] else []
        }
        
        new_dl.append(except_is_science_dict)
        
        
print(len(new_dl))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 3
#       1 new_dl = list()
# ----> 3 with open('sample_submission_4_final.csv', 'r') as f :
#       4     for line in f:
#       5         except_is_science_dict = dict()
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample_submission_4_final.csv'

# %%
import json

with open("sample_submission_4_final_without.csv", "w") as of:
    for dl in new_dl:
        of.write(f'{json.dumps(dl, ensure_ascii=False)}\n')

# %%
# !wc -l sample_submission.csv
# Out:
# 6 sample_submission.csv

# %% [markdown]
# #Reference

# %% [markdown]
# ## Required Package
#
# openai==1.7.2 <br>
# elasticsearch==8.8.0 <br>
# sentence_transformers==2.2.2 <br>

# %% [markdown]
# ## 콘텐츠 라이선스
#
# 저작권 : <font color='blue'> <b> ©2023 by Upstage X fastcampus Co., Ltd. All rights reserved.</font></b>
#
# <font color='red'><b>WARNING</font> : 본 교육 콘텐츠의 지식재산권은 업스테이지 및 패스트캠퍼스에 귀속됩니다. 본 콘텐츠를 어떠한 경로로든 외부로 유출 및 수정하는 행위를 엄격히 금합니다. </b>
