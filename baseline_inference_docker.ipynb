# %% [markdown]
# # Information Retrieval Baseline Code

# %% [markdown]
# ## 대회 설명
# Information Retrieval 경진대회에 오신 여러분 환영합니다! 🎉 <br>
# 본 대회에서는 과학 상식에 대한 멀터턴 질문에 대하여 RAG 기술을 활용하여 질문에 적합한 레퍼런스를 추출하고 이를 토대로 답변을 생성하는 어플리케이션을 구현해 봅니다. <br>
# LLM은 GPT-3.5 버전을 이용하고, 레퍼런스 추출을 위한 검색엔진 구축은 Elasticsearch를 활용합니다.

# %% [markdown]
# ## 데이터셋 준비
# * 질문에 대한 레퍼런스로 활용될 수 있는 4272개의 과학 상식을 다루는 문서
#  * Open Ko LLM Leaderboard에 들어가는 Ko-H4 데이터 중 MMLU, ARC 데이터를 기반으로 생성
#  * Question과 answer를 paraphrase (question과 answer를 토대로 GPT-4 활용하여 document 생성)
#  * 예시)
#   ```
#   수소, 산소, 질소 가스의 혼합물에서 평균 속도가 가장 빠른 분자는 수소입니다
# . 수소 분자는 가장 가볍고 작은 원자로 구성되어 있기 때문에 다른 분자들보다 더 빠르게 움직>입니다. 이러한 이유로 수소 분자는 주어진 온도에서 가장 빠른 평균 속도를 가지고 있습니다. >수소 분자는 화학 반응에서도 활발하게 참여하며, 수소 연료로도 널리 사용됩니다. 따라서 수소 분자는 주어진 온도에서 평균 속도가 가장 빠른 분자입니다.
#   ```
#
# * 가상의 질문 220개
#  * 과학 상식 질문 또는 일상 대화 메시지를 수동으로 생성
#  * 220개 중 20개는 멀티턴 대화 형태의 질문, 20개는 일상 칫챗 대화
#   * 예시)
#   ```
# {"eval_id": 0, "msg": [{"role": "user", "content": "나무의 분류에 대해 조사해 보기 위한 방
# 법은?"}], "refs": ["c63b9e3a-716f-423a-9c9b-0bcaa1b9f35d"]}
# {"eval_id": 1, "msg": [{"role": "user", "content": "각 나라에서의 공교육 지출 현황에 대해 알려줘."}], "refs": ["79c93deb-fe60-4c81-8d51-cb7400a0a156"]}
# {"eval_id": 2, "msg": [{"role": "user", "content": "기억 상실증 걸리면 너무 무섭겠다."}, {"role": "assistant", "content": "네 맞습니다."}, {"role": "user", "content": "어떤 원인 때
# 문에 발생하는지 궁금해."}], "refs": ["25de4ffd-cee4-4f27-907e-fd6b802c6ede"]}
#   ```

# %%
 # 색인 대상 문서 및 평가 데이터 다운로드
 # !wget https://aistages-api-public-prod.s3.amazonaws.com/app/Competitions/000291/data/data.tar.gz
 # !tar -xzvf data.tar.gz
# Out:
# --2024-02-14 05:15:10--  https://aistages-api-public-prod.s3.amazonaws.com/app/Competitions/000291/data/data.tar.gz
# Resolving aistages-api-public-prod.s3.amazonaws.com (aistages-api-public-prod.s3.amazonaws.com)... 52.219.206.95, 52.219.202.27, 52.219.56.70, ...
# Connecting to aistages-api-public-prod.s3.amazonaws.com (aistages-api-public-prod.s3.amazonaws.com)|52.219.206.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1068264 (1.0M) [binary/octet-stream]
# Saving to: ‘data.tar.gz’
#
# data.tar.gz         100%[===================>]   1.02M  1.49MB/s    in 0.7s
#
# 2024-02-14 05:15:12 (1.49 MB/s) - ‘data.tar.gz’ saved [1068264/1068264]
#
# data/
# data/eval.jsonl
# data/documents.jsonl

# %% [markdown]
# ## 환경 설정
# 검색엔진을 위한 Elasitcsearch, 임베딩 생성을 위한 sentence transformers, LLM 사용을 위한 openai client 설치가 필요합니다.

# %%
# Elasticsearch python 패키지 설치
# !pip install elasticsearch==8.8.0

# OpenAI Python 패키지 설치
# !pip install openai==1.7.2

# 임베딩 생성을 위한 벡터 인코더 설치
# !pip install sentence-transformers==2.2.2
# Out:
# Collecting elasticsearch==8.8.0
#   Downloading elasticsearch-8.8.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting elastic-transport<9,>=8 (from elasticsearch==8.8.0)
#   Downloading elastic_transport-8.13.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /home/demyank/anaconda3/lib/python3.11/site-packages (from elastic-transport<9,>=8->elasticsearch==8.8.0) (1.26.18)
# Requirement already satisfied: certifi in /home/demyank/anaconda3/lib/python3.11/site-packages (from elastic-transport<9,>=8->elasticsearch==8.8.0) (2024.2.2)
# Downloading elasticsearch-8.8.0-py3-none-any.whl (393 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.8/393.8 kB 4.4 MB/s eta 0:00:00a 0:00:01m
# Downloading elastic_transport-8.13.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: elastic-transport, elasticsearch
# Successfully installed elastic-transport-8.13.0 elasticsearch-8.8.0
# Collecting openai==1.7.2
#   Downloading openai-1.7.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (1.8.0)
# Collecting httpx<1,>=0.23.0 (from openai==1.7.2)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (1.10.12)
# Requirement already satisfied: sniffio in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (1.3.0)
# Requirement already satisfied: tqdm>4 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /home/demyank/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai==1.7.2) (3.4)
# Requirement already satisfied: certifi in /home/demyank/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai==1.7.2) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai==1.7.2)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.7.2)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading openai-1.7.2-py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.1/212.1 kB 5.6 MB/s eta 0:00:00ta 0:00:01
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.7 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.7.2
# Collecting sentence-transformers==2.2.2
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (4.38.2)
# Requirement already satisfied: tqdm in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (2.2.1)
# Requirement already satisfied: torchvision in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (0.17.1)
# Requirement already satisfied: numpy in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (1.26.4)
# Requirement already satisfied: scikit-learn in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (1.2.2)
# Requirement already satisfied: scipy in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (1.11.4)
# Requirement already satisfied: nltk in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (3.8.1)
# Collecting sentencepiece (from sentence-transformers==2.2.2)
#   Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (0.21.4)
# Requirement already satisfied: filelock in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2023.10.0)
# Requirement already satisfied: requests in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.28.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (23.1)
# Requirement already satisfied: sympy in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (1.12)
# Requirement already satisfied: networkx in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.1)
# Requirement already satisfied: jinja2 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/demyank/anaconda3/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->sentence-transformers==2.2.2) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /home/demyank/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/demyank/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.4.2)
# Requirement already satisfied: click in /home/demyank/anaconda3/lib/python3.11/site-packages (from nltk->sentence-transformers==2.2.2) (8.1.7)
# Requirement already satisfied: joblib in /home/demyank/anaconda3/lib/python3.11/site-packages (from nltk->sentence-transformers==2.2.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence-transformers==2.2.2) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torchvision->sentence-transformers==2.2.2) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.6.0->sentence-transformers==2.2.2) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.6.0->sentence-transformers==2.2.2) (1.3.0)
# Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.6 MB/s eta 0:00:0000:0100:01m
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125937 sha256=a6b7e361d9a6d35feee368a7559085ee84b2d0243431cf89f0e983e370814e04
#   Stored in directory: /home/demyank/.cache/pip/wheels/ff/27/bf/ffba8b318b02d7f691a57084ee154e26ed24d012b0c7805881
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, sentence-transformers
# Successfully installed sentence-transformers-2.2.2 sentencepiece-0.2.0

# %% [markdown]
# ## 검색엔진 준비 - Elasticsearch

# %%
# 데몬이 구동되었는지 확인 (세개의 daemon process가 있어야 함)
# !ps -ef | grep elasticsearch
# Out:
# demyank  69360 68765  0 11:59 pts/11   00:00:00 /usr/bin/zsh -c ps -ef | grep elasticsearch
# demyank  69362 69360  0 11:59 pts/11   00:00:00 grep elasticsearch

# %%
import os
import torch
from elasticsearch import Elasticsearch, helpers
from peft import LoraConfig, AutoPeftModelForCausalLM, PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, BitsAndBytesConfig, AutoTokenizer, TrainingArguments, pipeline, DataCollatorForSeq2Seq

# %%
# Elasticsearch credentials (adjust these as per your Elasticsearch setup)
es_username = 'elastic'
es_password = os.getenv('ES_PASSWORD')  # Replace 'your_password_here' with your actual Elasticsearch password

# Path to your CA certificate on your host (adjust this after copying it from the container)
ca_cert_path = os.getenv('HTTP_CA_CRT_PATH')  # Update this to the actual path where you store your copied CA certificate

# Create an Elasticsearch client
es = Elasticsearch(
    ['https://localhost:9200'],
    basic_auth=(es_username, es_password),
    ca_certs=ca_cert_path
)

# Print Elasticsearch client information to verify connectivity
print(es.info())
# Out:
# {'name': '8b4375334f9c', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'XuaZu5E-QgWjjKSFBuUCaQ', 'version': {'number': '8.13.2', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '16cc90cd2d08a3147ce02b07e50894bc060a4cbf', 'build_date': '2024-04-05T14:45:26.420424304Z', 'build_snapshot': False, 'lucene_version': '9.10.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'}

# %%
from sentence_transformers import SentenceTransformer

# checkpoint_path = 'snunlp/KR-SBERT-V40K-klueNLI-augSTS'

# Sentence Transformer 모델 초기화 (한국어 임베딩 생성 가능한 어떤 모델도 가능)
model = SentenceTransformer('output/scientific_continue_training_kr_sbert_v40k_klueNLI_augSTS')

# %%
# SetntenceTransformer를 이용하여 임베딩 생성
def get_embedding(sentences):
    # return model.encode(sentences)
    return [model.encode(sentence) for sentence in sentences]


# 주어진 문서의 리스트에서 배치 단위로 임베딩 생성
def get_embeddings_in_batches(docs, batch_size=100):
    batch_embeddings = []
    for i in range(0, len(docs), batch_size):
        batch = docs[i:i + batch_size]
        contents = [doc["content"] for doc in batch]
        embeddings = get_embedding(contents)
        batch_embeddings.extend(embeddings)
        print(f'batch {i}')
    return batch_embeddings


# 새로운 index 생성
def create_es_index(index, settings, mappings):
    # 인덱스가 이미 존재하는지 확인
    if es.indices.exists(index=index):
        # 인덱스가 이미 존재하면 설정을 새로운 것으로 갱신하기 위해 삭제
        es.indices.delete(index=index)
    # 지정된 설정으로 새로운 인덱스 생성
    es.indices.create(index=index, settings=settings, mappings=mappings)


# 지정된 인덱스 삭제
def delete_es_index(index):
    es.indices.delete(index=index)


# Elasticsearch 헬퍼 함수를 사용하여 대량 인덱싱 수행
def bulk_add(index, docs):
    # 대량 인덱싱 작업을 준비
    actions = [
        {
            '_index': index,
            '_source': doc
        }
        for doc in docs
    ]
    return helpers.bulk(es, actions)


# 역색인을 이용한 검색
def sparse_retrieve(query_str, size):
    query = {
        "match": {
            "content": {
                "query": query_str
            }
        }
    }
    return es.search(index="test", query=query, size=size, sort="_score")


# Vector 유사도를 이용한 검색
def dense_retrieve(query_str, size):
    # 벡터 유사도 검색에 사용할 쿼리 임베딩 가져오기
    query_embedding = get_embedding([query_str])[0]

    # KNN을 사용한 벡터 유사성 검색을 위한 매개변수 설정
    knn = {
        "field": "embeddings",
        "query_vector": query_embedding.tolist(),
        "k": size,
        "num_candidates": 100
    }

    # 지정된 인덱스에서 벡터 유사도 검색 수행
    return es.search(index="test", knn=knn)

# %%
# 색인을 위한 setting 설정
settings = {
    "analysis": {
        "analyzer": {
            "nori": {
                "type": "custom",
                "tokenizer": "nori_tokenizer",
                "decompound_mode": "mixed",
                "filter": ["nori_posfilter"]
            }
        },
        "filter": {
            "nori_posfilter": {
                "type": "nori_part_of_speech",
                # 어미, 조사, 구분자, 줄임표, 지정사, 보조 용언 등
                "stoptags": ["E", "J", "SC", "SE", "SF", "VCN", "VCP", "VX"]
            }
        }
    }
}

# 색인을 위한 mapping 설정 (역색인 필드, 임베딩 필드 모두 설정)
mappings = {
    "properties": {
        "content": {"type": "text", "analyzer": "nori"},
        "embeddings": {
            "type": "dense_vector",
            "dims": 768,
            "index": True,
            "similarity": "l2_norm"
        }
    }
}

# %%
# settings, mappings 설정된 내용으로 'test' 인덱스 생성
create_es_index("test", settings, mappings)

# %%
import json

# 문서의 content 필드에 대한 임베딩 생성
index_docs = []
with open("data/documents.jsonl") as f:
    docs = [json.loads(line) for line in f]
embeddings = get_embeddings_in_batches(docs)

# 생성한 임베딩을 색인할 필드로 추가
for doc, embedding in zip(docs, embeddings):
    # doc["embeddings"] = embedding.tolist()
    doc["embeddings"] = embedding
    index_docs.append(doc)

# 'test' 인덱스에 대량 문서 추가
ret = bulk_add("test", index_docs)

# 색인이 잘 되었는지 확인 (색인된 총 문서수가 출력되어야 함)
print(ret)
# Out:
# batch 0
# batch 100
# batch 200
# batch 300
# batch 400
# batch 500
# batch 600
# batch 700
# batch 800
# batch 900
# batch 1000
# batch 1100
# batch 1200
# batch 1300
# batch 1400
# batch 1500
# batch 1600
# batch 1700
# batch 1800
# batch 1900
# batch 2000
# batch 2100
# batch 2200
# batch 2300
# batch 2400
# batch 2500
# batch 2600
# batch 2700
# batch 2800
# batch 2900
# batch 3000
# batch 3100
# batch 3200
# batch 3300
# batch 3400
# batch 3500
# batch 3600
# batch 3700
# batch 3800
# batch 3900
# batch 4000
# batch 4100
# batch 4200
# (4272, [])

# %%
# 검색엔진에 색인이 잘 되었는지 테스트하기 위한 질의
test_query = "금성이 다른 행성들보다 밝게 보이는 이유는 무엇인가요?"

# %%
# 역색인을 사용하는 검색 예제
search_result_retrieve = sparse_retrieve(test_query, 3)

# 결과 출력 테스트
for rst in search_result_retrieve['hits']['hits']:
    print('score:', rst['_score'], 'source:', rst['_source']["content"])
# Out:
# score: 33.68643 source: 금성이 다른 행성들보다 더 밝게 보이는 이유는 지구 쪽으로 가장 많은 햇빛을 반사하기 때문입니다. 케빈은 맑은 밤에 하늘을 관찰하고 있습니다. 그는 맨눈으로 금성, 화성, 목성, 토성을 볼 수 있습니다. 금성은 햇빛을 많이 반사하기 때문에 다른 행성들보다 더 밝게 보입니다. 이는 금성의 표면이 반사율이 높기 때문입니다. 금성은 태양으로부터 받은 햇빛을 표면에 반사하여 지구에서 관찰하기 쉽게 만듭니다. 따라서 케빈은 맑은 밤에 금성을 더 밝게 볼 수 있습니다.
# score: 18.915426 source: 금성은 태양계의 두 번째로 가까운 행성입니다. 이 행성의 대략적인 나이는 7억 5천만 년으로 추정됩니다. 금성은 지구와 매우 비슷한 크기와 구성을 가지고 있으며, 약 90% 이상이 이산화탄소로 이루어져 있습니다. 이 행성은 매우 뜨거운 온도와 압력을 가지고 있어서 인간이 살 수 있는 환경이 아닙니다. 금성의 대기는 두꺼워서 태양의 열을 가두고 있어서 행성의 표면은 평균 온도가 약 450도로 매우 뜨거운 상태입니다. 또한, 금성은 자전 속도가 매우 빠르기 때문에 하루가 지구의 약 243일과 같습니다. 이러한 특징들로 인해 금성은 우리 태양계에서 가장 가혹한 환경을 가진 행성 중 하나로 알려져 있습니다.
# score: 18.728905 source: 메릴랜드 Space Grant Observatory는 볼티모어에 위치해 있습니다. 학생들은 이 망원경을 방문하여 별, 행성, 달에 대해 배웠습니다. 그들은 아래와 같은 정보를 기록했습니다. 첫째, 별 패턴은 그대로 유지되지만, 하늘에서의 위치는 변하는 것처럼 보입니다. 둘째, 태양, 행성, 달은 하늘에서 움직이는 것처럼 보입니다. 셋째, 켄타우루스자리의 프록시마 성은 우리 태양계에서 가장 가까운 별입니다. 넷째, 북극성은 소 북두칠성이라 불리는 별 패턴의 일부입니다. 그렇다면 태양이 매일 하늘을 가로질러 움직이는 것처럼 보이는 이유는 무엇일까요? 지구가 자전축을 중심으로 회전하기 때문입니다.

# %%
# Vector 유사도 사용한 검색 예제
search_result_retrieve = dense_retrieve(test_query, 3)

# 결과 출력 테스트
for rst in search_result_retrieve['hits']['hits']:
    print('score:', rst['_score'], 'source:', rst['_source']["content"])
# Out:
# score: 0.008345666 source: 태양은 열을 발산하는 별입니다. 태양은 무수한 수의 핵융합 반응을 통해 엄청난 양의 에너지를 생성합니다. 이 에너지는 태양의 표면에서 방출되어 우리 행성에 도달합니다. 햇빛은 여러 가지 파장으로 구성되어 있으며, 그 중에서도 가시광선은 우리 눈으로 볼 수 있는 범위입니다. 햇빛은 지구의 대기를 통과하여 지표면에 도달하게 되는데, 이때 햇빛은 지표면에 흡수되거나 반사됩니다.
#
# 얼음은 물이 얼어서 만들어진 물체입니다. 얼음은 일반적으로 0도 미만의 온도에서 형성되며, 주로 물이 얼어서 만들어집니다. 얼음은 분자 간의 결합력으로 인해 고체 상태를 유지합니다. 그러나 햇빛에 노출되면 얼음 조각은 빠르게 녹게 됩니다. 이는 태양에서 발산되는 열 에너지가 얼음 조각에 흡수되어 얼음 분자 간의 결합력을 약화시키기 때문입니다. 따라서 햇빛에 노출된 얼음 조각은 녹게 되는 것입니다.
#
# 태양은 우리 생활에 매우 중요한 역할을 합니다. 태양의 열 에너지는 식물의 광합성을 통해 식물이 자라고, 동물들이 생존하고, 우리가 따뜻한 날씨를 느낄 수 있도록 합니다. 또한 태양은 태양광 발전을 통해 전기를 생산하는데에도 사용됩니다. 따라서 태양은 우리 생활에 필수적인 존재이며, 햇빛은 얼음이 녹는 현상을 설명하는 중요한 요소입니다.
# score: 0.008261326 source: 식물에게서 잎이 많이 없어지고 다른 잎에는 큰 구멍이 뚫려 있는 현상을 관찰한 제러마이아는 궁금해졌습니다. 왜 잎이 없어지는 것이 식물에 해로울까요? 이러한 현상은 식물이 더 적은 양의 양분을 만들기 때문입니다. 식물은 잎을 통해 태양의 에너지를 흡수하고 이를 이용하여 양분을 생산합니다. 그러나 양분이 부족하거나 제대로 전달되지 않으면 식물은 생존을 위해 잎을 제거하거나 손상시킵니다. 이로 인해 잎이 없어지고 다른 잎에는 큰 구멍이 뚫리는 것을 관찰할 수 있습니다. 이러한 현상은 식물이 생존을 위해 자신의 에너지와 양분을 효율적으로 사용하려는 자연의 방어 메커니즘입니다. 따라서 잎이 없어지는 것은 식물에게 해로운 것이 아니라, 오히려 생존을 위한 필수적인 과정입니다.
# score: 0.008102263 source: 화성은 붉은색인 이유는 표면이 많이 산화된("녹슨") 광물로 덮여 있기 때문입니다. 이 산화된 광물은 철 미립자로 이루어져 있어서 화성의 표면이 붉은 색으로 보입니다. 이러한 특징은 화성을 지구와 구별할 수 있는 중요한 특징 중 하나입니다. 화성의 붉은색은 우주 탐사선들이 보내는 사진들을 통해 우리에게 잘 알려져 있습니다. 이러한 특징은 화성의 지질학적 특성을 연구하는데도 중요한 역할을 합니다. 화성의 붉은색은 우리가 우주 탐사를 통해 더 많은 것을 알아갈 수 있도록 도와줍니다. 화성은 우리에게 아직 많은 비밀을 품고 있는 행성입니다.

# %% [markdown]
# ## RAG 구현
#
# 준비된 검색엔진과 LLM을 활용하셔 대화형 RAG 구현

# %%
from openai import OpenAI
import traceback

# OpenAI API 키를 환경변수에 설정
# os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')
#os.environ["OPENAI_API_KEY"] = "Your API Key"

client = OpenAI(organization=os.getenv('ORGANIZATION_ID'))
# 사용할 모델을 설정(여기서는 gpt-3.5-turbo-1106 모델 사용)
llm_model = "gpt-3.5-turbo-1106"
# llm_model = "gpt-3.5-turbo"

# %%
# RAG 구현에 필요한 Question Answering을 위한 LLM  프롬프트
persona_qa = """
## Role: 과학 지식 전문가

## Instructions
- 사용자의 이전 메시지 정보 및 주어진 Reference 정보를 활용하여 간결하게 답변을 생성한다.
- 주어진 검색 결과 정보로 대답할 수 없는 경우는 정보가 부족해서 답을 할 수 없다고 대답한다.
- 한국어로 답변을 생성한다.
- 결과는 json 형태로 생성하고, 반드시 'is_science' 필드를 추가하여 질문이 과학 지식에 관련된 내용이면 true를, 과학 지식에 관련된 내용이 아니라면 false를 value로 만든다. 답변 필드의 이름은 'answer'로 통일한다.
"""

# RAG 구현에 필요한 질의 분석 및 검색 이외의 일반 질의 대응을 위한 LLM 프롬프트
persona_function_calling = """
## Role: 과학 지식 전문가

## Instruction
- 사용자가 대화를 통해 과학 지식에 관한 주제로 질문하면 search api를 호출할 수 있어야 한다.
- 과학 지식과 관련되지 않은 나머지 대화 메시지에는 적절한 대답을 생성한다.
- 결과는 json 형태로 생성하고, 반드시 'is_science' 필드를 추가하여 질문이 과학 지식에 관련된 내용이면 true를, 과학 지식에 관련된 내용이 아니라면 false를 value로 만든다. 답변 필드의 이름은 'answer'로 통일한다.
"""

# Function calling에 사용할 함수 정의
tools = [
    {
        "type": "function",
        "function": {
            "name": "search",
            "description": "search relevant documents",
            "parameters": {
                "properties": {
                    "standalone_query": {
                        "type": "string",
                        "description": "Final query suitable for use in search from the user messages history."
                    }
                },
                "required": ["standalone_query"],
                "type": "object"
            }
        }
    },
]

# %%
# LLM과 검색엔진을 활용한 RAG 구현
def answer_question(messages):
    # 함수 출력 초기화
    response = {"standalone_query": "", "topk": [], "references": [], "answer": ""}

    # 질의 분석 및 검색 이외의 질의 대응을 위한 LLM 활용
    msg = [{"role": "system", "content": persona_function_calling}] + messages
    try:
        ### 이 부분을 바꿔서 json으로 만들어 줄까...
        result = client.chat.completions.create(
            model=llm_model,
            response_format={"type": "json_object"},
            messages=msg,
            tools=tools,
            #tool_choice={"type": "function", "function": {"name": "search"}},
            temperature=0,
            seed=1,
            timeout=10
        )
    except Exception as e:
        traceback.print_exc()
        return response

    # 검색이 필요한 경우 검색 호출후 결과를 활용하여 답변 생성
    if result.choices[0].message.tool_calls:
        tool_call = result.choices[0].message.tool_calls[0]
        function_args = json.loads(tool_call.function.arguments)
        standalone_query = function_args.get("standalone_query")

        # Baseline으로는 sparse_retrieve만 사용하여 검색 결과 추출
        search_result = dense_retrieve(standalone_query, 3)

        response["standalone_query"] = standalone_query
        retrieved_context = []
        for i,rst in enumerate(search_result['hits']['hits']):
            retrieved_context.append(rst["_source"]["content"])
            response["topk"].append(rst["_source"]["docid"])
            response["references"].append({"score": rst["_score"], "content": rst["_source"]["content"]})

        content = json.dumps(retrieved_context)
        messages.append({"role": "assistant", "content": content})
        msg = [{"role": "system", "content": persona_qa}] + messages
        try:
            qaresult = client.chat.completions.create(
                    model=llm_model,
                    response_format={"type": "json_object"},
                    messages=msg,
                    temperature=0,
                    seed=1,
                    timeout=30
                )
        except Exception as e:
            traceback.print_exc()
            return response
        response["answer"] = qaresult.choices[0].message.content

    # 검색이 필요하지 않은 경우 바로 답변 생성
    else:
        response["answer"] = result.choices[0].message.content

    return response

# %%
import json

# 평가를 위한 파일을 읽어서 각 평가 데이터에 대해서 결과 추출 후 파일에 저장
def eval_rag(eval_filename, output_filename):
    with open(eval_filename) as f, open(output_filename, "w") as of:
        idx = 0
        for line in f:
            # if idx > 5:
            #   break
            # if idx < 187 :
            #     idx += 1
            #     continue
            j = json.loads(line)
            print(f'Test {idx}\nQuestion: {j["msg"]}')
            response = answer_question(j["msg"])
            print(f'Answer: {response["answer"]}\n')

            # 대회 score 계산은 topk 정보를 사용, answer 정보는 LLM을 통한 자동평가시 활용
            # output = {"eval_id": j["eval_id"], "standalone_query": response["standalone_query"], "topk": response["topk"], "answer": response["answer"], "references": response["references"]}
            
            # json format으로 생성했을 때.
            output = {"eval_id": j["eval_id"], 
                      "standalone_query": response["standalone_query"], 
                      "topk": response["topk"], 
                      "answer": json.loads(response["answer"])['answer'], 
                      "is_science": json.loads(response["answer"])['is_science'], 
                      "references": response["references"]}
            of.write(f'{json.dumps(output, ensure_ascii=False)}\n')
            idx += 1

# %%
# 역색인을 사용하는 검색 예제
q1 = '나무의 분류에 대해 조사해 보기 위한 방법은?'
search_result_retrieve = sparse_retrieve(q1, 3)
search_result_retrieve
# Out:
# ObjectApiResponse({'took': 13, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 4238, 'relation': 'eq'}, 'max_score': 20.857122, 'hits': [{'_index': 'test', '_id': 'YZqJN48B-sAIPHWj34HJ', '_score': 20.857122, '_source': {'docid': 'c63b9e3a-716f-423a-9c9b-0bcaa1b9f35d', 'src': 'ko_ai2_arc__ARC_Challenge__test', 'content': '한 학생이 다양한 종류의 나무를 조사하고 있습니다. 이 학생은 성장 속도, 온도 범위, 크기가 비슷한 두 나무를 발견했습니다. 그러나 이 두 나무의 잎과 꽃은 서로 다릅니다. 이러한 특징을 고려하면, 이 나무들은 대체로 같은 속에 속해 있을 것으로 추측됩니다. 같은 속에 속한 나무들은 종류별로 유사한 특징을 가지고 있으며, 이는 생물 분류학에서 중요한 기준 중 하나입니다. 따라서 이 학생의 조사 결과는 나무의 분류와 관련된 중요한 정보를 제공할 수 있습니다. 이러한 조사는 나무의 성장과 생태에 대한 이해를 높이는 데 도움이 될 것입니다.', 'embeddings': [-0.2693350613117218, 0.16106565296649933, -0.6686766147613525, -0.4087434709072113, -0.6087977290153503, -0.5408722162246704, 1.4245141744613647, -1.4220963716506958, -0.8162183165550232, -0.9986358880996704, -1.0482354164123535, 1.2237915992736816, -1.3584719896316528, 0.29972395300865173, 0.5895066261291504, -0.02090403623878956, 0.27583420276641846, -1.0972949266433716, -0.4782058298587799, 0.566891074180603, -0.04273995757102966, 0.08423794060945511, 0.9294244050979614, 1.22434663772583, 0.8080000877380371, -0.5453926920890808, -0.5892763137817383, -1.5225648880004883, -1.5311918258666992, 0.3093801736831665, -0.916719913482666, 0.1462908387184143, 0.33276790380477905, -0.11941248178482056, -0.8636401295661926, 1.4611587524414062, -0.9125920534133911, -0.5032921433448792, 1.2054777145385742, -1.0653512477874756, -0.4573671519756317, -0.2715780735015869, -0.6439120173454285, 0.1095324233174324, -0.898736298084259, 0.09486313164234161, 0.05869128927588463, 0.2631889879703522, 0.0828084945678711, -0.5255855321884155, 0.3287999629974365, 0.10320410877466202, -0.13067148625850677, -0.849593997001648, 0.6599602699279785, -0.5816741585731506, -0.7374539971351624, -0.35787978768348694, -1.373934030532837, 0.46767696738243103, -0.6102631688117981, 0.14975573122501373, -0.6519489884376526, -1.3459899425506592, -0.14304596185684204, -0.1410156637430191, 0.4048808813095093, 1.270416498184204, 0.543582022190094, 1.4017144441604614, -0.13145679235458374, 0.5616637468338013, -0.6219454407691956, 0.7565515041351318, 2.692436456680298, 0.2520536184310913, -0.7891588807106018, 0.5574100017547607, -0.026874687522649765, -1.2929046154022217, 0.2505601644515991, 0.4488687813282013, -1.4590767621994019, 1.8176912069320679, 0.47459009289741516, -0.04225585609674454, -0.022463727742433548, -1.105310320854187, -0.23567622900009155, -0.5759019255638123, -0.39760857820510864, 0.9643349647521973, -0.6582993268966675, -0.5748084187507629, 0.5114393830299377, -1.8718098402023315, -1.1360796689987183, -0.1674317717552185, -0.43963146209716797, -0.4617367386817932, -1.2789775133132935, 1.5980581045150757, -1.4674233198165894, 0.9171792268753052, 1.8380210399627686, 0.7889441847801208, 0.10074567794799805, 0.9745189547538757, -1.3934438228607178, -1.379225254058838, -0.48446157574653625, 0.3751218616962433, 1.2205032110214233, 0.04264470934867859, -0.9063958525657654, -0.2489759624004364, -0.46812552213668823, 1.187987208366394, -0.43432408571243286, -0.33165213465690613, -1.2850106954574585, 1.8485008478164673, -0.4201721251010895, -1.1168651580810547, -1.5774537324905396, -0.6481029987335205, -0.6329235434532166, 0.40743497014045715, -0.31961590051651, -0.19268572330474854, 1.7388345003128052, -0.5140606164932251, 0.26741063594818115, -0.12754645943641663, -0.8777331709861755, 0.9905782341957092, -0.4253919720649719, 0.3258279263973236, 0.5121250152587891, 0.613684356212616, 0.8269867300987244, 2.0645604133605957, -0.15129096806049347, 0.6942378878593445, 0.46152785420417786, 0.8514750599861145, -0.4924948215484619, 0.6147627234458923, 0.7159149646759033, 0.1844656616449356, -0.30941471457481384, 1.4253267049789429, 0.32145196199417114, -0.19689743220806122, -1.2094703912734985, 0.13524223864078522, -0.0011889388551935554, -0.2609262764453888, 0.99288219 ...

# %%
# 평가 데이터에 대해서 결과 생성 - 파일 포맷은 jsonl이지만 파일명은 csv 사용
eval_rag("data/eval.jsonl", "sample_submission.csv")
# Out:
# Test 0
# Question: [{'role': 'user', 'content': '나무의 분류에 대해 조사해 보기 위한 방법은?'}]
# Answer: {
#   "answer": "나무의 분류를 조사하기 위한 방법은 주로 잎의 형태, 가지 분기 패턴, 꽃과 열매의 유무 등을 관찰하여 분류합니다. 또한, 나무의 지리적 분포와 면적을 조사하여 지리적 특성을 파악하기도 합니다. 이러한 조사는 나무의 생태와 연구에 중요한 정보를 제공하며, 이를 통해 나무의 분류와 생태학적 특성을 이해할 수 있습니다.",
#   "is_science": true
# }
#
# Test 1
# Question: [{'role': 'user', 'content': '각 나라에서의 공교육 지출 현황에 대해 알려줘.'}]
# Answer: {
#   "answer": "주어진 정보로는 각 나라의 공교육 지출 현황에 대한 구체적인 데이터를 제공하기 어렵습니다.",
#   "is_science": false
# }
#
# Test 2
# Question: [{'role': 'user', 'content': '기억 상실증 걸리면 너무 무섭겠다.'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '어떤 원인 때문에 발생하는지 궁금해.'}]
# Answer:
# {
#   "answer": "기억 상실증은 다양한 원인으로 발생할 수 있습니다. 이는 일상적인 사건이나 경험에 대한 기억을 저장하고, 일상적인 기억을 증가시키는 데 어려움을 겪는 것으로, 80세 이상의 사람들은 특히 (75% 이상) 발생합니다. 기억 상실증은 인지 기능의 감소와 연관되어 있으며, 비타민 B1로도 인한 기억상실증이 발생할 수 있습니다. 기억 상실증은 티아민의 결핍으로 인한 신경학적인 문제와 관련이 있으며, 티아민은 기억과 학습에 중요한 역할을 합니다. 따라서, 기억 상실증은 다양한 원인과 증상을 가지고 있으며, 이에 대한 관리와 치료는 각각의 상황에 맞게 이루어져야 합니다.",
#   "is_science": true
# }
#
# Test 3
# Question: [{'role': 'user', 'content': '통학 버스의 가치에 대해 말해줘.'}]
# Answer: {
#   "answer": "통학 버스는 학교나 학원으로 학생들을 운송하는 버스로, 학생들의 안전과 편의를 고려하여 설계되었습니다. 통학 버스는 학교 교통 체계의 중심 역할을 하며, 학생들의 안전을 보장하고 효율적인 교통을 제공합니다. 또한, 학교 교육 환경을 보다 나은 것으로 만들어주는 역할을 합니다. 통학 버스는 학교 내부의 교육 환경뿐만 아니라 주변 지역 사회의 발전과 교육을 촉진하는 역할을 합니다.",
#   "is_science": false
# }
#
# Test 4
# Question: [{'role': 'user', 'content': 'Dmitri Ivanovsky가 누구야?'}]
# Answer:
# {
#   "answer": "Dmitri Ivanovsky는 바이러스의 발견과 연구로 유명한 러시아의 식물학자입니다.",
#   "is_science": true
# }
#
# Test 5
# Question: [{'role': 'user', 'content': '피임을 하기 위한 방법중 약으로 처리하는 방법은 쓸만한가?'}]
# Answer: {
#   "answer": "약을 이용한 피임은 효과적일 수 있지만, 사용자의 상황과 건강 상태에 따라 적합한 약물 및 방법을 정확히 결정해야 합니다. 또한, 약물을 사용할 경우 부작용이 있을 수 있으므로 의사나 약사와 상담하여 결정하는 것이 중요합니다. 또한, 약물 피임은 정기적인 복용과 사용법을 엄격히 지켜야 하며, 사용자의 건강 상태와 상호작용을 고려하여야 합니다. 따라서, 약물을 이용한 피임은 전문가와의 상담 후 결정해아 합니다.",
#   "is_science": true
# }
#
# Test 6
# Question: [{'role': 'user', 'content': '헬륨이 다른 원소들과 반응을 잘 안하는 이유는?'}]
# Answer: {
#   "answer": "헬륨은 다른 원소들과 반응을 잘 안하는 이유는 헬륨이 안정한 원자 구조를 가지고 있기 때문입니다. 헬륨 원자는 이미 가장 안정한 상태로 존재하고 있어서 다른 원자들과 화학적으로 반응하기 어렵습니다. 이는 헬륨 원자가 매우 안정하고 비활성이기 때문에 발생하는 현상입니다.",
#   "is_science": true
# }
#
# Test 7
# Question: [{'role': 'user', 'content': '문맹 비율이 사회 발전에 미치는 영향은?'}]
# Answer: {
#   "answer": "문맹 비율이 사회 발전에 미치는 영향은 다양합니다. 문맹은 사람들의 지식과 정보에 대한 접근성을 제한하며, 이는 사회 발전에 부정적인 영향을 미칠 수 있습니다. 문맹으로 인해 교육 수준이 낮아지고 지식과 기술의 활용이 제한되는 등의 문제가 발생할 수 있습니다. 또한, 문맹은 사람들의 경제적, 사회적 권리 및 참여, 문화 및 예술 활동의 제한 등 다양한 영향을 미칠 수 있습니다. 따라서 문맹 문제를 해결하여 교육의 기회와 질, 사회 참여 및 문화 활동의 증진, 경제 및 사회 발전을 촉진하는 등의 노력이 필요합니다.",
#   "is_science": true
# }
#
# Test 8
# Question: [{'role': 'user', 'content': '이란 콘트라 사건이 뭐야'}, {'role': 'assistant', 'content': '이란-콘트라 사건은 로널드 레이건 집권기인 1986년에 레이건 행정부와 CIA가 적성국이었던 이란에게 무기를 몰래 수출한 대금으로 니카라과의 우익 성향 반군 콘트라를 지원하면서 동시에 반군으로부터 마약을 사들인 후 미국에 판매하다가 발각되어 큰 파장을 일으킨 사건입니다.'}, {'role': 'user', 'content': '이 사건이 미국 정치에 미친 영향은?'}]
# Answer:
# {
#   "answer": "이란-콘트라 사건은 미국 정치에 큰 파장을 일으켰습니다. 이 사건으로 미국 정부와 CIA의 비리가 드러나고, 이에 따른 수사와 청문회가 이루어졌습니다. 또한, 미국 내에서는 대규모 시민 운동이 일어나고, 이 사건으로 미국의 대외 정책에도 영향을 미치게 되었습니다.",
#   "is_science": false
# }
#
# Test 9
# Question: [{'role': 'user', 'content': '자기장이 얼마나 센지 표현하는 방식은?'}]
# Answer: {
#   "answer": "자기장의 세기를 표현하는 방식은 자기장이 얼마나 센지를 나타내는데, 주로 자기장의 강도를 가리키는 표현으로 사용됩니다. 자기장은 지구의 자기장을 가리키며, 이를 측정하고 표현하는 방법은 다양합니다. 또한, 세포 내의 이온 흐름, ATP와 클라스테르 이온은 활동 중에 분비되며, 이 이온은 최소 5-10분 간격으로 측정됩니다. 이 기간 동안의 분비량은 자극도와 세포 내에서의 활동에 따라 달라집니다. 따라서, 자기장의 세기를 나타내는 방식은 다양하며, 주로 자기장의 강도를 나타내는데 사용되는 표현입니다.",
#   "is_science": true
# }
#
# Test 10
# Question: [{'role': 'user', 'content': '피를 맑게 하고 몸 속의 노폐물을 없애는 역할을 하는 기관은?'}]
# Answer: {
#   "answer": "신장",
#   "is_science": true
# }
#
# Test 11
# Question: [{'role': 'user', 'content': '글리코겐의 분해는 인체에서 왜 필요한가?'}]
# Answer: {"answer": "글리코겐은 인체에서 에너지를 공급하기 위해 필요합니다. 글리코겐은 혈당을 저장하는 형태의 탄수화물이며, 혈당이 부족할 때 글리코겐이 분해되어 혈당을 생성하여 에너지원으로 활용됩니다.", "is_science": true}
#
# Test 12
# Question: [{'role': 'user', 'content': '빗방울이 점점 커지게 되는 요인은?'}]
# Answer: {
#   "answer": "빗방울이 점점 커지는 요인은 다양합니다. 빗방울은 공기 중의 수증기가 응축되어 형성되는데, 이때 수증기가 응축되는 과정에서는 다양한 요인들이 작용합니다. 먼저, 빗방울은 공기 중의 수증기로부터 응축되는 과정에서는 온도의 변화가 중요한데, 높은 고도에서 내려오는 빗방울은 온도가 낮아지면서 응축이 일어나고, 이를 통해 빗방울의 크기가 커집니다. 또한, 빗방울은 공기 중의 먼지, 빙정, 우박 등과 상호작용하여 크기가 커질 수 있습니다. 이러한 요인들은 빗방울의 형성 및 성장에 영향을 미치는데, 우리는 이러한 요인들을 이해하고 고려하여 빗방울의 형성 및 성장을 이해할 수 있습니다.",
#   "is_science": true
# }
#
# Test 13
# Question: [{'role': 'user', 'content': '기체의 부피나 형태가 왜 일정하지 않을까?'}]
# Answer: {
#   "answer": "기체의 부피나 형태가 일정하지 않는 이유는 기체 분자들이 운동하면서 상대적인 위치와 속도가 계속 변하기 때문입니다. 이로 인해 기체의 부피나 형태가 변하는 것입니다. 기체의 부피와 형태는 기체 분자들의 운동에 의해 결정되며, 이는 기체의 압력, 온도, 부피, 밀도 등과 관련된 다양한 물리적 특성에 영향을 미칩니다.",
#   "is_science": true
# }
#
# Test 14
# Question: [{'role': 'user', 'content': '식물이 빛을 에너지로 변환하는 과정에 대해 설명해줘.'}]
# Answer: {
#   "answer": "식물은 빛을 흡수하여 엽록소를 이용해 이를 에너지로 변환합니다. 이 과정에서 물과 이산화탄소가 사용되고 산소가 생성됩니다. 이러한 과정을 광합성이라고 합니다. 광합성은 주로 잎, 줄기, 꽃, 열매 등의 장기에서 일어나며, 엽록체 내에서 엽록소가 주로 역할을 합니다. 또한, 광합성은 태양빛, 이산화탄소, 물, 엽록소 등의 요소들이 필요합니다. 따라서, 이러한 과정은 광합성이라는 생물학적 프로세스를 통해 이루어집니다.",
#   "is_science": true
# }
#
# Test 15
# Question: [{'role': 'user', 'content': '직류와 교류 전류의 차이에 대해 알려줘.'}]
# Answer: {
#   "answer": "교류와 직류 전류의 차이는 교류가 주기적으로 방향이 바뀌는 전류이고, 직류는 한 방향으로만 흐르는 전류입니다. 이에 따라 교류는 효율적으로 에너지를 전달하며, 직류는 안정적으로 특정 장치에 전원을 공급하는 데 유용합니다. 전류의 흐름 방식과 특성에 따라 교류와 직류는 다양한 용도로 활용됩니다.",
#   "is_science": true
# }
#
# Test 16
# Question: [{'role': 'user', 'content': '기름과 물이 섞여 있을 수 있나?'}]
# Answer: {
#   "answer": "물과 기름은 섞일 수 없습니다. 물은 극성 분자로서 수소 원자가 양성자이고 산소 원자가 음성자입니다. 반면에 기름은 비극성 분자로서 극성을 가지지 않습니다. 따라서, 물과 기름은 서로 상호 작용하지 않고, 용해되지 않습니다. 따라서, 물과 기름이 섞여 있을 수 없습니다.",
#   "is_science": true
# }
#
# Test 17
# Question: [{'role': 'user', 'content': '인간이 2세를 생산할 때 DNA의 결합 과정에 대히 설명해줘.'}]
# Answer: {
#   "answer": "인간의 생식과정은 남성과 여성이 결합하여 매우 복잡한 과정으로 진행됩니다. DNA는 생물체의 유전정보를 담고 있으며 이를 통해 유전적 특성을 결정하고 유전자를 전달합니다. DNA의 결합과정은 두 부모의 유전자를 무작위로 섞어 새로운 조합을 만들어내는 과정입니다. 결합된 DNA는 부모의 유전 정보와 결합과정에서 발생한 돌연변이를 포함한 유전적 다양성을 보장합니다. 결합된 DNA는 유전적 다양성과 유전 정보를 결정하고 전달하는 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 18
# Question: [{'role': 'user', 'content': '금성에서 달이 어떻게 보일까?'}]
# Answer: {
#   "answer": "금성에서는 달이 없기 때문에 달을 볼 수 없습니다. 대신에 금성은 일출 직후나 일몰 직전에 가장 잘 관찰될 수 있습니다. 일몰 직후에는 달이 떠오르는 시간이기 때문에, 달이 떠오를 때와 비슷한 모습을 관찰할 수 있습니다. 따라서, 금성이 일몰 직후에는 달이 떠오르는 것처럼 보일 것입니다.",
#   "is_science": true
# }
#
# Test 19
# Question: [{'role': 'user', 'content': '차량의 연비가 좋아질때 나타나는 긍정적인 효과는?'}]
# Answer: {
#   "answer": "차량의 연비가 좋아지면 나타나는 긍정적인 효과는 주로 환경과 경제적인 측면에서 나타납니다. 연비가 좋아지면 연료를 더 효율적으로 사용하고, 대기 오염과 온실가스 배출량을 줄일 수 있습니다. 또한, 연비 향상은 주행 거리를 늘리고 연료비를 줄일 수 있어 경제적으로 이점을 가져다 줍니다. 또한, 연비 향상은 주행 안전성을 높일 수 있습니다. 따라서 차량의 연비가 좋아지면 환경, 경제, 안전 등 다양한 측면에서 긍정적인 영향을 미칩니다.",
#   "is_science": true
# }
#
# Test 20
# Question: [{'role': 'user', 'content': '혼합물의 특성에 대해 알려줘.'}]
# Answer: {
#   "answer": "혼합물은 두 개 이상의 물질이 섞여있는 것을 말합니다. 혼합물의 특성은 각 성분의 비율에 따라 달라지며, 혼합물은 물리적으로 섞여있어 분리가 가능하고, 새로운 물질이 형성되지 않습니다. 혼합물은 물과 소금의 용액, 공기와 이산화탄소로 이루어진 대기 등으로 볼 수 있습니다. 이 두 가지의 혼합물은 서로 다른 성질을 가지고 있어 상호작용이 일어나며, 혼합물은 다른 성질을 가진 물질을 추가하고 있어 새로운 혼합물을 만들어낼 수 있습니다. 혼합물은 물질의 성질과 특성을 결정하는 요소로 작용하며, 물리적 혼합물은 물질을 분리할 수 있지만, 화학적으로는 상호작용이 일어나지 않습니다.",
#   "is_science": true
# }
#
# Test 21
# Question: [{'role': 'user', 'content': '요새 너무 힘들다.'}]
# Answer: {
#   "answer": "힘든 상황에서는 자신의 감정을 이해하고, 필요하다면 도움을 청하는 것이 중요합니다. 과학적 연구에 따르면, 스트레스를 관리하는 방법으로는 규칙적인 운동, 충분한 휴식, 식이 균형, 그리고 사회적 지원이 도움이 된다고 합니다. 또한, 마음을 편안하게 하는 것도 중요한데, 음악 감상, 예술 활동, 그리고 취미 활동이 도움이 될 수 있습니다.",
#   "is_science": true
# }
#
# Test 22
# Question: [{'role': 'user', 'content': '세제의 거품이 만들어지는 원리는?'}]
# Answer: {
#   "answer": "세제의 거품이 만들어지는 원리는 세제 분자의 수성과 지방성을 이용하여 거품을 형성하는 것입니다. 이때, 세제 분자의 수성은 물을 좋아하는 부분이고, 지방성 분자는 거품 내의 물과 유지를 결합하여 거품을 형성합니다. 거품은 두 개의 세포막으로 이루어진 구조로, 세포막 내부의 EPR 스핀 스핀트론에 의해 안정화됩니다. H2SO4는 황산으로 알려진 강산성 물질입니다. 높은 농도의 H2SO4를 사용하면 거품을 생성할 수 있습니다.",
#   "is_science": true
# }
#
# Test 23
# Question: [{'role': 'user', 'content': '나무가 생태계에서 하는 역할에 대해 설명해줘.'}]
# Answer: {
#   "answer": "나무는 생태계에서 다양한 역할을 합니다. 나무는 산소를 생산하고 이산화탄소를 흡수하여 대기 중의 이산화탄소 농도를 줄이는 역할을 합니다. 또한, 나무는 토양을 고정시켜 토양 침식을 막고, 다양한 동식물의 서식지를 제공하며, 생태 다양성을 유지하는 역할을 합니다. 또한, 나무는 목재, 과일, 씨앗, 의약품 등 다양한 자원을 제공하며, 생활 환경과 생태계를 유지하는 데 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 24
# Question: [{'role': 'user', 'content': '전류의 흐름을 극대화 하려면 배터리와 저항을 어떻게 연결해야 하나?'}]
# Answer: {
#   "answer": "전류를 극대화하기 위해서는 배터리와 저항을 어떻게 연결해야 하는지에 대한 질문인 것으로 보입니다. 전류를 극대화하기 위해서는 전압과 전류의 관계를 이해하고, 저항을 최소화하여 전류를 증가시켜야 합니다. 배터리는 전압을 제공하고 저항은 전압에 의해 전류를 제어하므로, 전압을 유지하면서 저항을 최소화하여 전류를 극대화해야 합니다. 전류를 극대화하기 위해서는 전압과 저항을 고려하여 적절한 배터리와 저항을 선택해야 합니다. 이를 통해 전류를 극대화할 수 있습니다.",
#   "is_science": true
# }
#
# Test 25
# Question: [{'role': 'user', 'content': '식물이 높이 자랄 수 있게 하는 메커니즘이 궁금해.'}]
# Answer: {
#   "answer": "식물이 높이 자랄 수 있게 하는 메커니즘은 주로 광합성과 수분흡수, 영양분 공급, 세포분열 등의 과정으로 이루어집니다. 광합성은 태양빛을 이용하여 이루어지며, 이를 통해 식물은 에너지를 얻고 성장합니다. 뿌리는 수분과 영양분을 흡수하여 세포분열과 세포확장을 통해 식물의 성장을 지원합니다. 또한, 식물의 성장을 조절하는 호르몬과 광합성에 필요한 엽록소 등의 역할도 중요합니다.",
#   "is_science": true
# }
#
# Test 26
# Question: [{'role': 'user', 'content': '달을 보면 항상 같은 면만 보이더라구'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 이유가 뭐야?'}]
# Answer:
# {
#   "answer": "달은 지구 주변을 돌면서 항상 같은 면만을 보여주는데, 이는 달의 자전과 공전이 서로 거의 같은 속도로 이루어지기 때문입니다. 이로 인해 지구에서는 달의 한 면만을 지속적으로 관찰할 수 있습니다. 이러한 현상을 '달의 자전 축의 고정'이라고 합니다. 달의 자전 축의 고정은 지구의 중력과 달의 중력이 상호 작용하여 발생하며, 지구가 달을 향해 끌어당기고 상호작용하는 결과로 발생합니다. 이러한 현상으로 달은 항상 같은 면만을 보여주게 됩니다.",
#   "is_science": true
# }
#
# Test 27
# Question: [{'role': 'user', 'content': '식초와 베이킹 소다를 섞어주면 어떤 일이 일어나?'}]
# Answer: {
#   "answer": "식초와 베이킹 소다를 섞으면 발효 반응이 일어나며 이때 이산화탄소, 물, 소금이 생성됩니다. 이산화탄소는 거품을 일으켜 반죽이 부풀어 오르게 합니다. 또한, 베이킹 소다의 성분이 식초의 성분과 반응하여 소금과 물이 생성됩니다. 이 반응은 화학적으로 열을 발생시키며, 발효 과정에서의 온도는 0°C 이상이 됩니다. 발효 과정의 산도가 높으면서 온도가 적절하면 발효가 원활하게 일어납니다. 따라서, 식초와 베이킹 소다를 섞으면 발효 반응이 일어나며 산도와 온도에 따라 발효 과정이 진행됩니다.",
#   "is_science": true
# }
#
# Test 28
# Question: [{'role': 'user', 'content': '세균이 나쁜줄말 알았는데 그게 아니야?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그럼 순기능에 대해 알려줄래?'}]
# Answer: {"answer": "세균은 다양한 기능을 수행하며, 우리 몸에 유익한 역할을 합니다. 예를 들어, 미생물은 소화기의 건강을 유지하고 영양소를 생성하는 등의 다양한 기능을 합니다. 또한, 미생물은 면역 체계를 조절하고 유해 세균을 제거하는 데 도움을 줍니다. 또한, EPA와 DHA는 신체 기능에 중요한 영향을 미치며, 뇌와 눈의 건강을 지원하고 염증을 감소시키는 등의 기능을 합니다. 따라서, 세균과 EPA 및 DHA를 섭취하는 것은 건강에 도움이 될 수 있습니다.", "is_science": true}
#
# Test 29
# Question: [{'role': 'user', 'content': '오토마톤의 특징에 대해 알려줘.'}]
# Answer: {
#   "answer": "오토마톤은 인간의 동작을 모방하는 로봇으로, 특히 자동화된 기계로서 다양한 산업 및 연구 분야에서 활용됩니다. 이러한 로봇들은 인체의 움직임을 모방하고 벽돌을 쌓는 등의 작업을 수행할 수 있습니다. 또한, 오토마톤은 공학 및 예술 분야에서도 활용되며, 특히 조각 및 회화 작품을 만드는 데 사용됩니다. 이러한 오토마톤 로봇들은 우리의 일상 결정에서도 다양한 용도로 활용되고 있습니다.",
#   "is_science": true
# }
#
# Test 30
# Question: [{'role': 'user', 'content': '다양한 책을 catalog화 하는 코드에서 class 정의 방법 알려줘.'}]
# Answer: {
#   "answer": "클래스를 정의하는 방법은 프로그래밍 언어에 따라 다를 수 있지만, 일반적으로 클래스는 다양한 속성과 메서드를 포함하는 객체 지향 프로그래밍의 기본 구성 요소입니다. 클래스를 정의할 때에는 속성(멤버 변수)과 메서드(멤버 함수)를 포함하여 설계해야 합니다. 이를 통해 책을 catalog화하는 코드에서도 각 책의 속성(제목, 저자, 출판사 등)과 메서드(대출, 반납, 정보출력 등)를 포함하는 Book 클래스를 정의할 수 있습니다.",
#   "is_science": false
# }
#
# Test 31
# Question: [{'role': 'user', 'content': '전구가 병렬로 연결될 때 전류가 줄어드는 원인은?'}]
# Answer:
# {
#   "answer": "전구가 병렬로 연결될 때 전류가 줄어드는 원인은 전체 전기 회로에 걸리는 전압이 일정하기 때문입니다. 병렬 연결된 전구는 각각이 독립적으로 전압을 유지하므로 전체 전기 회로에 걸리는 전압이 변하지 않습니다. 따라서 전류가 감소하게 됩니다.",
#   "is_science": true
# }
#
# Test 32
# Question: [{'role': 'user', 'content': '물속에서 침전이 발생하는 원리에 대해 알려줘.'}]
# Answer: {
#   "answer": "물속에서 침전이 발생하는 원리는 물 온도에 따라 다르지만, 일반적으로 냉각된 물에서 용질이 용해도가 낮아지면 침전이 발생합니다. 이는 용질이 용해도를 초과하여 용액에서 침전물이 생성되기 때문입니다.",
#   "is_science": true
# }
#
# Test 33
# Question: [{'role': 'user', 'content': '화산 폭발이 발생한 후 새로운 생물 군집이 생겨나는 것을 무엇이라 부르나?'}]
# Answer: {
#   "answer": "화산 폭발 후에 새로운 생물 군집이 형성되는 현상을 '화생채'라고 합니다. 화생채는 화산 폭발로 인해 새로운 환경이 형성되고, 이 환경에 맞춰 다양한 생물이 적응하며 생태계를 구축하는 현상을 말합니다. 이는 생태학적으로 매우 흥미로운 결과를 가져옵니다.",
#   "is_science": true
# }
#
# Test 34
# Question: [{'role': 'user', 'content': '축전기를 병렬로 이어주면 전체 용량이 어떻게 되는가?'}]
# Answer: {
#   "answer": "축전기를 병렬로 연결하면 전체 용량은 각 축전기의 용량을 더한 값이 됩니다. 이는 축전기의 용량이 더해져서 총 용량이 증가하기 때문에 병렬 연결의 경우 전체 용량이 증가하게 됩니다.",
#   "is_science": true
# }
#
# Test 35
# Question: [{'role': 'user', 'content': '정육면체가 가라앉지 않고 물 위에 떠 있을 때 수면 윗부분에 해당하는 부피를 구하는 방법은?'}]
# Answer: {
#   "answer": "정육면체가 물 위에 떠 있을 때 수면 윗부분에 해당하는 부피를 구하는 방법은 정육면체의 무게를 알고 있을 때, 정육면체의 부피 중 0.6배의 부분을 물 위에 떠 있는 정육면체의 부피로 간주할 수 있습니다. 따라서 물 위에 떠 있는 정육면체의 부피를 구하려면 0.25배의 부피를 구한 후 이 값을 더해주면 됩니다. 이렇게 구한 부피는 정육면체가 물 위에 떠 있는 상태에서의 부피입니다.",
#   "is_science": true
# }
#
# Test 36
# Question: [{'role': 'user', 'content': '니가 대답을 잘해줘서 너무 신나!'}]
# Answer: {
#   "answer": "죄송합니다, 이해할 수 없는 메시지입니다. 다른 질문이 있으시면 도와드리겠습니다.",
#   "is_science": false
# }
#
# Test 37
# Question: [{'role': 'user', 'content': '건설 현장에서 망치로 벽을 치는 이유는?'}]
# Answer: {
#   "answer": "건설 현장에서 망치로 벽을 치는 이유는 다양합니다. 망치를 사용하여 벽을 치는 이유 중 하나는 벽을 고정시키고 철근을 박는 등의 작업을 하기 위해서입니다. 또한, 망치로 치는 작업은 소리를 내어 다른 작업자들에게 신호를 주고 협조를 구하는데에도 사용됩니다. 망치로 치는 작업은 벽을 고정시킨 후에 철근을 박는 등의 작업을 하기 위한 절차의 일부이기도 합니다. 이러한 작업은 건설 현장에서 안전을 유지하고 협력을 돕기 위한 것입니다.",
#   "is_science": true
# }
#
# Test 38
# Question: [{'role': 'user', 'content': '차량의 매연이 발생하지 않게 만드는 장치가 무엇인가?'}]
# Answer: {
#   "answer": "차량의 매연을 줄이는 장치로 촉매 변환기와 화물층이 있습니다. 촉매 변환기를 통해 탈취 및 이산화탄소를 생성하며, 화물층은 연소 가스를 제거합니다. 또한, 촉매 변환기와 화물층을 함께 사용하는 시스템도 있습니다. 이 외에도 차량의 매연을 줄이는 다양한 방법이 연구되고 있습니다.",
#   "is_science": true
# }
#
# Test 39
# Question: [{'role': 'user', 'content': 'python에서 lambda 함수를 언제 사용할 수 있어?'}]
# Answer: {
#   "answer": "람다 함수는 간단한 함수를 한 줄로 표현할 수 있는데, 주로 함수형 프로그래밍이나 간단한 연산을 수행할 때 사용됩니다.",
#   "is_science": false
# }
#
# Test 40
# Question: [{'role': 'user', 'content': '강이나 바다의 물이 증발하는 가장 중요한 원인은?'}]
# Answer: {
#   "answer": "강이나 바다의 물이 증발하는 가장 중요한 원인은 대기 중의 황산가스(SO2)와 질산가스(NO)입니다. 이러한 물질들은 수증기와 반응하여 산성비를 형성합니다. 산성비는 물을 부식시키고 생물의 pH를 변화시키는 등의 영향을 미칩니다. 또한, 산성비는 대기 중의 먼지를 흡수하고 토양의 흙먼지나 해양의 염분을 흡수하는 성질이 있습니다. 이로 인해 물의 pH를 낮추고, 이로 인해 수증기의 결정화를 방해하는 결과를 초래합니다. 따라서, 강이나 바다의 물이 증발하는 가장 중요한 원인은 대기 중의 황산가스와 질산가스의 영향으로 인해 물의 pH를 낮추는 결과를 초래합니다.",
#   "is_science": true
# }
#
# Test 41
# Question: [{'role': 'user', 'content': '남녀 관계에서 정서적인 행동이 왜 중요해?'}]
# Answer: {
#   "answer": "정서적인 행동은 남녀 간의 관계에서 상호 이해와 신뢰를 증진시키며, 갈등을 해소하고 사랑과 안정감을 조성하는 데 중요합니다. 상호 이해와 신뢰를 바탕으로 한 대화와 스트레스 관리를 통해 관계를 유지하고 상호 의지를 키우는 것이 중요합니다. 또한, 정서적인 행동은 사회적인 관계에서 상호 의지와 소통을 통해 다양한 상황에서 상호 작용하고 지원받는 데 도움이 됩니다. 정서적인 행동은 사람 간의 상호작용과 지원을 통해 다양한 상황에서 상호 작용하고 지원받는 데 도움이 됩니다.",
#   "is_science": true
# }
#
# Test 42
# Question: [{'role': 'user', 'content': 'DNA 조각들이 서로 결합되도록 돕는 것은?'}]
# Answer: {
#   "answer": "DNA 결합을 돕는 것은 DNA 리가제나 DNA 리간드입니다.",
#   "is_science": true
# }
#
# Test 43
# Question: [{'role': 'user', 'content': '해가 뜨는 현상이 지구의 자전과 관련있어?'}]
# Answer: {
#   "answer": "해가 뜨는 현상은 지구의 자전과 관련이 있습니다. 지구는 해가 뜨고 지는 현상을 경험하는 동안 지구의 자전축과 적위에 의해 발생합니다. 해가 뜨는 현상은 지구의 표면과 자전축에 의해 발생하는 현상으로, 일출 시간은 동쪽으로 이동하며, 해가 뜨는 시간은 지구의 표면과 적위에 따라 변화합니다. 이러한 현상은 지구의 자전과 표면의 특성에 의해 발생하는 것입니다.",
#   "is_science": true
# }
#
# Test 44
# Question: [{'role': 'user', 'content': '두 물질이 다른 분자구조나 화학적인 성분으로 이루어져 있다는 것을 어떻게 알 수 있나요?'}]
# Answer: {
#   "answer": "두 물질이 다른 분자구조나 화학적 성분으로 이루어져 있다는 것을 알아내는 방법은 두 분자의 구조를 비교하고, 화학적 특성을 분석하여 확인할 수 있습니다. 또한, 두 물질의 화학적 특성을 비교하여 다른 분자들 간의 상호작용을 파악할 수 있습니다. 또한, 화학적인 성분에 따라서는 pH나 화학적 반응을 통해 확인할 수 있습니다.",
#   "is_science": true
# }
#
# Test 45
# Question: [{'role': 'user', 'content': '수성이 뜨거운 이유는?'}]
# Answer: {
#   "answer": "수성은 태양으로부터 매우 가까운 궤도(0.304 AU)를 도는데, 이는 수성이 태양에 매우 가까워서 뜨거운 이유입니다. 수성의 궤도는 태양과의 거리에 따라 온도가 매우 높고, 수성의 대기는 거의 없어서 태양의 복사에 노출되는 시간이 길기 때문에 수성은 매우 뜨거운 행성입니다.",
#   "is_science": true
# }
#
# Test 46
# Question: [{'role': 'user', 'content': '하구 퇴적지의 기능에 대해 알려줘.'}]
# Answer: {
#   "answer": "하구 퇴적지는 강이나 바다의 흐름으로부터 퇴적물이 쌓이는 지형으로, 강물이나 파도 등의 흐름에 의해 퇴적물이 쌓이면서 형성됩니다. 이러한 지형은 강의 유역과 연결된 지역에서 발생하며, 강물의 흐름과 퇴적물의 층으로 인해 다양한 이점을 제공합니다. 하구 퇴적지의 기능은 토양의 토양수분을 조절하고, 산업, 농업, 건설용지 등 다양한 용도로 활용됩니다. 또한, 하구에서의 생태계와 생물다양성을 유지하고 생태적인 이점을 제공합니다.",
#   "is_science": true
# }
#
# Test 47
# Question: [{'role': 'user', 'content': '디엔에이에서 퓨린과 피리미딘은 어떤 비율로 존재하는가?'}]
# Answer: {
#   "answer": "주어진 정보로는 디엔에이에서 퓨린과 피리미딘의 비율에 대한 구체적인 정보를 찾을 수 없습니다.",
#   "is_science": true
# }
#
# Test 48
# Question: [{'role': 'user', 'content': 'interferon의 역할에 대해 알려줘.'}]
# Answer: {
#   "answer": "인터페론은 면역 체계에서 세포의 증식을 억제하고 세포 사이의 상호작용을 조절하는 역할을 합니다. 이러한 역할은 인터페론이 세포와 상호작용하여 면역 반응을 조절하고 결국 세포의 증식을 억제함으로써 면역 체계의 균형을 유지하는 데 기여합니다.",
#   "is_science": true
# }
#
# Test 49
# Question: [{'role': 'user', 'content': '하나의 유전자에서 여러가지 단백질이 만들어질 수 있는 원인은?'}]
# Answer: {
#   "answer": "하나의 유전자에서 여러 가지 단백질이 만들어질 수 있는 원인은 유전자의 다양한 스플라이싱 현상과 유전자의 다형성 때문입니다. 이러한 다양성은 유전자 내의 특정 부위의 변이로 인해 발생하며, 이 변이는 다양한 개체들에게 적응할 수 있도록 합니다. 또한 유전자는 사람의 성장 요소를 결정하는데, A형 유전자, B형 유전자, AB형 유전자, O형 유전자로 구분되며, 각 유전자형은 다른 유전자형과의 조합에 따라 결정되는 성질이 다릅니다. 유전자는 다른 유전자형과의 조합에 따라 다양한 성질을 결정하며, 이러한 다양성은 사람의 특성을 결정하는 데 중요합니다. 따라서 유전자 다양성은 우리의 다양한 특성과 성질을 결정하는데 중요하며, 사람의 특성과 환경 요소, 학습 환경, 유전적 요소 등 다양한 요소에 의해 결정됩니다. 이러한 이유로 우리는 유전자 다양성을 다양한 환경에서 발현되는 특성과 결합하여 이해해야 합니다.",
#   "is_science": true
# }
#
# Test 50
# Question: [{'role': 'user', 'content': '질산을 통한 염화물 침전시 염소의 비율을 구하는 방법은?'}]
# Answer: {
#   "answer": "죄송합니다, 주어진 정보로는 질산을 통한 염화물 침전시 염소의 비율을 구하는 방법에 대한 정보를 찾을 수 없습니다.",
#   "is_science": false
# }
#
# Test 51
# Question: [{'role': 'user', 'content': '이제 그만 얘기해!'}]
# Answer: {
#   "answer": "죄송합니다, 과학 지식과는 무관한 내용이라 답변을 드릴 수 없습니다.",
#   "is_science": false
# }
#
# Test 52
# Question: [{'role': 'user', 'content': '오늘 너무 즐거웠다!'}]
# Answer: {
#   "answer": "너무 즐거우셨다니 다행입니다. 즐거운 시간을 보내셨다니 기쁩니다. 과학적인 내용은 아니지만, 행복한 시간을 보내셨다니 다행입니다.",
#   "is_science": false
# }
#
# Test 53
# Question: [{'role': 'user', 'content': '우울한데 신나는 얘기 좀 해줘!'}]
# Answer: {
#   "answer": "최근 연구에 따르면, 음악이 우울증 증상을 완화시키고 긍정적인 감정을 유발하는 것으로 나타났습니다. 특히 12주 간의 연구에서, 우울증의 초기 징후를 보이는 환자들은 4주간 매일 1만 단계의 걸음을 걷는 것으로 치료효과가 나타났습니다. 이러한 연구 결과는 우울증의 진단과 관리에 중요한 도구로 활용될 수 있습니다.",
#   "is_science": true
# }
#
# Test 54
# Question: [{'role': 'user', 'content': '연구자가 갖추어야 할 태도와 자세가 뭘까?'}]
# Answer: {
#   "answer": "연구자가 가져야 할 태도와 자세는 책임감과 윤리, 창의성과 학습에 대한 열정입니다. 연구자는 인간의 존엄과 윤리적 책임을 중시하고, 인간의 삶과 문제에 대한 관심을 가지며, 사회적 가치와 발전을 고려해야 합니다. 또한, 연구자는 자기주도적 학습과 학문적 호기심을 갖고, 타인과의 협력과 소통을 통해 새로운 아이디어를 창출하고 발전시켜야 합니다. 연구자는 사회와 개인의 발전을 고려하며, 사회적 책임과 도덕적 의무를 이행하고, 인간의 행복과 발전을 위해 노력해야 합니다.",
#   "is_science": true
# }
#
# Test 55
# Question: [{'role': 'user', 'content': '나이가 들수록 시간이 더 빨리 가는 것 처럼 느끼게 되는 원인은?'}]
# Answer: {
#   "answer": "나이가 들수록 시간이 더 빨리 가는 것 처럼 느끼는 이유는 여러 가지가 있습니다. 먼저, 인간의 뇌는 경험과 기억을 기반으로 시간을 인식합니다. 나이가 들면서 새로운 경험과 기억이 줄어들어서 시간이 빨리 가는 것처럼 느껴지기도 합니다. 또한, 일상적인 활동이나 관심사가 더 다양해지고 복잡해지면서 더 많은 활동과 정보를 처리하게 되어 시간이 빨리 가는 것으로 느껴지기도 합니다. 또한, 일상적인 활동이 더 다양해지고 관심사가 더 많아지면서 새로운 경험을 많이 하게 되고, 정보 처리 능력이 높아지면서 시간이 빨리 가는 것으로 느껴지기도 합니다.",
#   "is_science": true
# }
#
# Test 56
# Question: [{'role': 'user', 'content': '퇴직한 사람들에게 사회 보장은 어떤 의미인가?'}]
# Answer: {
#   "answer": "퇴직한 사람들에게 사회 보장은 경제적 안정과 안위를 제공하여 노후를 준비하고 안락한 삶을 유지할 수 있도록 돕는 제도입니다. 사회 보장은 개인의 사회적, 경제적 안정, 건강 상태, 가족 권익 등을 보호하고 비약적인 경제적 안정을 보장합니다. 이를 통해 퇴직 후의 삶을 준비하고, 경제적 부담을 줄일 수 있습니다.",
#   "is_science": false
# }
#
# Test 57
# Question: [{'role': 'user', 'content': '사람이나 물체가 지구 위에서 땅속으로 꺼지거나 바깥으로 튕겨나가지 않고 가만히 서 있을 수 있잖아?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 이유를 힘의 원리로 설명해줘.'}]
# Answer:
# {
#   "answer": "힘의 원리에 따르면 물체는 두 가지 경우에만 정지할 수 있습니다. 첫 번째로, 중력의 영향으로 땅에 붙어 있는 경우입니다. 이는 중력이 물체를 땅으로 끌어당기는 결과로 발생하는 현상과 마찬가지입니다. 두 번째로, 중력의 반대 방향으로 밀려나는 경우에도 정지할 수 있습니다. 이 경우는 물체의 중력을 상쇄시키는 결과로 발생합니다. 이 두 경우의 힘은 땅으로부터 사용하여 물체를 정지시키는 힘과 반대 방향으로 밀어내는 힘으로, 물체를 땅으로부터 사용하여 정지시키는 동력-반력 관계를 설명합니다. 중력은 물체의 무게를 가져다주며, 우리가 상쇄시키는 동력을 설명하는 데 도움을 줍니다. 중력의 힘은 상대적으로 작은 힘이며, 물체의 동력을 상쇄시키는 데 사용됩니다. 따라서, 힘의 원리에 따르면 물체가 땅에 붙어 있는 경우, 중력의 영향으로 물체를 정지시키는 힘과 반대 방향으로 밀어내는 힘으로 인해 정지할 수 있습니다.",
#   "is_science": true
# }
#
# Test 58
# Question: [{'role': 'user', 'content': '씨앗의 기능에 대해 자세히 알려줘?'}]
# Answer: {
#   "answer": "씨앗은 생물이나 식물을 생성할 수 있는 물질을 담고 있습니다. 씨앗은 자연적으로 씨앗을 품고, 발아, 성장을 거쳐 새로운 생명을 만들어냅니다. 씨앗의 씨앗은 씨앗의 존재와 번식을 지원하며, 씨앗이 산란하고, 씨앗이 산란하는 방법을 지원합니다. 씨앗의 씨앗은 번식을 지원하고, 다양한 기능을 수행합니다. 씨앗은 생장과 생활의 많은 부분을 포함하고 있으며, 이런 부분을 가지고 씨앗이 산란하고, 번식하는 방법을 지원합니다. 씨앗은 또한 다양한 환경에 적응하여 번식하고, 생존할 수 있는 능력을 가지고 있습니다.",
#   "is_science": true
# }
#
# Test 59
# Question: [{'role': 'user', 'content': '친환경 재생 가능 재료가 어떤것들이 있나?'}]
# Answer: {
#   "answer": "친환경 재생 가능한 재료로는 너트로펜, 친환경 너트로펜 2가지가 있습니다. 이러한 재료들은 환경에 무해하며 재활용이 가능합니다. 또한, 아이오딘화 납(PbI2)의 용해도 곱염기계수(K_sp)는 25°C에서 4.0 × 10^-9입니다. 이는 1.00 L의 물에 1.0 mmol의 PbI2가 용해될 수 있다는 것을 의미합니다.",
#   "is_science": true
# }
#
# Test 60
# Question: [{'role': 'user', 'content': '남미의 라틴 역사에 대해 알려줘.'}]
# Answer: {
#   "answer": "남미의 라틴 역사에 대해 알려드릴게요. 남미는 라틴 아메리카로 불리며, 라틴어를 기반으로 하는 문화와 언어를 갖고 있습니다. 남미는 다양한 역사적 배경을 가지고 있으며, 특히 스페인, 포르투갈, 네덜란드, 영국 등 다양한 국가들의 영향을 받아 많은 변화를 겪었습니다. 라틴 아메리카는 남미의 다양한 문화와 역사적인 요소를 반영하며, 라틴 아메리카의 사회와 경제에 큰 영향을 미치고 있습니다. 또한 라틴 아메리카는 남미의 다양한 문화적인 특징을 반영하며, 사람들의 풍부한 생활과 이해를 즐기고 있습니다. 라틴 아메리카는 남미의 다양한 문화적인 특징을 반영하며, 사람들의 풍부한 생활과 이해를 즐기고 있습니다.",
#   "is_science": false
# }
#
# Test 61
# Question: [{'role': 'user', 'content': '원자의 내부 구조에 대해 설명해줘.'}]
# Answer: {
#   "answer": "원자의 내부 구조는 양성자와 음성자로 구성되어 있습니다. 양성자는 원자의 중심에 위치하고 있으며, 양전하를 가지고 있습니다. 음성자는 양성자 주변을 돌면서 음전하를 가지고 있습니다. 또한, 원자의 중심에는 양성자와 음성자의 결합 법칙과 양전하의 결합 법칙에 의해 안정화된 상태입니다.",
#   "is_science": true
# }
#
# Test 62
# Question: [{'role': 'user', 'content': '난관의 기능에 대해 알려줘.'}]
# Answer: {"answer": "난관의 기능은 난관의 특성을 나타내는 정보를 가져오거나 반송할 때 생성되는 특정한 물질의 묶음이다. 이러한 난관의 기능은 셀벽을 형성하고 분비를 통해 세포의 생리와 특성을 결정하는 데 중요하다. 또한, 난관의 기능은 난관의 세포와 특성을 분석하여 세포의 상태와 특성을 결정하는 데 도움을 준다. 난관의 기능은 난관의 특성과 분석이 가능하며, 이를 통해 세포의 상태와 특성을 결정할 수 있다.", "is_science": true}
#
# Test 63
# Question: [{'role': 'user', 'content': '공기의 온도가 기후에 미치는 영향은?'}]
# Answer: {
#   "answer": "공기의 온도는 기후에 미치는 영향이 큽니다. 온도는 사람들의 활동과 건강에 영향을 미치며, 기후의 산란도와 변화에도 영향을 줍니다. 온도는 기후의 변화와 균형, 변화의 속도, 환경 변화 등을 결정하며, 기후의 특성과 상태에 따라 다양한 영향을 발휘합니다. 따라서, 온도는 기후의 특성과 변화에 따라 다양한 영향을 미치는 중요한 요소입니다.",
#   "is_science": true
# }
#
# Test 64
# Question: [{'role': 'user', 'content': '안녕 반갑다'}]
# Answer: {
#   "answer": "안녕하세요! 과학 지식과는 관련이 없는 내용 같아요. 다른 궁금한 점이 있으시면 물어보세요!",
#   "is_science": false
# }
#
# Test 65
# Question: [{'role': 'user', 'content': '평균을 구하는 코드를 작성중이야.'}, {'role': 'assistant', 'content': '네 무엇을 도와드릴까요?'}, {'role': 'user', 'content': '예외처리가 필요한 경우를 알려줘.'}]
# Answer:
# {
#   "answer": "평균을 구하는 코드에서 예외 처리가 필요한 경우는 입력값이 없거나 잘못된 형식일 때입니다. 예외 처리는 입력값의 유효성을 검증하고, 평균 계산을 위한 처리과정에서 발생할 수 있는 오류를 방지합니다. 예외 처리는 코드 안정성을 높이고, 사용자의 편의를 위해 필요합니다. 또한, 평균 계산 결과를 활용하는 다른 모듈이나 시스템의 안정성을 확인하는 것이 중요합니다. 평균을 구하는 코드에서는 입력값이나 계산과정에서 발생할 수 있는 예외를 고려하여 예외 처리를 구현해야 합니다.",
#   "is_science": true
# }
#
# Test 66
# Question: [{'role': 'user', 'content': '소프트웨어 개발이 사람의 편향없이 이루어질 수 있나?'}]
# Answer: {
#   "answer": "소프트웨어 개발이 완전히 편향 없이 이루어지는 것은 어렵습니다. 이는 소프트웨어가 인간의 의사결정에 의해 설계되고 구축되기 때문입니다. 또한, 로봇은 인간의 편향을 반영하고, 결정을 내리며, 책임을 질 수 있습니다. 이러한 요소들은 사람의 편향 없이 소프트웨어가 개발되는 것을 어렵게 만듭니다. 따라서 소프트웨어의 개발과 사용에는 책임과 투명성이 필요합니다.",
#   "is_science": true
# }
#
# Test 67
# Question: [{'role': 'user', 'content': '전체 인구에서 특정 유전자의 비율이 변하지 않고 유지되는 상태를 뭐라고 해?'}]
# Answer: {
#   "answer": "유전자 주파의 유지를 의미하는 것으로, 유전자 주파는 시간이 지나도 변하지 않고 유지되는 상태를 가리킵니다. 유전자 주파는 선택된 개체에 대해 또 다른을 모두 포함하며, 순수성 및 광역성을 결정하는 특성을 가지고 있습니다. 이는 개체의 유전적 다양성과 선택적인 특성을 결정하는데 중요한 역할을 합니다. 유전자 주파의 유지는 유전적 다양성과 선택적 특성을 유지하는데 중요한 역할을 합니다. 이는 유전적 다양성의 유지와 선택적 특성을 결정하는데 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 68
# Question: [{'role': 'user', 'content': '지구가 생겨난지 얼마나 오래 되었는지 확인하는 방법은?'}]
# Answer: {
#   "answer": "지구의 나이를 확인하는 방법은 바위층의 연대를 조사하거나, 지질학적으로 측정하는 등 다양한 방법으로 확인할 수 있습니다. 이러한 방법들은 지구의 역사를 추적하고 다른 지질학자들과 협력하여 정보를 공유하는 등의 과정을 거치게 됩니다. 이러한 방법들은 지구의 역사를 추적하고 다른 지질학자들과 협력하여 정보를 공유하는 등의 과정을 거치게 됩니다. 지구의 나이를 확인하는 방법은 다양한 지질학적 정보를 조합하여 결정되며, 이는 지구의 역사와 관련된 복잡한 프로세스를 반영합니다.",
#   "is_science": true
# }
#
# Test 69
# Question: [{'role': 'user', 'content': '성적인 자극이 발생하는 과정에 대해 알려줘.'}]
# Answer: {
#   "answer": "성적인 자극이 발생하는 과정은 대략적으로 다음과 같습니다. 성적 자극이나 유혹을 받으면 뇌의 특정 영역인 피팅스가 활성화되어 관여합니다. 이로 인해 성적 자극이나 유혹에 대한 욕구가 증폭되고 관련된 결정이 내려지게 됩니다. 이러한 과정은 대략적으로 10초에서 30초 사이에 시작되며, 성적 자극이 성숙의 중요한 부분에서 발생하므로, 성적 자극은 성숙의 중요한 부분에서 효과적으로 처리되며, 결정이 증폭되는 것으로 보입니다. 성적 자극의 유혹은 성적 자극이 뇌의 특정 영역에서 발생하므로, 성적 자극은 성숙의 중요한 부분에서 결정을 내리는 데 도움이 됩니다. 성적 자극의 유혹은 성적 자극이 뇌의 특정 영역에서 발생하므로, 성적 자극은 성숙의 중요한 부분에서 결정을 내리는 데 도움이 됩니다. 성적 자극의 유혹은 성적 자극이 뇌의 특정 영역에서 발생하므로, 성적 자극은 성숙의 중요한 부분에서 결정을 내리는 데 도움이 됩니다.",
#   "is_science": true
# }
#
# Test 70
# Question: [{'role': 'user', 'content': '전선 주위로 흐르는 자기장의 모습은 어떻게 보이나?'}]
# Answer: {
#   "answer": "전선 주위로 흐르는 자기장은 LED 등의 표시기로는 보이지 않습니다. 이는 전류 흐름의 특성상 눈으로 감지하기 어렵기 때문입니다. 전선 주위의 자기장은 특정 장비를 사용하여 감지할 수 있으며, 이때는 특별한 규모의 자기장 측정기가 필요합니다.",
#   "is_science": true
# }
#
# Test 71
# Question: [{'role': 'user', 'content': '간헐적으로 높은 강도의 운동을 하면 어떤 효과가 있나요?'}]
# Answer: {"answer": "간헐적으로 높은 강도의 운동을 하면 운동 후 대사율이 증가하고, 근육량이 증가하며 체지방이 감소합니다. 또한, 혈당 및 혈중 지질 수치가 개선되고, 심혈관 기능이 향상됩니다. 이로 인해 대사 증진, 체지방 감소, 근육량 증가 등의 효과를 얻을 수 있습니다.", "is_science": true}
#
# Test 72
# Question: [{'role': 'user', 'content': '아세틸 콜린의 역할이 뭐야?'}]
# Answer: {"answer": "아세틸콜린은 신경 전달 물질로 작용하며, 뇌와 근육 간의 신호 전달에 관여합니다.", "is_science": true}
#
# Test 73
# Question: [{'role': 'user', 'content': '디엔에이와 단백질의 관계와 역할에 대해 설명해줘.'}]
# Answer: {
#   "answer": "디엔에이(DNA)는 유전 정보를 담고 있는 분자로서, 유전자를 구성하는 단위로서 기능을 담당합니다. DNA는 우리의 유전정보, 세포, 생식, 대사 등 다양한 기능을 담당하며 중요한 역할을 합니다. 단백질은 셀의 기능을 담당하는 유용한 분자입니다. 단백질은 우리의 특성, 대사, 운동, 소화 등 다양한 기능을 담당하며 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 74
# Question: [{'role': 'user', 'content': '자전축이 기후에 미치는 영향은?'}]
# Answer: {"answer": "자전축은 지구의 기후에 미치는 영향이 큽니다. 자전축은 지구의 기후와 기후 변화에 영향을 미치는 중요한 요소입니다. 자전축은 지구의 기후와 기후 변화에 영향을 미치는 중요한 역할을 합니다. 자전축은 우리가 하루 동안 경험하는 낮과 밤의 변화를 조절하고, 지구의 기후와 날씨를 결정합니다. 또한, 자전축은 지구의 기후 변화와 날씨 변화에 영향을 미치는데, 이는 우리의 일상 생활에 큰 영향을 미칩니다. 기후 변화 → 자전축 → 영향 → 낮과 밤의 변화와 기후 변화를 조절하는 역할을 합니다.", "is_science": true}
#
# Test 75
# Question: [{'role': 'user', 'content': '여행을 통해 얻을 수 있는 좋은 점들이 뭐가 있어?'}]
# Answer: {
#   "answer": "여행을 통해 얻을 수 있는 좋은 점들은 다양한 경험과 기억을 만들어내는 것, 새로운 문화를 경험하고 이해하는 것, 여유롭고 편안한 시간을 보내며 스트레스를 해소하는 것, 자연의 아름다움을 감상하고 도시의 문화를 경험하는 것, 다양한 스포츠와 문화 활동을 통해 즐거움을 느끼는 것 등이 있습니다.",
#   "is_science": false
# }
#
# Test 76
# Question: [{'role': 'user', 'content': '은하들이 점점 멀어지고 있다던데 맞아?'}, {'role': 'assistant', 'content': '네 맞아요.'}, {'role': 'user', 'content': '어떤 물리적인 현상을 보고 그걸 알게 되었어?'}]
# Answer:
# {
#   "answer": "은하들이 서로 멀어지고 있는 현상은 우주의 팽창으로 인해 발생하는 현상입니다. 이 현상은 1929년에 에드윈 허블에 의해 처음 관측되었습니다. 허블은 별들의 붉은 이동을 관측하여 우주가 팽창하고 있다는 결론을 내렸습니다. 이후 우주의 팽창은 다양한 천문학적 증거를 통해 확인되었습니다. 이러한 현상은 우주의 탄생과 진화에 관한 중요한 정보를 제공합니다. 우리는 이를 통해 우주의 형태와 진화에 대한 다양한 정보를 얻을 수 있습니다.",
#   "is_science": true
# }
#
# Test 77
# Question: [{'role': 'user', 'content': '목성 trojan의 특징에 대해 알려줘.'}]
# Answer: {
#   "answer": "목성 Trojan은 목성 주위의 Lagrange 점에 위치한 천체들을 가리키는 용어입니다. Lagrange 점은 두 천체 사이의 중력으로 인해 특별한 안정한 위치를 가지는 점으로, 목성 Trojan은 목성과 그 위성 사이의 Lagrange 점에 위치한 천체들을 말합니다. 이러한 천체들은 목성의 중력과의 상호작용으로 인해 안정적인 궤도를 유지하며, 목성의 공전 주기와 거의 일치하는 궤도를 가집니다. 따라서 목성 Trojan은 목성과의 상호작용에 의해 안정적인 궤도를 유지하고 있는 천체들을 가리키는 용어입니다.",
#   "is_science": true
# }
#
# Test 78
# Question: [{'role': 'user', 'content': '슈퍼옥시드 디스무타아제 라는 효소에 대해 설명해줘.'}]
# Answer: {
#   "answer": "슈퍼옥시드 디스무타아제는 세포 내에서 활성산소를 생성하는 효소로, 세포의 대사 및 면역 반응에서 중요한 역할을 합니다. 이 효소는 세포의 대사를 촉진하고 활성산소의 생성을 촉진하여 세포의 생존을 돕습니다. 또한, 슈퍼옥시드 디스무타아제는 세포 내에서 활성산소를 이용한 다양한 기능을 수행하며, 세포의 생존, 세포 신호 및 세포 손상 등에 관여합니다.",
#   "is_science": true
# }
#
# Test 79
# Question: [{'role': 'user', 'content': '네바다주에 살고 있는데...'}, {'role': 'assistant', 'content': '네 그러시군요?'}, {'role': 'user', 'content': '여기 비가 많이 오지 않는 이유가 뭐야?'}]
# Answer:
# {
#   "answer": "네바다 주에서 비가 많이 오지 않는 이유는 주변 산들이 비를 막아서 그렇습니다. 또한, 네바다 주의 위치와 대기 압력의 영향으로 인해 강수량이 적을 수 있습니다. 또한, 네바다 주의 대부분 지역은 사막 지형이기 때문에 강수량이 적습니다.",
#   "is_science": true
# }
#
# Test 80
# Question: [{'role': 'user', 'content': '어떤 물체를 매우 크게 확대해서 볼수 있는 기계는?'}]
# Answer:
# {
#   "answer": "물체를 매우 크게 확대해서 볼 수 있는 기계는 전자 현미경입니다.",
#   "is_science": true
# }
#
# Test 81
# Question: [{'role': 'user', 'content': 'merge sort 알고리즘에 대해 설명해줘.'}]
# Answer: {
#   "answer": "병합 정렬(merge sort)은 분할 정복 알고리즘의 하나로, 리스트를 반으로 나눈 뒤 각각을 정렬하고, 정렬된 부분 리스트를 합쳐서 전체 리스트를 정렬하는 방식의 알고리즘입니다.",
#   "is_science": true
# }
#
# Test 82
# Question: [{'role': 'user', 'content': '심해가 생태계에 미치는 영향은?'}]
# Answer: {"answer": "심해는 지구 생태계에 매우 중요한 영향을 미치며, 다양한 생물이 서식하고 상호작용합니다. 심해 생태계는 다른 생태계와 연결되어 있어 상호 의존적인 관계를 가지며, 해양 생태계의 다양한 생물들과 생태학적 상호작용에 영향을 미칩니다. 또한, 심해는 지구 생태계의 안정성과 생물 다양성에 중요한 영향을 미치며, 심해의 변화는 다른 생태계와의 상호작용에도 영향을 줍니다. 따라서 심해 생태계는 지구 생태계의 안정성을 유지하는 데 중요한 역할을 합니다.", "is_science": true}
#
# Test 83
# Question: [{'role': 'user', 'content': '저항이 2배로 증가하면 전력은 어떻게 되나?'}]
# Answer: {
#   "answer": "저항이 2배로 증가하면 전력은 4배로 감소합니다. 전력은 전압의 제곱을 저항으로 나눈 값이기 때문에, 저항이 증가하면 전력은 제곱에 반비례하여 감소합니다.",
#   "is_science": true
# }
#
# Test 84
# Question: [{'role': 'user', 'content': '산에 불이 나면 동식물이 많이 죽을텐데'}, {'role': 'assistant', 'content': '네 안타까운 일입니다.'}, {'role': 'user', 'content': '불난 후에 자연의 회복 과정은 어떻게 돼?'}]
# Answer: {
#   "answer": "산불 후 자연의 회복 과정은 다양한 단계를 거치게 됩니다. 먼저, 산불로부터 생존한 동물들이 새로운 생태계를 구축하고, 씨앗, 나무, 풀을 심어서 숲을 복원하게 됩니다. 이후 몇 년 동안은 산불로부터 생존한 동물들이 새로운 생태계를 구축하고, 씨앗, 나무, 풀을 심어서 숲을 복원하게 됩니다. 산불로부터 생존한 동물들은 새로운 환경에서의 적응과 상호작용을 통해 생태계를 회복하고, 씨앗과 나무의 성장을 통해 숲을 재생합니다. 이러한 과정은 산불의 피해를 최소화하고, 산불로부터 생존한 동물들이 새로운 환경에서의 적응과 상호작용을 통해 생태계를 회복하고, 씨앗과 나무의 성장을 통해 숲을 재생합니다. 산불의 피해를 최소화하고, 산불로부터 생존한 동물들이 새로운 환경에서의 적응과 상호작용을 통해 생태계를 회복하고, 씨앗과 나무의 성장을 통해 숲을 재생합니다. 이러한 과정은 산불의 피해를 최소화하고, 산불로부터 생존한 동물들이 새로운 환경에서의 적응과 상호작용을 통해 생태계를 회복하고, 씨앗과 나무의 성장을 통해 숲을 재생합니다.",
#   "is_science": true
# }
#
# Test 85
# Question: [{'role': 'user', 'content': 'DNA 분해 효소의 역할에 대해 알려줘.'}]
# Answer: {
#   "answer": "DNA 분해 효소는 DNA 분자를 분해하는 역할을 합니다. 이 효소는 DNA 분자의 A:T 비율을 2:3으로 유지하며, 새로운 DNA를 합성할 때 A와 T의 비율을 유지하도록 도와줍니다. 또한, 전체 DNA 중에서 이전 DNA의 메틸화 패턴을 유지하는 역할을 하는 DNMT1 효소도 있습니다. 이 효소는 DNA 메틸화의 유지와 새로운 DNA의 메틸화 패턴을 조절합니다. 또한, 헤모글로빈은 산소(O2)와 이산화탄소(CO2) 분자에 대해 반응하는 역할을 합니다. 이는 혈액 내의 산소와 이산화탄소의 교환을 조절합니다. 또한, 헤모글로빈의 pH는 혈액의 산소와 이산화탄소 교환에 영향을 미치며, pH가 낮아지면 헤모글로빈은 산소를 더 적극적으로 방출합니다.",
#   "is_science": true
# }
#
# Test 86
# Question: [{'role': 'user', 'content': '특정 농도의 황산 sample을 만드는 방법?'}]
# Answer: {
#   "answer": "황산을 특정 농도로 만드는 방법에 대한 정보가 아닌 것 같습니다.",
#   "is_science": false
# }
#
# Test 87
# Question: [{'role': 'user', 'content': '달은 1년 동안 지구를 몇바퀴 도는가?'}]
# Answer: {
#   "answer": "달은 1년 동안 지구를 13바퀴 돕니다.",
#   "is_science": true
# }
#
# Test 88
# Question: [{'role': 'user', 'content': '개인의 생물학적, 사회적인 특성 형성에 영향을 미치는 요소에 대해 설명해줘.'}]
# Answer: {
#   "answer": "개인의 생물학적, 사회적인 특성 형성에 영향을 미치는 요소에는 유전적 요인, 환경적 요인, 사회적 상호작용, 문화적 영향 등이 있습니다. 특히 유전적 요인은 개인의 생물학적 특성과 성향을 결정하며, 환경적 요인은 사회적 상호작용과 문화적 영향을 통해 형성됩니다. 이러한 요소들은 각각의 상황에서 상대적인 영향을 미치며, 상황에 따라 다양한 특성을 형성합니다.",
#   "is_science": true
# }
#
# Test 89
# Question: [{'role': 'user', 'content': '너는 누구야?'}]
# Answer: {"answer": "죄송합니다, 제가 도와드릴 수 있는 정보가 아닌 것 같습니다.", "is_science": false}
#
# Test 90
# Question: [{'role': 'user', 'content': '지각은 주로 무엇으로 이루어져 있어?'}]
# Answer: {
#   "answer": "지각은 빛과 물질로 이루어져 있습니다. 빛은 주로 전자와 전자의 진동으로 인해 발생하며, 물질은 원자와 분자의 상호작용으로 구성되어 있습니다. 빛과 물질은 상호작용하여 에너지를 전달하고, 이 상호작용은 광학적 현상을 발생시키며, 이를 통해 우리는 주변을 인지하고 환경을 탐험합니다. 따라서 지각은 정보처리를 통해 발생하며, 복잡한 상호작용을 통해 발생합니다. 빛과 물질의 상호작용은 광학적 현상을 발생시키며, 이를 통해 우리는 주변을 탐험하고, 환경을 인식합니다. 이러한 상호작용은 복잡한 정보를 전달하며, 다양한 상황에서 신속한 판단을 가능하게 합니다.",
#   "is_science": true
# }
#
# Test 91
# Question: [{'role': 'user', 'content': '오세아니아 섬나라에 광견병이 있어?'}]
# Answer: {
#   "answer": "오세아니아 섬나라에는 광견병이 있습니다. 광견병은 오세아니아 지역의 특정 지역에서 발견되는 질병으로, 특히 광견병의 유전적 증상을 보이는 개들은 국제적으로 이동이 제한되며, 국내에서는 특별한 주의가 필요합니다. 광견병은 주로 동물 사육 환경에서 전염되며, 예방주사와 적절한 관리가 필요합니다.",
#   "is_science": true
# }
#
# Test 92
# Question: [{'role': 'user', 'content': '추울때 폭이 넓은 회색의 구름이 끼면 어떤 날씨가 예상되나?'}]
# Answer: {
#   "answer": "추울 때 폭이 넓은 회색의 구름이 끼면 비나 눈이 올 확률이 높고, 이에 따라 기온이 상승하고 흐린 날씨가 예상됩니다. 이는 폭이 넓은 구름이 끼면서 비나 눈이 오는 경우가 많고, 이에 따라 기온이 상승하여 흐린 날씨가 될 가능성이 높습니다. 또한, 회색 구름이 끼면서 비나 눈이 오면서 기온이 상승하는 경우 1년 내내 적은 경우의 기온이 발생합니다. 이는 기온이 상승하는 사람들이 더욱 활발하고 변화를 좋아하는 특성으로 보입니다. 또한, 회색 구름이 끼면서 비나 눈이 오면서 기온이 상승하는 경우에는 기온이 상승하여 더운 날씨를 경험하는 지역이 많습니다. 이는 기온이 상승하여 더운 지역에서는 적은 경우의 비가 오는 경우가 많아서 더운 지역의 특성으로 보입니다. 이에 따른 결과는 비나 눈이 오는 경우가 많은 경우에는 활발한 사람들이 더욱 활발하고 변화를 좋아하는 특성으로 보입니다.",
#   "is_science": true
# }
#
# Test 93
# Question: [{'role': 'user', 'content': '안정성이 높은 PRP를 만드는 방법에 대해 알려줘.'}]
# Answer: {
#   "answer": "안정성이 높은 PRP를 만드는 방법에는 다양한 실험, 수행 및 분석을 통해 안정성을 검증하고, 안정성을 향상시키는 방법을 모색하는 것이 포함됩니다. 안정성 검증을 통해 안정성을 확인하고, 필요한 수정을 통해 안정성을 향상시키는 것이 중요합니다. 안정성을 높이기 위한 방법 중 하나로는 실험 중에 발생할 수 있는 불안정성을 예방하고, 안정성을 향상시키기 위한 조치를 취하는 것이 있습니다. 또한, 안정성을 확인하고 필요한 수정을 통해 안정성을 향상시키는 것이 중요합니다. 이러한 방법들을 통해 안정성을 높일 수 있습니다.",
#   "is_science": true
# }
#
# Test 94
# Question: [{'role': 'user', 'content': '너 모르는 것도 있니?'}]
# Answer: {
#   "answer": "죄송합니다, 제가 그것에 대해 알고 있는 정보가 충분하지 않습니다.",
#   "is_science": false
# }
#
# Test 95
# Question: [{'role': 'user', 'content': '중성자의 특징에 대해 설명해줘.'}]
# Answer: {
#   "answer": "중성자는 원자의 구성 요소 중 하나로서 양성자와는 달리 전하를 가지고 있지 않습니다. 중성자는 원자핵의 구성 요소로서 전자와 양성자로 이루어진 원자 내부에서 주로 발견되며, 중성자의 질량은 양성자보다 조금 더 큽니다. 또한 중성자는 중성자 별과 같은 천체에서 발견되며, 중성자의 밀도는 매우 높고 중력이 강합니다.",
#   "is_science": true
# }
#
# Test 96
# Question: [{'role': 'user', 'content': '플랑크톤의 역할에 대해 알려줘.'}]
# Answer: {
#   "answer": "플랑크톤은 해양 생태계에서 중요한 역할을 합니다. 이들은 해양 식물의 기초로서 100분의 1 크기로서 존재하며, 생태학적으로는 1일에 10,000분의 1 크기로 번식합니다. 이들은 해양 생태계의 중요한 먹이로 작용하며, 해양 생물들의 번식과 생존에 중요한 영향을 미칩니다.",
#   "is_science": true
# }
#
# Test 97
# Question: [{'role': 'user', 'content': '기생과 공생의 차이에 대해 알려줘.'}]
# Answer: {
#   "answer": "기생과 공생의 차이는 기생은 호스트의 몸속이나 표면에서 생활하면서 이익을 얻는다. 이는 호스트의 생활 환경을 이용하며, 호스트의 영양분을 빼앗아 먹는 등의 방법으로 생존합니다. 반면에 공생은 두 종이나 여러 종의 생물이 상호 작용하여 상생 또는 협생을 하는 것을 말합니다. 공생은 두 종의 생물이 상호 작용하여 상생 또는 협생을 하며, 이를 통해 상생의 이점을 얻는다. 이러한 상생은 다양한 상황을 포함하며, 공생의 이점을 얻기 위한 다양한 전략을 취한다.",
#   "is_science": true
# }
#
# Test 98
# Question: [{'role': 'user', 'content': '강아지가 사회화되는 행동의 사례는 뭐가 있을까?'}]
# Answer: {
#   "answer": "강아지가 사회화되는 행동의 사례로는 주인과의 상호작용, 타인과의 교류, 사회적 상황에서의 행동 등이 있습니다. 또한 강아지는 놀이를 통해 사회화되기도 합니다. 강아지는 주인과의 상호작용을 통해 사회적인 교류를 경험하고, 타인의 존재와 물건을 인식하며, 사회적으로 적합한 행동을 학습합니다. 이러한 행동은 강아지의 사회적 발달과 행동에 중요한 영향을 미치며, 강아지의 사회화는 주인과의 상호작용, 타인과의 교류, 놀이 등을 통해 이루어집니다.",
#   "is_science": true
# }
#
# Test 99
# Question: [{'role': 'user', 'content': '너 잘하는게 뭐야?'}]
# Answer: {
#   "answer": "제가 잘하는 것은 과학적인 지식과 분석을 활용하여 문제를 해결하고, 과학적인 사고방식을 촉진하는 것입니다.",
#   "is_science": true
# }
#
# Test 100
# Question: [{'role': 'user', 'content': '지구에서 새로운 땅이 생겨나는 메커니즘은?'}]
# Answer: {"answer": "지구에서 새로운 땅이 생겨나는 메커니즘은 플레이트 틱토닉이라고 합니다. 지구 표면의 플레이트가 서로 충돌하거나 멀어지는 과정에서 산소, 화산, 지진 등의 현상을 발생시키며 새로운 지형을 형성합니다. 이러한 과정은 지구의 지진, 화산 폭발, 토지 이동 등의 현상을 통해 관측되며, 플레이트의 이동과 지구의 지각 변동을 발생시킵니다. 이러한 지각 변동은 지구의 지각과 지각 변동을 발생시키며, 새로운 지형을 형성합니다. 이러한 지각 변동은 지구의 지각과 지각 변동을 발생시키며, 새로운 지형을 형성합니다. 이러한 지각 변동은 지구의 지각과 지각 변동을 발생시키며, 새로운 지형을 형성합니다. 이러한 지각 변동은 지구의 지각과 지각 변동을 발생시키며, 새로운 지형을 형성합니다.", "is_science": true}
#
# Test 101
# Question: [{'role': 'user', 'content': '더러워진 엔진오일을 잘 처리하는 방법에 대해 알려줘.'}]
# Answer: {
#   "answer": "엔진 오일을 처리하는 방법은 오염된 오일을 안전하게 폐기하는 것이 중요합니다. 오염된 엔진 오일을 폐기할 때는 지역 법규를 준수해야 합니다. 자세한 내용은 지역 정부나 폐기물 처리 시설에 문의하시기 바랍니다.",
#   "is_science": false
# }
#
# Test 102
# Question: [{'role': 'user', 'content': '너 정말 똑똑하다!'}]
# Answer: {
#   "answer": "감사합니다! 제가 도와드릴 수 있는 다른 질문이 있으면 언제든지 물어보세요.",
#   "is_science": false
# }
#
# Test 103
# Question: [{'role': 'user', 'content': '다람쥐가 열매를 땅에 묻는 행동이 나무에 미치는 영향은?'}]
# Answer: {
#   "answer": "다람쥐가 열매를 땅에 묻는 행동은 나무에 다양한 영향을 미칩니다. 열매를 묻는 행위는 씨앗의 확산을 도와주며, 이는 나무의 새로운 생장을 촉진합니다. 또한, 열매를 묻는 행위는 지하의 미생물과의 상호작용을 통해 토양을 향상시키고 영양분을 공급합니다. 이러한 행위는 생태계의 순환을 촉진하고, 생태계의 안정성을 높일 수 있습니다. 따라서, 다람쥐의 열매 묻는 행동은 생태계의 다양성과 안정성을 높이는데 기여할 수 있습니다.",
#   "is_science": true
# }
#
# Test 104
# Question: [{'role': 'user', 'content': '새로운 생명체의 발생에 대한 오래된 믿음을 깨기 위해 어떤 방법이 사용되었나?'}]
# Answer: {"answer": "새로운 생명체의 발생에 대한 오래된 믿음을 깨기 위해 사용된 방법은 다양했습니다. 예를 들어, 17세기에는 실험적인 방법으로 접근하여 생명체의 발생과정을 연구하였습니다. 또한, 19세기에는 루이 파스퇴르가 발효를 막는 실험을 통해 생명체의 발생에 대한 오래된 믿음을 반박하였습니다. 또한, 현대의 과학적 방법론을 통해 다른 학자들이 생명체의 발생을 확인하고자 할 때 다양한 실험을 통해 확인이 이루어지며, 이를 통해 과학적인 증거를 통해 논증이 이루어지게 됩니다. 이러한 과학적 방법을 통해 새로운 생명체의 발생에 대한 오래된 믿음을 깨는데 도움이 되었습니다.", "is_science": true}
#
# Test 105
# Question: [{'role': 'user', 'content': '협곡이 형성되는 과정은?'}]
# Answer: {
#   "answer": "협곡이 형성되는 과정은 강의 유속이 빠르거나 물이 급격히 흘러서 강둑이 침식되어 협곡이 형성되는 것으로, 강의 유속이 빠를수록 침식률이 높아지며, 협곡의 깊이와 폭은 주로 강의 유속과 침식률에 의해 결정된다. 또한, 협곡을 형성하는 데는 강의 유속과 관련된 진동수의 변화도 영향을 미친다. 협곡을 형성하는 과정에서는 강의 유속과 진동수의 변화에 따른 침식률의 변화를 고려해야 하며, 협곡의 형성은 강의 힘과 관련된 다양한 요소를 고려하여 결정된다.",
#   "is_science": true
# }
#
# Test 106
# Question: [{'role': 'user', 'content': 'python 공부중인데...'}, {'role': 'assistant', 'content': '네 꼭 필요한 언어라서 공부해 두면 좋습니다.'}, {'role': 'user', 'content': '숫자 계산을 위한 operator 우선순위에 대해 알려줘.'}]
# Answer: {
#   "answer": "숫자 계산을 위한 operator 우선순위에 대해 알려드리겠습니다. 연산자는 연산을 수행하는 기호로, 연산자에 따라 연산의 우선순위와 시간 데이터를 처리할 수 있습니다. 연산자는 x좌표를 이용하여 덧셈을 우선적으로 처리하고, 이를 통해 시간 데이터를 순서적으로 처리할 수 있습니다. 연산자를 사용하여 숫자는 연산의 우선순위와 시간 데이터를 처리할 수 있고, 추가를 통해 연산을 처리할 수 있습니다. 연산자를 사용하여 연산의 우선순위와 시간 데이터를 처리하면, 데이터의 처리를 좀 더 효율적으로 할 수 있고, 추가를 통해 연산을 처리할 수도 있습니다.",
#   "is_science": true
# }
#
# Test 107
# Question: [{'role': 'user', 'content': '지구상에 존재하는 물 중 가장 많은 물은 바닷물이잖아?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '바닷물 말고 담수가 가장 많이 있는 곳이 어디야?'}]
# Answer: {
#   "answer": "바닷물 이외에도 담수가 많이 있는 곳이 있습니다. 이곳은 강, 호수, 눈, 얼음 등에서 찾을 수 있습니다. 특히 북극지방에서는 얼음이 많이 존재하며, 이 지역의 얼음은 담수로서 사용될 수 있습니다. 또한, 이 지역의 빙하와 빙산은 많은 담수를 포함하고 있으며, 이를 녹여서 이용할 수 있습니다. 따라서, 바닷물 이외의 담수는 다양한 지형과 환경에서 발견될 수 있으며, 이를 활용하는 방법에 따라 다양한 용도로 사용될 수 있습니다.",
#   "is_science": true
# }
#
# Test 108
# Question: [{'role': 'user', 'content': '폭풍을 쫓는 사람들이 누구야?'}]
# Answer: {
#   "answer": "폭풍을 쫓는 사람들은 폭풍쫓이라고 불리며, 주로 폭풍의 구조와 움직임을 연구하고 예측하는 과학자들이나 엔지니어들입니다. 폭풍쫓이들은 폭풍의 발달과 특성을 조사하고 폭풍 추적을 통해 데이터를 수집하여 폭풍의 움직임과 발전을 이해하려고 합니다. 이러한 연구를 통해 폭풍의 예측과 경로를 이해하는 데 도움이 됩니다.",
#   "is_science": true
# }
#
# Test 109
# Question: [{'role': 'user', 'content': '우라늄을 사용한 원자력 발전의 단점에 대해 알려줘.'}]
# Answer: {
#   "answer": "우라늄을 사용한 원자력 발전의 단점은 다음과 같습니다. \n1. 원자력 발전소의 안전 문제: 원자력 발전소는 사고 발생 시 방사선 유출과 환경 오염을 초래할 수 있습니다. 또한 우라늄은 오랜 기간 방사능을 가지고 있어, 인간 및 환경에도 영향을 줄 수 있습니다. \n2. 원자력 발전소의 관리 문제: 원자력 발전소는 우라늄 연료를 사용하여 발전합니다. 이로 인해 핵연료의 사용과 관련된 안전 및 관리 문제가 발생할 수 있습니다. \n3. 원자력 발전소의 경제성: 원자력 발전소의 핵연료, 운영 비용, 방사능 처리 비용 등이 상당한 비용을 요구합니다. 이에 따라 원자력 발전소의 경제성이 논란이 될 수 있습니다. \n4. 원자력 발전소와 관련된 환경 문제: 원자력 발전소는 폐기물 처리 문제와 관련이 있습니다. 또한 원자력 발전소의 핵연료와 관련된 환경 문제도 발생할 수 있습니다. \n이러한 단점으로 인해 원자력 발전은 안전 및 경제적인 측면에서 논란이 있습니다. 또한, 이러한 단점은 환경 문제와 관련된 책임과 인식의 문제를 야기할 수 있습니다.",
#   "is_science": true
# }
#
# Test 110
# Question: [{'role': 'user', 'content': '고체에서 액체로 변할 때 엔트로피는 어떻게 되나?'}]
# Answer: {
#   "answer": "고체에서 액체로 변할 때 엔트로피는 증가합니다. 이는 분자가 더 많은 자유도를 가지고, 액체 상태에서 더 많은 운동 에너지를 가지기 때문입니다.",
#   "is_science": true
# }
#
# Test 111
# Question: [{'role': 'user', 'content': '사회로부터의 감정적인 지원이 어떤 형태로 나타날 수 있어?'}]
# Answer: {
#   "answer": "사회적 지원은 다양한 형태로 나타날 수 있습니다. 사회적 지원은 개인이나 집단에게 제공되는 지원으로, 이는 경제적, 정서적, 정보적, 교육적 등 다양한 형태로 이루어질 수 있습니다. 이러한 지원은 사람들의 사회적 관계와 상호작용을 강화하며, 스트레스를 줄이고, 자아존중감을 높이는 데 도움을 줄 수 있습니다. 또한, 사회적 지원은 개인의 사회적 성공과 웰빙을 증진시키며, 사회적 관계의 품질을 향상시키는 데 도움을 줄 수 있습니다.",
#   "is_science": false
# }
#
# Test 112
# Question: [{'role': 'user', 'content': '석탄을 에너지원으로 사용할 때의 장단점이 뭐야?'}]
# Answer: {
#   "answer": "석탄을 에너지원으로 사용할 때의 장단점은 다양합니다. 이러한 석탄의 특성으로 인해 활용 가능한 분야가 다양하며, 경제적인 측면에서도 이점이 있습니다. 또한, 석탄의 에너지밀도와 사용 가능성으로 인해 산업의 생산 용량을 늘리고 경제적 효율을 높일 수 있습니다. 그러나 석탄의 사용은 환경 문제와 안전 문제를 야기할 수 있습니다. 따라서 석탄을 활용하고 발전하는 분야에서는 이러한 문제를 고려하여 대응해야 합니다.",
#   "is_science": true
# }
#
# Test 113
# Question: [{'role': 'user', 'content': '탄소의 내부 구조를 알아낼 수 있는 방법은?'}]
# Answer: {
#   "answer": "탄소의 내부 구조를 알아내는 방법으로는 입자 가속기를 사용하여 탄소 원자의 내부 구조를 연구하는 방법이 있습니다. 또한, 탄소의 내부 구조를 연구하는 방법으로는 X선 결정학, 전자 현미경 및 다양한 분광학적 기술을 활용하는 등 여러 실험적 방법이 활용됩니다. 그러나 탄소의 내부 구조를 직접적으로 관찰하고 연구하는 것은 실험적으로 어려운 부분이 있습니다.",
#   "is_science": true
# }
#
# Test 114
# Question: [{'role': 'user', 'content': '연구의 과정과 결과를 잘 기록해야 하는 이유?'}]
# Answer: {
#   "answer": "연구의 과정과 결과를 잘 기록하는 이유는 연구자가 실험 결과를 정확하게 기록하고 데이터의 일관성을 유지하여 연구의 타당성을 보장하기 위해서입니다. 또한, 연구 결과를 다른 연구자들과 공유하여 학문적인 진전을 이끌어내고, 향후 연구나 실험의 참고 자료로 활용하기 위해서도 중요합니다. 따라서 연구자는 연구 과정과 결과를 세심하게 기록하고 분석 방법을 명확히 기술하며 결과를 도출할 때의 근거를 명확히 기록하여야 합니다. 또한, 연구 결과를 분석하여 새로운 가설을 제시하고 다른 연구자들과 토의하여 학문적인 진전을 이끌어내기도 합니다. 따라서 연구자는 연구 결과를 정확하게 기록하고 분석하여 타당성을 보장하며, 다른 연구자들과의 공유와 토의를 통해 학문적인 진전을 도모해야 합니다.",
#   "is_science": true
# }
#
# Test 115
# Question: [{'role': 'user', 'content': '니가 대답을 잘해줘서 기분이 좋아!'}]
# Answer: {
#   "answer": "좋은 말씀 감사합니다. 제가 도와드릴 수 있는 과학적인 질문이 있으면 언제든지 물어봐 주세요.",
#   "is_science": false
# }
#
# Test 116
# Question: [{'role': 'user', 'content': '밀물과 썰물의 강도에 영향을 주는 요소들에 대해 알려줘.'}]
# Answer: {
#   "answer": "밀물과 썰물의 강도에 영향을 주는 요소는 다음과 같습니다: 1. 밀물과 썰물이 영향을 받는 요소로는 Estimated Daily Intake (EDI)가 Acceptable Daily Intake (ADI)보다 높을 경우, 썰물이 강해질 수 있습니다. 2. 썰물의 강도는 산소와 이산화탄소의 영향을 받으며, 이러한 환경 요소가 적절하게 유지되면 썰물이 강해질 수 있습니다. 3. 국제적인 요소 제어를 포함한 환경적 요소도 썰물의 강도에 영향을 줄 수 있습니다.",
#   "is_science": true
# }
#
# Test 117
# Question: [{'role': 'user', 'content': '우울한데 신나는 얘기 좀 해줄래?'}]
# Answer: {
#   "answer": "죄송하지만, 현재 제가 신나는 이야기를 들려드릴 수는 없습니다.",
#   "is_science": false
# }
#
# Test 118
# Question: [{'role': 'user', 'content': '이제 그만 얘기하자.'}]
# Answer: {"answer": "죄송합니다, 과학 지식과는 무관한 내용으로 답변드릴 수 없습니다.", "is_science": false}
#
# Test 119
# Question: [{'role': 'user', 'content': '유전 교차에서 복잡형질과 관련된 염색체 영역 식별 방법은?'}]
# Answer: {
#   "answer": "유전 교차에서 복잡형질과 관련된 염색체 영역을 식별하는 방법은 다양합니다. 염색체 맵핑을 통해 특정 염색체 영역을 식별할 수 있으며, 유전자의 상호작용을 통해 복잡형질을 분석할 수도 있습니다. 또한 유전자의 특정 영역을 식별하기 위해 유전자형을 분석하는 방법도 있습니다. 이러한 방법들은 유전체학적 연구나 유전자의 표현과 다양성을 이해하는 데 도움이 됩니다.",
#   "is_science": true
# }
#
# Test 120
# Question: [{'role': 'user', 'content': '척추 동물이 영역을 가지고 다투는 이유는?'}]
# Answer: {
#   "answer": "척추 동물이 영역을 가지고 다투는 이유는 다양합니다. 척추 동물은 먹이를 얻거나 영역을 지키기 위해 경쟁을 벌이며, 이는 생존과 번식을 위한 행동입니다. 또한, 영역 다툼은 척추 동물의 사회적인 상호작용과 자원 확보를 위한 행동으로 이해될 수 있습니다. 이러한 행동은 척추 동물의 생존 전략과 사회적 구조에 영향을 미치는 중요한 요소입니다.",
#   "is_science": true
# }
#
# Test 121
# Question: [{'role': 'user', 'content': '어린 새들이 생존에서 살아남기 위해 진화한 기능들이 뭐가 있어?'}]
# Answer: {
#   "answer": "어린 새들이 생존에서 살아남기 위해 진화한 기능들은 다양합니다. 예를 들어, 새들은 더 나은 먹잇감을 찾기 위해 뛰어다니고, 더 나은 보금자리를 찾기 위해 날아다닙니다. 또한, 어린 새들은 부모 새들의 선택에 따라 다양한 특성을 발전시키며, 생존에 필요한 습관을 형성합니다. 이러한 진화는 어린 새들의 선택과 새들의 적응에 의해 이루어지며, 유전자의 변이와 선택에 의해 결정됩니다. 이러한 진화는 어린 새들의 적응과 생존에 필요한 선택을 반영하며, 환경에 적합한 변화를 가져옵니다.",
#   "is_science": true
# }
#
# Test 122
# Question: [{'role': 'user', 'content': '입자가 같은 속력으로 원운동을 할 때 속도와 가속도 벡터 사이의 각도는 얼마인가?'}]
# Answer: {
#   "answer": "원운동을 하는 입자의 속도와 가속도 벡터 사이의 각도는 입자의 질량, 중력 및 마찰력과 같은 요소에 따라 달라집니다. 따라서 각도를 구하기 위해서는 입자의 질량, 중력, 마찰력 등의 요소를 고려해야 합니다. 이에 대한 자세한 계산은 제공된 정보가 충분하지 않아서 답변을 드릴 수 없습니다.",
#   "is_science": true
# }
#
# Test 123
# Question: [{'role': 'user', 'content': '곤충 눈의 구조에 대해 설명해줘.'}]
# Answer: {
#   "answer": "곤충의 눈은 여러 가지 유형으로 구성되어 있습니다. 대부분의 곤충은 복합 눈을 가지고 있으며, 이는 여러 개의 단순 눈으로 구성되어 있습니다. 복합 눈은 여러 가지 색과 특정을 구별할 수 있는데, 이는 곤충이 다양한 환경에서 먹이를 찾거나 위험을 피하는 데 도움을 줍니다. 또한, 단순 눈은 빛을 감지하고 시각적인 정보를 처리하는 데 도움을 줍니다. 또한, 곤충의 눈은 UV 광선을 감지할 수 있는데, 이는 곤충이 꽃의 꿀을 찾거나 서로의 특정 신호를 감지하는 데 도움을 줍니다.",
#   "is_science": true
# }
#
# Test 124
# Question: [{'role': 'user', 'content': '너는 누구니?'}]
# Answer: {"answer": "제는 과학 지식을 바탕으로 정보를 제공하고, 과학적인 사고를 통해 문제를 해결하는 데 도움을 주는 인공지능입니다. 이와 관련된 질문이 있으면 도와드릴 수 있습니다. 과학 분야 이외의 질문이라면 도와드릴 수 없습니다.", "is_science": false}
#
# Test 125
# Question: [{'role': 'user', 'content': '물고기는 어떻게 숨을 쉬는가?'}]
# Answer: {
#   "answer": "물고기는 에라모사라는 기관을 통해 산소를 흡입하고 이산화탄소를 배출합니다. 물고기의 에라모사는 특별한 기능을 가지고 있어서 물 속에서 효율적으로 호흡할 수 있습니다. 또한, 물고기는 피질을 이용하여 산소를 흡수하고 이산화탄소를 배출합니다. 이러한 생리적 기능은 물고기가 물 속에서 살아갈 수 있도록 도와줍니다.",
#   "is_science": true
# }
#
# Test 126
# Question: [{'role': 'user', 'content': '하천을 모델링하고 싶어.'}, {'role': 'assistant', 'content': '네 무엇을 도와 드릴까요?'}, {'role': 'user', 'content': '모델링할 때 신경써야 할 사항들이 뭐가 있어?'}]
# Answer:
# {
#   "answer": "하천 모델링을 할 때에는 수문학적인 요소뿐만 아니라 환경적인 측면도 고려해야 합니다. 수문학적인 특성과 환경적 영향을 고려하여 모델링하고, 수질 특성 및 pH 등을 고려하여야 합니다. 또한, 적합한 모델링 소프트웨어를 사용하여 수문, 수질, 환경 요소를 반영한 모델링을 해야 하며, 적절한 모델링 방법과 분석을 통해 결과를 검증해야 합니다.",
#   "is_science": true
# }
#
# Test 127
# Question: [{'role': 'user', 'content': '체질량 지수의 한계에 대해 알려줘.'}]
# Answer: {"answer": "체질량 지수(BMI)는 체중을 신장의 제곱으로 나눈 값으로, 일반적으로 몇 가지 범위 내에서 BMI는 체중과 체중이 다른 요인들을 고려하여 측정합니다. 이러한 요인들은 건강, 성별, 나이 등 다양한 요소를 고려하여 측정됩니다. 이에 따라 BMI는 개인의 신체 구성과 체질에 대한 정보를 제공하지만, 개인의 건강 상태를 완전히 반영하지는 않습니다. 따라서 BMI는 체질량을 측정하는 도구로 사용되지만, 개별적인 건강 상태를 평가하기에는 부족한 면이 있습니다.", "is_science": true}
#
# Test 128
# Question: [{'role': 'user', 'content': '행성의 내부 구조를 이해하기 위한 방법은?'}]
# Answer: {
#   "answer": "행성의 내부 구조를 이해하기 위한 방법은 지질학적 조사와 지구과학적 모델링을 통해 행성의 구조와 특성을 파악하는 것입니다. 이를 통해 지구 내부의 구조와 다른 행성의 내부를 비교하고 분석하여 행성의 내부 구조를 추론하고 분석할 수 있습니다. 지구과학적 모델링은 지구 내부의 특성과 구조, 그리고 지구 역사에 관한 정보를 제공하며, 이를 통해 행성의 내부 구조를 추론하고 분석할 수 있습니다.",
#   "is_science": true
# }
#
# Test 129
# Question: [{'role': 'user', 'content': '식물의 잎이 다수 떨어지거나 구멍이 생기는 현상을 어떻게 해석해야 해?'}]
# Answer: {
#   "answer": "식물의 잎이 다수 떨어지거나 구멍이 생기는 현상은 다양한 원인으로 해석될 수 있습니다. 잎이 떨어지는 경우에는 식물의 자연적인 과정이거나 질병, 해충 등의 영향일 수 있습니다. 또한 잎에 구멍이 생기는 경우에는 과거의 해충 공격이나 환경적 요인에 의한 것일 수 있습니다. 따라서 정확한 해석을 위해서는 해당 식물의 종류와 잎의 상태를 고려하여 전문가의 조언을 구하는 것이 좋습니다.",
#   "is_science": true
# }
#
# Test 130
# Question: [{'role': 'user', 'content': '일식이 발생하는 원리는?'}]
# Answer: {
#   "answer": "일식은 지구의 달과 태양의 상대적 위치에 따라 발생합니다. 달은 지구 주변을 도는데, 이때 달이 지구와 태양 사이에 위치하면 태양빛이 지구에 가려져 일식이 발생합니다. 이러한 현상은 천문학적인 현상으로, 태양의 광학적 특성과 지구의 자전과 공전의 조합으로 발생합니다. 따라서 일식은 천문학적 현상으로, 태양의 광학적 특성과 지구의 자전과 공전의 조합으로 발생하는 현상입니다.",
#   "is_science": true
# }
#
# Test 131
# Question: [{'role': 'user', 'content': '광합성이 무엇인지 그리고 효과에 대해 알려줘.'}]
# Answer: {
#   "answer": "광합성은 광에너지를 이용하여 이산화탄소와 물을 이용해 포도당과 산소를 생산하는 과정입니다. 광합성은 식물의 역학 및 생태학적으로 중요한 역할을 합니다. 이 과정은 태양에서 광에너지를 흡수하여 포도당을 생산하고, 산소를 방출합니다. 광합성은 식물의 세포에서 일어나며, 태양광을 이용해 이산화탄소를 고정시키고, 물을 분해하여 산소를 생성합니다. 이러한 광합성은 생물의 생존 및 생태계의 유지에 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 132
# Question: [{'role': 'user', 'content': '리보오솜의 역할이 뭐야?'}]
# Answer: {
#   "answer": "리보오티드는 유전물질의 전달과 단백질 합성에 관여하는 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 133
# Question: [{'role': 'user', 'content': '오늘 너무 즐거웠어!'}]
# Answer: {
#   "answer": "좋은 소식이네요! 오늘 하루를 즐겁게 보내셨군요.",
#   "is_science": false
# }
#
# Test 134
# Question: [{'role': 'user', 'content': '바람이 부는 이유는?'}]
# Answer: {
#   "answer": "바람이 부는 이유는 다양한 요인들로 인해 발생합니다. 바람은 대기의 기압 차이로 인해 발생하며, 이로 인해 대기 중의 공기가 움직입니다. 또한, 태양열, 지구 자전, 수증기, 기온 등의 요소도 바람 발생에 영향을 미칩니다. 따라서 바람은 다양한 환경적 조건에 의해 발생하며, 이에 따라 바람의 세기와 방향이 결정됩니다.",
#   "is_science": true
# }
#
# Test 135
# Question: [{'role': 'user', 'content': '메릴랜드의 대표적인 천연 자원은?'}]
# Answer: {
#   "answer": "메릴랜드의 대표적인 천연 자원은 바다와 해안 지역입니다. 이 지역은 해양 생태계의 중요한 부분으로, 조개 채취와 해양 생물다양성을 포함한 다양한 자원을 보유하고 있습니다. 또한, 메릴랜드 해안은 해양 생물의 서식지로서 중요한 역할을 하며, 해안 보호구역에서는 다양한 생물다양성을 보호하고 있습니다. 바다와 해안은 메릴랜드의 경제적 발전을 지원하고, 지역 사회의 식생활을 풍부하게 합니다.",
#   "is_science": true
# }
#
# Test 136
# Question: [{'role': 'user', 'content': '디엔에이 리가아제의 주요 기능이 뭐야?'}]
# Answer: {
#   "answer": "디엔에이 리가아제의 주요 기능은 VLDL 생성, ATP 생산, 지질 대사에 관여하는 것입니다.",
#   "is_science": true
# }
#
# Test 137
# Question: [{'role': 'user', 'content': '신체 변화의 정도나 속도가 사람들마다 다른 점으로부터 고려 할 수 있는 사항은?'}]
# Answer: {
#   "answer": "신체 변화의 정도나 속도가 사람들마다 다른 이유는 유전적 요소, 환경적 요인, 생활습관 등 여러 가지 요인에 의해 결정되기 때문입니다. 유전적인 요소는 DNA 구조와 관련이 있으며, 환경적인 요인은 주로 개인의 생활 환경과 관련이 있습니다. 또한, 신체 변화의 정도와 속도는 개인의 유전적 특성, 사회적 요인, 환경적 요인 등에 의해 결정됩니다. 유전적 특성은 변화와 관련된 유전자, 개인 선택, 유전적 변이 등을 포함하며, 환경적인 요인은 개인의 생활 환경과 관련된 요소 및 특성을 말합니다. 이러한 이유로 신체 변화의 정도나 속도는 사람마다 다를 수 있습니다.",
#   "is_science": true
# }
#
# Test 138
# Question: [{'role': 'user', 'content': '머클-담고르 해시 함수를 사용한 MAC 보안 취약점은?'}]
# Answer: {
#   "answer": "머클-담고르 해시 함수를 사용한 MAC 보안 취약점은 H(k || m)을 이용한 경우에 발생할 수 있습니다. 이 MAC의 해시 함수는 입력값에 따라 H(k || m || PB || w)를 계산하는 방식으로 설계되어 있습니다. 이로 인해 MAC의 인증 기능을 우회하여 데이터를 변경하는 공격을 할 수 있습니다.",
#   "is_science": true
# }
#
# Test 139
# Question: [{'role': 'user', 'content': '초코렛이 녹는 물리적인 원리는?'}]
# Answer: {
#   "answer": "초콜렛이 녹는 물리적인 원리는 초콜렛이 녹을 때 분자들이 열을 받아 움직이면서 녹는 현상입니다. 이는 열을 받아 분자들이 움직이면서 결국에는 분자 간의 상호작용이 약해져 초콜렛 결정이 녹는 현상으로 이어지게 됩니다. 따라서, 초콜렛이 녹는 것은 열을 받아 분자 간의 상호작용이 약화되어 결국에는 고체 상태에서 액체 상태로 변하는 과정입니다.",
#   "is_science": true
# }
#
# Test 140
# Question: [{'role': 'user', 'content': '배터리가 완구를 움직이게 하는 원리는?'}]
# Answer: {
#   "answer": "배터리가 완구를 움직이게 하는 원리는 전기 에너지를 활용하여 모터를 작동시키고, 모터의 작용으로 완구가 움직이게 됩니다. 이 과정에서는 전기 에너지의 변환과 운동 에너지의 변환 등이 일어납니다. 따라서 배터리의 전기 에너지를 활용하여 운동 에너지로 변환되어 완구를 움직이게 됩니다.",
#   "is_science": true
# }
#
# Test 141
# Question: [{'role': 'user', 'content': '궤양성 대장염이 있는 사람들이 조심해야 할 사항들은 뭐가 있어?'}]
# Answer: {
#   "answer": [
#     "궤양성 대장염 환자는 규칙적인 검진을 받아야 하며, 궤양성 대장염의 증상이 있는 경우 의사의 지시에 따라 치료를 받아야 합니다. 또한, 궤양성 대장염 환자는 식이요법을 준수하고 체중을 유지하는 것이 중요합니다. 이를 위해 고섬유 식품과 건강한 식습관을 유지해야 합니다. 또한, 궤양성 대장염 환자는 스트레스와 과식을 피하고 적절한 운동을 통해 건강을 유지해야 합니다.",
#     "일반적으로 B형 간염 환자는 식이요법을 통해 건강한 식습관을 유지해야 합니다. B형 간염 환자는 고단백, 고지방, 고설탕 식품을 피하고, 적정한 식단 및 영양섭취를 유지해야 합니다. 또한, B형 간염 환자는 음주, 흡연, 스트레스를 피하고 적절한 휴식과 운동을 통해 건강을 유지해야 합니다.",
#     "간염 환자는 VLDL이 증가할 수 있으므로 적절한 식이요법과 운동을 통해 VLDL 수치를 관리해야 합니다. VLDL은 혈중 지질 수치를 높일 수 있으므로, 적정한 식이 및 운동을 통해 건강을 유지해야 합니다."
#   ],
#   "is_science": true
# }
#
# Test 142
# Question: [{'role': 'user', 'content': '음파의 주파수와 속도의 관계가 어떻게 돼?'}]
# Answer: {
#   "answer": "음파의 주파수와 속도는 밀접한 관련이 있습니다. 속도는 주파수의 파장을 결정하며, 주파수가 높으면 속도도 높아지고, 주파수가 낮으면 속도도 낮아집니다. 음파의 주파수가 높으면 파장이 짧아지고, 음파의 주파수가 낮으면 파장이 길어집니다. 속도는 음파의 밀도에서 파생되며, 음파의 압력과 음속에도 영향을 줍니다. 따라서 음파의 주파수와 속도는 밀접한 관련이 있습니다.",
#   "is_science": true
# }
#
# Test 143
# Question: [{'role': 'user', 'content': '목성 내부에서 온도가 높아지는 원리가 뭐야?'}]
# Answer: {
# ...
#   "is_science": true
# }
#
# Test 175
# Question: [{'role': 'user', 'content': '너 뭘 잘해?'}]
# Answer: {"answer": "제가 잘하는 것은 과학적인 지식을 바탕으로 사용자의 질문에 답변하는 것입니다.", "is_science": false}
#
# Test 176
# Question: [{'role': 'user', 'content': 'bridge inverter의 역할에 대해 알려줘?'}]
# Answer:
# {
#   "answer": "브릿지 인버터는 전력을 교류에서 직류로 변환하거나, 직류에서 교류로 변환하는 역할을 합니다. 이러한 변환기는 다양한 산업 및 과학 분야에서 사용됩니다. 브릿지 인버터는 전력을 안정적으로 변환하고 제어할 수 있는 장치로, 다양한 용도에 활용됩니다.",
#   "is_science": true
# }
#
# Test 177
# Question: [{'role': 'user', 'content': '캠핑의 선기능에 대해 알려줘.'}]
# Answer: {
#   "answer": "캠핑의 선기능은 주로 햇빛을 받아야 하는 식물들을 심고 키우는 것이며, 이를 통해 캠핑 지역의 생태계를 보호하고 유지하는 역할을 합니다. 또한, 햇빛을 받아야 하는 식물들은 햇빛을 흡수하여 산소를 생산하고, 증발작용을 통해 물순환을 유지합니다. 캠핑 지역에서는 햇빛을 받아야 하는 식물들을 심어 산소생산과 물순환을 유지하며, 캠핑을 즐기는 사람들에게 쾌적한 환경을 제공합니다. 캠핑 지역의 생태계를 보호하고 유지하기 위해 캠핑 지역의 햇빛을 받아야 하는 식물들을 심고, 쾌적한 환경을 유지하는데 도움을 주는 역할을 합니다.",
#   "is_science": true
# }
#
# Test 178
# Question: [{'role': 'user', 'content': '지구 온난화 때문에 문제가 발생할 수 있는 지역은?'}]
# Answer: {"answer": "지구 온난화로 인해 문제가 발생할 수 있는 지역은 지구의 여러 지점이 포함됩니다. 이로 인해 지구의 기후와 생태계가 변화하고, 극지방의 빙하 및 빙산의 녹는 속도가 가속화되며, 해수면 상승과 극지방의 빙하 및 빙산이 녹아들어 육지의 침수 및 해안 침식이 발생할 수 있습니다. 또한, 지구 온난화로 인해 기후변화의 영향으로 인해 농업 생산량, 수자원 확보의 어려움, 수질오염의 증가, 생태계의 변화 등 다양한 문제가 발생할 수 있습니다. 이로 인해 지구 온난화로 인한 해양 산성화의 증가, 지구 온난화로 인한 기후변화의 영향으로 인한 이민과 난민, 지속 가능한 발전의 어려움 등 다양한 문제가 발생할 수 있습니다. 따라서 지구 온난화로 인한 문제는 지구 전체에 영향을 미치며, 특히 극지방 및 해안 지역, 농업 및 생태계 등에 심각한 영향을 미칠 수 있습니다.", "is_science": true}
#
# Test 179
# Question: [{'role': 'user', 'content': '염소 원자에 빛을 방출했을 때 발생할 수 있는 시나리오에 대해 알려줘.'}]
# Answer:
# {
#   "answer": "염소 원자가 빛을 방출하는 시나리오에 대해 설명해드릴 수 있습니다. 염소는 화학적으로 활성화된 상태에서 에너지를 흡수하고 이를 방출함으로써 안정 상태로 돌아갑니다. 이 과정에서 빛이 방출될 수 있습니다.",
#   "is_science": true
# }
#
# Test 180
# Question: [{'role': 'user', 'content': '후두가 안정성을 유지할 수 있는 이유는?'}]
# Answer: {
#   "answer": "후두가 안정성을 유지하는 이유는 다양한 생리적 기능과 활동을 조절하기 위해 필요한 에너지를 제공하고, 산소 및 이산화탄소의 교환을 도와주기 때문입니다. 또한, ATP와 미토콘드리아는 세포 내에서 에너지를 공급하고, 산소를 이용한 세포호흡을 통해 에너지를 생성합니다. 이러한 기능들은 세포의 안정성과 대사 활동을 유지하는 데 중요합니다.",
#   "is_science": true
# }
#
# Test 181
# Question: [{'role': 'user', 'content': '요새 너무 힘드네..'}]
# Answer: {
#   "answer": "힘든 시기를 견뎌내는 것은 어려운 일이지만, 지금의 어려움을 극복하고 성장할 수 있는 기회가 될 수도 있습니다. 힘든 시기를 극복하는 데는 여러 가지 방법이 있지만, 주변의 지원을 받고 긍정적인 마음가짐을 유지하는 것이 중요합니다. 또한, 힘든 상황에서는 자신의 감정을 솔직하게 표현하고, 적절한 스트레스 관리 방법을 찾는 것도 중요합니다. 이러한 과정을 통해 힘든 시기를 극복하고, 성장할 수 있는 기회로 만들 수 있습니다.",
#   "is_science": false
# }
#
# Test 182
# Question: [{'role': 'user', 'content': '연구실에서 무엇인지 파악이 안된 가루를 저울로 옮기는 좋은 방법은?'}]
# Answer: {
#   "answer": "연구실에서 무엇인지 파악이 안된 가루를 저울로 옮기는 좋은 방법은 가루를 플라스틱 봉지나 용기에 옮긴 후 저울로 측정하는 것입니다. 이 방법은 가루를 정확하게 측정하고 옮기는데 유용한 방법입니다. 또한, 가루를 옮길 때는 정전기가 발생하지 않도록 플라스틱 용기를 사용하는 것이 좋습니다. 또한, 가루를 옮길 때는 정전기가 발생하지 않도록 플라스틱 용기를 사용하는 것이 좋습니다. 가루를 옮길 때는 정전기가 발생하지 않도록 플라스틱 용기를 사용하는 것이 좋습니다. 또한, 가루를 옮길 때는 정전기가 발생하지 않도록 플라스틱 용기를 사용하는 것이 좋습니다.",
#   "is_science": true
# }
#
# Test 183
# Question: [{'role': 'user', 'content': '금성이 행성중 가장 밝게 보이는 이유는?'}]
# Answer: {
#   "answer": "금성은 태양계에서 가장 밝게 보이는 행성 중 하나입니다. 금성은 태양에서 가까운 위치에 있어서 태양빛을 강하게 받고, 이를 반사하여 지구에서 밝게 보입니다. 또한 금성은 자체적으로 두꺼운 구름층을 가지고 있어서 빛을 강하게 반사하고, 이를 이용하여 밝게 보입니다. 이러한 금성의 밝은 모습은 관측의 어려움으로 인해 오랫동안 수수께끼였습니다. 금성은 우리의 이해를 돕기 위해 계속 연구되고 있습니다.",
#   "is_science": true
# }
#
# Test 184
# Question: [{'role': 'user', 'content': '자석의 세기에 가장 큰 영향을 주는 불순물은?'}]
# Answer: {
#   "answer": "자석의 세기에 가장 큰 영향을 주는 불순물은 주로 철이며, 철의 성질에 따라 자석의 세기가 결정됩니다. 또한, 온도도 자석의 세기에 영향을 미치는데, 일반적으로 온도가 낮을수록 자석의 세기가 높아집니다.",
#   "is_science": true
# }
#
# Test 185
# Question: [{'role': 'user', 'content': '솔레노이드가 뭐야?'}]
# Answer: {"answer": "솔레노이드는 전기가 흐르면서 자기장을 만드는 장치입니다. 주로 전기를 이용하여 자기장을 만들어내는데, 이 자기장은 다양한 용도로 활용됩니다. 솔레노이드의 주요한 용도 중 하나는 ATP를 생성하는 과정에서 H+ 이온의 운반에 관여하는 것입니다. 또한 산소와 이산화탄소의 운반에도 관여하며, 혈액 내의 산소와 이산화탄소의 이동을 조절합니다. 또한, 솔레노이드의 pH에 따라 산소의 운반 능력이 변화하며, 혈액 내의 산소와 이산화탄소의 교환에 영향을 미칩니다.", "is_science": true}
#
# Test 186
# Question: [{'role': 'user', 'content': '여러개의 약을 동시에 먹고 있어.'}, {'role': 'assistant', 'content': '네, 무엇을 도와드릴까요?'}, {'role': 'user', 'content': '이렇게 동시에 먹는 경우 어떤 문제가 생길수 있나?'}]
# Answer:
# {
#   "answer": "여러 약을 동시에 복용하는 경우 상호작용으로 인해 부작용이 발생할 수 있습니다. 또한, 약물의 대사나 효과가 간섭을 받을 수 있으며, 약물의 흡수나 배설이 영향을 받을 수 있습니다. 따라서, 여러 약을 복용할 때에는 의사나 약사와 상의하여야 하며, 가능하면 한 약을 복용할 때 다른 약을 복용하지 않도록 주의해야 합니다.",
#   "is_science": true
# }
#
# Test 187
# Question: [{'role': 'user', 'content': '진폭 변조와 주파수 변조의 차이에 대해 알려줘.'}]
# Answer: {
#   "answer": "진폭 변조는 신호의 진폭을 변화시켜 정보를 전달하는 것이고, 주파수 변조는 신호의 주파수를 변화시켜 정보를 전달하는 것입니다.",
#   "is_science": true
# }
#
# Test 188
# Question: [{'role': 'user', 'content': '잠을 잘 잤을 때 이로운 점을 나열해줘.'}]
# Answer: {
#   "answer": "잠을 잘 잤을 때의 이로운 점으로는 면역력 증진, 정상적인 대사 및 호르몬 분비, 뇌 기능 향상, 스트레스 감소, 심혈관 질환 예방 등이 있습니다.",
#   "is_science": true
# }
#
# Test 189
# Question: [{'role': 'user', 'content': '음파는 어떻게 이동하는가?'}]
# Answer: {
#   "answer": "음파는 탄성 매질인 공기, 물 등을 통해 전파됩니다. 이 전파는 압축과 이완으로 이루어지며, 압축된 부분은 고압이고, 이완된 부분은 저압입니다. 음파는 압력의 변화로 인해 발생하며, 압력의 변화가 공기 분자나 물 분자를 흔들어 전달됩니다. 따라서 음파는 탄성파로서 탄성체의 밀도와 응력에 의해 전파되며, 탄성체의 성질과 탄성에너지에도 영향을 받습니다.",
#   "is_science": true
# }
#
# Test 190
# Question: [{'role': 'user', 'content': '테러로 인한 이슈와 대응책에 대해 알려줘.'}]
# Answer: {
#   "answer": "테러로 인한 이슈와 대응책에 대해 알려드릴 수 있습니다. 테러로 인한 이슈는 국내외에서 발생하는 다양한 공격으로, 국제사회 및 국내에서의 대응이 중요합니다. 대부분의 국가는 테러로부터 시민을 보호하기 위해 다양한 노력을 기울이고 있습니다. 이에 따라 시민들은 현실적인 대책과 안전에 대한 인식을 갖고 대비해야 합니다. 테러로 인한 이슈와 대응책은 국가 및 지역에 따라 다양하며, 시민들은 이에 대한 인식과 대비를 갖추어야 합니다.",
#   "is_science": false
# }
#
# Test 191
# Question: [{'role': 'user', 'content': '바닥의 마찰이 없는 곳에서 두 사람이 서로 밀어낼때 무게가 덜 나가는 사람이 더 나가는 사람이 더 빨리 움직이게 되는 이유는?'}]
# Answer: {
#   "answer": "바닥의 마찰이 없는 곳에서 두 사람이 서로 밀어낼 때 무게가 덜 나가는 사람이 더 나가는 이유는, 물체를 밀 때의 마찰력과 관련된 것입니다. 마찰력은 물체의 무게와 마찰 계수에 의해 결정되며, 물체를 밀 때의 가속도와 관련이 있습니다. 따라서 마찰력이 없는 곳에서는 가속도가 0이므로 물체가 빠르게 움직이게 됩니다.",
#   "is_science": true
# }
#
# Test 192
# Question: [{'role': 'user', 'content': '세포간에 갭결합이 생기는 것을 규명한 실험에 대해 알려줘.'}]
# Answer: {
#   "answer": "세포간에 갭결합이 생기는 것을 규명한 실험은 세포 내의 이온을 추적하기 위한 실험입니다. 이 실험에서는 인산염을 이용하여 세포 내의 화학적 활동을 추적하고, 이를 통해 세포들이 전기적으로 연결되어 상호작용하고 통신하는 것을 확인했습니다.",
#   "is_science": true
# }
#
# Test 193
# Question: [{'role': 'user', 'content': '행성의 크기와 화산이 얼마나 자주 폭발하는지가 관련이 있어?'}]
# Answer: {
#   "answer": "행성의 크기와 화산이 얼마나 자주 폭발하는지는 밀접한 관련이 있습니다. 행성의 크기는 화산 폭발 빈도에 영향을 미치며, 더 큰 행성은 더 자주 화산 폭발을 일으킬 가능성이 있습니다. 또한 화산 폭발은 지구과학적으로 매우 중요한 규모와 영향을 가지고 있습니다. 따라서 화산 폭발을 추적하고 연구함으로써 지구과학의 다양한 요소를 이해하고 발전시킬 수 있습니다.",
#   "is_science": true
# }
#
# Test 194
# Question: [{'role': 'user', 'content': '우성인 빨간색 꽃과 열성인 흰꽃을 교배한다고 하자.'}, {'role': 'assistant', 'content': '네 말씀하세요.'}, {'role': 'user', 'content': '두 꽃을 교배한 후 다음세대 꽃의 색깔은 어떻게 되나?'}]
# Answer: {
#   "answer": "두 꽃을 교배한 후 다음 세대 꽃의 색깔은 100% 빨간색일 것입니다. 이는 빨간색이 열성인 꽃을 가지고 있고, 흰색이 열성인 꽃을 가지고 있기 때문에 발생하는 현상입니다. 따라서, 빨간색 꽃과 흰색 꽃의 교배 결과로 나타나는 현상은 100% 빨간색일 것입니다.",
#   "is_science": true
# }
#
# Test 195
# Question: [{'role': 'user', 'content': '기계가 연료를 태울 때 어떤 형태로 에너지가 낭비되는가?'}]
# Answer: {
#   "answer": "기계가 연료를 태울 때 에너지는 열과 운동 에너지로 낭비됩니다. 연료를 태우면 열과 압력이 발생하여 기계의 동력을 생성하게 됩니다. 이러한 과정에서 일부 열은 유용한 작업으로 전환되지만, 대부분의 열은 환경으로 방출되어 유용하지 않은 형태의 에너지로 낭비됩니다. 또한, 연료를 태우는 과정에서 발생하는 열과 압력을 제어하는 장치를 통해 효율적으로 에너지를 사용하는 것이 중요합니다.",
#   "is_science": true
# }
#
# Test 196
# Question: [{'role': 'user', 'content': '동물들이 종종 집단으로 이주하는 경우가 발생하더라구?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '이렇게 집단으로 이주하게 되는 계기는 어떤 것들이 있어?'}]
# Answer:
# {
#   "answer": "동물들이 집단으로 이주하는 계기는 여러 가지가 있습니다. 예를 들어, 사회적 이유로 인해 동물들이 집단을 이루어 이주하는 경우가 있습니다. 또한, 환경 변화로 인해 생태적인 이유로 동물들이 집단으로 이주하기도 합니다. 또한, 동물들의 생존과 번식을 위한 이유로 집단 이주가 발생하기도 합니다. 이러한 집단 이주는 동물들의 생태적인 변화와 적응을 도와주는 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 197
# Question: [{'role': 'user', 'content': '남미 여러 나라들이 중고등학교 취학률을 높이기 위해 어떤 일들을 하고 있어?'}]
# Answer: {
#   "answer": "남미 여러 나라들은 중고등학교 취학률을 높이기 위해 다양한 노력을 기울이고 있습니다. 이들은 교육에 대한 투자를 늘리고, 학생들의 교육 환경을 개선하며, 교육 시설을 확충하는 등의 다양한 방법을 사용하고 있습니다. 또한, 교육 당국과 지자체는 학교 교육에 대한 투자를 늘리고, 교육의 질을 향상시키며, 학생들의 학습 효과를 증진시키기 위한 다양한 프로그램을 운영하고 있습니다. 이러한 노력들은 교육의 질을 향상시키고, 학생들의 학습 효과를 증진시키는 데 도움이 될 것으로 기대됩니다.",
#   "is_science": false
# }
#
# Test 198
# Question: [{'role': 'user', 'content': '네트웍 계층 중 IP에 대해 설명해줘.'}]
# Answer: {
#   "answer": "IP(인터넷 프로토콜)는 네트워크에서 데이터를 주고받을 때 사용하는 프로토콜입니다. IP 프로토콜은 SNMP를 통해 관리되는 장치의 정보를 수집하고 분석하는 데 사용됩니다. 또한 IP 프로토콜은 인터넷에서 데이터를 전송하고 수신하는 사용자를 식별하고 결정하는 데 사용됩니다. IP 프로토콜은 SNMP를 통해 관리자가 장치 정보를 확인하고 결정할 수 있도록 합니다. IP 프로토콜은 데이터를 전송하고 수신하는 사용자의 식별 및 결정에 관련된 정보를 포함하고 있습니다.",
#   "is_science": true
# }
#
# Test 199
# Question: [{'role': 'user', 'content': '같은 독감에 다시 걸리면 빨리 회복이 되더라구?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 이유가 뭐야?'}]
# Answer:
# {
#   "answer": "같은 독감에 다시 걸리면 빨리 회복되지 않습니다. 이는 독감에 걸린 경우에 이미 면역체계가 활성화되어 있어서 빠르게 회복되지 않는 것이 일반적입니다. 또한, MMR 백신은 독감에 대한 효과가 없습니다. 독감에 걸린 경우에는 휴식을 취하고 수분을 충분히 섭취하여 회복하는 것이 중요합니다.",
#   "is_science": true
# }
#
# Test 200
# Question: [{'role': 'user', 'content': '시소에서 균형을 잡기 위해 양쪽에서 가하는 힘의 크기에 대해 설명해줘.'}]
# Answer: {
#   "answer": "시소에서 균형을 잡기 위해 양쪽에서 가하는 힘의 크기는 두 가지 힘이 서로 반대 방향으로 같은 크기를 가져야 합니다. 시소에서 양쪽으로 가해지는 힘이 균형을 이루면서 물체를 고정시키는 역할을 합니다. 두 힘은 반대 방향과 크기가 같아야 하며, 이렇게 균형 힘들이 서로 상쇄되어 결과적으로 물체를 고정시키는 역할을 합니다. 힘은 두 방향과 크기의 합으로 물체의 움직임과 위치를 결정합니다. 따라서 양쪽에서 가해지는 힘은 서로 상쇄되어 균형을 이루어야 합니다.",
#   "is_science": true
# }
#
# Test 201
# Question: [{'role': 'user', 'content': '두개의 소스로부터 발생한 사건중 어떤 쪽에서 기인한 것인지 확률 계산하는 예시 알려줘.'}]
# Answer: {
#   "answer": "주어진 정보로는 확률을 계산할 수 없습니다.",
#   "is_science": false
# }
#
# Test 202
# Question: [{'role': 'user', 'content': '곤충의 생태를 관찰할 때 사용할 수 있는 방법은?'}]
# Answer: {
#   "answer": "곤충을 관찰할 때 사용할 수 있는 방법은 다양합니다. 먼저 특수한 날개나 발달된 눈을 가진 특정 종의 곤충을 찾아내고, 이들이 어떤 이유로 특정한 행동을 하는지 관찰하고 이해하는 것이 중요합니다. 또한, 먹이사슬을 관찰하고, 먹이를 찾아내고, 먹이를 먹는 행동을 관찰하며, 생태적으로 중요한 특성을 관찰하는 것이 필요합니다. 이러한 관찰은 생태학적으로 중요한 정보를 알려주며, 곤충의 생태학적 특성을 이해하는 데 도움이 됩니다. 또한, 수집된 곤충을 분석하여 그들의 특성을 파악하고, 다른 생물들과의 상호작용을 관찰하는 것이 중요합니다. 이러한 분석 작업은 생태학적으로 중요한 정보를 제공하며, 생태계의 변화를 이해하는 데 도움이 됩니다. 곤충을 관찰하는 데는 다양한 도구와 방법을 사용하여야 하며, 이를 통해 생태학적으로 중요한 정보를 얻을 수 있습니다.",
#   "is_science": true
# }
#
# Test 203
# Question: [{'role': 'user', 'content': '작은 기체 하나의 질량을 어떻게 구할 수 있어?'}]
# Answer: {
#   "answer": "작은 기체의 질량을 구하는 방법은 그 기체를 포함하는 용기의 질량을 먼저 측정한 후, 그 용기와 기체가 함께 움직일 때의 총 질량을 측정하여 두 질량의 차이를 구하는 것입니다. 질량은 SI 단위인 킬로그램(kg)으로 표시되며, 기체의 질량은 보통 무게를 측정하여 추정하고 있습니다. 따라서, 작은 기체의 질량은 보통의 무게와는 다른 개념으로, 정확한 측정이 어렵습니다. 따라서, 작은 기체의 질량은 보통의 질량과는 다른 개념으로, 정확한 결정이 어렵습니다.",
#   "is_science": true
# }
#
# Test 204
# Question: [{'role': 'user', 'content': '평형분극비율이 뭐야?'}]
# Answer: {
#   "answer": "평형분극비율은 물질의 용해도에 관한 개념으로, 물질이 물에 용해되어 평형을 이룰 때 물질의 농도를 나타내는 지표입니다. 주어진 정보에 따르면 평형분극비율은 물질의 농도를 나타내는 중요한 값으로, 화학 및 물리학 실험에서 중요하게 활용됩니다.",
#   "is_science": true
# }
#
# Test 205
# Question: [{'role': 'user', 'content': '근친간의 성행위가 금해지는 이유는?'}]
# Answer: {
#   "answer": "근친간의 성행위가 금지되는 이유는 주로 유전적 질환 및 유전자 이상을 방지하기 위해서입니다. 근친간의 성행위는 유전적 질환과 이상을 가진 후손을 낳을 가능성이 높기 때문에 금지되고 있습니다. 또한, 근친간의 성행위는 사회적, 법적으로 불쾌하고 부적절한 행위로 여겨지며, 과학적으로도 유전자의 다양성을 유지하기 위해 금지되고 있습니다.",
#   "is_science": true
# }
#
# Test 206
# Question: [{'role': 'user', 'content': '노인들이 종종 후각 능력을 잃게 되는 경우가 있더라구?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '이렇게 냄새를 못맡게 되면 어떤 결과로 이어지지?'}]
# Answer:
# {
#   "answer": "후각 능력을 잃게 되면 음식의 맛을 느끼는 능력이 크게 감소하며, 먹을 음식에 대한 만족도와 영양 섭취량이 감소할 수 있습니다. 또한, 후각 능력이 감소하면 음식물 조리나 신선도에 대한 경각심이 줄어들어 음식 중독의 위험이 높아질 수 있습니다. 후각 능력이 감소하면 냄새에 대한 경각심이 줄어들어 화재나 가스 누출과 같은 위험에 노출될 수도 있습니다. 또한, 후각 능력이 감소하면 일상 생활에서의 안전과 식품 조리에 필요한 정보를 파악하는 능력이 감소하므로, 노인들은 후각 능력 감퇴로 인한 위험에 노출될 수 있습니다.",
#   "is_science": true
# }
#
# Test 207
# Question: [{'role': 'user', 'content': '하늘이 파란 이유는?'}]
# Answer: {
#   "answer": "하늘이 파란 이유는, 태양빛이 대기 속에서 흩어지면 파란빛의 파장이 더 많이 흩어지기 때문입니다. 이로 인해 우리가 본 하늘은 파란색으로 보입니다. 또한, 북극성이 하늘에서 더 밝게 빛나는데, 이는 북극성이 북극 방향으로 향하고 있기 때문입니다. 이러한 이유로 하늘은 파란색으로 보이게 됩니다. 또한, 하늘의 색온도는 약 6000K입니다. 이는 태양의 색온도와 비슷하여 우리가 본 하늘의 색깔을 결정짓는 중요한 요소입니다.",
#   "is_science": true
# }
#
# Test 208
# Question: [{'role': 'user', 'content': '짚신 벌레의 번식은 어떻게 이루어지나?'}]
# Answer: {"answer": "짚신 벌레의 번식은 알을 낳는 방식으로 이루어집니다. 알을 낳은 뒤에는 부화하여 애벌레가 태어나며, 이후에는 번데기 단계를 거쳐 성충이 됩니다.", "is_science": true}
#
# Test 209
# Question: [{'role': 'user', 'content': '온난 전선이 발생하면 이후 날씨는 어떻게 되나?'}]
# Answer: {
#   "answer": "온난 전선이 발생하면 이후 날씨는 다양한 현상이 나타날 수 있습니다. 온난 전선은 대체로 따뜻하고 습한 날씨를 가져오며, 강한 비나 천둥번개를 유발할 수 있습니다. 또한, 온난 전선이 지나가면서 기온이 상승하고 습도가 높아지는데, 이는 다음 날에는 더위가 지속될 수 있음을 의미합니다. 그러나 온난 전선이 지나가면서 지역마다 다양한 기상 현상이 나타날 수 있으므로 정확한 예보를 위해서는 해당 지역의 기상 정보를 확인해야 합니다.",
#   "is_science": true
# }
#
# Test 210
# Question: [{'role': 'user', 'content': '전기가 흐르는 회로에서 전선과 전구의 전류는 동일한가?'}]
# Answer: {
#   "answer": "전기가 흐르는 회로에서 전선과 전구의 전류는 동일합니다. 이는 전기 회로의 기본 원리로, 특정 회로에서 전류가 흐를 때 전선과 전구의 전류는 동일하게 흐릅니다. 전선의 전류가 2A이면, 다른 전구의 전류도 2A입니다.",
#   "is_science": true
# }
#
# Test 211
# Question: [{'role': 'user', 'content': '플로리다에서 친환경 에너지를 가장 효과적으로 활용할 수 있는 시기는?'}]
# Answer: {
#   "answer": "플로리다에서는 6월이 친환경 에너지를 가장 효과적으로 활용할 수 있는 시기입니다. 6월은 태양에너지를 활용하기에 매우 적합하고, 더운 날씨로 인해 에어컨을 많이 사용하므로 태양열을 이용한 발전이 효과적입니다. 또한, 플로리다에서는 6월에 많은 인구가 해변이나 호수에서 레저 활동을 즐기는데, 이는 친환경 발전에 도움이 되는 풍력에너지를 활용하기에도 좋은 환경을 제공합니다.",
#   "is_science": true
# }
#
# Test 212
# Question: [{'role': 'user', 'content': '농장이 해안가 환경에 나쁜 영향을 미칠 수 있는 원인이 뭐가 있어?'}]
# Answer: {
#   "answer": "농장이 해안가 환경에 나쁜 영향을 미칠 수 있는 원인으로는 농업 폐기물과 농업 화학물질이 해안 생태계에 부정적인 영향을 미칠 수 있습니다. 이러한 화학물질은 해양 생물의 생태계를 파괴하고 환경 오염을 초래할 수 있습니다. 또한, 농장에서 발생하는 폐기물은 해양 생태계에 유해한 영향을 미칠 수 있으며, 이로 인해 해안 생태계의 균형이 깨질 수 있습니다. 이러한 문제를 해결하기 위해서는 농업 폐기물을 적절히 처리하고 화학물질의 남용을 줄이는 등의 대책이 필요합니다.",
#   "is_science": true
# }
#
# Test 213
# Question: [{'role': 'user', 'content': '자성을 띄지 않는 유전체 내부에서 빛의 속도는 어떻게 되나?'}]
# Answer: {"answer": "유전체 내부에서 빛의 속도는 4.0 x 10^8 m/s입니다. 이는 유전체 내부의 특성에 따라 변할 수 있지만, 일반적으로 빛의 속도는 이와 같이 측정됩니다. 따라서 유전체 내부에서 빛의 속도는 자성을 띄지 않는 유전체의 특성에 따라 변할 수 있지만, 일반적으로는 4.0 x 10^8 m/s로 측정됩니다.", "is_science": true}
#
# Test 214
# Question: [{'role': 'user', 'content': '자연보호구역이 필요한 이유는?'}]
# Answer: {
#   "answer": "자연보호구역이 필요한 이유는 다양한 이유가 있습니다. 먼저, 자연은 우리의 생태계를 유지하고, 생태다양성을 보존하는 역할을 합니다. 또한 자연은 풍부한 자원과 생태계를 제공하여 우리에게 유익한 환경을 조성합니다. 또한, 환경파괴가 빈번하여 새로운 생태계를 구축하고, 풍부한 생태계를 보전하는데 중요한 역할을 합니다. 따라서 자연보호구역은 자연을 보호하고, 새로운 생태계를 조성하며, 환경을 보전하는 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 215
# Question: [{'role': 'user', 'content': '정상파가 뭐야?'}]
# Answer: {"answer": "정상파는 시간에 따라 진폭이 변하지 않고 일정한 주기로 진동하는 파형을 말합니다. 일반적으로 정상파의 주기는 다른 주기와 비교하여 특정한 주파수를 갖고 있으며, 이 주기는 100 mV입니다. 또한 두 번째 주기는 정현파의 신호를 나타내며, 주파수는 314 t이고 초기 위상은 400 sin입니다. 정상파의 진폭은 200 V이며 위상각은 30도에서 150도까지 변할 수 있습니다. 정상파의 위상각이 30도 또는 150도일 때 진동의 방향을 결정하고, 이에 따라 진동의 방향이 결정됩니다. 따라서, 정상파는 특정한 주파수를 갖고 일정한 주기로 진동하는 파형을 말합니다.", "is_science": true}
#
# Test 216
# Question: [{'role': 'user', 'content': '공에 힘이 주어졌을 때 공이 어떻게 움직이는지 과학적으로 설명해줘.'}]
# Answer: {
#   "answer": "공에 힘이 주어지면 공은 그 방향으로 가속을 받아 움직입니다. 이에 따라 공이 움직이는 방향은 주어진 힘의 방향과 관련하여 결정되며, 가속이 공의 내부에서 발생하면 공은 그 방향으로 가속됩니다. 만일 힘이 외부에서 작용하면 9.8 m/s^2의 가속도로 가속됩니다. 이는 중력의 영향으로 인한 것으로, 가속도 없이는 공은 정지합니다. 따라서, 공을 움직이게 하려면 힘이 가해져야 합니다. 힘이 없으면 공은 정지하게 됩니다.",
#   "is_science": true
# }
#
# Test 217
# Question: [{'role': 'user', 'content': '동물들이 피부나 털의 색깔을 통해 생존의 확률을 높이는 방식에 대해 설명해줘.'}]
# Answer: {
#   "answer": "동물들은 피부나 털의 색깔을 통해 생존의 확률을 높이는 방식이 있습니다. 이는 주로 우생학적 측면에서 설명됩니다. 피부나 털의 색깔은 주로 환경에 대한 적응성을 나타내며, 이는 동물들이 서식지에 적응하고 적응하지 못하는 데 영향을 미칩니다. 색깔은 주로 동물의 우생학적 특성에 따라 결정되며, 이는 주로 유전자에 의해 결정됩니다. 색깔은 주로 동물의 우생학적 특성에 따라 결정되며, 이는 주로 유전자에 의해 결정됩니다. 색깔은 주로 동물의 우생학적 특성에 따라 결정되며, 이는 주로 유전자에 의해 결정됩니다.",
#   "is_science": true
# }
#
# Test 218
# Question: [{'role': 'user', 'content': '메탄과 산소의 화학 반응에 대해 알려줘.'}]
# Answer:
# {
#   "answer": "메탄과 산소의 화학 반응은 메탄과 산소가 반응하여 이산화탄소와 물이 생성되는 화학 반응입니다. 이 반응은 화염을 동반하며, 열과 에너지를 방출합니다. 메탄, 산소, 이산화탄소는 화학 반응을 통해 다른 물질과 비교적 안정한 화합물로 변환되며, 이로 인해 에너지가 생성됩니다.",
#   "is_science": true
# }
#
# Test 219
# Question: [{'role': 'user', 'content': '복숭아 키우는 노하우좀?'}]
# Answer: {
#   "answer": "복숭아를 키우는 노하우에는 복숭아의 특성을 이해하고 적절한 관리를 하는 것이 중요합니다. 복숭아의 특성을 이해하고 적절한 관리를 통해 열매 수확을 기대할 수 있습니다. 복숭아의 적정 온도와 습도를 유지하고, 복숭아나무의 가지를 적절히 다듬어 주는 것이 중요합니다. 복숭아의 적정 관리를 통해 열매 수확을 기대할 수 있습니다. 복숭아를 키우는 방법에 대한 자세한 정보는 복숭아 재배 전문가의 조언을 찾아보거나, 복숭아의 특성과 요구조건을 충족시키는 데 주의를 기울이는 것이 좋습니다. 복숭아의 적정 관리 방법은 복숭아 재배자들에게 많은 도움이 되는 정보를 제공하며, 복숭아의 수확과 수량을 증가시킬 수 있습니다. 복숭아 재배에는 복숭아의 특성과 수확량을 높일 수 있는 방법을 이해하는 것이 중요합니다. 따라서 복숭아를 키우는 방법에 대한 정보를 찾고, 복숭아의 특성과 수확량을 높일 수 있는 방법을 적용하는 것이 좋습니다.",
#   "is_science": false
# }

# %%
new_dl = list()

with open('sample_submission_4_final.csv', 'r') as f :
    for line in f:
        except_is_science_dict = dict()
        
        j = json.loads(line)        # dict
        print(j.keys())
        
        except_is_science_dict = {
            "eval_id": j['eval_id'],
            "standalone_query": j['standalone_query'],
            "topk": j['topk'] if j['is_science'] else [],
            "answer": j['answer'],
            "references": j['references'] if j['is_science'] else []
        }
        
        new_dl.append(except_is_science_dict)
        
        
print(len(new_dl))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 3
#       1 new_dl = list()
# ----> 3 with open('sample_submission_4_final.csv', 'r') as f :
#       4     for line in f:
#       5         except_is_science_dict = dict()
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample_submission_4_final.csv'

# %%
import json

with open("sample_submission_4_final_without.csv", "w") as of:
    for dl in new_dl:
        of.write(f'{json.dumps(dl, ensure_ascii=False)}\n')

# %%
# !wc -l sample_submission.csv
# Out:
# 6 sample_submission.csv

# %% [markdown]
# #Reference

# %% [markdown]
# ## Required Package
#
# openai==1.7.2 <br>
# elasticsearch==8.8.0 <br>
# sentence_transformers==2.2.2 <br>

# %% [markdown]
# ## 콘텐츠 라이선스
#
# 저작권 : <font color='blue'> <b> ©2023 by Upstage X fastcampus Co., Ltd. All rights reserved.</font></b>
#
# <font color='red'><b>WARNING</font> : 본 교육 콘텐츠의 지식재산권은 업스테이지 및 패스트캠퍼스에 귀속됩니다. 본 콘텐츠를 어떠한 경로로든 외부로 유출 및 수정하는 행위를 엄격히 금합니다. </b>
