# %% [markdown]
# # Information Retrieval Baseline Code

# %% [markdown]
# ## 대회 설명
# Information Retrieval 경진대회에 오신 여러분 환영합니다! 🎉 <br>
# 본 대회에서는 과학 상식에 대한 멀터턴 질문에 대하여 RAG 기술을 활용하여 질문에 적합한 레퍼런스를 추출하고 이를 토대로 답변을 생성하는 어플리케이션을 구현해 봅니다. <br>
# LLM은 GPT-3.5 버전을 이용하고, 레퍼런스 추출을 위한 검색엔진 구축은 Elasticsearch를 활용합니다.

# %% [markdown]
# ## 데이터셋 준비
# * 질문에 대한 레퍼런스로 활용될 수 있는 4272개의 과학 상식을 다루는 문서
#  * Open Ko LLM Leaderboard에 들어가는 Ko-H4 데이터 중 MMLU, ARC 데이터를 기반으로 생성
#  * Question과 answer를 paraphrase (question과 answer를 토대로 GPT-4 활용하여 document 생성)
#  * 예시)
#   ```
#   수소, 산소, 질소 가스의 혼합물에서 평균 속도가 가장 빠른 분자는 수소입니다
# . 수소 분자는 가장 가볍고 작은 원자로 구성되어 있기 때문에 다른 분자들보다 더 빠르게 움직>입니다. 이러한 이유로 수소 분자는 주어진 온도에서 가장 빠른 평균 속도를 가지고 있습니다. >수소 분자는 화학 반응에서도 활발하게 참여하며, 수소 연료로도 널리 사용됩니다. 따라서 수소 분자는 주어진 온도에서 평균 속도가 가장 빠른 분자입니다.
#   ```
#
# * 가상의 질문 220개
#  * 과학 상식 질문 또는 일상 대화 메시지를 수동으로 생성
#  * 220개 중 20개는 멀티턴 대화 형태의 질문, 20개는 일상 칫챗 대화
#   * 예시)
#   ```
# {"eval_id": 0, "msg": [{"role": "user", "content": "나무의 분류에 대해 조사해 보기 위한 방
# 법은?"}], "refs": ["c63b9e3a-716f-423a-9c9b-0bcaa1b9f35d"]}
# {"eval_id": 1, "msg": [{"role": "user", "content": "각 나라에서의 공교육 지출 현황에 대해 알려줘."}], "refs": ["79c93deb-fe60-4c81-8d51-cb7400a0a156"]}
# {"eval_id": 2, "msg": [{"role": "user", "content": "기억 상실증 걸리면 너무 무섭겠다."}, {"role": "assistant", "content": "네 맞습니다."}, {"role": "user", "content": "어떤 원인 때
# 문에 발생하는지 궁금해."}], "refs": ["25de4ffd-cee4-4f27-907e-fd6b802c6ede"]}
#   ```

# %%
 # 색인 대상 문서 및 평가 데이터 다운로드
 # !wget https://aistages-api-public-prod.s3.amazonaws.com/app/Competitions/000291/data/data.tar.gz
 # !tar -xzvf data.tar.gz
# Out:
# --2024-02-14 05:15:10--  https://aistages-api-public-prod.s3.amazonaws.com/app/Competitions/000291/data/data.tar.gz
# Resolving aistages-api-public-prod.s3.amazonaws.com (aistages-api-public-prod.s3.amazonaws.com)... 52.219.206.95, 52.219.202.27, 52.219.56.70, ...
# Connecting to aistages-api-public-prod.s3.amazonaws.com (aistages-api-public-prod.s3.amazonaws.com)|52.219.206.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1068264 (1.0M) [binary/octet-stream]
# Saving to: ‘data.tar.gz’
#
# data.tar.gz         100%[===================>]   1.02M  1.49MB/s    in 0.7s
#
# 2024-02-14 05:15:12 (1.49 MB/s) - ‘data.tar.gz’ saved [1068264/1068264]
#
# data/
# data/eval.jsonl
# data/documents.jsonl

# %% [markdown]
# ## 환경 설정
# 검색엔진을 위한 Elasitcsearch, 임베딩 생성을 위한 sentence transformers, LLM 사용을 위한 openai client 설치가 필요합니다.

# %%
# Elasticsearch python 패키지 설치
# !pip install elasticsearch==8.8.0

# OpenAI Python 패키지 설치
# !pip install openai==1.7.2

# 임베딩 생성을 위한 벡터 인코더 설치
# !pip install sentence-transformers==2.2.2
# Out:
# Collecting elasticsearch==8.8.0
#   Downloading elasticsearch-8.8.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting elastic-transport<9,>=8 (from elasticsearch==8.8.0)
#   Downloading elastic_transport-8.13.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /home/demyank/anaconda3/lib/python3.11/site-packages (from elastic-transport<9,>=8->elasticsearch==8.8.0) (1.26.18)
# Requirement already satisfied: certifi in /home/demyank/anaconda3/lib/python3.11/site-packages (from elastic-transport<9,>=8->elasticsearch==8.8.0) (2024.2.2)
# Downloading elasticsearch-8.8.0-py3-none-any.whl (393 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.8/393.8 kB 4.4 MB/s eta 0:00:00a 0:00:01m
# Downloading elastic_transport-8.13.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: elastic-transport, elasticsearch
# Successfully installed elastic-transport-8.13.0 elasticsearch-8.8.0
# Collecting openai==1.7.2
#   Downloading openai-1.7.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (1.8.0)
# Collecting httpx<1,>=0.23.0 (from openai==1.7.2)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (1.10.12)
# Requirement already satisfied: sniffio in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (1.3.0)
# Requirement already satisfied: tqdm>4 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/demyank/anaconda3/lib/python3.11/site-packages (from openai==1.7.2) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /home/demyank/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai==1.7.2) (3.4)
# Requirement already satisfied: certifi in /home/demyank/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai==1.7.2) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai==1.7.2)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.7.2)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading openai-1.7.2-py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.1/212.1 kB 5.6 MB/s eta 0:00:00ta 0:00:01
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.7 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.7.2
# Collecting sentence-transformers==2.2.2
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (4.38.2)
# Requirement already satisfied: tqdm in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (2.2.1)
# Requirement already satisfied: torchvision in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (0.17.1)
# Requirement already satisfied: numpy in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (1.26.4)
# Requirement already satisfied: scikit-learn in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (1.2.2)
# Requirement already satisfied: scipy in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (1.11.4)
# Requirement already satisfied: nltk in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (3.8.1)
# Collecting sentencepiece (from sentence-transformers==2.2.2)
#   Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sentence-transformers==2.2.2) (0.21.4)
# Requirement already satisfied: filelock in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2023.10.0)
# Requirement already satisfied: requests in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.28.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /home/demyank/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (23.1)
# Requirement already satisfied: sympy in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (1.12)
# Requirement already satisfied: networkx in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.1)
# Requirement already satisfied: jinja2 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/demyank/anaconda3/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->sentence-transformers==2.2.2) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /home/demyank/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/demyank/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.4.2)
# Requirement already satisfied: click in /home/demyank/anaconda3/lib/python3.11/site-packages (from nltk->sentence-transformers==2.2.2) (8.1.7)
# Requirement already satisfied: joblib in /home/demyank/anaconda3/lib/python3.11/site-packages (from nltk->sentence-transformers==2.2.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence-transformers==2.2.2) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from torchvision->sentence-transformers==2.2.2) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/demyank/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.6.0->sentence-transformers==2.2.2) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/demyank/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/demyank/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.6.0->sentence-transformers==2.2.2) (1.3.0)
# Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.6 MB/s eta 0:00:0000:0100:01m
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125937 sha256=a6b7e361d9a6d35feee368a7559085ee84b2d0243431cf89f0e983e370814e04
#   Stored in directory: /home/demyank/.cache/pip/wheels/ff/27/bf/ffba8b318b02d7f691a57084ee154e26ed24d012b0c7805881
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, sentence-transformers
# Successfully installed sentence-transformers-2.2.2 sentencepiece-0.2.0

# %% [markdown]
# ## 검색엔진 준비 - Elasticsearch

# %%
# 데몬이 구동되었는지 확인 (세개의 daemon process가 있어야 함)
# !ps -ef | grep elasticsearch
# Out:
# demyank  69360 68765  0 11:59 pts/11   00:00:00 /usr/bin/zsh -c ps -ef | grep elasticsearch
# demyank  69362 69360  0 11:59 pts/11   00:00:00 grep elasticsearch

# %%
import os
import torch
from elasticsearch import Elasticsearch, helpers
from peft import LoraConfig, AutoPeftModelForCausalLM, PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, BitsAndBytesConfig, AutoTokenizer, TrainingArguments, pipeline, DataCollatorForSeq2Seq
from datetime import datetime

# %%
# Elasticsearch credentials (adjust these as per your Elasticsearch setup)
es_username = 'elastic'
es_password = os.getenv('ES_PASSWORD')  # Replace 'your_password_here' with your actual Elasticsearch password

# Path to your CA certificate on your host (adjust this after copying it from the container)
ca_cert_path = os.getenv('HTTP_CA_CRT_PATH')  # Update this to the actual path where you store your copied CA certificate

# Create an Elasticsearch client
es = Elasticsearch(
    ['https://localhost:9200'],
    basic_auth=(es_username, es_password),
    ca_certs=ca_cert_path
)

# Print Elasticsearch client information to verify connectivity
print(es.info())
# Out:
# {'name': '8b4375334f9c', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'XuaZu5E-QgWjjKSFBuUCaQ', 'version': {'number': '8.13.2', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '16cc90cd2d08a3147ce02b07e50894bc060a4cbf', 'build_date': '2024-04-05T14:45:26.420424304Z', 'build_snapshot': False, 'lucene_version': '9.10.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'}

# %%
from sentence_transformers import SentenceTransformer

# checkpoint_path = 'snunlp/KR-SBERT-V40K-klueNLI-augSTS'

# Sentence Transformer 모델 초기화 (한국어 임베딩 생성 가능한 어떤 모델도 가능)
model = SentenceTransformer('output/scientific_continue_training_kr_sbert_v40k_klueNLI_augSTS')

# %%
# SetntenceTransformer를 이용하여 임베딩 생성
def get_embedding(sentences):
    # return model.encode(sentences)
    return [model.encode(sentence) for sentence in sentences]


# 주어진 문서의 리스트에서 배치 단위로 임베딩 생성
def get_embeddings_in_batches(docs, batch_size=100):
    batch_embeddings = []
    for i in range(0, len(docs), batch_size):
        batch = docs[i:i + batch_size]
        contents = [doc["content"] for doc in batch]
        embeddings = get_embedding(contents)
        batch_embeddings.extend(embeddings)
        print(f'batch {i}')
    return batch_embeddings


# 새로운 index 생성
def create_es_index(index, settings, mappings):
    # 인덱스가 이미 존재하는지 확인
    if es.indices.exists(index=index):
        # 인덱스가 이미 존재하면 설정을 새로운 것으로 갱신하기 위해 삭제
        es.indices.delete(index=index)
    # 지정된 설정으로 새로운 인덱스 생성
    es.indices.create(index=index, settings=settings, mappings=mappings)


# 지정된 인덱스 삭제
def delete_es_index(index):
    es.indices.delete(index=index)


# Elasticsearch 헬퍼 함수를 사용하여 대량 인덱싱 수행
def bulk_add(index, docs):
    # 대량 인덱싱 작업을 준비
    actions = [
        {
            '_index': index,
            '_source': doc
        }
        for doc in docs
    ]
    return helpers.bulk(es, actions)


# 역색인을 이용한 검색
def sparse_retrieve(query_str, size):
    query = {
        "match": {
            "content": {
                "query": query_str
            }
        }
    }
    return es.search(index="test", query=query, size=size, sort="_score")


# Vector 유사도를 이용한 검색
def dense_retrieve(query_str, size):
    # 벡터 유사도 검색에 사용할 쿼리 임베딩 가져오기
    query_embedding = get_embedding([query_str])[0]

    # KNN을 사용한 벡터 유사성 검색을 위한 매개변수 설정
    knn = {
        "field": "embeddings",
        "query_vector": query_embedding.tolist(),
        "k": size,
        "num_candidates": 100
    }

    # 지정된 인덱스에서 벡터 유사도 검색 수행
    return es.search(index="test", knn=knn)

# %%
# 색인을 위한 setting 설정
settings = {
    "analysis": {
        "analyzer": {
            "nori": {
                "type": "custom",
                "tokenizer": "nori_tokenizer",
                "decompound_mode": "mixed",
                "filter": ["nori_posfilter"]
            }
        },
        "filter": {
            "nori_posfilter": {
                "type": "nori_part_of_speech",
                # 어미, 조사, 구분자, 줄임표, 지정사, 보조 용언 등
                "stoptags": ["E", "J", "SC", "SE", "SF", "VCN", "VCP", "VX"]
            }
        }
    }
}

# 색인을 위한 mapping 설정 (역색인 필드, 임베딩 필드 모두 설정)
mappings = {
    "properties": {
        "content": {"type": "text", "analyzer": "nori"},
        "embeddings": {
            "type": "dense_vector",
            "dims": 768,
            "index": True,
            "similarity": "l2_norm"
        }
    }
}

# %%
# settings, mappings 설정된 내용으로 'test' 인덱스 생성
create_es_index("test", settings, mappings)

# %%
import json

# 문서의 content 필드에 대한 임베딩 생성
index_docs = []
with open("data/documents.jsonl") as f:
    docs = [json.loads(line) for line in f]
embeddings = get_embeddings_in_batches(docs)

# 생성한 임베딩을 색인할 필드로 추가
for doc, embedding in zip(docs, embeddings):
    # doc["embeddings"] = embedding.tolist()
    doc["embeddings"] = embedding
    index_docs.append(doc)

# 'test' 인덱스에 대량 문서 추가
ret = bulk_add("test", index_docs)

# 색인이 잘 되었는지 확인 (색인된 총 문서수가 출력되어야 함)
print(ret)
# Out:
# batch 0
# batch 100
# batch 200
# batch 300
# batch 400
# batch 500
# batch 600
# batch 700
# batch 800
# batch 900
# batch 1000
# batch 1100
# batch 1200
# batch 1300
# batch 1400
# batch 1500
# batch 1600
# batch 1700
# batch 1800
# batch 1900
# batch 2000
# batch 2100
# batch 2200
# batch 2300
# batch 2400
# batch 2500
# batch 2600
# batch 2700
# batch 2800
# batch 2900
# batch 3000
# batch 3100
# batch 3200
# batch 3300
# batch 3400
# batch 3500
# batch 3600
# batch 3700
# batch 3800
# batch 3900
# batch 4000
# batch 4100
# batch 4200
# (4272, [])

# %%
# 검색엔진에 색인이 잘 되었는지 테스트하기 위한 질의
test_query = "금성이 다른 행성들보다 밝게 보이는 이유는 무엇인가요?"

# %%
# 역색인을 사용하는 검색 예제
search_result_retrieve = sparse_retrieve(test_query, 3)

# 결과 출력 테스트
for rst in search_result_retrieve['hits']['hits']:
    print('score:', rst['_score'], 'source:', rst['_source']["content"])
# Out:
# score: 33.68643 source: 금성이 다른 행성들보다 더 밝게 보이는 이유는 지구 쪽으로 가장 많은 햇빛을 반사하기 때문입니다. 케빈은 맑은 밤에 하늘을 관찰하고 있습니다. 그는 맨눈으로 금성, 화성, 목성, 토성을 볼 수 있습니다. 금성은 햇빛을 많이 반사하기 때문에 다른 행성들보다 더 밝게 보입니다. 이는 금성의 표면이 반사율이 높기 때문입니다. 금성은 태양으로부터 받은 햇빛을 표면에 반사하여 지구에서 관찰하기 쉽게 만듭니다. 따라서 케빈은 맑은 밤에 금성을 더 밝게 볼 수 있습니다.
# score: 18.915426 source: 금성은 태양계의 두 번째로 가까운 행성입니다. 이 행성의 대략적인 나이는 7억 5천만 년으로 추정됩니다. 금성은 지구와 매우 비슷한 크기와 구성을 가지고 있으며, 약 90% 이상이 이산화탄소로 이루어져 있습니다. 이 행성은 매우 뜨거운 온도와 압력을 가지고 있어서 인간이 살 수 있는 환경이 아닙니다. 금성의 대기는 두꺼워서 태양의 열을 가두고 있어서 행성의 표면은 평균 온도가 약 450도로 매우 뜨거운 상태입니다. 또한, 금성은 자전 속도가 매우 빠르기 때문에 하루가 지구의 약 243일과 같습니다. 이러한 특징들로 인해 금성은 우리 태양계에서 가장 가혹한 환경을 가진 행성 중 하나로 알려져 있습니다.
# score: 18.728905 source: 메릴랜드 Space Grant Observatory는 볼티모어에 위치해 있습니다. 학생들은 이 망원경을 방문하여 별, 행성, 달에 대해 배웠습니다. 그들은 아래와 같은 정보를 기록했습니다. 첫째, 별 패턴은 그대로 유지되지만, 하늘에서의 위치는 변하는 것처럼 보입니다. 둘째, 태양, 행성, 달은 하늘에서 움직이는 것처럼 보입니다. 셋째, 켄타우루스자리의 프록시마 성은 우리 태양계에서 가장 가까운 별입니다. 넷째, 북극성은 소 북두칠성이라 불리는 별 패턴의 일부입니다. 그렇다면 태양이 매일 하늘을 가로질러 움직이는 것처럼 보이는 이유는 무엇일까요? 지구가 자전축을 중심으로 회전하기 때문입니다.

# %%
# Vector 유사도 사용한 검색 예제
search_result_retrieve = dense_retrieve(test_query, 3)

# 결과 출력 테스트
for rst in search_result_retrieve['hits']['hits']:
    print('score:', rst['_score'], 'source:', rst['_source']["content"])
# Out:
# score: 0.012061637 source: 금성은 태양계에서 가장 가까운 행성 중 하나입니다. 그러나 화성이나 지구처럼 계절이 없는 이유는 금성의 자전축이 태양계의 평면에 거의 수직이기 때문입니다. 자전축이 수직이기 때문에 금성은 태양으로부터 받는 햇빛의 양이 일정하게 유지됩니다. 이로 인해 금성은 계절 변화가 없으며 항상 일정한 온도를 유지합니다. 이러한 환경은 생명체에게는 적합하지 않을 수 있지만, 금성의 특이한 기후 조건은 우주 탐사에 대한 연구에 많은 도움을 주고 있습니다. 금성은 여전히 우리에게 알려지지 않은 많은 비밀을 품고 있으며, 미래에 더 많은 연구와 탐사가 이루어질 것으로 기대됩니다.
# score: 0.011799942 source: 금성은 태양계의 두 번째로 가까운 행성입니다. 이 행성의 대략적인 나이는 7억 5천만 년으로 추정됩니다. 금성은 지구와 매우 비슷한 크기와 구성을 가지고 있으며, 약 90% 이상이 이산화탄소로 이루어져 있습니다. 이 행성은 매우 뜨거운 온도와 압력을 가지고 있어서 인간이 살 수 있는 환경이 아닙니다. 금성의 대기는 두꺼워서 태양의 열을 가두고 있어서 행성의 표면은 평균 온도가 약 450도로 매우 뜨거운 상태입니다. 또한, 금성은 자전 속도가 매우 빠르기 때문에 하루가 지구의 약 243일과 같습니다. 이러한 특징들로 인해 금성은 우리 태양계에서 가장 가혹한 환경을 가진 행성 중 하나로 알려져 있습니다.
# score: 0.005973127 source: 금성이 다른 행성들보다 더 밝게 보이는 이유는 지구 쪽으로 가장 많은 햇빛을 반사하기 때문입니다. 케빈은 맑은 밤에 하늘을 관찰하고 있습니다. 그는 맨눈으로 금성, 화성, 목성, 토성을 볼 수 있습니다. 금성은 햇빛을 많이 반사하기 때문에 다른 행성들보다 더 밝게 보입니다. 이는 금성의 표면이 반사율이 높기 때문입니다. 금성은 태양으로부터 받은 햇빛을 표면에 반사하여 지구에서 관찰하기 쉽게 만듭니다. 따라서 케빈은 맑은 밤에 금성을 더 밝게 볼 수 있습니다.

# %% [markdown]
# ## RAG 구현
#
# 준비된 검색엔진과 LLM을 활용하셔 대화형 RAG 구현

# %%
from openai import OpenAI
import traceback

# OpenAI API 키를 환경변수에 설정
# os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')
#os.environ["OPENAI_API_KEY"] = "Your API Key"

client = OpenAI(organization=os.getenv('ORGANIZATION_ID'))
# 사용할 모델을 설정(여기서는 gpt-3.5-turbo-1106 모델 사용)
llm_model = "gpt-4-turbo" # "gpt-3.5-turbo" # 
# llm_model = "gpt-3.5-turbo"

# %%
# RAG 구현에 필요한 Question Answering을 위한 LLM  프롬프트
persona_qa = """
## Role: 과학 지식 전문가

## Instructions
- 사용자의 이전 메시지 정보 및 주어진 Reference 정보를 활용하여 간결하게 답변을 생성한다.
- 주어진 검색 결과 정보로 대답할 수 없는 경우는 정보가 부족해서 답을 할 수 없다고 대답한다.
- 한국어로 답변을 생성한다.
- 결과는 json 형태로 생성하고, 반드시 'is_science' 필드를 추가하여 질문이 과학 지식에 관련된 내용이면 true를, 과학 지식에 관련된 내용이 아니라면 false를 value로 만든다. 답변 필드의 이름은 'answer'로 통일한다.
"""

# RAG 구현에 필요한 질의 분석 및 검색 이외의 일반 질의 대응을 위한 LLM 프롬프트
persona_function_calling = """
## Role: 과학 지식 전문가

## Instruction
- 제대로 답변을 하지 않으면 기업이 엄청난 손해를 보게된다.
- 사용자가 대화를 통해 생물학, 물리학, 지구과학, 화학, 의학, 공학, 컴퓨터, 농학, 산업공학, 전자공학, 수학, 통계학, 과학자 등 과학 지식에 관한 주제로 질문하면 search api를 호출할 수 있어야 한다.
- 사회, 경제, 시사, 문화, 문학, 역사, 인문학, 사교 등 과학 지식과 관련되지 않은 나머지 대화 메시지에는 적절한 대답을 생성한다.
- 결과는 json 형태로 생성하고, 반드시 'is_science' 필드를 추가하여 질문이 과학 지식에 관련된 내용이면 true를, 과학 지식에 관련된 내용이 아니라면 false를 value로 만든다. 답변 필드의 이름은 'answer'로 통일한다.
"""

# Function calling에 사용할 함수 정의
tools = [
    {
        "type": "function",
        "function": {
            "name": "search",
            "description": "search relevant documents",
            "parameters": {
                "properties": {
                    "standalone_query": {
                        "type": "string",
                        "description": "Final query suitable for use in search from the user messages history."
                    }
                },
                "required": ["standalone_query"],
                "type": "object"
            }
        }
    },
]

# %%
# LLM과 검색엔진을 활용한 RAG 구현
def answer_question(messages):
    # 함수 출력 초기화
    response = {"standalone_query": "", "topk": [], "references": [], "answer": ""}

    # 질의 분석 및 검색 이외의 질의 대응을 위한 LLM 활용
    msg = [{"role": "system", "content": persona_function_calling}] + messages
    try:
        ### 이 부분을 바꿔서 json으로 만들어 줄까...
        result = client.chat.completions.create(
            model=llm_model,
            response_format={"type": "json_object"},
            messages=msg,
            tools=tools,
            #tool_choice={"type": "function", "function": {"name": "search"}},
            temperature=0,
            seed=1,
            timeout=60
        )
    except Exception as e:
        traceback.print_exc()
        return response

    # 검색이 필요한 경우 검색 호출후 결과를 활용하여 답변 생성
    if result.choices[0].message.tool_calls:
        tool_call = result.choices[0].message.tool_calls[0]
        function_args = json.loads(tool_call.function.arguments)
        standalone_query = function_args.get("standalone_query")

        # Baseline으로는 sparse_retrieve만 사용하여 검색 결과 추출
        search_result = dense_retrieve(standalone_query, 3)

        response["standalone_query"] = standalone_query
        retrieved_context = []
        for i,rst in enumerate(search_result['hits']['hits']):
            retrieved_context.append(rst["_source"]["content"])
            response["topk"].append(rst["_source"]["docid"])
            response["references"].append({"score": rst["_score"], "content": rst["_source"]["content"]})

        content = json.dumps(retrieved_context)
        messages.append({"role": "assistant", "content": content})
        msg = [{"role": "system", "content": persona_qa}] + messages
        try:
            qaresult = client.chat.completions.create(
                    model=llm_model,
                    response_format={"type": "json_object"},
                    messages=msg,
                    temperature=0,
                    seed=1,
                    timeout=30
                )
        except Exception as e:
            traceback.print_exc()
            return response
        response["answer"] = qaresult.choices[0].message.content

    # 검색이 필요하지 않은 경우 바로 답변 생성
    else:
        response["answer"] = result.choices[0].message.content

    return response

# %%
import json

# 평가를 위한 파일을 읽어서 각 평가 데이터에 대해서 결과 추출 후 파일에 저장
def eval_rag(eval_filename, output_filename, start_idx=-1):
    with open(eval_filename) as f, open(output_filename, "w") as of:
        idx=0
        for line in f:
            if idx < start_idx:
                idx += 1
                continue
            j = json.loads(line)
            print(f'Test {idx}\nQuestion: {j["msg"]}')
            response = answer_question(j["msg"])
            print(f'Answer: {response["answer"]}\n')

            # 대회 score 계산은 topk 정보를 사용, answer 정보는 LLM을 통한 자동평가시 활용
            # output = {"eval_id": j["eval_id"], "standalone_query": response["standalone_query"], "topk": response["topk"], "answer": response["answer"], "references": response["references"]}

            # json.loads(response)
            res_answer = json.loads(response["answer"])
            is_science = res_answer.get("is_science", False)
            if not is_science:
                answer = "과학 지식에 관련한 질문이 아닙니다."
                topk = []
            else:
                answer = res_answer['answer']
                topk = response["topk"]
            
            # json format으로 생성했을 때.
            output = {"eval_id": j["eval_id"], 
                      "standalone_query": response["standalone_query"], 
                      "topk": topk, 
                      "answer": answer, 
                      "references": response["references"]}
            of.write(f'{json.dumps(output, ensure_ascii=False)}\n')
            idx += 1

# %%
# 역색인을 사용하는 검색 예제
q1 = '나무의 분류에 대해 조사해 보기 위한 방법은?'
search_result_retrieve = sparse_retrieve(q1, 3)
search_result_retrieve
# Out:
# ObjectApiResponse({'took': 7, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 4238, 'relation': 'eq'}, 'max_score': 20.857122, 'hits': [{'_index': 'test', '_id': 'cZphOI8B-sAIPHWjBLOI', '_score': 20.857122, '_source': {'docid': 'c63b9e3a-716f-423a-9c9b-0bcaa1b9f35d', 'src': 'ko_ai2_arc__ARC_Challenge__test', 'content': '한 학생이 다양한 종류의 나무를 조사하고 있습니다. 이 학생은 성장 속도, 온도 범위, 크기가 비슷한 두 나무를 발견했습니다. 그러나 이 두 나무의 잎과 꽃은 서로 다릅니다. 이러한 특징을 고려하면, 이 나무들은 대체로 같은 속에 속해 있을 것으로 추측됩니다. 같은 속에 속한 나무들은 종류별로 유사한 특징을 가지고 있으며, 이는 생물 분류학에서 중요한 기준 중 하나입니다. 따라서 이 학생의 조사 결과는 나무의 분류와 관련된 중요한 정보를 제공할 수 있습니다. 이러한 조사는 나무의 성장과 생태에 대한 이해를 높이는 데 도움이 될 것입니다.', 'embeddings': [0.17039655148983002, -0.13365022838115692, -0.20746152102947235, 0.9684341549873352, 0.09740294516086578, 0.3687126636505127, 1.2090917825698853, -0.09777592867612839, -0.12069620937108994, -0.4030536413192749, -0.835671603679657, 0.40196850895881653, -0.2718091607093811, 1.1951520442962646, -0.10160969942808151, -0.5087798833847046, 0.33753693103790283, -0.16032810509204865, -0.3896369934082031, 0.5736127495765686, 1.3078765869140625, -0.13725215196609497, 0.42126819491386414, 0.4572317898273468, 0.2764871418476105, -0.9314201474189758, -0.13462430238723755, -0.5210184454917908, 0.3066173195838928, -0.20353762805461884, -0.2882412374019623, 1.1706711053848267, -0.38542085886001587, -0.07747980952262878, -0.4532502591609955, 0.19780582189559937, -1.091675877571106, 0.3252946436405182, -0.25284409523010254, -1.0262646675109863, 0.6548763513565063, -0.5591380596160889, 0.7589282989501953, -0.27778276801109314, 0.602864682674408, 0.022455133497714996, 0.0827639177441597, 0.6599311828613281, -0.8281084895133972, 0.18013995885849, 0.5710203051567078, -1.5662246942520142, 0.7665377855300903, -0.3579629957675934, -0.033898767083883286, -0.4699185788631439, 1.1970975399017334, 0.6455050110816956, -0.2720514237880707, 0.4284261465072632, -0.3160991370677948, 0.49031776189804077, 0.022561144083738327, -0.6772618889808655, -0.8679713606834412, -0.25454697012901306, -0.9354437589645386, 0.2789747416973114, 0.3745100796222687, -0.1776115596294403, -0.4876278042793274, 0.0067003159783780575, 0.3261241912841797, 0.01901065930724144, 0.25587689876556396, -0.09727168083190918, -1.2272573709487915, 0.40042954683303833, 0.3197261691093445, -0.20465382933616638, -0.2819634974002838, -0.06497403979301453, 1.1192231178283691, 0.9521888494491577, -0.11685013025999069, -0.3009378910064697, 0.2742285132408142, -0.28198346495628357, 0.26059409976005554, 0.2917404770851135, 0.22703436017036438, 0.8185682892799377, 0.21499763429164886, -0.911631166934967, 0.21972332894802094, -0.25214317440986633, -0.5786407589912415, -0.9535561203956604, -0.2536630630493164, -0.026205025613307953, 1.037853717803955, 0.579581618309021, -0.4627806842327118, -0.15206724405288696, 0.9352381825447083, -0.7733242511749268, 0.45124608278274536, 0.07849004864692688, 0.04031994566321373, 0.7738380432128906, -0.9371283054351807, 0.08249349892139435, 0.34269335865974426, -0.5625115633010864, 0.46605154871940613, 0.3591384291648865, -0.5010135769844055, -0.21018017828464508, 0.026508282870054245, 0.28094688057899475, -0.8415848016738892, 1.19404935836792, -0.3219076097011566, -0.15236932039260864, 0.07308151572942734, 0.5339446663856506, -0.3542468547821045, 0.21561135351657867, -0.14568518102169037, 0.953896701335907, 0.30173763632774353, -0.4554567039012909, -0.37854209542274475, 0.0026848050765693188, 0.024260958656668663, -0.03578099608421326, -0.04365142807364464, -0.1212092712521553, 0.5730496644973755, -0.13933683931827545, 0.2657463848590851, -0.1035965085029602, -0.4159095585346222, -0.8227988481521606, -0.7633656859397888, -0.7400039434432983, 0.4601360559463501, -0.3901209533214569, 0.2995399534702301, 0.25657474994659424, -0.7826962471008301, 0.44608575105667114, 0.6585895419120789, -0.4471273124217987, 0.08272828906774521, -0.2561902403831482, -0.46384644508361816, 0.025 ...

# %%
# 평가 데이터에 대해서 결과 생성 - 파일 포맷은 jsonl이지만 파일명은 csv 사용
eval_rag("data/eval.jsonl", f"submission_{datetime.now().strftime('%Y-%m-%d_%H-%M')}.csv")
# Out:
# Test 0
# Question: [{'role': 'user', 'content': '나무의 분류에 대해 조사해 보기 위한 방법은?'}]
# Answer: {
#   "answer": "나무의 분류를 조사하기 위해서는 다음과 같은 방법을 사용할 수 있습니다. 첫째, 나무의 형태학적 특징을 관찰합니다. 이는 나무의 잎, 꽃, 열매, 줄기 등의 외형적 특성을 관찰하여 분류하는 방법입니다. 둘째, DNA 바코딩을 이용한 유전적 분석을 할 수 있습니다. 이 방법은 나무의 DNA 시퀀스를 분석하여 종을 식별하는 현대적인 방법입니다. 셋째, 생태적 특성을 고려한 분류도 가능합니다. 나무가 자라는 환경과 그 생태계 내에서의 역할을 고려하여 분류할 수 있습니다. 이러한 방법들을 통해 나무의 분류학적 연구를 진행할 수 있습니다.",
#   "is_science": true
# }
#
# Test 1
# Question: [{'role': 'user', 'content': '각 나라에서의 공교육 지출 현황에 대해 알려줘.'}]
# Answer:
# {
#   "answer": "각 나라에서의 공교육 지출 현황에 대한 정보는 제 전문 분야인 과학 지식과 직접적인 관련이 없습니다. 이에 대한 정보는 교육 통계나 경제 관련 자료를 참고하시는 것이 좋을 것 같습니다.",
#   "is_science": false
# }
#
# Test 2
# Question: [{'role': 'user', 'content': '기억 상실증 걸리면 너무 무섭겠다.'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '어떤 원인 때문에 발생하는지 궁금해.'}]
# Answer: {
#   "answer": "기억 상실증은 다양한 원인으로 발생할 수 있습니다. 대표적으로 뇌 손상, 알츠하이머병 같은 신경 퇴행성 질환, 뇌졸중, 감염, 약물의 부작용, 심한 스트레스나 정신적 충격 등이 있습니다. 이러한 원인들은 뇌의 기억을 담당하는 부분에 영향을 미쳐 기억력에 장애를 일으킬 수 있습니다.",
#   "is_science": true
# }
#
# Test 3
# Question: [{'role': 'user', 'content': '통학 버스의 가치에 대해 말해줘.'}]
# Answer: {
#   "is_science": false,
#   "answer": "통학 버스는 학생들이 학교에 안전하고 편리하게 다닐 수 있도록 도와주는 중요한 수단입니다. 특히 거리가 먼 학생들이나 대중교통이 잘 발달하지 않은 지역의 학생들에게 큰 도움이 됩니다. 또한, 통학 버스는 교통 혼잡을 줄이고 환경 오염을 감소시키는 데에도 기여할 수 있습니다."
# }
#
# Test 4
# Question: [{'role': 'user', 'content': 'Dmitri Ivanovsky가 누구야?'}]
# Answer: {
#   "answer": "Dmitri Ivanovsky는 러시아의 미생물학자로, 바이러스의 발견과 연구에 기여한 인물입니다. 그는 1892년에 식물 질병 연구 중에 토바코 모자이크 바이러스를 발견했으며, 이는 바이러스로 인한 첫 번째 질병으로 기록되었습니다. 이 발견은 바이러스학의 발전에 중요한 역할을 했습니다.",
#   "is_science": true
# }
#
# Test 5
# Question: [{'role': 'user', 'content': '피임을 하기 위한 방법중 약으로 처리하는 방법은 쓸만한가?'}]
# Answer: {
#   "answer": "피임약은 효과적인 피임 방법 중 하나로 널리 사용되고 있습니다. 피임약은 정확하게 복용할 경우 매우 높은 피임 효과를 보이며, 부작용은 있을 수 있지만 대부분의 사용자에게 안전하게 사용될 수 있습니다. 그러나 개인의 건강 상태나 다른 약물과의 상호작용 등을 고려해야 하므로, 피임약을 시작하기 전에 의사와 상담하는 것이 중요합니다.",
#   "is_science": true
# }
#
# Test 6
# Question: [{'role': 'user', 'content': '헬륨이 다른 원소들과 반응을 잘 안하는 이유는?'}]
# Answer: {
#   "answer": "헬륨은 매우 안정된 전자 구성을 가지고 있어서 다른 원소들과 반응을 잘 하지 않습니다. 헬륨 원자는 전자가 2개만 있고, 이는 가장 낮은 에너지 준위인 1s 오비탈을 완전히 채워 안정된 상태입니다. 이로 인해 헬륨은 더 이상의 전자를 얻거나 잃을 필요가 없어 화학적으로 매우 불활성입니다.",
#   "is_science": true
# }
#
# Test 7
# Question: [{'role': 'user', 'content': '문맹 비율이 사회 발전에 미치는 영향은?'}]
# Answer:
# {
#   "answer": "문맹 비율과 사회 발전의 관계는 매우 중요한 주제이지만, 이는 과학 지식과 직접적인 관련이 없는 사회학적, 경제학적 문제입니다. 문맹 비율이 높은 사회는 교육 수준이 낮고, 이는 경제 발전, 고용 기회, 건강 상태 등 여러 사회적 문제에 영향을 미칠 수 있습니다. 교육을 통해 문맹률을 감소시키는 것은 사회 전반의 발전을 촉진할 수 있는 중요한 방법 중 하나입니다.",
#   "is_science": false
# }
#
# Test 8
# Question: [{'role': 'user', 'content': '이란 콘트라 사건이 뭐야'}, {'role': 'assistant', 'content': '이란-콘트라 사건은 로널드 레이건 집권기인 1986년에 레이건 행정부와 CIA가 적성국이었던 이란에게 무기를 몰래 수출한 대금으로 니카라과의 우익 성향 반군 콘트라를 지원하면서 동시에 반군으로부터 마약을 사들인 후 미국에 판매하다가 발각되어 큰 파장을 일으킨 사건입니다.'}, {'role': 'user', 'content': '이 사건이 미국 정치에 미친 영향은?'}]
# Answer:
# {
#   "answer": "이란-콘트라 사건은 미국 정치에 큰 영향을 미쳤습니다. 이 사건으로 인해 레이건 대통령의 신뢰도가 크게 하락했으며, 미국 정부의 외교 정책과 중앙정보국(CIA)의 활동에 대한 국민의 불신이 증가했습니다. 또한, 이 사건은 미국 정부 내에서의 비밀리에 이루어지는 불법 행위와 권력 남용에 대한 경각심을 불러일으켰고, 이후 정부의 투명성과 책임성 강화를 위한 법적 및 정책적 변화를 촉구하는 계기가 되었습니다.",
#   "is_science": false
# }
#
# Test 9
# Question: [{'role': 'user', 'content': '자기장이 얼마나 센지 표현하는 방식은?'}]
# Answer: {
#   "answer": "자기장의 세기는 '테슬라(Tesla, T)' 단위로 표현합니다. 테슬라는 자기장의 세기를 나타내는 국제단위계(SI)의 단위로, 자기장이 한 미터에 걸쳐 한 암페어의 전류에 작용하는 힘을 1 뉴턴으로 정의합니다.",
#   "is_science": true
# }
#
# Test 10
# Question: [{'role': 'user', 'content': '피를 맑게 하고 몸 속의 노폐물을 없애는 역할을 하는 기관은?'}]
# Answer: {
#   "answer": "피를 맑게 하고 몸 속의 노폐물을 제거하는 주요 기관은 신장입니다. 신장은 혈액을 여과하여 노폐물을 소변으로 배출하고, 체내의 전해질 균형을 유지하는 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 11
# Question: [{'role': 'user', 'content': '글리코겐의 분해는 인체에서 왜 필요한가?'}]
# Answer: {
#   "answer": "글리코겐의 분해는 인체에서 에너지를 생성하기 위해 필요합니다. 글리코겐은 간과 근육에 저장된 다당류로, 필요할 때 글루코스로 분해되어 에너지를 공급하고 혈당 수준을 조절하는 데 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 12
# Question: [{'role': 'user', 'content': '빗방울이 점점 커지게 되는 요인은?'}]
# Answer: {
#   "answer": "빗방울이 커지는 주된 요인은 '충돌-합체 과정'입니다. 구름 속에서 작은 물방울들이 서로 부딪히며 합쳐져 점점 큰 물방울을 형성합니다. 이 과정을 통해 충분히 커진 빗방울은 중력의 영향으로 지상으로 떨어지게 됩니다.",
#   "is_science": true
# }
#
# Test 13
# Question: [{'role': 'user', 'content': '기체의 부피나 형태가 왜 일정하지 않을까?'}]
# Answer: {
#   "answer": "기체는 분자들이 자유롭게 움직이며 서로 간의 간격이 크기 때문에 부피나 형태가 일정하지 않습니다. 기체의 부피와 형태는 주변 환경의 압력과 온도에 따라 변할 수 있습니다.",
#   "is_science": true
# }
#
# Test 14
# Question: [{'role': 'user', 'content': '식물이 빛을 에너지로 변환하는 과정에 대해 설명해줘.'}]
# Answer: {
#   "answer": "식물은 광합성 과정을 통해 빛을 에너지로 변환합니다. 이 과정에서 식물의 엽록체는 태양광을 흡수하여 물과 이산화탄소를 사용해 포도당과 산소를 생성합니다. 생성된 포도당은 식물의 에너지원으로 사용되며, 산소는 대기로 방출됩니다.",
#   "is_science": true
# }
#
# Test 15
# Question: [{'role': 'user', 'content': '직류와 교류 전류의 차이에 대해 알려줘.'}]
# Answer: {
#   "answer": "직류(DC)는 전류가 한 방향으로만 흐르는 전류를 말하며, 교류(AC)는 전류가 주기적으로 방향을 바꾸면서 흐르는 전류를 말합니다. 직류는 배터리에서 주로 사용되며, 교류는 가정용 전력 공급에 주로 사용됩니다. 교류는 변압기를 통해 전압을 쉽게 변환할 수 있어 전력 손실을 줄이면서 장거리 전송이 가능합니다.",
#   "is_science": true
# }
#
# Test 16
# Question: [{'role': 'user', 'content': '기름과 물이 섞여 있을 수 있나?'}]
# Answer: {
#   "answer": "기름과 물은 서로 섞이지 않습니다. 이는 물이 극성 분자이고 기름이 비극성 분자이기 때문에 서로 다른 성질을 가지고 있어 서로 섞이지 않는 것입니다.",
#   "is_science": true
# }
#
# Test 17
# Question: [{'role': 'user', 'content': '인간이 2세를 생산할 때 DNA의 결합 과정에 대히 설명해줘.'}]
# Answer: {
#   "answer": "인간의 생식 과정에서 DNA의 결합은 수정란 형성 시 중요한 역할을 합니다. 남성과 여성의 감수분열을 통해 각각 정자와 난자가 형성되며, 이들 각각은 23개의 염색체를 가집니다. 정자와 난자가 결합하여 수정란을 형성할 때, 각각의 염색체들이 서로 결합하여 총 46개의 염색체를 가진 새로운 세포가 만들어집니다. 이 과정에서 DNA는 염색체 내에서 이중나선 구조를 이루며, 각 나선은 상보적인 염기쌍으로 연결됩니다. 이렇게 형성된 DNA는 부모로부터 물려받은 유전 정보를 담고 있어, 자손이 부모의 특성을 이어받을 수 있게 합니다.",
#   "is_science": true
# }
#
# Test 18
# Question: [{'role': 'user', 'content': '금성에서 달이 어떻게 보일까?'}]
# Answer: {
#   "answer": "금성에서는 달을 볼 수 없습니다. 금성은 태양계에서 태양에 가장 가까운 행성 중 하나이며, 지구와는 다르게 자체 위성이 없습니다. 따라서 금성에서는 지구의 달을 관측할 수 없습니다.",
#   "is_science": true
# }
#
# Test 19
# Question: [{'role': 'user', 'content': '차량의 연비가 좋아질때 나타나는 긍정적인 효과는?'}]
# Answer: {
#     "answer": "차량의 연비가 좋아지면 연료 비용 절감, 환경 오염 감소, 이산화탄소 배출량 감소 등의 긍정적인 효과가 있습니다.",
#     "is_science": true
# }
#
# Test 20
# Question: [{'role': 'user', 'content': '혼합물의 특성에 대해 알려줘.'}]
# Answer: {
#   "answer": "혼합물은 두 가지 이상의 물질이 물리적으로 섞여 있는 것을 말하며, 각 성분은 화학적 특성을 유지합니다. 혼합물은 균일 혼합물과 불균일 혼합물로 나뉘며, 균일 혼합물은 전체에 걸쳐 동일한 성질을 보이고, 불균일 혼합물은 물질의 분포가 일정하지 않습니다. 예를 들어, 소금물은 균일 혼합물이고, 모래와 소금의 혼합은 불균일 혼합물입니다.",
#   "is_science": true
# }
#
# Test 21
# Question: [{'role': 'user', 'content': '요새 너무 힘들다.'}]
# Answer: {
#   "answer": "많이 힘드시겠어요. 어떤 부분이 힘드신지 나누고 싶으시면 말씀해주세요. 조금이나마 도움이 되고자 합니다.",
#   "is_science": false
# }
#
# Test 22
# Question: [{'role': 'user', 'content': '세제의 거품이 만들어지는 원리는?'}]
# Answer: {
#   "answer": "세제의 거품이 만들어지는 원리는 세제 분자가 물과 기름을 연결하는 역할을 하여 물과 기름이 섞이게 합니다. 세제 분자의 한쪽 끝은 물을 좋아하는 친수성을 가지고 있고, 다른 한쪽 끝은 기름을 좋아하는 소수성을 가집니다. 이로 인해 세제 분자는 물과 기름 사이에 자리 잡아 두 물질이 섞일 수 있도록 돕습니다. 이 과정에서 미세한 거품이 형성되며, 이 거품들이 모여 큰 거품을 형성하게 됩니다.",
#   "is_science": true
# }
#
# Test 23
# Question: [{'role': 'user', 'content': '나무가 생태계에서 하는 역할에 대해 설명해줘.'}]
# Answer: {
#   "answer": "나무는 생태계에서 다양한 역할을 합니다. 첫째, 나무는 이산화탄소를 흡수하고 산소를 방출하는 광합성 과정을 통해 대기의 질을 개선합니다. 둘째, 나무의 뿌리는 토양을 고정시켜 침식을 방지하고, 물의 순환을 돕습니다. 셋째, 나무는 생물 다양성의 보고로서 다양한 동식물의 서식지를 제공합니다. 이 외에도 나무는 기후 조절, 레크리에이션 공간 제공 등 여러 면에서 중요한 역할을 수행합니다.",
#   "is_science": true
# }
#
# Test 24
# Question: [{'role': 'user', 'content': '전류의 흐름을 극대화 하려면 배터리와 저항을 어떻게 연결해야 하나?'}]
# Answer: {
#   "answer": "전류의 흐름을 극대화 하려면 배터리와 저항을 직렬로 연결해야 합니다. 직렬 연결은 배터리와 저항기가 한 줄로 연결되는 구성을 말합니다. 이 구성에서는 배터리의 전압이 저항기에 모두 걸리기 때문에 전류가 최대로 흐를 수 있습니다.",
#   "is_science": true
# }
#
# Test 25
# Question: [{'role': 'user', 'content': '식물이 높이 자랄 수 있게 하는 메커니즘이 궁금해.'}]
# Answer: {
#   "answer": "식물이 높이 자라는 메커니즘은 주로 식물 호르몬인 '오스모신'과 '지베렐린'의 작용에 의해 조절됩니다. 오스모신은 식물의 세포 분열과 확장을 촉진하여 식물이 높이 자라게 하며, 지베렐린은 식물의 줄기가 길어지도록 돕습니다. 또한, 빛과 물, 영양소의 적절한 공급도 식물의 성장에 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 26
# Question: [{'role': 'user', 'content': '달을 보면 항상 같은 면만 보이더라구'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 이유가 뭐야?'}]
# Answer: {
#   "answer": "달이 지구에 항상 같은 면만 보이는 현상은 '동조 회전' 또는 '조석 고정' 때문입니다. 달의 자전 주기와 공전 주기가 같아서, 달이 한 바퀴 돌아 자기 자리로 돌아오는 동안에도 정확히 한 번 자전하기 때문에 지구에서 보는 달의 면은 항상 같은 면입니다.",
#   "is_science": true
# }
#
# Test 27
# Question: [{'role': 'user', 'content': '식초와 베이킹 소다를 섞어주면 어떤 일이 일어나?'}]
# Answer: {
#   "answer": "식초와 베이킹 소다를 섞으면 화학 반응이 일어나 이산화탄소 가스가 발생합니다. 이 반응은 산(식초)과 염기(베이킹 소다)가 만나면서 이산화탄소, 물, 그리고 나트륨 아세테이트라는 소금을 생성합니다.",
#   "is_science": true
# }
#
# Test 28
# Question: [{'role': 'user', 'content': '세균이 나쁜줄말 알았는데 그게 아니야?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그럼 순기능에 대해 알려줄래?'}]
# Answer: {
#   "answer": "세균은 우리 몸에서 유익한 역할을 많이 합니다. 예를 들어, 인간의 장내 세균은 소화를 돕고, 비타민을 합성하며, 면역 체계를 강화하는 데 중요한 역할을 합니다. 또한, 환경에서는 유기물 분해와 영양소 순환에 기여하여 생태계의 균형을 유지하는 데 필수적입니다.",
#   "is_science": true
# }
#
# Test 29
# Question: [{'role': 'user', 'content': '오토마톤의 특징에 대해 알려줘.'}]
# Answer: {
#   "answer": "오토마톤은 자동으로 작동하는 기계 장치로, 주로 기계적 또는 전자적 수단을 사용하여 특정 작업을 수행합니다. 초기 형태는 기계적 장치였으나 현대에는 컴퓨터 프로그래밍을 통해 복잡한 작업을 수행하는 전자 오토마톤도 포함됩니다. 이들은 반복적이거나 정밀한 작업을 인간 대신 수행할 수 있어 다양한 산업 분야에서 활용됩니다.",
#   "is_science": true
# }
#
# Test 30
# Question: [{'role': 'user', 'content': '다양한 책을 catalog화 하는 코드에서 class 정의 방법 알려줘.'}]
# Answer:
# {
#   "answer": "책을 카탈로그화 하는 코드에서 클래스를 정의하는 방법은 프로그래밍 언어에 따라 다를 수 있습니다. 예를 들어, Python에서는 다음과 같이 클래스를 정의할 수 있습니다:\n\n```python\nclass Book:\n    def __init__(self, title, author, isbn):\n        self.title = title\n        self.author = author\n        self.isbn = isbn\n\n    def display_info(self):\n        print(f'Title: {self.title}, Author: {self.author}, ISBN: {self.isbn}')\n```\n\n이 클래스는 책의 제목, 저자, ISBN을 속성으로 가지며, `display_info` 메서드를 통해 이 정보를 출력할 수 있습니다. 다른 프로그래밍 언어에서도 비슷한 방식으로 클래스를 정의할 수 있습니다.",
#   "is_science": true
# }
#
# Test 31
# Question: [{'role': 'user', 'content': '전구가 병렬로 연결될 때 전류가 줄어드는 원인은?'}]
# Answer: {
#   "answer": "전구가 병렬로 연결될 때 전체 회로의 저항이 감소합니다. 각 전구에 걸리는 전압은 동일하게 유지되지만, 전체 회로의 저항이 줄어들면서 전체 회로를 통과하는 전류가 증가합니다. 따라서 각 전구를 통과하는 전류는 줄어들 수 있습니다.",
#   "is_science": true
# }
#
# Test 32
# Question: [{'role': 'user', 'content': '물속에서 침전이 발생하는 원리에 대해 알려줘.'}]
# Answer: {
#   "answer": "물속에서 침전이 발생하는 원리는 물질들이 물 속에서 서로 반응하여 더 이상 물에 용해되지 않고 고체 형태로 바닥에 가라앉는 현상입니다. 이는 주로 용해도의 차이, 온도, 압력의 변화 등에 의해 발생합니다. 예를 들어, 물에 녹아 있는 이온들이 서로 반응하여 용해도가 낮은 화합물을 형성하면 그 화합물은 고체 형태로 침전하여 물속에서 분리됩니다.",
#   "is_science": true
# }
#
# Test 33
# Question: [{'role': 'user', 'content': '화산 폭발이 발생한 후 새로운 생물 군집이 생겨나는 것을 무엇이라 부르나?'}]
# Answer: {
#   "answer": "화산 폭발 후 새로운 생물 군집이 생겨나는 것을 '1차 서식지 조성'이라고 부릅니다.",
#   "is_science": true
# }
#
# Test 34
# Question: [{'role': 'user', 'content': '축전기를 병렬로 이어주면 전체 용량이 어떻게 되는가?'}]
# Answer: {
#   "answer": "축전기를 병렬로 연결하면 각 축전기의 용량이 합산되어 전체 용량이 증가합니다.",
#   "is_science": true
# }
#
# Test 35
# Question: [{'role': 'user', 'content': '정육면체가 가라앉지 않고 물 위에 떠 있을 때 수면 윗부분에 해당하는 부피를 구하는 방법은?'}]
# Answer: {
#   "answer": "정육면체가 물 위에 떠 있을 때 수면 위로 떠 있는 부분의 부피를 구하기 위해서는 물의 밀도와 정육면체의 무게, 그리고 부피를 알아야 합니다. 먼저, 정육면체의 무게를 물의 밀도와 곱하여 물에 의해 밀려 올라가는 힘(부력)을 계산합니다. 이 부력이 정육면체의 무게와 같아지는 지점이 물 위로 떠 있는 부분의 부피와 관련이 있습니다. 정육면체의 전체 부피에서 물 속에 잠긴 부분의 부피를 빼면, 물 위로 떠 있는 부분의 부피를 구할 수 있습니다.",
#   "is_science": true
# }
#
# Test 36
# Question: [{'role': 'user', 'content': '니가 대답을 잘해줘서 너무 신나!'}]
# Answer: {
#   "answer": "감사합니다! 언제든지 궁금한 점이 있으면 물어보세요.",
#   "is_science": false
# }
#
# Test 37
# Question: [{'role': 'user', 'content': '건설 현장에서 망치로 벽을 치는 이유는?'}]
# Answer:
# {
#   "answer": "건설 현장에서 망치로 벽을 치는 이유는 여러 가지가 있을 수 있습니다. 주로 못을 박거나, 구조물을 고정시키기 위해 사용되며, 때로는 벽체의 일부를 철거하거나 조정하기 위해 사용될 수도 있습니다. 망치는 건설 현장에서 가장 기본적이면서 필수적인 도구 중 하나입니다.",
#   "is_science": false
# }
#
# Test 38
# Question: [{'role': 'user', 'content': '차량의 매연이 발생하지 않게 만드는 장치가 무엇인가?'}]
# Answer: {
#   "answer": "차량의 매연을 줄이기 위해 사용되는 장치는 촉매 변환기(catalytic converter)입니다. 이 장치는 차량의 배기 시스템에 설치되어 유해한 배출가스를 덜 해로운 물질로 변환하여 대기 오염을 줄이는 역할을 합니다.",
#   "is_science": true
# }
#
# Test 39
# Question: [{'role': 'user', 'content': 'python에서 lambda 함수를 언제 사용할 수 있어?'}]
# Answer:
# {
#   "answer": "Python에서 lambda 함수는 작은 익명 함수를 정의할 때 사용할 수 있습니다. 이는 일반적으로 간단한 연산이나 함수를 인자로 전달할 때 유용하며, `map()`, `filter()`, `reduce()` 같은 함수와 함께 자주 사용됩니다. lambda 함수는 `lambda` 키워드를 사용하여 정의되며, 간결한 한 줄 코드로 함수를 작성할 수 있게 해줍니다.",
#   "is_science": false
# }
#
# Test 40
# Question: [{'role': 'user', 'content': '강이나 바다의 물이 증발하는 가장 중요한 원인은?'}]
# Answer: {
#   "answer": "강이나 바다의 물이 증발하는 가장 중요한 원인은 높은 온도입니다. 높은 온도는 물 분자의 운동 에너지를 증가시켜, 분자 간의 결합을 약화시키고, 이로 인해 물 분자가 쉽게 수증기로 변할 수 있게 합니다.",
#   "is_science": true
# }
#
# Test 41
# Question: [{'role': 'user', 'content': '남녀 관계에서 정서적인 행동이 왜 중요해?'}]
# Answer: {
#   "answer": "남녀 관계에서 정서적인 행동은 서로의 감정을 이해하고 공감하는 데 중요한 역할을 합니다. 이는 신뢰와 깊은 연결을 구축하는 데 도움이 되며, 관계의 안정성과 만족도를 높일 수 있습니다. 감정을 적절히 표현하고 상대방의 감정을 존중하는 것은 건강한 관계를 유지하는 데 필수적입니다.",
#   "is_science": false
# }
#
# Test 42
# Question: [{'role': 'user', 'content': 'DNA 조각들이 서로 결합되도록 돕는 것은?'}]
# Answer: {
#   "answer": "DNA 조각들이 서로 결합되도록 돕는 것은 DNA 리가제입니다. DNA 리가제는 DNA 복제와 수리 과정에서 DNA 단편들을 연결하는 역할을 합니다.",
#   "is_science": true
# }
#
# Test 43
# Question: [{'role': 'user', 'content': '해가 뜨는 현상이 지구의 자전과 관련있어?'}]
# Answer: {
#   "answer": "네, 해가 뜨는 현상은 지구의 자전과 관련이 있습니다. 지구가 자신의 축을 중심으로 24시간 동안 한 바퀴 회전하면서, 태양이 동쪽에서 떠서 서쪽으로 지는 것처럼 보이는 현상이 발생합니다. 이러한 지구의 자전으로 인해 낮과 밤이 교차하게 됩니다.",
#   "is_science": true
# }
#
# Test 44
# Question: [{'role': 'user', 'content': '두 물질이 다른 분자구조나 화학적인 성분으로 이루어져 있다는 것을 어떻게 알 수 있나요?'}]
# Answer: {
#   "answer": "두 물질이 다른 분자구조나 화학적인 성분으로 이루어져 있는지 알아보기 위해서는 여러 과학적 방법을 사용할 수 있습니다. 예를 들어, 분광학적 방법(예: 적외선 분광학, 핵자기 공명 분광학)을 통해 물질의 분자 구조를 분석할 수 있습니다. 또한, 크로마토그래피 같은 분리 기술을 사용하여 물질을 구성하는 성분을 분리하고 각 성분의 화학적 특성을 파악할 수 있습니다. 이러한 방법들은 물질의 화학적 구성과 구조적 차이를 명확하게 밝혀줄 수 있습니다.",
#   "is_science": true
# }
#
# Test 45
# Question: [{'role': 'user', 'content': '수성이 뜨거운 이유는?'}]
# Answer: {
#   "answer": "수성이 뜨거운 이유는 태양에 매우 가까이 위치해 있기 때문입니다. 수성의 궤도는 태양으로부터 평균 약 0.39 천문단위(AU) 떨어져 있으며, 이는 지구와 태양 사이의 거리의 약 39%에 해당합니다. 이렇게 가까운 거리 때문에 수성은 태양으로부터 많은 양의 태양 에너지를 받아 표면 온도가 매우 높아집니다.",
#   "is_science": true
# }
#
# Test 46
# Question: [{'role': 'user', 'content': '하구 퇴적지의 기능에 대해 알려줘.'}]
# Answer: {
#   "answer": "하구 퇴적지는 많은 종이 알을 낳고 새끼를 키우는 곳으로 알려져 있습니다. 이러한 곳은 바다의 보호원으로 불리며, 많은 생물들에게 안전한 은신처를 제공합니다. 하구 퇴적지는 풍부한 은신처를 가지고 있어 다양한 해양 생물들이 서식할 수 있습니다. 또한, 하구 퇴적지는 농축된 영양분을 가지고 있어 생물들이 영양을 공급받을 수 있습니다. 이러한 특징들이 하구 퇴적지가 바다의 보호원 역할을 가장 잘 뒷받침하는 이유입니다.",
#   "is_science": true
# }
#
# Test 47
# Question: [{'role': 'user', 'content': '디엔에이에서 퓨린과 피리미딘은 어떤 비율로 존재하는가?'}]
# Answer: {
#   "answer": "DNA에서 퓨린과 피리미딘은 1:1의 비율로 존재합니다. 이는 DNA의 구조적 안정성을 유지하기 위해 중요한 역할을 합니다. 퓨린(아데닌과 구아닌)과 피리미딘(시토신과 티민)은 수소 결합을 통해 서로 결합하며, 이러한 결합은 DNA의 이중 나선 구조를 형성하는 데 필수적입니다.",
#   "is_science": true
# }
#
# Test 48
# Question: [{'role': 'user', 'content': 'interferon의 역할에 대해 알려줘.'}]
# Answer: {
#   "answer": "인터페론은 바이러스 감염에 대응하여 우리 몸의 면역 체계가 생성하는 단백질입니다. 바이러스 감염된 세포가 인터페론을 생성하면, 이는 주변의 건강한 세포에 신호를 보내어 바이러스의 복제를 억제하는 물질을 생성하도록 합니다. 이를 통해 인터페론은 바이러스의 확산을 막고, 면역 체계의 다른 부분이 감염을 효과적으로 제거할 수 있도록 돕습니다.",
#   "is_science": true
# }
#
# Test 49
# Question: [{'role': 'user', 'content': '하나의 유전자에서 여러가지 단백질이 만들어질 수 있는 원인은?'}]
# Answer: {
#   "answer": "하나의 유전자에서 여러 가지 단백질이 만들어질 수 있는 원인은 대체 스플라이싱 때문입니다. 대체 스플라이싱은 유전자가 전사된 후, 생성된 전령 RNA(mRNA)가 다양한 방식으로 조립되어 서로 다른 mRNA 분자들을 생성하게 되는 과정입니다. 이로 인해 하나의 유전자로부터 여러 종류의 단백질이 생산될 수 있습니다.",
#   "is_science": true
# }
#
# Test 50
# Question: [{'role': 'user', 'content': '질산을 통한 염화물 침전시 염소의 비율을 구하는 방법은?'}]
# Answer: {
#   "answer": "질산을 이용한 염화물 침전시 염소의 비율을 구하는 방법은 다음과 같습니다. 먼저, 질산은 Ag+와 Cl- 이온을 반응시켜 AgCl 침전을 형성합니다. 예를 들어, 2.35g의 시료에서 0.435g의 AgCl 침전이 형성되었다면, 염소의 비율을 계산하기 위해 다음 공식을 사용할 수 있습니다.\n염소 비율 = (침전물의 질량 / AgCl의 몰 질량) x Cl의 몰 질량\n= (0.435g / 143.32g/mol) x 35.45g/mol\n= 0.107g\n이제 시료에서 염소의 비율을 계산할 수 있습니다.\n염소 비율 = (0.107g / 2.35g) x 100\n= 4.60%\n따라서 시료의 염소 비율은 4.60%입니다.",
#   "is_science": true
# }
#
# Test 51
# Question: [{'role': 'user', 'content': '이제 그만 얘기해!'}]
# Answer: {
#   "answer": "알겠습니다, 더 필요하신 것이 있으면 언제든지 말씀해주세요.",
#   "is_science": false
# }
#
# Test 52
# Question: [{'role': 'user', 'content': '오늘 너무 즐거웠다!'}]
# Answer: {
#   "is_science": false,
#   "answer": "즐거운 하루였다니 정말 좋네요! 무엇을 하셨나요?"
# }
#
# Test 53
# Question: [{'role': 'user', 'content': '우울한데 신나는 얘기 좀 해줘!'}]
# Answer: {
#   "is_science": false,
#   "answer": "요즘 날씨가 점점 따뜻해지고 있어요. 곧 화창한 봄날이 찾아올 거예요. 봄꽃이 만발하는 공원에서 산책을 하거나 맛있는 아이스크림을 먹으며 기분 전환을 해보는 건 어떨까요? 때로는 작은 변화가 큰 기쁨을 가져다 줄 수 있답니다!"
# }
#
# Test 54
# Question: [{'role': 'user', 'content': '연구자가 갖추어야 할 태도와 자세가 뭘까?'}]
# Answer: {
#   "answer": "연구자가 갖추어야 할 태도와 자세는 호기심, 체계적인 사고, 꼼꼼함, 개방성, 윤리적인 행동, 협력적인 자세 등이 중요합니다. 연구 과정에서 발생할 수 있는 다양한 문제들을 해결하기 위해 이러한 자질들이 필수적입니다.",
#   "is_science": false
# }
#
# Test 55
# Question: [{'role': 'user', 'content': '나이가 들수록 시간이 더 빨리 가는 것 처럼 느끼게 되는 원인은?'}]
# Answer: {
#     "answer": "나이가 들면서 시간이 빨리 가는 것처럼 느껴지는 현상은 여러 심리학적 요인에 의해 설명될 수 있습니다. 첫째, '비례 이론'에 따르면, 나이가 들수록 각 해가 전체 생애에서 차지하는 비율이 줄어들어 상대적으로 시간이 짧게 느껴집니다. 둘째, 새로운 경험의 감소로 인해 시간이 더 빠르게 흐르는 것처럼 느껴질 수 있습니다. 젊었을 때는 새로운 경험과 학습이 많지만, 나이가 들면서 일상이 반복되고 새로운 자극이 줄어들기 때문입니다.",
#     "is_science": true
# }
#
# Test 56
# Question: [{'role': 'user', 'content': '퇴직한 사람들에게 사회 보장은 어떤 의미인가?'}]
# Answer: {
#   "answer": "퇴직한 사람들에게 사회 보장은 경제적 안정과 생활의 질을 유지하는 데 중요한 역할을 합니다. 이는 노후에도 기본적인 생활비를 보장받을 수 있도록 도와주며, 의료비, 주거비 등의 부담을 줄여주는 중요한 수단이 됩니다. 사회 보장은 노인 빈곤을 예방하고, 퇴직 후에도 안정적인 생활을 영위할 수 있도록 지원하는 기능을 합니다.",
#   "is_science": false
# }
#
# Test 57
# Question: [{'role': 'user', 'content': '사람이나 물체가 지구 위에서 땅속으로 꺼지거나 바깥으로 튕겨나가지 않고 가만히 서 있을 수 있잖아?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 이유를 힘의 원리로 설명해줘.'}]
# Answer: {
#   "answer": "사람이나 물체가 지구 위에서 땅속으로 꺼지거나 바깥으로 튕겨나가지 않고 가만히 서 있을 수 있는 이유는 지구의 중력 때문입니다. 지구는 자신의 질량으로 인해 주변의 모든 물체를 자신 쪽으로 끌어당기는 중력을 발생시킵니다. 이 중력이 사람이나 물체를 지구 표면에 붙잡아 두어, 우리가 땅속으로 꺼지거나 우주로 튕겨나가지 않고 안정적으로 서 있을 수 있게 합니다.",
#   "is_science": true
# }
#
# Test 58
# Question: [{'role': 'user', 'content': '씨앗의 기능에 대해 자세히 알려줘?'}]
# Answer: {
#   "answer": "씨앗은 식물의 번식을 위해 필수적인 역할을 합니다. 주요 기능으로는 다음과 같습니다:\n1. 보호: 씨앗의 외부 층은 내부의 배아를 환경적 요인으로부터 보호합니다.\n2. 영양 저장: 씨앗은 발아할 때 필요한 영양분을 저장하고 있어, 식물이 자라기 시작할 때 필요한 초기 에너지를 제공합니다.\n3. 번식: 씨앗은 식물이 새로운 위치에서 자라날 수 있도록 돕습니다. 바람, 물, 동물 등에 의해 새로운 장소로 옮겨질 수 있습니다.\n4. 지연 발아: 씨앗은 적절한 환경 조건이 갖추어질 때까지 발아를 지연시킬 수 있습니다, 이는 생존율을 높이는 데 도움을 줍니다.",
#   "is_science": true
# }
#
# Test 59
# Question: [{'role': 'user', 'content': '친환경 재생 가능 재료가 어떤것들이 있나?'}]
# Answer: {
#   "answer": "친환경 재생 가능 재료로는 태양광 패널, 풍력 터빈, 바이오매스, 재활용 가능한 플라스틱, 유기농 섬유 등이 있습니다. 이러한 재료들은 자원의 지속 가능한 사용을 가능하게 하며 환경 오염을 줄이는 데 기여합니다.",
#   "is_science": true
# }
#
# Test 60
# Question: [{'role': 'user', 'content': '남미의 라틴 역사에 대해 알려줘.'}]
# Answer: {
#   "answer": "남미의 라틴 역사에 대한 질문은 과학 지식과 관련이 없습니다. 역사적인 내용에 대해 더 알고 싶으시다면, 해당 분야의 전문가나 관련 서적을 참고하시는 것이 좋을 것 같습니다.",
#   "is_science": false
# }
#
# Test 61
# Question: [{'role': 'user', 'content': '원자의 내부 구조에 대해 설명해줘.'}]
# Answer: {
#   "answer": "원자는 핵과 전자로 구성되어 있습니다. 핵은 양성자와 중성자로 이루어져 있으며, 전자는 핵 주위를 돌고 있습니다. 양성자는 양의 전하를, 중성자는 전하가 없으며, 전자는 음의 전하를 가집니다. 원자의 화학적 성질은 전자의 배열과 상호작용에 의해 결정됩니다.",
#   "is_science": true
# }
#
# Test 62
# Question: [{'role': 'user', 'content': '난관의 기능에 대해 알려줘.'}]
# Answer: {
#   "answer": "난관은 여성의 생식 기관 중 하나로, 주요 기능은 난소에서 방출된 난자를 받아 자궁으로 이동시키는 역할을 합니다. 또한, 난관은 정자와 난자가 만나 수정이 일어나는 장소이기도 합니다. 이곳에서 수정된 난자는 배아로 발달하여 자궁으로 이동하게 됩니다.",
#   "is_science": true
# }
#
# Test 63
# Question: [{'role': 'user', 'content': '공기의 온도가 기후에 미치는 영향은?'}]
# Answer: {
#   "answer": "공기의 온도는 기후에 큰 영향을 미칩니다. 공기 온도가 변하면 대기 중의 열 전달과 수증기의 양이 변화하여, 이는 구름 형성, 강수량, 바람 패턴 등 다양한 기상 현상에 영향을 줍니다. 따라서, 특정 지역의 기후 변화와 극단적인 날씨 현상의 원인 중 하나로 공기 온도 변화를 들 수 있습니다.",
#   "is_science": true
# }
#
# Test 64
# Question: [{'role': 'user', 'content': '안녕 반갑다'}]
# Answer: {
#   "answer": "안녕하세요! 반갑습니다. 어떤 과학적인 질문이든 도와드릴 준비가 되어 있습니다!",
#   "is_science": false
# }
#
# Test 65
# Question: [{'role': 'user', 'content': '평균을 구하는 코드를 작성중이야.'}, {'role': 'assistant', 'content': '네 무엇을 도와드릴까요?'}, {'role': 'user', 'content': '예외처리가 필요한 경우를 알려줘.'}]
# Answer:
# {
#   "answer": "평균을 구하는 코드에서 예외 처리를 고려해야 할 몇 가지 경우는 다음과 같습니다:\n\n1. 입력 데이터가 비어 있는 경우: 데이터가 없을 때 평균을 계산하려고 하면 오류가 발생할 수 있습니다. 이 경우를 처리하기 위해 입력 데이터가 비어 있으면 예외를 발생시키거나 특정 값을 반환할 수 있습니다.\n\n2. 입력 데이터 타입이 잘못된 경우: 예를 들어 숫자가 아닌 문자열이나 다른 타입의 데이터가 입력으로 주어졌을 때, 이를 처리하기 위한 예외 처리가 필요합니다.\n\n3. 분모가 0이 되는 경우: 모든 입력 값이 0이거나 다른 특정 조건으로 인해 분모가 0이 되는 경우를 처리해야 합니다. 이는 평균을 계산할 때 나눗셈을 포함하기 때문에 중요합니다.\n\n이러한 예외 사항들을 코드에 적절히 처리하면 더 견고하고 오류에 강한 프로그램을 작성할 수 있습니다.",
#   "is_science": false
# }
#
# Test 66
# Question: [{'role': 'user', 'content': '소프트웨어 개발이 사람의 편향없이 이루어질 수 있나?'}]
# Answer: {
#   "answer": "소프트웨어 개발은 사람이 개입하는 과정이기 때문에 완전히 편향 없이 이루어지기는 어렵습니다. 개발자의 경험, 배경, 가치관 등이 소프트웨어의 설계와 구현에 영향을 미칠 수 있습니다. 또한, 사용하는 데이터나 알고리즘 선택에도 편향이 발생할 수 있습니다. 이러한 편향을 최소화하기 위해 다양성을 고려한 팀 구성, 편향을 인식하고 수정하는 과정, 투명한 개발 프로세스 등이 필요합니다.",
#   "is_science": false
# }
#
# Test 67
# Question: [{'role': 'user', 'content': '전체 인구에서 특정 유전자의 비율이 변하지 않고 유지되는 상태를 뭐라고 해?'}]
# Answer: {
#   "answer": "하디-바인베르크 평형",
#   "is_science": true
# }
#
# Test 68
# Question: [{'role': 'user', 'content': '지구가 생겨난지 얼마나 오래 되었는지 확인하는 방법은?'}]
# Answer: {
#   "answer": "지구의 나이를 알아내는 방법 중 하나는 방사성 동위원소 연대 측정입니다. 이 방법은 지구상의 암석이나 광물에 포함된 방사성 동위원소가 시간이 지남에 따라 안정된 동위원소로 붕괴하는 비율을 측정하여 그 연대를 추정합니다. 예를 들어, 우라늄-납 연대 측정 방법은 지구의 나이를 약 45억 년으로 추정하는 데 사용됩니다.",
#   "is_science": true
# }
#
# Test 69
# Question: [{'role': 'user', 'content': '성적인 자극이 발생하는 과정에 대해 알려줘.'}]
# Answer: {
#   "answer": "성적인 자극은 신체적, 심리적 반응을 포함하는 복잡한 과정입니다. 성적 자극이 시작되면, 호르몬과 신경화학물질이 활성화되어 성기의 혈류를 증가시키고 성적 흥분을 유발합니다. 이 과정은 뇌의 여러 부위를 활성화시키며, 이는 성적 만족감과 오르가즘으로 이어질 수 있습니다. 성적 자극은 시각적, 청각적, 촉각적 요소 등 다양한 자극에 의해 발생할 수 있습니다.",
#   "is_science": true
# }
#
# Test 70
# Question: [{'role': 'user', 'content': '전선 주위로 흐르는 자기장의 모습은 어떻게 보이나?'}]
# Answer: {
#   "answer": "전선 주위로 흐르는 자기장은 전선을 중심으로 원형의 고리 모양을 이룹니다. 전류가 흐르는 방향을 따라 오른손 법칙을 적용하면, 엄지손가락이 전류의 방향을 가리키고 나머지 손가락이 구부러지는 방향이 자기장의 방향이 됩니다. 따라서, 전선을 따라 흐르는 전류에 의해 생성된 자기장은 전선을 감싸는 원형의 고리들로 나타납니다.",
#   "is_science": true
# }
#
# Test 71
# Question: [{'role': 'user', 'content': '간헐적으로 높은 강도의 운동을 하면 어떤 효과가 있나요?'}]
# Answer: {
#   "answer": "간헐적으로 높은 강도의 운동, 즉 고강도 인터벌 트레이닝(HIIT)은 여러 건강상의 이점을 제공합니다. 첫째, 이 운동 방식은 심폐 기능을 향상시키고, 둘째, 체지방 감소에 효과적입니다. 셋째, 전반적인 대사율을 증가시켜 더 많은 칼로리를 소모하게 하며, 넷째, 근육량을 유지하면서 체력을 증진시킬 수 있습니다. 또한, HIIT는 시간 효율적인 운동 방법으로 바쁜 일상 속에서도 짧은 시간에 집중적으로 운동할 수 있는 장점이 있습니다.",
#   "is_science": true
# }
#
# Test 72
# Question: [{'role': 'user', 'content': '아세틸 콜린의 역할이 뭐야?'}]
# Answer: {
#   "answer": "아세틸콜린은 신경계에서 중요한 신경전달물질로, 신경과 근육 사이의 신호 전달을 담당하여 근육 수축을 유발하고, 뇌에서는 학습과 기억에 관여합니다.",
#   "is_science": true
# }
#
# Test 73
# Question: [{'role': 'user', 'content': '디엔에이와 단백질의 관계와 역할에 대해 설명해줘.'}]
# Answer: {
#   "answer": "DNA는 유전 정보를 담고 있는 분자로, 생명체의 세포에서 유전자의 역할을 합니다. DNA에서 정보는 RNA로 전사되며, 이 RNA는 다시 단백질로 번역됩니다. 단백질은 생명체의 구조와 기능을 결정하는 주요 요소로, 효소, 호르몬, 면역 분자 등 다양한 형태로 존재합니다. 따라서 DNA는 단백질의 합성을 지시하는 지침서 역할을 하며, 단백질은 이 지침에 따라 생명체의 필수 기능을 수행합니다.",
#   "is_science": true
# }
#
# Test 74
# Question: [{'role': 'user', 'content': '자전축이 기후에 미치는 영향은?'}]
# Answer: {
#   "answer": "지구의 자전축 기울기는 계절 변화와 낮과 밤의 길이에 영향을 미칩니다. 자전축이 태양을 향하면 해당 반구는 여름이 되고, 반대로 태양에서 멀어지면 겨울이 됩니다. 이러한 자전축의 기울기는 지구의 기후 패턴에 중요한 역할을 하며, 특히 극지방에서는 태양 노출의 차이가 더욱 두드러집니다.",
#   "is_science": true
# }
#
# Test 75
# Question: [{'role': 'user', 'content': '여행을 통해 얻을 수 있는 좋은 점들이 뭐가 있어?'}]
# Answer: {
#   "answer": "여행을 통해 새로운 문화와 환경을 경험하고, 다양한 사람들을 만나며 네트워크를 확장할 수 있습니다. 또한, 일상에서 벗어나 휴식을 취하고 스트레스를 해소하는 데 도움이 됩니다. 여행은 새로운 경험을 통해 개인의 시야를 넓히고 창의력을 증진시킬 수 있는 좋은 기회이기도 합니다.",
#   "is_science": false
# }
#
# Test 76
# Question: [{'role': 'user', 'content': '은하들이 점점 멀어지고 있다던데 맞아?'}, {'role': 'assistant', 'content': '네 맞아요.'}, {'role': 'user', 'content': '어떤 물리적인 현상을 보고 그걸 알게 되었어?'}]
# Answer: {
#   "answer": "은하들이 멀어지고 있다는 것은 빅뱅 이론을 통해 알려진 현상입니다. 빅뱅 이론은 우주가 한 점에서 폭발적으로 팽창하기 시작했다고 설명하며, 이로 인해 은하들이 서로 멀어지고 있습니다. 이 현상은 에드윈 허블에 의해 발견된 '허블의 법칙'을 통해 더욱 명확해졌습니다. 허블은 은하들이 멀어질수록 그들이 내는 빛의 파장이 빨강으로 이동하는 '적색 편이' 현상을 관찰하였고, 이는 은하들이 우리로부터 멀어지고 있음을 의미합니다.",
#   "is_science": true
# }
#
# Test 77
# Question: [{'role': 'user', 'content': '목성 trojan의 특징에 대해 알려줘.'}]
# Answer: {
#   "answer": "목성의 트로이 목마(Trojan)는 목성의 궤도에서 앞뒤로 60도 떨어진 라그랑주 점 L4와 L5에 위치한 소행성군을 말합니다. 이들은 목성과 같은 궤도를 공유하면서도 안정적인 위치에 존재합니다. 트로이 목마는 다양한 크기와 조성을 가진 천체들로 구성되어 있으며, 목성의 중력에 의해 안정된 궤도를 유지하고 있습니다. 이 소행성들은 태양계 초기의 잔해로, 초기 태양계의 조건과 진화에 대한 중요한 단서를 제공할 수 있습니다.",
#   "is_science": true
# }
#
# Test 78
# Question: [{'role': 'user', 'content': '슈퍼옥시드 디스무타아제 라는 효소에 대해 설명해줘.'}]
# Answer: {
#   "answer": "슈퍼옥시드 디스무타아제(SOD)는 세포 내에서 발생하는 슈퍼옥시드 라디칼(산소 음이온)을 해독하는 효소입니다. 이 효소는 슈퍼옥시드 라디칼을 덜 반응성이 있는 분자인 과산화수소와 산소로 변환시킵니다. 이 과정은 세포의 산화 스트레스를 줄이고, 세포 손상을 방지하는 데 중요한 역할을 합니다. SOD는 다양한 생물에서 발견되며, 인간을 포함한 많은 생물에서는 여러 형태의 SOD가 존재합니다.",
#   "is_science": true
# }
#
# Test 79
# Question: [{'role': 'user', 'content': '네바다주에 살고 있는데...'}, {'role': 'assistant', 'content': '네 그러시군요?'}, {'role': 'user', 'content': '여기 비가 많이 오지 않는 이유가 뭐야?'}]
# Answer:
# {
#   "answer": "네바다주는 미국에서 가장 건조한 주 중 하나입니다. 이 지역이 비가 많이 오지 않는 주된 이유는 그 위치 때문입니다. 네바다주는 대부분 사막과 반사막 지역으로 이루어져 있으며, 시에라 네바다 산맥이 서쪽에 위치해 있어 대부분의 습기를 차단합니다. 이 산맥은 태평양에서 오는 습한 공기가 넘어오는 것을 막아, 이 공기가 네바다 지역에 도달하기 전에 대부분의 수분을 잃게 만듭니다. 따라서 네바다주는 매우 적은 양의 강수량을 기록하게 됩니다.",
#   "is_science": true
# }
#
# Test 80
# Question: [{'role': 'user', 'content': '어떤 물체를 매우 크게 확대해서 볼수 있는 기계는?'}]
# Answer: {
#   "answer": "전자 현미경이 매우 작은 물체를 크게 확대하여 볼 수 있는 기계입니다.",
#   "is_science": true
# }
#
# Test 81
# Question: [{'role': 'user', 'content': 'merge sort 알고리즘에 대해 설명해줘.'}]
# Answer: {
#     "answer": "Merge sort는 분할 정복 알고리즘의 일종으로, 배열을 반복적으로 반으로 나누어 각 부분을 정렬한 다음, 정렬된 부분 배열들을 다시 합치는 방식으로 작동합니다. 이 과정은 재귀적으로 이루어지며, 최종적으로 정렬된 배열을 얻을 수 있습니다. 효율적인 정렬 방법 중 하나로, 평균 및 최악의 경우 시간 복잡도는 O(n log n)입니다.",
#     "is_science": true
# }
#
# Test 82
# Question: [{'role': 'user', 'content': '심해가 생태계에 미치는 영향은?'}]
# Answer: {
#   "answer": "심해는 생태계에 중요한 영향을 미칩니다. 심해는 다양한 해양 생물들의 서식지로, 특히 많은 종들이 심해의 특수한 환경에 적응하여 살아가고 있습니다. 또한, 심해는 탄소 순환과 같은 지구의 여러 환경적 과정에 기여하며, 심해 생물들은 해양 식물 플랑크톤과 함께 지구의 산소를 생산하는 데 중요한 역할을 합니다. 이러한 심해의 역할은 지구의 생태계 균형 유지에 필수적입니다.",
#   "is_science": true
# }
#
# Test 83
# Question: [{'role': 'user', 'content': '저항이 2배로 증가하면 전력은 어떻게 되나?'}]
# Answer: {
#   "answer": "저항이 2배로 증가하면 전력은 1/4로 감소합니다. 전력은 전압과 전류의 곱으로 계산되며, 저항이 증가하면 전류가 감소하기 때문에 전력도 감소합니다.",
#   "is_science": true
# }
#
# Test 84
# Question: [{'role': 'user', 'content': '산에 불이 나면 동식물이 많이 죽을텐데'}, {'role': 'assistant', 'content': '네 안타까운 일입니다.'}, {'role': 'user', 'content': '불난 후에 자연의 회복 과정은 어떻게 돼?'}]
# Answer: {
#   "answer": "산불 이후 자연의 회복 과정은 여러 단계를 거칩니다. 초기에는 불에 의해 파괴된 지역에서 재생 가능한 식물들이 빠르게 자라기 시작하며, 이는 '재생 단계'라고 불립니다. 이후에는 더 다양한 식물과 동물이 서서히 돌아오면서 생태계가 점차 복원됩니다. 이 과정은 몇 년에서 수십 년까지 걸릴 수 있으며, 토양의 상태, 기후, 지역 생태계의 특성 등에 따라 달라집니다.",
#   "is_science": true
# }
#
# Test 85
# Question: [{'role': 'user', 'content': 'DNA 분해 효소의 역할에 대해 알려줘.'}]
# Answer: {
#   "answer": "DNA 분해 효소는 DNA를 분해하여 뉴클레오타이드 단위로 분해하는 역할을 합니다. 이 과정은 세포의 DNA 복제, 수리, 그리고 유전 정보의 조절에 중요합니다. DNA 분해 효소는 특정 위치에서 DNA를 인식하고 분해하는 기능을 가지며, 이는 세포 내에서 DNA의 정확한 복제와 유지에 필수적입니다.",
#   "is_science": true
# }
#
# Test 86
# Question: [{'role': 'user', 'content': '특정 농도의 황산 sample을 만드는 방법?'}]
# Answer: {
#   "answer": "4.0 M 황산 100 mL를 준비하기 위해서는 먼저 플라스크에 67.7 mL의 물을 넣고, 12.0 M 황산 33.3 mL를 플라스크에 넣은 후 충분히 혼합합니다. 이 방법으로 원하는 4.0 M 황산 용액을 얻을 수 있습니다.",
#   "is_science": true
# }
#
# Test 87
# Question: [{'role': 'user', 'content': '달은 1년 동안 지구를 몇바퀴 도는가?'}]
# Answer: {
#   "answer": "달은 지구를 약 13번 공전합니다.",
#   "is_science": true
# }
#
# Test 88
# Question: [{'role': 'user', 'content': '개인의 생물학적, 사회적인 특성 형성에 영향을 미치는 요소에 대해 설명해줘.'}]
# Answer: {
#   "answer": "개인의 생물학적, 사회적 특성 형성에 영향을 미치는 요소로는 유전적 요인, 환경적 요인, 교육, 문화 등이 있습니다. 유전적 요인은 부모로부터 물려받은 유전자가 개인의 신체적 특성 및 일부 성향을 결정합니다. 환경적 요인은 개인이 성장하고 생활하는 물리적, 사회적 환경을 포함하며, 이는 건강, 행동, 사회적 상호작용에 영향을 줍니다. 교육은 지식 습득 및 사고 방식에 영향을 미치며, 문화는 가치관, 행동 규범 등을 형성하는 데 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 89
# Question: [{'role': 'user', 'content': '너는 누구야?'}]
# Answer: {
#   "answer": "저는 과학 지식에 대해 도움을 드릴 수 있는 AI입니다. 과학과 관련된 질문이 있으시면 언제든지 도와드릴 준비가 되어 있습니다.",
#   "is_science": false
# }
#
# Test 90
# Question: [{'role': 'user', 'content': '지각은 주로 무엇으로 이루어져 있어?'}]
# Answer: {
#   "answer": "지각은 주로 규산염 광물로 이루어져 있으며, 이 중에서도 특히 석영, 장석, 운모 등이 흔하게 포함되어 있습니다.",
#   "is_science": true
# }
#
# Test 91
# Question: [{'role': 'user', 'content': '오세아니아 섬나라에 광견병이 있어?'}]
# Answer: {
#   "answer": "오세아니아의 많은 섬나라들은 광견병이 없는 지역으로 알려져 있습니다. 이 지역들은 광견병 예방 및 관리 정책을 철저히 시행하고 있으며, 동물의 검역 절차가 엄격하여 광견병의 유입을 막고 있습니다.",
#   "is_science": true
# }
#
# Test 92
# Question: [{'role': 'user', 'content': '추울때 폭이 넓은 회색의 구름이 끼면 어떤 날씨가 예상되나?'}]
# Answer: {
#   "answer": "추운 날씨에 폭이 넓은 회색 구름이 끼면, 대체로 눈이나 비와 같은 강수 현상이 예상됩니다. 이런 구름은 보통 낮은 온도에서 수증기가 응결되어 형성되며, 구름의 두께가 두꺼워지면 강수로 이어질 가능성이 높습니다.",
#   "is_science": true
# }
#
# Test 93
# Question: [{'role': 'user', 'content': '안정성이 높은 PRP를 만드는 방법에 대해 알려줘.'}]
# Answer: {
#   "answer": "안정성이 높은 PRP를 만드는 방법은 GGM PRF를 Luby-Rackoff 구조에 연결하는 것입니다. GGM PRF는 안전한 의사난수를 생성하고, Luby-Rackoff 구조는 Feistel 구조를 사용하여 안전한 블록 암호를 구성합니다. 이 방법을 통해 안전한 PRP를 구축할 수 있습니다.",
#   "is_science": true
# }
#
# Test 94
# Question: [{'role': 'user', 'content': '너 모르는 것도 있니?'}]
# Answer:
# {
#   "answer": "저는 계속해서 배우고 업데이트되는 인공지능이지만, 모든 것을 알지는 못합니다. 특히 과학 지식 외의 다양한 주제에 대해서는 제한적인 정보를 가지고 있을 수 있습니다.",
#   "is_science": false
# }
#
# Test 95
# Question: [{'role': 'user', 'content': '중성자의 특징에 대해 설명해줘.'}]
# Answer: {
#   "answer": "중성자는 원자핵에 존재하는 입자로, 양성자와 함께 원자의 질량 대부분을 차지합니다. 중성자는 전하가 없으며, 이로 인해 전기적으로 중성입니다. 중성자는 원자핵 안에서 양성자와 강한 상호작용을 하며, 원자핵의 안정성을 유지하는 데 중요한 역할을 합니다. 또한, 중성자는 핵반응과 핵분열 과정에서 중요한 역할을 하며, 이를 통해 에너지를 생산하거나 다른 원소로 변환될 수 있습니다.",
#   "is_science": true
# }
#
# Test 96
# Question: [{'role': 'user', 'content': '플랑크톤의 역할에 대해 알려줘.'}]
# Answer: {
#   "answer": "플랑크톤은 바다의 미세한 생물로, 주로 광합성을 통해 에너지를 생산하며, 이 과정에서 대기 중의 이산화탄소를 흡수하고 산소를 방출합니다. 이들은 해양 식물플랑크톤과 동물플랑크톤으로 나뉘며, 해양 생태계의 기초 식량원으로서 다양한 해양 동물들의 먹이가 됩니다. 또한, 플랑크톤은 탄소 순환에 중요한 역할을 하여 지구 기후 조절에도 기여합니다.",
#   "is_science": true
# }
#
# Test 97
# Question: [{'role': 'user', 'content': '기생과 공생의 차이에 대해 알려줘.'}]
# Answer: {
#   "answer": "기생은 한 생물이 다른 생물에게 피해를 주면서 이득을 보는 관계이고, 공생은 두 생물이 서로 협력하여 이득을 보는 관계입니다. 기생에서는 한 쪽만 혜택을 받지만, 공생에서는 양쪽 모두 혜택을 받습니다.",
#   "is_science": true
# }
#
# Test 98
# Question: [{'role': 'user', 'content': '강아지가 사회화되는 행동의 사례는 뭐가 있을까?'}]
# Answer:
# {
#   "answer": "강아지의 사회화는 다양한 환경, 사람, 동물과의 긍정적인 경험을 통해 이루어집니다. 예를 들어, 강아지가 다양한 연령대와 성별의 사람들을 만나게 하거나, 다른 강아지나 동물들과의 놀이 시간을 갖게 하는 것이 포함됩니다. 또한, 다양한 소리와 환경에 노출시켜 새로운 상황에 대한 두려움을 줄이는 것도 중요합니다.",
#   "is_science": false
# }
#
# Test 99
# Question: [{'role': 'user', 'content': '너 잘하는게 뭐야?'}]
# Answer: {
#   "is_science": false,
#   "answer": "저는 과학 지식에 관한 질문에 답변하는 것을 잘합니다. 생물학, 물리학, 화학, 의학 등 다양한 과학 분야에 대해 정보를 제공할 수 있어요. 다른 주제에 대해서도 도움을 드릴 수 있으니 언제든지 질문해주세요!"
# }
#
# Test 100
# Question: [{'role': 'user', 'content': '지구에서 새로운 땅이 생겨나는 메커니즘은?'}]
# Answer: {
#   "answer": "지구에서 새로운 땅이 생겨나는 주요 메커니즘은 판구조론에 의해 설명됩니다. 지구의 리소스피어는 여러 개의 판으로 나뉘어져 있으며, 이 판들이 움직이면서 상호작용합니다. 판들이 서로 멀어지는 곳에서는 맨틀에서 물질이 상승하여 새로운 지각을 형성하고, 이 과정을 해령 확장이라고 합니다. 또한, 판이 다른 판 아래로 들어가면서 발생하는 화산 활동을 통해서도 새로운 땅이 생성될 수 있습니다. 이러한 판의 움직임과 상호작용은 지구의 지형을 형성하고 변화시키는 주된 원인입니다.",
#   "is_science": true
# }
#
# Test 101
# Question: [{'role': 'user', 'content': '더러워진 엔진오일을 잘 처리하는 방법에 대해 알려줘.'}]
# Answer: {
#   "answer": "사용한 엔진오일은 환경에 해로울 수 있으므로 적절한 처리가 필요합니다. 사용한 엔진오일은 지정된 수거 장소나 재활용 센터에 가져가서 처리해야 합니다. 많은 지역에서는 자동차 정비소나 특정 소매점에서도 사용한 엔진오일을 수거해 줍니다. 절대로 엔진오일을 일반 쓰레기에 버리거나 배수구나 토양에 버리지 마세요.",
#   "is_science": true
# }
#
# Test 102
# Question: [{'role': 'user', 'content': '너 정말 똑똑하다!'}]
# Answer: {
#   "answer": "감사합니다! 무엇을 도와드릴까요?",
#   "is_science": false
# }
#
# Test 103
# Question: [{'role': 'user', 'content': '다람쥐가 열매를 땅에 묻는 행동이 나무에 미치는 영향은?'}]
# Answer: {
#   "answer": "다람쥐가 열매를 땅에 묻는 행동은 나무의 번식에 도움을 줍니다. 다람쥐가 먹이를 저장하기 위해 열매를 땅에 묻지만, 모든 열매를 찾아 먹지 못하는 경우가 많습니다. 이 묻힌 열매들이 발아하여 새로운 나무로 자라날 수 있습니다. 이 과정을 통해 다람쥐는 실질적으로 숲의 재생과 확장에 기여하게 됩니다.",
#   "is_science": true
# }
#
# Test 104
# Question: [{'role': 'user', 'content': '새로운 생명체의 발생에 대한 오래된 믿음을 깨기 위해 어떤 방법이 사용되었나?'}]
# Answer: {
#   "answer": "과학자들은 실험을 통해 생명체가 살아있지 않은 물질에서 발생할 수 있다는 오래된 믿음을 깨뜨렸습니다. 특히, 프란체스코 레디와 루이 파스퇴르의 실험은 자연발생설을 반박하는 결정적인 증거를 제공했습니다. 레디는 고기와 파리의 관계를 실험하여 생명체가 기존 생명체에서만 발생한다는 것을 보여주었고, 파스퇴르는 멸균된 육수에서는 미생물이 자라지 않는다는 것을 증명함으로써 자연발생설을 무너뜨렸습니다.",
#   "is_science": true
# }
#
# Test 105
# Question: [{'role': 'user', 'content': '협곡이 형성되는 과정은?'}]
# Answer: {
#   "answer": "협곡은 주로 강이나 물줄기가 지질학적 시간 동안 지표를 침식하여 깊고 좁은 계곡을 형성하는 과정을 통해 만들어집니다. 물이 흐르면서 바위와 토양을 점차적으로 침식시키고, 이러한 침식 작용이 수천 또는 수백만 년에 걸쳐 지속되면서 협곡이 점점 더 깊어지고 형성됩니다.",
#   "is_science": true
# }
#
# Test 106
# Question: [{'role': 'user', 'content': 'python 공부중인데...'}, {'role': 'assistant', 'content': '네 꼭 필요한 언어라서 공부해 두면 좋습니다.'}, {'role': 'user', 'content': '숫자 계산을 위한 operator 우선순위에 대해 알려줘.'}]
# Answer:
# {
#   "is_science": true,
#   "answer": "Python에서 숫자 계산을 위한 연산자 우선순위는 다음과 같습니다:\n\n1. 괄호 안의 표현식\n2. 지수 (**)\n3. 부호 연산자 (+, -) (단항 연산자)\n4. 곱셈 (*), 나눗셈 (/), 나머지 (%), 몫 (//)\n5. 덧셈 (+), 뺄셈 (-)\n\n이 우선순위에 따라 Python은 수식을 계산합니다. 예를 들어, `3 + 5 * 2`는 5와 2를 먼저 곱한 후에 3을 더하여 결과는 13이 됩니다."
# }
#
# Test 107
# Question: [{'role': 'user', 'content': '지구상에 존재하는 물 중 가장 많은 물은 바닷물이잖아?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '바닷물 말고 담수가 가장 많이 있는 곳이 어디야?'}]
# Answer: {
#   "answer": "담수가 가장 많이 있는 곳은 남극과 그린란드의 빙하 및 얼음층입니다. 이곳에는 지구상의 담수의 대부분이 얼음 형태로 존재합니다.",
#   "is_science": true
# }
#
# Test 108
# Question: [{'role': 'user', 'content': '폭풍을 쫓는 사람들이 누구야?'}]
# Answer:
# {
#   "answer": "폭풍을 쫓는 사람들은 '스톰 체이서(Storm Chaser)'라고 불립니다. 이들은 기상학자, 연구원, 사진작가, 모험가 등 다양한 배경을 가진 사람들로 구성되어 있으며, 폭풍, 토네이도, 허리케인과 같은 극심한 기상 현상을 직접 추적하고 관찰하여 데이터를 수집하고 연구하는 일을 합니다. 이들의 활동은 기상학의 발전에 중요한 기여를 하며, 때로는 위험한 상황에도 직면하게 됩니다.",
#   "is_science": true
# }
#
# Test 109
# Question: [{'role': 'user', 'content': '우라늄을 사용한 원자력 발전의 단점에 대해 알려줘.'}]
# Answer: {
#   "answer": "우라늄을 사용한 원자력 발전의 단점은 다음과 같습니다:\n1. 고준위 방사성 폐기물 생성: 사용 후 남은 우라늄 연료는 매우 오랜 시간 동안 방사능을 유지하며, 이 폐기물의 안전한 처리와 저장이 필요합니다.\n2. 핵 사고 위험: 원자로의 사고는 치명적인 방사능 유출을 일으킬 수 있으며, 체르노빌이나 후쿠시마 사고와 같은 재난을 초래할 수 있습니다.\n3. 자원의 한정성: 우라늄은 비재생 자원이므로, 채굴 가능한 우라늄의 양이 한정되어 있습니다.\n4. 테러 위험: 원자력 시설이 테러의 대상이 될 수 있으며, 이는 국가 안보에 심각한 위협이 될 수 있습니다.",
#   "is_science": true
# }
#
# Test 110
# Question: [{'role': 'user', 'content': '고체에서 액체로 변할 때 엔트로피는 어떻게 되나?'}]
# Answer: {
#   "answer": "고체에서 액체로 변할 때, 엔트로피는 증가합니다. 이는 고체에서 액체로의 상태 변화가 일어날 때 분자들의 무질서도가 증가하기 때문입니다.",
#   "is_science": true
# }
#
# Test 111
# Question: [{'role': 'user', 'content': '사회로부터의 감정적인 지원이 어떤 형태로 나타날 수 있어?'}]
# Answer: {
#   "answer": "사회로부터의 감정적인 지원은 여러 형태로 나타날 수 있습니다. 예를 들어, 가족이나 친구들로부터의 격려와 위로, 전문 상담가나 심리치료사로부터의 전문적인 도움, 지역사회나 온라인 커뮤니티에서의 지지와 공감 등이 있습니다. 또한, 직장이나 학교에서의 동료들의 이해와 지원도 중요한 역할을 할 수 있습니다.",
#   "is_science": false
# }
#
# Test 112
# Question: [{'role': 'user', 'content': '석탄을 에너지원으로 사용할 때의 장단점이 뭐야?'}]
# Answer: {
#   "answer": "석탄을 에너지원으로 사용할 때의 장점은 풍부한 매장량과 저렴한 비용입니다. 하지만 단점으로는 화석 연료를 연소할 때 발생하는 대기 오염과 온실가스 배출이 있어 환경에 부정적인 영향을 미칩니다.",
#   "is_science": true
# }
#
# Test 113
# Question: [{'role': 'user', 'content': '탄소의 내부 구조를 알아낼 수 있는 방법은?'}]
# Answer: {
#   "answer": "탄소의 내부 구조를 알아내는 방법으로는 X-선 결정학, 전자 현미경, 스펙트로스코피 등이 있습니다. 이 방법들은 탄소 원자의 배열과 결합 상태를 분석하여 탄소의 다양한 형태(예: 다이아몬드, 그래핀, 풀러렌 등)의 내부 구조를 밝힐 수 있습니다.",
#   "is_science": true
# }
#
# Test 114
# Question: [{'role': 'user', 'content': '연구의 과정과 결과를 잘 기록해야 하는 이유?'}]
# Answer: {
#   "answer": "연구 과정과 결과를 잘 기록하는 것은 여러 가지 중요한 이유가 있습니다. 첫째, 정확한 기록은 연구의 재현성을 보장합니다. 이는 다른 연구자들이 같은 실험을 반복하여 비슷한 결과를 얻을 수 있도록 돕습니다. 둘째, 연구 기록은 연구 과정에서 발생할 수 있는 오류를 추적하고 수정하는 데 도움을 줍니다. 셋째, 잘 정리된 기록은 연구 결과의 신빙성을 높이고, 학술적 논문이나 보고서 작성 시 근거 자료로 활용될 수 있습니다. 마지막으로, 효과적인 기록은 지적 재산권을 보호하는 데 중요한 역할을 하며, 특허 출원 등 법적 문제에 있어서도 중요한 증거 자료가 될 수 있습니다.",
#   "is_science": true
# }
#
# Test 115
# Question: [{'role': 'user', 'content': '니가 대답을 잘해줘서 기분이 좋아!'}]
# Answer: {
#   "answer": "감사합니다! 기분 좋은 말씀을 해주셔서 저도 기쁩니다. 또 다른 질문이 있으시면 언제든지 도와드릴게요.",
#   "is_science": false
# }
#
# Test 116
# Question: [{'role': 'user', 'content': '밀물과 썰물의 강도에 영향을 주는 요소들에 대해 알려줘.'}]
# Answer: {
#   "answer": "밀물과 썰물의 강도에 영향을 주는 주요 요소는 달과 태양의 위치, 지구와의 거리, 지구의 자전, 해양의 깊이와 지형입니다. 달과 태양의 중력이 지구의 물을 끌어당겨 조석을 일으키며, 이들 천체의 상대적 위치에 따라 조석의 강도가 달라집니다. 또한, 해안선의 형태와 해저 지형도 조석의 높이와 강도에 영향을 미칩니다.",
#   "is_science": true
# }
#
# Test 117
# Question: [{'role': 'user', 'content': '우울한데 신나는 얘기 좀 해줄래?'}]
# Answer: {
#   "answer": "요즘 과학계에서는 매일 새로운 발견과 발전이 이루어지고 있어요. 예를 들어, 최근에는 인공지능이 의료 분야에서 환자의 진단을 돕고, 더 정확한 치료 방법을 제시하는 데 큰 도움을 주고 있다고 해요. 이런 기술의 발전이 우리의 삶을 더욱 편리하고 건강하게 만들어 줄 거라는 생각에 신나지 않나요?",
#   "is_science": false
# }
#
# Test 118
# Question: [{'role': 'user', 'content': '이제 그만 얘기하자.'}]
# Answer: {
#   "is_science": false,
#   "answer": "알겠습니다. 다른 도움이 필요하시면 언제든지 말씀해주세요."
# }
#
# Test 119
# Question: [{'role': 'user', 'content': '유전 교차에서 복잡형질과 관련된 염색체 영역 식별 방법은?'}]
# Answer: {
#   "answer": "유전 교차에서 복잡형질과 관련된 염색체 영역을 식별하는 방법에 대한 구체적인 정보는 제공된 자료에서 찾을 수 없습니다. 유전학적 연구에서는 일반적으로 유전자 지도 작성, 연관성 분석, 유전자 염기서열 분석 등의 방법을 사용하여 염색체의 특정 영역을 식별할 수 있습니다.",
#   "is_science": true
# }
#
# Test 120
# Question: [{'role': 'user', 'content': '척추 동물이 영역을 가지고 다투는 이유는?'}]
# Answer: {
#   "answer": "척추 동물들이 영역을 가지고 다투는 주된 이유는 생존과 번식을 위한 자원 확보입니다. 이들은 안전한 서식지와 충분한 식량을 확보하기 위해 영역을 설정하고, 이 영역을 다른 개체나 종과 경쟁하며 방어합니다. 영역 내에서는 식량, 물, 쉴 곳 등 생존에 필수적인 자원을 독점적으로 사용할 수 있으며, 번식 기간에는 안정적인 환경에서 후손을 기를 수 있습니다.",
#   "is_science": true
# }
#
# Test 121
# Question: [{'role': 'user', 'content': '어린 새들이 생존에서 살아남기 위해 진화한 기능들이 뭐가 있어?'}]
# Answer: {
#   "answer": "새들은 생존과 번식을 위해 다양한 진화적 특성을 발달시켰습니다. 예를 들어, 새들은 빠른 비행 능력, 효율적인 에너지 사용을 위한 경량의 뼈 구조, 다양한 크기와 형태의 부리를 갖추고 있습니다. 이러한 부리는 각기 다른 환경에서 다양한 종류의 먹이를 섭취할 수 있게 해줍니다. 또한, 색깔과 깃털의 패턴은 위장이나 짝짓기 시 상대를 유혹하는 데 도움을 줍니다. 이외에도 날카로운 발톱과 뛰어난 시각 등이 새들의 생존에 기여하는 진화적 특성입니다.",
#   "is_science": true
# }
#
# Test 122
# Question: [{'role': 'user', 'content': '입자가 같은 속력으로 원운동을 할 때 속도와 가속도 벡터 사이의 각도는 얼마인가?'}]
# Answer: {
#   "answer": "입자가 같은 속력으로 원운동을 할 때, 속도 벡터는 원의 접선 방향을 가리키고, 가속도 벡터는 원의 중심을 향하는 방향을 가리키므로, 이 두 벡터 사이의 각도는 90도입니다.",
#   "is_science": true
# }
#
# Test 123
# Question: [{'role': 'user', 'content': '곤충 눈의 구조에 대해 설명해줘.'}]
# Answer: {
#   "answer": "곤충의 눈은 주로 복합 눈과 단순 눈으로 구성되어 있습니다. 복합 눈은 수많은 작은 눈(오마티디움)이 모여 있는 구조로, 각각의 작은 눈이 하나의 픽셀처럼 작동하여 넓은 시야를 제공하지만, 상대적으로 해상도는 낮습니다. 이를 통해 곤충은 빠르게 움직이는 물체를 잘 감지할 수 있습니다. 반면, 단순 눈은 보통 크기가 더 크고, 하나 또는 소수의 렌즈를 가지고 있어 더 세밀한 이미지를 포착할 수 있으나 시야는 좁습니다.",
#   "is_science": true
# }
#
# Test 124
# Question: [{'role': 'user', 'content': '너는 누구니?'}]
# Answer: {
#   "answer": "저는 과학 지식에 대해 도움을 드릴 수 있는 AI입니다. 과학과 관련된 질문이 있으시면 언제든지 도와드릴 준비가 되어 있습니다!",
#   "is_science": false
# }
#
# Test 125
# Question: [{'role': 'user', 'content': '물고기는 어떻게 숨을 쉬는가?'}]
# Answer: {
#   "answer": "물고기는 아가미를 통해 숨을 쉽니다. 물 속에 녹아 있는 산소를 아가미의 얇은 막을 통해 흡수하고, 이산화탄소를 배출하는 과정을 통해 호흡합니다.",
#   "is_science": true
# }
#
# Test 126
# Question: [{'role': 'user', 'content': '하천을 모델링하고 싶어.'}, {'role': 'assistant', 'content': '네 무엇을 도와 드릴까요?'}, {'role': 'user', 'content': '모델링할 때 신경써야 할 사항들이 뭐가 있어?'}]
# Answer: {
#   "answer": "하천 모델링을 할 때 고려해야 할 주요 사항은 다음과 같습니다: 1. 하천의 지형과 경사도, 이는 물의 흐름과 속도에 영향을 미칩니다. 2. 유량과 유속, 즉 하천을 통과하는 물의 양과 속도입니다. 3. 하천의 폭과 깊이, 이는 하천의 수용 능력과 퇴적물 이동에 영향을 줍니다. 4. 주변 지역의 토지 사용과 개발 상황, 이는 하천으로의 유입물과 오염원에 영향을 줄 수 있습니다. 5. 기후 변화와 강수량 패턴, 이는 하천의 유량과 수위 변화에 중요한 요소입니다. 이러한 요소들을 종합적으로 고려하여 하천 모델을 구축해야 합니다.",
#   "is_science": true
# }
#
# Test 127
# Question: [{'role': 'user', 'content': '체질량 지수의 한계에 대해 알려줘.'}]
# Answer: {
#   "answer": "체질량 지수(BMI)는 체중을 키의 제곱으로 나눈 값으로, 체지방의 양을 간접적으로 추정하는 지표입니다. 그러나 BMI는 근육량이 많은 사람이나 특정 인종, 연령대에서는 체지방을 과대평가하거나 과소평가할 수 있는 한계가 있습니다. 또한, BMI는 체지방의 분포나 체형을 고려하지 않기 때문에 건강 상태를 평가하는 데 있어서 제한적일 수 있습니다.",
#   "is_science": true
# }
#
# Test 128
# Question: [{'role': 'user', 'content': '행성의 내부 구조를 이해하기 위한 방법은?'}]
# Answer: {
#   "answer": "행성의 내부 구조를 이해하기 위한 방법으로는 지진파 분석, 중력장 측정, 자기장 분석 등이 있습니다. 지진파는 행성 내부를 통과하면서 다양한 속도로 진행되며, 이를 통해 내부 구조에 대한 정보를 얻을 수 있습니다. 중력장 측정은 행성의 질량 분포를 파악하여 내부 구조를 추론할 수 있게 해줍니다. 또한, 자기장 분석을 통해 행성의 내부에서 발생하는 전기적 활동과 금속성 코어의 존재 여부를 파악할 수 있습니다.",
#   "is_science": true
# }
#
# Test 129
# Question: [{'role': 'user', 'content': '식물의 잎이 다수 떨어지거나 구멍이 생기는 현상을 어떻게 해석해야 해?'}]
# Answer: {
#   "answer": "식물의 잎이 많이 떨어지거나 구멍이 생기는 현상은 여러 원인에 의해 발생할 수 있습니다. 잎이 떨어지는 것은 식물이 스트레스를 받고 있을 때 나타날 수 있는 자연스러운 방어 메커니즘일 수 있습니다. 예를 들어, 물 부족, 영양소 부족, 해충의 공격, 질병 등이 원인일 수 있습니다. 구멍이 생기는 현상은 주로 해충에 의한 피해일 가능성이 높습니다. 정확한 원인을 파악하기 위해서는 식물의 전반적인 상태를 관찰하고 필요한 경우 전문가의 도움을 받는 것이 좋습니다.",
#   "is_science": true
# }
#
# Test 130
# Question: [{'role': 'user', 'content': '일식이 발생하는 원리는?'}]
# Answer: {
#   "answer": "일식은 태양, 달, 지구가 일직선으로 정렬될 때 발생합니다. 이때 달이 태양과 지구 사이에 위치하여 태양의 빛을 가려 지구에 도달하는 빛이 차단되면서 발생하는 현상입니다. 이로 인해 지구의 일부 지역에서는 태양이 완전히 또는 부분적으로 가려지는 것을 관찰할 수 있습니다.",
#   "is_science": true
# }
#
# Test 131
# Question: [{'role': 'user', 'content': '광합성이 무엇인지 그리고 효과에 대해 알려줘.'}]
# Answer: {
#   "answer": "광합성은 식물이 탄소를 고정하여 유기물을 생산하는 과정입니다. 이 과정은 빛, 이산화탄소(CO2), 그리고 물이 필요합니다. 빛은 광합성에서 에너지원으로 작용하며, 이산화탄소는 광합성에서 탄소원으로 사용됩니다. 물은 광합성에서 전자와 수소원으로 작용하여 유기물 합성에 필요한 에너지를 제공합니다. 따라서, 광합성은 빛, CO2, 그리고 물이 함께 작용하여 일어나는 중요한 생물학적 과정입니다.",
#   "is_science": true
# }
#
# Test 132
# Question: [{'role': 'user', 'content': '리보오솜의 역할이 뭐야?'}]
# Answer: {
#   "answer": "리보솜은 세포 내에서 단백질을 합성하는 역할을 합니다. mRNA로부터 전달받은 유전 정보를 해독하여 아미노산을 연결함으로써 특정 단백질을 생성합니다.",
#   "is_science": true
# }
#
# Test 133
# Question: [{'role': 'user', 'content': '오늘 너무 즐거웠어!'}]
# Answer: {
#   "answer": "즐거운 하루였다니 정말 좋네요! 무엇을 하셨나요?",
#   "is_science": false
# }
#
# Test 134
# Question: [{'role': 'user', 'content': '바람이 부는 이유는?'}]
# Answer:
# {
#   "answer": "바람은 대기 중에서 공기의 이동으로 발생합니다. 이는 주로 지구 표면의 온도와 압력 차이 때문에 생기는데, 높은 압력 지역에서 낮은 압력 지역으로 공기가 이동하면서 바람이 불게 됩니다.",
#   "is_science": true
# }
#
# Test 135
# Question: [{'role': 'user', 'content': '메릴랜드의 대표적인 천연 자원은?'}]
# Answer: {
#   "answer": "메릴랜드의 대표적인 천연 자원으로는 석탄과 나무가 있습니다. 이들 자원은 주로 열 생산에 사용됩니다.",
#   "is_science": true
# }
#
# Test 136
# Question: [{'role': 'user', 'content': '디엔에이 리가아제의 주요 기능이 뭐야?'}]
# Answer: {
#   "answer": "DNA 리가아제는 DNA 복제 과정에서 단절된 DNA 가닥을 연결하여 연속적인 DNA 이중나선을 형성하는 역할을 합니다. 이는 DNA의 안정성과 유전 정보의 정확한 전달을 보장하는 데 중요합니다.",
#   "is_science": true
# }
#
# Test 137
# Question: [{'role': 'user', 'content': '신체 변화의 정도나 속도가 사람들마다 다른 점으로부터 고려 할 수 있는 사항은?'}]
# Answer: {
#   "answer": "신체 변화의 정도나 속도가 개인마다 다른 이유는 유전적 요인, 환경적 요인, 생활 습관 등 다양한 요소에 의해 영향을 받기 때문입니다. 이러한 차이를 고려할 때, 개인의 건강 상태, 운동 능력, 영양 상태 등을 개별적으로 평가하고, 개인에 맞는 맞춤형 건강 관리 계획을 수립하는 것이 중요합니다.",
#   "is_science": true
# }
#
# Test 138
# Question: [{'role': 'user', 'content': '머클-담고르 해시 함수를 사용한 MAC 보안 취약점은?'}]
# Answer: {
#   "answer": "제공된 정보로는 머클-담고르 해시 함수를 사용한 MAC의 보안 취약점에 대해 설명할 충분한 정보가 없습니다.",
#   "is_science": true
# }
#
# Test 139
# Question: [{'role': 'user', 'content': '초코렛이 녹는 물리적인 원리는?'}]
# Answer: {
#   "answer": "초콜릿이 녹는 원리는 열에 의한 물리적 변화입니다. 초콜릿은 주로 코코아 버터를 포함하고 있는데, 이 코코아 버터가 특정 온도(약 30°C~34°C)에 도달하면 고체에서 액체로 상태가 변합니다. 이 과정에서 초콜릿의 결정 구조가 녹으면서 부드러운 액체 상태로 변화하는 것입니다.",
#   "is_science": true
# }
#
# Test 140
# Question: [{'role': 'user', 'content': '배터리가 완구를 움직이게 하는 원리는?'}]
# Answer: {
#   "answer": "배터리는 화학적 에너지를 전기 에너지로 변환하여 완구에 전력을 공급합니다. 이 전기 에너지가 모터를 구동시켜 완구가 움직이게 됩니다.",
#   "is_science": true
# }
#
# Test 141
# Question: [{'role': 'user', 'content': '궤양성 대장염이 있는 사람들이 조심해야 할 사항들은 뭐가 있어?'}]
# Answer: {
#   "answer": "궤양성 대장염을 가진 사람들은 특히 식습관과 생활습관을 주의해야 합니다. 특히, 고지방, 고섬유질, 매운 음식, 카페인이 많은 음료는 증상을 악화시킬 수 있으므로 피하는 것이 좋습니다. 또한, 금연과 적절한 수분 섭취가 중요하며, 스트레스 관리도 궤양성 대장염 관리에 중요한 부분입니다. 정기적인 의료 검진을 통해 상태를 모니터링하고 필요한 치료를 받는 것도 중요합니다.",
#   "is_science": true
# }
#
# Test 142
# Question: [{'role': 'user', 'content': '음파의 주파수와 속도의 관계가 어떻게 돼?'}]
# Answer: {
#   "answer": "음파의 속도는 주파수와 파장의 곱으로 결정됩니다. 주파수가 높아질수록 파장은 짧아지며, 속도는 매질에 따라 일정하게 유지됩니다. 따라서, 주파수가 변해도 음파의 속도는 그 매질에서는 변하지 않습니다.",
#   "is_science": true
# }
#
# Test 143
# Question: [{'role': 'user', 'content': '목성 내부에서 온도가 높아지는 원리가 뭐야?'}]
# Answer: {
#   "answer": "목성 내부의 온도가 높아지는 원리는 주로 그 크기와 질량 때문입니다. 목성은 태양계에서 가장 큰 행성으로, 그 질량은 막대한 중력을 생성하여 행성 내부의 압력을 극도로 높입니다. 이 고압은 내부의 가스와 액체를 압축시켜 열을 발생시키고, 이로 인해 내부 온도가 상승합니다. 또한, 목성은 형성 초기에 축적된 원시 열을 여전히 가지고 있으며, 방사성 붕괴로 인한 열도 내부 온도를 높이는 데 기여합니다.",
#   "is_science": true
# }
#
# Test 144
# Question: [{'role': 'user', 'content': '결혼 전에 성관계를 가지는 것이 괜찮다고 생각하는 사람들의 주된 특징은?'}]
# Answer: {
#   "answer": "결혼 전 성관계에 대한 태도는 개인의 문화적, 종교적, 개인적 가치관 및 교육 수준 등 다양한 요인에 의해 영향을 받을 수 있습니다. 이러한 태도는 사회적 환경과 개인의 성장 배경에 따라 크게 다를 수 있습니다.",
#   "is_science": false
# }
#
# Test 145
# Question: [{'role': 'user', 'content': '나이와 코호트 차이를 다 고려하는 디자인 방식은?'}]
# Answer:
# {
#   "answer": "나이와 코호트 차이를 고려하는 디자인 방식에 대한 질문은 과학 지식과 직접적인 관련이 없습니다. 이는 주로 사회학적 또는 인구학적 연구 설계에 관련된 주제입니다. 연구 설계에서 다양한 연령대와 세대를 고려하는 것은 중요할 수 있으며, 이를 통해 더 광범위하고 정확한 데이터를 수집할 수 있습니다.",
#   "is_science": false
# }
#
# Test 146
# Question: [{'role': 'user', 'content': '건강한 입을 가지고 있는지 판단할 수 있는 방법에 대해 알려줘.'}]
# Answer: {
#   "answer": "건강한 입을 가지고 있는지 판단하는 방법은 다음과 같습니다:\n1. 정기적인 치과 검진을 받아 치아와 잇몸의 상태를 확인합니다.\n2. 치아가 깨끗하고 밝은 색을 유지하는지, 치석이 적게 쌓이는지 확인합니다.\n3. 잇몸이 붉지 않고 부어 있지 않으며, 출혈이 없어야 합니다.\n4. 입 냄새가 심하지 않아야 하며, 입안이 건조하지 않아야 합니다.\n5. 정기적으로 칫솔질과 치실 사용으로 구강 위생을 관리합니다.\n이러한 조건들을 충족시키면 건강한 입 상태를 유지하고 있다고 볼 수 있습니다.",
#   "is_science": true
# }
#
# Test 147
# Question: [{'role': 'user', 'content': '성대 주름이 긴장했는지 어떻게 알 수 있나?'}]
# Answer: {
#   "answer": "성대 주름이 긴장되었는지 알 수 있는 명확한 방법은 직접적인 의학적 검사를 통해서입니다. 예를 들어, 음성 장애를 전문으로 하는 의사가 성대의 움직임을 검사할 수 있습니다. 성대가 긴장되었을 때의 증상으로는 목소리의 변화, 발성 시 불편함, 목의 긴장감 등이 있을 수 있습니다. 하지만 정확한 진단은 전문가의 검사를 통해 이루어져야 합니다.",
#   "is_science": true
# }
#
# Test 148
# Question: [{'role': 'user', 'content': '안녕 반가워'}]
# Answer: {
#   "answer": "안녕하세요! 반갑습니다. 어떤 과학적인 질문이든 도와드릴 준비가 되어 있어요.",
#   "is_science": false
# }
#
# Test 149
# Question: [{'role': 'user', 'content': 'B-형 간염에 대해 알려줘.'}]
# Answer: {
#   "answer": "B형 간염은 간에 영향을 주는 바이러스로 인해 발생하는 감염병입니다. 이 바이러스는 감염된 사람의 혈액, 체액, 성기 등을 통해 전파될 수 있습니다. B형 간염은 만성 간염, 간경변증, 간암 등 심각한 합병증을 일으킬 수 있으므로 예방과 조기진단이 중요합니다. 예방을 위해 B형 간염 예방접종을 받는 것이 좋으며, 감염 위험이 있는 사람들은 정기적인 검진을 받아야 합니다. 세계보건기구(WHO)는 B형 간염의 예방과 치료를 위해 국가별로 감염 예방 정책을 수립하고 있습니다.",
#   "is_science": true
# }
#
# Test 150
# Question: [{'role': 'user', 'content': '노인 학대를 막기 위한 방안이 뭐가 있을까?'}]
# Answer: {
#   "answer": "노인 학대를 막기 위한 방안으로는 다음과 같은 것들이 있습니다: 1) 노인 학대에 대한 인식 개선 교육, 2) 노인 보호를 위한 법적 조치 강화, 3) 노인복지 서비스의 확대 및 접근성 개선, 4) 지역사회 내에서 노인을 위한 지원 네트워크 구축, 5) 학대 피해 노인을 위한 신고 및 지원 시스템 강화. 이러한 조치들이 종합적으로 이루어질 때 노인 학대를 예방하고 효과적으로 대응할 수 있습니다.",
#   "is_science": false
# }
#
# Test 151
# Question: [{'role': 'user', 'content': '너 정말 똑똑하구나?'}]
# Answer: {
#   "is_science": false,
#   "answer": "감사합니다! 무엇이든 도와드릴 준비가 되어 있어요."
# }
#
# Test 152
# Question: [{'role': 'user', 'content': '식물과 동물중 누가 번식력이 높다고 할 수 있어?'}]
# Answer:
# {
#   "answer": "식물과 동물의 번식력을 비교하는 것은 종류에 따라 다양하게 달라질 수 있습니다. 일반적으로 식물은 종자, 포자, 뿌리나 줄기를 통해 무성생식과 유성생식을 할 수 있어서 빠르고 다양한 방법으로 번식할 수 있습니다. 반면, 동물은 주로 유성생식을 하며, 번식 속도와 성공률은 종에 따라 크게 다릅니다. 따라서 '누가 더 번식력이 높다'고 일반화하기보다는 각각의 생물 종에 따라 번식 방법과 효율을 고려해야 합니다.",
#   "is_science": true
# }
#
# Test 153
# Question: [{'role': 'user', 'content': '엽록체의 역할에 대해 설명해줘.'}]
# Answer: {
#   "answer": "엽록체는 식물 세포에서 광합성을 담당하여, 태양으로부터 받은 빛 에너지를 화학 에너지로 변환합니다. 이 과정에서 식물은 탄소와 물을 사용하여 포도당과 같은 영양분을 생산하고, 산소를 방출합니다. 엽록체 내부의 엽록소라는 녹색 색소가 빛을 흡수하여 이 과정을 가능하게 합니다.",
#   "is_science": true
# }
#
# Test 154
# Question: [{'role': 'user', 'content': '특정 물질이 금속으로 되어 있는지 확인 하는 방법은?'}]
# Answer: {
#   "answer": "특정 물질이 금속인지 확인하는 방법으로는 전기 전도성과 열 전도성을 테스트하는 것이 일반적입니다. 금속은 전기와 열을 잘 전달하는 특성을 가지고 있습니다. 따라서, 전기가 잘 통하는지, 열을 잘 전달하는지 확인하면 금속인지 아닌지를 판별할 수 있습니다.",
#   "is_science": true
# }
#
# Test 155
# Question: [{'role': 'user', 'content': '파리가 생태계에 미치는 영향에 대해 알려줘.'}]
# Answer: {
#   "answer": "파리는 생태계에서 중요한 역할을 합니다. 파리는 분해자로서 죽은 동식물의 분해 과정에 기여하며, 이는 생태계 내 영양소 순환에 중요합니다. 또한, 파리는 많은 포식자들의 먹이원으로서 생태계 내 먹이사슬에 기여합니다. 그러나 파리는 질병을 전파하는 매개체로서 부정적인 영향을 미칠 수도 있습니다.",
#   "is_science": true
# }
#
# Test 156
# Question: [{'role': 'user', 'content': '칼리시 바이러스는 어떻게 생존을 이어나가는가?'}]
# Answer: {
#   "answer": "칼리시 바이러스는 RNA 바이러스로, 호스트 세포에 침투하여 호스트의 기계적인 시스템을 이용해 복제합니다. 바이러스는 자신의 RNA를 복사하고 새로운 바이러스 입자를 형성합니다. 이 과정은 호스트 세포의 생리학적 기능을 방해하고, 세포의 죽음을 유발할 수 있습니다. 또한, 칼리시 바이러스는 호스트의 면역 시스템을 회피하기 위해 다양한 전략을 사용합니다.",
#   "is_science": true
# }
#
# Test 157
# Question: [{'role': 'user', 'content': '옥수수 수확에 어류를 활용하는 방법은?'}]
# Answer: {
#   "answer": "정보가 부족해서 답을 할 수 없습니다.",
#   "is_science": true
# }
#
# Test 158
# Question: [{'role': 'user', 'content': '이태리에서 언론의 자유는 어떤 편이야?'}]
# Answer:
# {
#   "answer": "이태리의 언론 자유에 대해 궁금하시군요. 이태리는 일반적으로 언론의 자유가 보장되는 나라로 알려져 있습니다. 유럽 내에서도 상대적으로 언론의 자유가 잘 보호되고 있으며, 다양한 미디어를 통해 정보를 제공받을 수 있습니다. 하지만 때때로 정치적 영향력이 언론에 미치는 영향에 대한 논란이 있기도 합니다.",
#   "is_science": false
# }
#
# Test 159
# Question: [{'role': 'user', 'content': '은하에는 엄청나게 많은 별들이 모여 있잖아?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 많은 별들이 어떻게 뭉쳐 있을 수 있지?'}]
# Answer: {
#   "answer": "별들은 중력에 의해 서로 끌어당겨져 은하를 형성합니다. 은하 내의 별들은 중력적 상호작용을 통해 안정적으로 유지되며, 이 중력은 은하 내의 별, 가스, 먼지 등의 질량에 의해 발생합니다.",
#   "is_science": true
# }
#
# Test 160
# Question: [{'role': 'user', 'content': '네트웍 통신시에 주소를 속이는 공격 방법이 뭐야?'}]
# Answer: {
#   "answer": "네트워크 통신에서 주소를 속이는 공격 방법 중 하나는 IP 스푸핑(IP Spoofing)입니다. 이 방법은 공격자가 자신의 IP 주소를 다른 컴퓨터의 IP 주소로 위장하여 네트워크에 접근하거나 데이터를 조작하는 기법입니다.",
#   "is_science": true
# }
#
# Test 161
# Question: [{'role': 'user', 'content': '너 모르는 것도 있어?'}]
# Answer: {
#   "answer": "저는 계속해서 배우고 정보를 업데이트하고 있지만, 모든 것을 알고 있는 것은 아닙니다. 어떤 질문이든 도움을 드릴 수 있도록 최선을 다하겠습니다!",
#   "is_science": false
# }
#
# Test 162
# Question: [{'role': 'user', 'content': '과일 샐러드의 특징에 대해 알려줘.'}]
# Answer: {
#   "answer": "과일 샐러드는 다양한 종류의 신선한 과일을 썰어서 섞은 요리입니다. 과일의 달콤하고 상큼한 맛이 조화를 이루며, 비타민과 미네랄이 풍부하여 건강에 좋습니다. 간단하게 준비할 수 있어서 간식이나 디저트로 인기가 많습니다.",
#   "is_science": false
# }
#
# Test 163
# Question: [{'role': 'user', 'content': '새로 만든 항생제가 드디어 나왔어.'}, {'role': 'assistant', 'content': '네 무엇을 도와 드릴까요?'}, {'role': 'user', 'content': '그 효과를 확실히 얘기하기 위해서 해야할 일은?'}]
# Answer:
# {
#   "is_science": true,
# ...
#   "is_science": false
# }
#
# Test 168
# Question: [{'role': 'user', 'content': 'Python 공부중이야.'}, {'role': 'assistant', 'content': '네 python은 배워 두시면 유용합니다.'}, {'role': 'user', 'content': 'list의 값중 가장 작은 값을 알려주는 함수가 뭐야?'}]
# Answer:
# {
#   "answer": "Python에서 리스트의 가장 작은 값을 찾기 위해 사용할 수 있는 함수는 `min()` 함수입니다. 예를 들어, `my_list = [5, 3, 9, 1]` 이라는 리스트가 있을 때, `min(my_list)`를 호출하면 `1`이 반환됩니다.",
#   "is_science": true
# }
#
# Test 169
# Question: [{'role': 'user', 'content': '글루텐이 에너지 흡수에 미치는 영향은?'}]
# Answer: {
#   "answer": "글루텐은 탄수화물 흡수 불량을 증가시킬 수 있습니다. 글루텐은 밀, 보리, 쌀 등의 곡물에 포함되어 있으며, 일부 사람들은 글루텐에 민감할 수 있습니다. 글루텐 민감성은 소화기계의 기능에 영향을 주어 탄수화물 흡수에 문제를 일으킬 수 있습니다. 이로 인해 소화기계가 글루텐을 처리하는 데 어려움을 겪을 수 있으며, 결과적으로 탄수화물 흡수 불량이 발생할 수 있습니다. 탄수화물은 우리 몸에 필요한 에너지원이므로, 글루텐 민감성이 있는 사람들은 글루텐을 제한하거나 피하는 것이 좋습니다. 이를 통해 탄수화물 흡수 불량을 예방하고 건강을 유지할 수 있습니다.",
#   "is_science": true
# }
#
# Test 170
# Question: [{'role': 'user', 'content': '해구가 생겨나는 원리는?'}]
# Answer: {
#   "answer": "해구는 대륙판과 해양판이 충돌하거나 해양판끼리 충돌할 때 발생합니다. 이러한 충돌로 인해 한 판이 다른 판 아래로 잠겨 들어가면서 해구가 형성됩니다. 이 과정을 '섭입'이라고 하며, 섭입하는 판은 지구 내부로 들어가면서 용융되고, 이로 인해 지진이나 화산 활동이 일어날 수 있습니다.",
#   "is_science": true
# }
#
# Test 171
# Question: [{'role': 'user', 'content': '비만도를 어떻게 측정할 수 있나?'}]
# Answer: {
#   "answer": "비만도를 측정하는 가장 일반적인 방법은 체질량 지수(BMI)를 사용하는 것입니다. BMI는 몸무게(kg)를 키의 제곱(m²)으로 나눈 값으로 계산됩니다. BMI 범위에 따라 저체중, 정상, 과체중, 비만으로 분류할 수 있습니다. 또한, 체지방률 측정이나 허리둘레 측정도 비만도를 평가하는 데 사용될 수 있습니다.",
#   "is_science": true
# }
#
# Test 172
# Question: [{'role': 'user', 'content': '원자번호는 원자내의 어떤 소립자와 관계 있는가?'}]
# Answer: {
#   "answer": "원자번호는 원자의 핵에 있는 양성자의 수와 관계가 있습니다. 원자번호는 원소의 고유한 특성을 나타내며, 같은 원자번호를 가진 원소는 같은 종류의 원소입니다.",
#   "is_science": true
# }
#
# Test 173
# Question: [{'role': 'user', 'content': '바이러스가 원핵 세포와 서로 작용할 때 사용하는 것은?'}]
# Answer: {
#   "answer": "바이러스는 원핵 세포와 상호 작용할 때 자신의 유전 정보를 사용하여 원핵 세포의 기능을 조작하고, 자신을 복제합니다. 이 과정에서 바이러스는 원핵 세포의 복제 기계를 이용하여 자신의 RNA 또는 DNA를 복제하게 만듭니다.",
#   "is_science": true
# }
#
# Test 174
# Question: [{'role': 'user', 'content': '연기 열수공의 특성에 대해 설명해줘.'}]
# Answer: {
#   "answer": "연기 열수공은 심해저에서 발견되는 뜨거운 물과 광물이 풍부한 수중 분출구입니다. 이곳에서는 고온과 화학적으로 풍부한 환경 때문에 특수한 생태계가 형성되어 있습니다. 연기 열수공 주변에서는 일반적인 해양 환경에서는 찾아볼 수 없는 독특한 생물들이 서식하며, 이들은 화학적 에너지를 이용해 생존하는 화학합성 생물입니다. 이러한 환경은 지구상에서 생명의 기원과 진화에 대한 중요한 단서를 제공할 수 있습니다.",
#   "is_science": true
# }
#
# Test 175
# Question: [{'role': 'user', 'content': '너 뭘 잘해?'}]
# Answer:
# {
#   "answer": "저는 과학 지식에 관한 질문에 답변하는 것을 잘합니다. 생물학, 물리학, 화학, 의학, 공학 등 다양한 과학 분야에 대한 정보를 제공할 수 있어요.",
#   "is_science": false
# }
#
# Test 176
# Question: [{'role': 'user', 'content': 'bridge inverter의 역할에 대해 알려줘?'}]
# Answer: {
#   "answer": "Bridge inverter는 전기 회로에서 직류(DC)를 교류(AC)로 변환하는 역할을 합니다. 이러한 인버터는 주로 전력 변환 시스템에서 사용되며, 다양한 전기 장비와 장치에서 필요로 하는 AC 전원을 제공하기 위해 사용됩니다.",
#   "is_science": true
# }
#
# Test 177
# Question: [{'role': 'user', 'content': '캠핑의 선기능에 대해 알려줘.'}]
# Answer:
# {
#   "is_science": false,
#   "answer": "캠핑은 자연과 가까워질 수 있는 기회를 제공하며, 일상에서 벗어나 휴식을 취하고 스트레스를 해소하는 데 도움을 줍니다. 또한 가족이나 친구들과의 관계를 강화하고, 새로운 사람들을 만나 교류할 기회도 마련해 줍니다. 신체 활동을 증가시켜 건강에도 긍정적인 영향을 미칠 수 있습니다."
# }
#
# Test 178
# Question: [{'role': 'user', 'content': '지구 온난화 때문에 문제가 발생할 수 있는 지역은?'}]
# Answer: {
#   "answer": "지구 온난화로 인해 특히 문제가 발생할 수 있는 지역은 해안 지역, 저지대, 북극 및 남극 지역, 그리고 소규모 섬나라들입니다. 해수면 상승으로 인해 해안 침식, 홍수, 염수 침투 등의 문제가 발생할 수 있으며, 극지방의 빙하가 녹으면서 해수면이 상승할 수 있습니다. 또한, 기후 변화로 인한 극심한 날씨 변화는 농업, 수자원, 생태계에도 영향을 미칠 수 있습니다.",
#   "is_science": true
# }
#
# Test 179
# Question: [{'role': 'user', 'content': '염소 원자에 빛을 방출했을 때 발생할 수 있는 시나리오에 대해 알려줘.'}]
# Answer: {
#   "answer": "염소 원자에 빛을 방출하면, 염소 원자의 전자들이 더 높은 에너지 준위로 흥분될 수 있습니다. 이 흥분된 상태는 일시적이며, 전자가 다시 낮은 에너지 준위로 돌아올 때 에너지를 광자의 형태로 방출하게 됩니다. 이 과정을 통해 발생하는 빛의 파장은 염소 원자의 특정 에너지 준위 차이에 따라 결정됩니다.",
#   "is_science": true
# }
#
# Test 180
# Question: [{'role': 'user', 'content': '후두가 안정성을 유지할 수 있는 이유는?'}]
# Answer: {
#   "answer": "후두가 안정성을 유지할 수 있는 이유는 후두의 구조적 특성과 연골, 근육, 인대 등이 복합적으로 작용하기 때문입니다. 후두는 목구멍 뒤쪽에 위치하며, 호흡과 발성에 필수적인 역할을 합니다. 후두의 연골 구조는 충분한 강도를 제공하여 안정적으로 기능을 수행할 수 있도록 돕습니다. 또한, 여러 근육과 인대가 후두를 지지하고, 움직임을 조절하여 음식물이 기도로 들어가는 것을 방지하고, 발성 시에는 공기의 흐름을 조절합니다.",
#   "is_science": true
# }
#
# Test 181
# Question: [{'role': 'user', 'content': '요새 너무 힘드네..'}]
# Answer: {
#   "answer": "많이 힘드시군요. 어떤 부분이 힘드신지 말씀해주시면 조금이나마 위로가 되었으면 좋겠습니다.",
#   "is_science": false
# }
#
# Test 182
# Question: [{'role': 'user', 'content': '연구실에서 무엇인지 파악이 안된 가루를 저울로 옮기는 좋은 방법은?'}]
# Answer: {
#   "answer": "연구실에서 파악되지 않은 가루를 저울로 옮기는 좋은 방법은 연구실용 스푼이나 스패츌러를 사용하는 것입니다. 이 도구들은 정밀하게 소량의 가루를 취급할 수 있어 적합합니다. 또한, 가루가 공기 중으로 날리지 않도록 조심스럽게 다루어야 합니다.",
#   "is_science": true
# }
#
# Test 183
# Question: [{'role': 'user', 'content': '금성이 행성중 가장 밝게 보이는 이유는?'}]
# Answer: {
#   "answer": "금성이 다른 행성들보다 밝게 보이는 이유는 그 표면이 태양으로부터 받은 빛을 매우 잘 반사하기 때문입니다. 금성의 대기는 주로 이산화탄소로 이루어져 있고, 높은 구름층이 태양 빛을 효과적으로 반사하여 지구에서 보기에 매우 밝게 보입니다.",
#   "is_science": true
# }
#
# Test 184
# Question: [{'role': 'user', 'content': '자석의 세기에 가장 큰 영향을 주는 불순물은?'}]
# Answer: {
#   "answer": "자석의 세기에 가장 큰 영향을 주는 불순물에 대한 구체적인 정보를 제공할 수 있는 자료가 부족합니다.",
#   "is_science": true
# }
#
# Test 185
# Question: [{'role': 'user', 'content': '솔레노이드가 뭐야?'}]
# Answer: {
#   "answer": "솔레노이드는 전기 전류가 흐르는 와이어로 구성된 장치입니다. 이 와이어가 코일 형태로 감겨 있어 전류가 흐를 때 자기장을 생성합니다. 이 자기장은 다양한 전자기적 응용, 예를 들어 전자기 밸브나 전기 모터에서 중요한 역할을 합니다.",
#   "is_science": true
# }
#
# Test 186
# Question: [{'role': 'user', 'content': '여러개의 약을 동시에 먹고 있어.'}, {'role': 'assistant', 'content': '네, 무엇을 도와드릴까요?'}, {'role': 'user', 'content': '이렇게 동시에 먹는 경우 어떤 문제가 생길수 있나?'}]
# Answer: {
#   "answer": "여러 약을 동시에 복용할 경우, 약물 간 상호작용으로 인해 부작용이 발생할 수 있습니다. 예를 들어, 약물들이 서로의 효과를 감소시키거나 증가시킬 수 있고, 예상치 못한 새로운 부작용을 일으킬 수도 있습니다. 따라서 여러 약을 동시에 복용해야 할 경우, 의사나 약사와 상의하여 안전하게 관리하는 것이 중요합니다.",
#   "is_science": true
# }
#
# Test 187
# Question: [{'role': 'user', 'content': '진폭 변조와 주파수 변조의 차이에 대해 알려줘.'}]
# Answer: {
#   "answer": "진폭 변조(AM)는 신호의 진폭을 변화시켜 정보를 전달하는 방식이고, 주파수 변조(FM)는 신호의 주파수를 변화시켜 정보를 전달합니다. AM은 신호의 높낮이(진폭)를 변화시켜 데이터를 인코딩하는 반면, FM은 신호의 주파수 변화를 통해 데이터를 인코딩합니다.",
#   "is_science": true
# }
#
# Test 188
# Question: [{'role': 'user', 'content': '잠을 잘 잤을 때 이로운 점을 나열해줘.'}]
# Answer: {
#   "answer": "잠을 잘 자면 여러 가지 이로운 점이 있습니다. 첫째, 기억력과 학습 능력이 향상됩니다. 둘째, 신체의 회복과 성장이 촉진됩니다. 셋째, 스트레스와 불안을 감소시키고 정신 건강을 개선할 수 있습니다. 넷째, 면역 체계가 강화되어 질병에 대한 저항력이 증가합니다. 다섯째, 심혈관 건강을 유지하는 데 도움이 됩니다. 이외에도 좋은 수면은 전반적인 삶의 질을 향상시키는 데 중요한 역할을 합니다.",
#   "is_science": false
# }
#
# Test 189
# Question: [{'role': 'user', 'content': '음파는 어떻게 이동하는가?'}]
# Answer: {
#   "answer": "음파는 공기와 같은 매질을 통해 진동을 전달하면서 이동합니다. 음파는 매질의 분자들이 진동하면서 인접한 분자들에게 진동을 전달하는 방식으로 전파됩니다. 이러한 진동의 연쇄 반응이 음파의 전파를 가능하게 합니다.",
#   "is_science": true
# }
#
# Test 190
# Question: [{'role': 'user', 'content': '테러로 인한 이슈와 대응책에 대해 알려줘.'}]
# Answer: {
#   "answer": "테러와 관련된 이슈와 대응책에 대해서는 전문적인 안보나 정치 분야의 지식이 필요합니다. 과학 지식에 관한 질문이 있다면 도와드릴 수 있습니다.",
#   "is_science": false
# }
#
# Test 191
# Question: [{'role': 'user', 'content': '바닥의 마찰이 없는 곳에서 두 사람이 서로 밀어낼때 무게가 덜 나가는 사람이 더 나가는 사람이 더 빨리 움직이게 되는 이유는?'}]
# Answer: {
#   "answer": "뉴턴의 제3법칙에 따르면, 서로 밀어낼 때 각자가 받는 힘은 같지만, 무게가 더 적은 사람은 더 적은 질량을 가지고 있기 때문에 같은 힘을 받았을 때 더 큰 가속도를 얻게 됩니다. 따라서 무게가 덜 나가는 사람이 더 빨리 움직이게 됩니다.",
#   "is_science": true
# }
#
# Test 192
# Question: [{'role': 'user', 'content': '세포간에 갭결합이 생기는 것을 규명한 실험에 대해 알려줘.'}]
# Answer: {
#   "answer": "제공된 정보에는 세포 간 갭결합을 규명한 실험에 대한 구체적인 내용이 포함되어 있지 않습니다. 따라서 해당 실험에 대해 설명드릴 수 있는 정보가 부족합니다.",
#   "is_science": true
# }
#
# Test 193
# Question: [{'role': 'user', 'content': '행성의 크기와 화산이 얼마나 자주 폭발하는지가 관련이 있어?'}]
# Answer: {
#   "answer": "행성의 크기가 클수록 내부에서 더 많은 열과 압력이 발생하여 화산 활동이 더 활발할 수 있습니다. 따라서 행성의 크기와 화산 활동의 빈도는 관련이 있을 수 있습니다.",
#   "is_science": true
# }
#
# Test 194
# Question: [{'role': 'user', 'content': '우성인 빨간색 꽃과 열성인 흰꽃을 교배한다고 하자.'}, {'role': 'assistant', 'content': '네 말씀하세요.'}, {'role': 'user', 'content': '두 꽃을 교배한 후 다음세대 꽃의 색깔은 어떻게 되나?'}]
# Answer: {
#   "answer": "정보가 부족해서 답을 할 수 없습니다.",
#   "is_science": true
# }
#
# Test 195
# Question: [{'role': 'user', 'content': '기계가 연료를 태울 때 어떤 형태로 에너지가 낭비되는가?'}]
# Answer: {
#   "answer": "기계가 연료를 태울 때 에너지 낭비는 주로 열, 마찰, 소음 등의 형태로 발생합니다. 이러한 에너지는 유용하게 사용되지 않고 주변 환경으로 방출되어 기계의 효율을 감소시킵니다.",
#   "is_science": true
# }
#
# Test 196
# Question: [{'role': 'user', 'content': '동물들이 종종 집단으로 이주하는 경우가 발생하더라구?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '이렇게 집단으로 이주하게 되는 계기는 어떤 것들이 있어?'}]
# Answer: {
#   "answer": "동물들이 집단으로 이주하는 주된 계기는 계절 변화와 식량 부족입니다. 계절 변화로 인해 생존에 필요한 조건이 변하거나, 식량 자원이 감소할 때 더 나은 환경을 찾아 이동합니다. 또한, 자연재해나 인간의 환경 개발로 인한 서식지 파괴도 동물들이 이주하게 되는 원인 중 하나입니다.",
#   "is_science": true
# }
#
# Test 197
# Question: [{'role': 'user', 'content': '남미 여러 나라들이 중고등학교 취학률을 높이기 위해 어떤 일들을 하고 있어?'}]
# Answer:
# {
#   "answer": "남미 여러 나라들의 중고등학교 취학률을 높이기 위한 노력은 교육 정책, 재정 지원, 인프라 개선 등 다양한 방면에서 이루어지고 있습니다. 예를 들어, 장학금 제공, 학교 시설 개선, 원격 교육 기회 확대, 교육 프로그램의 다양화 등이 포함될 수 있습니다. 각국의 정확한 정책이나 실행 사례에 대해서는 추가적인 정보가 필요할 수 있습니다.",
#   "is_science": false
# }
#
# Test 198
# Question: [{'role': 'user', 'content': '네트웍 계층 중 IP에 대해 설명해줘.'}]
# Answer: {
#   "answer": "IP 프로토콜은 인터넷 프로토콜의 약자로, 네트워크를 통해 데이터를 전송하는 데 사용되는 프로토콜입니다. IP 프로토콜은 인터넷에서 데이터를 패킷으로 분할하여 전송하고, 이러한 패킷을 목적지까지 라우팅하는 역할을 합니다. 이를 통해 데이터는 여러 개의 네트워크를 거쳐 목적지에 도달할 수 있습니다. IP 프로토콜은 패킷의 출발지와 목적지 IP 주소를 사용하여 패킷을 전송하고, 패킷의 손실이나 손상을 감지하고 복구하기 위한 기능도 제공합니다. 따라서 IP 프로토콜은 네트워크 통신에서 핵심적인 역할을 수행하며, 인터넷의 기반 기술로 사용되고 있습니다.",
#   "is_science": true
# }
#
# Test 199
# Question: [{'role': 'user', 'content': '같은 독감에 다시 걸리면 빨리 회복이 되더라구?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 이유가 뭐야?'}]
# Answer: {
#   "answer": "같은 독감 바이러스에 다시 감염되었을 때 더 빠르게 회복되는 이유는 '기억 세포' 때문입니다. 첫 번째 감염 시 면역 시스템이 바이러스를 인식하고 기억 세포를 생성합니다. 이 기억 세포들은 같은 바이러스가 다시 침입했을 때 빠르게 반응하여 바이러스를 제거하고, 이로 인해 증상이 덜하게 나타나고 회복이 빨라집니다.",
#   "is_science": true
# }
#
# Test 200
# Question: [{'role': 'user', 'content': '시소에서 균형을 잡기 위해 양쪽에서 가하는 힘의 크기에 대해 설명해줘.'}]
# Answer: {
#   "answer": "시소에서 균형을 잡기 위해서는 양쪽에서 가하는 힘이 같아야 합니다. 또한, 각 사람의 무게와 시소의 지지점으로부터의 거리가 힘의 크기에 영향을 미칩니다. 이 두 요소가 서로 상쇄되어야 시소가 수평을 유지하며 균형 상태가 됩니다.",
#   "is_science": true
# }
#
# Test 201
# Question: [{'role': 'user', 'content': '두개의 소스로부터 발생한 사건중 어떤 쪽에서 기인한 것인지 확률 계산하는 예시 알려줘.'}]
# Answer:
# {
#   "is_science": true,
#   "answer": "두 개의 소스로부터 발생한 사건의 원인을 확률적으로 계산하는 예시를 들어 설명하겠습니다. 이러한 문제는 베이즈 정리를 사용하여 접근할 수 있습니다. 베이즈 정리는 주어진 증거를 바탕으로 특정 가설의 조건부 확률을 계산하는 데 사용됩니다.\n\n예를 들어, 두 개의 공장 A와 B에서 화학 물질 유출 사건이 발생할 수 있고, 어느 한 곳에서 실제로 유출 사건이 발생했다고 가정해 봅시다. 공장 A에서 사건이 발생할 확률을 P(A), 공장 B에서 사건이 발생할 확률을 P(B)라고 할 때, 사건이 발생했다는 증거 E가 주어졌을 때 각 공장이 사건의 원인일 확률은 다음과 같이 계산할 수 있습니다.\n\nP(A|E) = (P(E|A) * P(A)) / P(E)\nP(B|E) = (P(E|B) * P(B)) / P(E)\n\n여기서 P(E|A)는 공장 A에서 사건이 발생했을 때 증거 E가 관찰될 확률, P(E|B)는 공장 B에서 사건이 발생했을 때 증거 E가 관찰될 확률입니다. P(E)는 전체적으로 증거 E가 관찰될 확률로, P(E) = P(E|A) * P(A) + P(E|B) * P(B)로 계산할 수 있습니다.\n\n이러한 방식으로 각 소스에서 발생한 사건의 원인을 확률적으로 추정할 수 있습니다."
# }
#
# Test 202
# Question: [{'role': 'user', 'content': '곤충의 생태를 관찰할 때 사용할 수 있는 방법은?'}]
# Answer: {
#   "answer": "곤충의 생태를 관찰할 때 사용할 수 있는 방법은 다음과 같습니다:\n1. 직접 관찰: 곤충이 자주 출몰하는 자연 환경에서 직접 관찰하는 방법입니다. 쌍안경이나 돋보기를 사용하여 곤충의 행동을 관찰할 수 있습니다.\n2. 트랩 사용: 빛 트랩이나 냄새 트랩을 설치하여 곤충을 유인하고 관찰하는 방법입니다.\n3. 샘플링: 특정 지역에서 곤충을 채집하여 돋보기나 현미경으로 관찰하는 방법입니다.\n4. 비디오 또는 사진 기록: 곤충의 행동을 비디오 또는 사진으로 기록하여 분석하는 방법입니다.\n이러한 방법들을 통해 곤충의 생태와 행동 패턴을 자세히 관찰할 수 있습니다.",
#   "is_science": true
# }
#
# Test 203
# Question: [{'role': 'user', 'content': '작은 기체 하나의 질량을 어떻게 구할 수 있어?'}]
# Answer: {
#   "answer": "작은 기체 하나의 질량을 구하기 위해서는 기체의 몰 질량을 알아야 합니다. 기체의 몰 질량은 기체의 밀도와 온도, 압력을 이용하여 계산할 수 있습니다. 이를 위해 이상 기체 방정식 PV=nRT를 사용할 수 있으며, 여기서 P는 압력, V는 부피, n은 몰 수, R은 기체 상수, T는 절대 온도입니다. 기체의 밀도를 알고 있으면, 이를 통해 몰 질량을 계산할 수 있습니다.",
#   "is_science": true
# }
#
# Test 204
# Question: [{'role': 'user', 'content': '평형분극비율이 뭐야?'}]
# Answer: {
#   "answer": "평형분극비율은 전자와 양성자의 평형 상태에서의 분극 에너지의 비율을 나타내는 값입니다. 예를 들어, 특정 조건에서 전자와 양성자의 평형 분극 비율이 820이라면, 이는 전자의 분극 에너지를 양성자의 분극 에너지로 나눈 값이 820임을 의미합니다. 이 비율은 자기장의 강도와 온도에 따라 변할 수 있습니다.",
#   "is_science": true
# }
#
# Test 205
# Question: [{'role': 'user', 'content': '근친간의 성행위가 금해지는 이유는?'}]
# Answer: {
#   "answer": "근친간의 성행위는 유전적 다양성을 저해하고 유전병의 위험을 증가시킬 수 있습니다. 이로 인해 생물학적으로 건강한 후손을 낳는 데 문제가 생길 수 있습니다. 또한, 사회적, 윤리적, 문화적 이유로도 대부분의 사회에서 금기시되고 법적으로도 금지되어 있습니다. 이러한 금지는 가족 구성원 간의 신뢰와 보호를 강화하고, 사회 질서를 유지하는 데 기여합니다.",
#   "is_science": true
# }
#
# Test 206
# Question: [{'role': 'user', 'content': '노인들이 종종 후각 능력을 잃게 되는 경우가 있더라구?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '이렇게 냄새를 못맡게 되면 어떤 결과로 이어지지?'}]
# Answer: {
#   "answer": "후각 상실은 음식의 맛을 제대로 느끼지 못하게 하고, 식욕 감소와 영양 섭취 부족으로 이어질 수 있습니다. 또한, 환경에서의 위험 요소를 감지하지 못해 안전 문제가 발생할 수 있습니다. 예를 들어, 가스 누출이나 부패한 음식을 인지하지 못할 수 있습니다. 따라서 후각 상실은 노인의 건강과 안전에 중요한 영향을 미칠 수 있습니다.",
#   "is_science": true
# }
#
# Test 207
# Question: [{'role': 'user', 'content': '하늘이 파란 이유는?'}]
# Answer: {
#   "answer": "하늘이 파란 이유는 대기 중의 분자가 파란색 빛을 더 효과적으로 산란시키기 때문입니다. 파란색은 빛의 파장이 짧아서 분자에 의해 더 많이 산란되고 반사됩니다. 이로 인해 우리가 보는 하늘은 파란색으로 보이게 됩니다.",
#   "is_science": true
# }
#
# Test 208
# Question: [{'role': 'user', 'content': '짚신 벌레의 번식은 어떻게 이루어지나?'}]
# Answer: {
#   "answer": "짚신벌레의 번식에 대한 구체적인 정보는 제공된 자료에서 찾을 수 없습니다. 따라서 정확한 답변을 제공하기 어렵습니다.",
#   "is_science": true
# }
#
# Test 209
# Question: [{'role': 'user', 'content': '온난 전선이 발생하면 이후 날씨는 어떻게 되나?'}]
# Answer: {
#   "answer": "온난 전선이 발생하면 따뜻한 공기가 차가운 공기 위로 올라가면서 구름을 형성하고, 이로 인해 강수가 발생할 수 있습니다. 따라서 온난 전선이 지나간 후에는 비가 오거나 날씨가 흐려질 가능성이 높습니다.",
#   "is_science": true
# }
#
# Test 210
# Question: [{'role': 'user', 'content': '전기가 흐르는 회로에서 전선과 전구의 전류는 동일한가?'}]
# Answer: {
#   "answer": "단일 회로에서 전선과 전구를 포함한 모든 부품을 직렬로 연결했을 경우, 전체 회로를 통해 흐르는 전류는 동일합니다. 따라서 전선과 전구를 통과하는 전류도 같습니다.",
#   "is_science": true
# }
#
# Test 211
# Question: [{'role': 'user', 'content': '플로리다에서 친환경 에너지를 가장 효과적으로 활용할 수 있는 시기는?'}]
# Answer: {
#   "answer": "플로리다에서 친환경 에너지를 가장 효과적으로 활용할 수 있는 시기는 6월입니다. 이 시기에는 플로리다의 날씨가 가장 따뜻하고 맑은 날이 많아 태양 에너지를 효율적으로 수집할 수 있습니다.",
#   "is_science": true
# }
#
# Test 212
# Question: [{'role': 'user', 'content': '농장이 해안가 환경에 나쁜 영향을 미칠 수 있는 원인이 뭐가 있어?'}]
# Answer: {
#   "answer": "농장이 해안가 환경에 나쁜 영향을 미칠 수 있는 원인으로는 농약과 비료의 사용이 있습니다. 이러한 화학물질들이 비나 관개를 통해 농장에서 유출되어 해안가로 흘러들어갈 수 있습니다. 이는 해양 생태계에 해로운 영향을 미치며, 특히 물속의 산소량을 감소시키고 해양 생물들의 생존을 위협할 수 있습니다. 또한, 농장에서의 과도한 토양 침식도 해안가에 퇴적물을 증가시켜 해양 생태계에 부정적인 영향을 줄 수 있습니다.",
#   "is_science": true
# }
#
# Test 213
# Question: [{'role': 'user', 'content': '자성을 띄지 않는 유전체 내부에서 빛의 속도는 어떻게 되나?'}]
# Answer: {
#   "answer": "자성을 띄지 않는 유전체 내부에서 빛의 속도는 유전체의 유전율에 따라 결정됩니다. 유전체의 유전율이 높을수록 빛의 속도는 느려집니다. 공기 중 빛의 속도는 약 299,792 km/s이며, 유전체 내부에서는 이보다 느릴 수 있습니다.",
#   "is_science": true
# }
#
# Test 214
# Question: [{'role': 'user', 'content': '자연보호구역이 필요한 이유는?'}]
# Answer: {
#   "answer": "자연보호구역은 인간의 개입을 최소화하고 자연 생태계를 보호하는 역할을 합니다. 이러한 보호구역은 생물 다양성을 유지하고 멸종 위기에 처한 동식물들을 보호하는데 도움을 줍니다. 또한, 대기 중의 이산화탄소를 흡수하여 온실가스 배출을 줄이는 역할을 하며, 지역 생태계의 안정성을 유지하는데도 도움을 줍니다. 따라서, 자연보호구역을 만들면 지구의 환경을 보호하고 지속 가능한 미래를 위한 조치를 취할 수 있습니다.",
#   "is_science": true
# }
#
# Test 215
# Question: [{'role': 'user', 'content': '정상파가 뭐야?'}]
# Answer: {
#   "answer": "정상파는 매질 내에서 진동이 일정한 주기와 파장을 가지고 전파되는 파동입니다. 이는 매질의 한 지점에서 다른 지점으로 에너지를 전달하지만, 매질 자체는 전체적으로 이동하지 않습니다. 예를 들어, 물결이나 소리 파동이 정상파의 예시가 될 수 있습니다.",
#   "is_science": true
# }
#
# Test 216
# Question: [{'role': 'user', 'content': '공에 힘이 주어졌을 때 공이 어떻게 움직이는지 과학적으로 설명해줘.'}]
# Answer: {
#   "answer": "공에 힘이 주어지면, 뉴턴의 운동 법칙에 따라 힘은 공의 질량과 가속도의 곱과 같습니다. 즉, F=ma (힘 = 질량 x 가속도) 공식을 사용하여 공의 움직임을 예측할 수 있습니다. 힘이 작용하는 방향으로 공은 가속되며, 힘이 중단되면 공은 다른 외력이 작용할 때까지 그 속도를 유지하거나 점차 감속합니다.",
#   "is_science": true
# }
#
# Test 217
# Question: [{'role': 'user', 'content': '동물들이 피부나 털의 색깔을 통해 생존의 확률을 높이는 방식에 대해 설명해줘.'}]
# Answer: {
#   "answer": "동물들은 피부나 털의 색깔을 변화시켜 자신을 포식자로부터 보호하거나, 사냥을 할 때 먹이를 속이는 등 생존 확률을 높입니다. 예를 들어, 북극 여우는 겨울에는 흰색 털로 눈에 잘 녹아들어 포식자로부터 숨을 수 있고, 여름에는 주변 환경과 어울리는 갈색이나 회색 털로 바뀝니다. 이러한 색 변화는 주변 환경에 따라 위장하고, 생존에 유리한 조건을 만드는 데 도움을 줍니다.",
#   "is_science": true
# }
#
# Test 218
# Question: [{'role': 'user', 'content': '메탄과 산소의 화학 반응에 대해 알려줘.'}]
# Answer: {
#   "answer": "메탄(CH4)과 산소(O2)의 화학 반응은 연소 반응으로, 메탄이 산소와 반응하여 이산화탄소(CO2)와 물(H2O)을 생성합니다. 이 반응은 에너지를 방출하는 발열 반응입니다. 반응식은 CH4 + 2O2 -> CO2 + 2H2O 입니다.",
#   "is_science": true
# }
#
# Test 219
# Question: [{'role': 'user', 'content': '복숭아 키우는 노하우좀?'}]
# Answer: {
#   "answer": "복숭아를 잘 키우기 위해서는 다음과 같은 노하우가 필요합니다. 첫째, 복숭아 나무는 햇빛이 잘 드는 장소를 선호하므로 충분한 일조량을 확보해 주세요. 둘째, 복숭아 나무는 물 빠짐이 좋은 토양을 선호하므로 배수가 잘 되도록 관리해야 합니다. 셋째, 정기적인 가지치기를 통해 나무의 형태를 관리하고 과도한 열매가 맺히지 않도록 조절해야 합니다. 넷째, 복숭아 나무는 병충해에 취약할 수 있으므로 정기적인 병충해 방제가 필요합니다.",
#   "is_science": true
# }

# %%
eval_rag("data/eval.jsonl", f"submission_{datetime.now().strftime('%Y-%m-%d_%H-%M')}.csv", 4)
# Out:
# Test 4
# Question: [{'role': 'user', 'content': 'Dmitri Ivanovsky가 누구야?'}]
# Answer:
# {
#   "answer": "Dmitri Ivanovsky는 러시아의 미생물학자로, 바이러스의 발견과 연구에 기여한 인물입니다. 그는 1892년에 식물 질병인 담배 모자이크 바이러스를 연구하면서, 이 질병이 세균을 통과하는 필터를 통과할 수 있는 작은 감염원에 의해 발생한다는 것을 발견했습니다. 이 발견은 나중에 바이러스라는 새로운 병원체 범주로 이어졌습니다.",
#   "is_science": true
# }
#
# Test 5
# Question: [{'role': 'user', 'content': '피임을 하기 위한 방법중 약으로 처리하는 방법은 쓸만한가?'}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 eval_rag("data/eval.jsonl", f"submission_{datetime.now().strftime('%Y-%m-%d_%H-%M')}.csv", 4)
#
# Cell In[36], line 13, in eval_rag(eval_filename, output_filename, start_idx)
#      11 j = json.loads(line)
#      12 print(f'Test {idx}\nQuestion: {j["msg"]}')
# ---> 13 response = answer_question(j["msg"])
#      14 print(f'Answer: {response["answer"]}\n')
#      16 # 대회 score 계산은 topk 정보를 사용, answer 정보는 LLM을 통한 자동평가시 활용
#      17 # output = {"eval_id": j["eval_id"], "standalone_query": response["standalone_query"], "topk": response["topk"], "answer": response["answer"], "references": response["references"]}
#      18
#      19 # json.loads(response)
#
# Cell In[35], line 44, in answer_question(messages)
#      42 msg = [{"role": "system", "content": persona_qa}] + messages
#      43 try:
# ---> 44     qaresult = client.chat.completions.create(
#      45             model=llm_model,
#      46             response_format={"type": "json_object"},
#      47             messages=msg,
#      48             temperature=0,
#      49             seed=1,
#      50             timeout=30
#      51         )
#      52 except Exception as e:
#      53     traceback.print_exc()
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/resources/chat/completions.py:579, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     548 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     549 def create(
#     550     self,
#    (...)
#     577     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     578 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 579     return self._post(
#     580         "/chat/completions",
#     581         body=maybe_transform(
#     582             {
#     583                 "messages": messages,
#     584                 "model": model,
#     585                 "frequency_penalty": frequency_penalty,
#     586                 "function_call": function_call,
#     587                 "functions": functions,
#     588                 "logit_bias": logit_bias,
#     589                 "logprobs": logprobs,
#     590                 "max_tokens": max_tokens,
#     591                 "n": n,
#     592                 "presence_penalty": presence_penalty,
#     593                 "response_format": response_format,
#     594                 "seed": seed,
#     595                 "stop": stop,
#     596                 "stream": stream,
#     597                 "temperature": temperature,
#     598                 "tool_choice": tool_choice,
#     599                 "tools": tools,
#     600                 "top_logprobs": top_logprobs,
#     601                 "top_p": top_p,
#     602                 "user": user,
#     603             },
#     604             completion_create_params.CompletionCreateParams,
#     605         ),
#     606         options=make_request_options(
#     607             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     608         ),
#     609         cast_to=ChatCompletion,
#     610         stream=stream or False,
#     611         stream_cls=Stream[ChatCompletionChunk],
#     612     )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:952, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     949 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     951 try:
# --> 952     response = self._client.send(
#     953         request,
#     954         stream=stream or self._should_stream_response_body(request=request),
#     955         **kwargs,
#     956     )
#     957 except httpx.TimeoutException as err:
#     958     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1292     if flags != 0:
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#    1298     return super().recv(buflen, flags)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1167         return self._sslobj.read(len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#    1171     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# !wc -l sample_submission.csv
# Out:
# 6 sample_submission.csv

# %% [markdown]
# #Reference

# %% [markdown]
# ## Required Package
#
# openai==1.7.2 <br>
# elasticsearch==8.8.0 <br>
# sentence_transformers==2.2.2 <br>

# %% [markdown]
# ## 콘텐츠 라이선스
#
# 저작권 : <font color='blue'> <b> ©2023 by Upstage X fastcampus Co., Ltd. All rights reserved.</font></b>
#
# <font color='red'><b>WARNING</font> : 본 교육 콘텐츠의 지식재산권은 업스테이지 및 패스트캠퍼스에 귀속됩니다. 본 콘텐츠를 어떠한 경로로든 외부로 유출 및 수정하는 행위를 엄격히 금합니다. </b>
