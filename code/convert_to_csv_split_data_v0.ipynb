# %%
import os
import re
import jsonlines
import pandas as pd
import jsonlines
import json
from collections import OrderedDict

count = 0

idx = 0
docids = []
srcs = []
contents = []
questions = []
q1_list = []
q2_list = []
q3_list = []
q4_list = []
q5_list = []


with jsonlines.open(os.path.join(os.getcwd(),"../data/generated_questions_1068.jsonl"), 'r') as f:
    for line in f.iter():
        count += 1
        docid= line['docid']
        src = line['src']
        content = line['content']
        q1 = line['q1']
        q2 = line['q2']
        q3 = line['q3']
        q4 = line['q4']
        q5 = line['q5']
        #print(qs, len(qs))
        #break
        docids.append(docid)
        srcs.append(src)
        contents.append(content)
        q1_list.append(q1)
        q2_list.append(q2)
        q3_list.append(q3)
        q4_list.append(q4)
        q5_list.append(q5)


df = pd.DataFrame({'docid': docids,
                   'src': srcs,
                   'content': contents,
                   'q1': q1_list,
                   'q2': q2_list,
                   'q3': q3_list,
                   'q4': q4_list,
                   'q5': q5_list
                   }) 

df
# Out:
#                                      docid  \
# 0     42508ee0-c543-4338-878e-d98c6babee66
# 1     4a437e7f-16c1-4c62-96b9-f173d44f4339
# 2     d3c68be5-9cb1-4d6e-ba18-5f81cf89affb
# 3     910107a6-2a42-41a2-b337-fbf22d6440fe
# 4     74f22819-1a8e-4646-8a9d-13323de8cdb8
# ...                                    ...
# 1063  c9839504-a70c-4755-b933-7d71dcb800c7
# 1064  840c3bcf-3caf-43fb-b4b8-e77b450e0fee
# 1065  2d5d7d1a-79a2-4859-925c-524c5e25bbe4
# 1066  9bfc76e2-d492-42af-97eb-da5957af935f
# 1067  46e9683f-1ba0-4e93-83bc-1cde390e80e6
#
#                                         src  \
# 0                  ko_mmlu__nutrition__test
# 1         ko_mmlu__conceptual_physics__test
# 2           ko_ai2_arc__ARC_Challenge__test
# 3           ko_ai2_arc__ARC_Challenge__test
# 4     ko_ai2_arc__ARC_Challenge__validation
# ...                                     ...
# 1063  ko_ai2_arc__ARC_Challenge__validation
# 1064               ko_mmlu__astronomy__test
# ...

# %% [markdown]
# # Divivde Data into Train, Validation, Test

# %%
"ko_mmlu__nutrition__test".split("__")
# Out:
# ['ko_mmlu', 'nutrition', 'test']

# %%
"ko_mmlu__nutrition__test".split("__")[-1], "ko_mmlu__nutrition__test".split("__")[-2]
# Out:
# ('test', 'nutrition')

# %%
"ko_ai2_arc__ARC_Challenge__validation".split("__")[-1], "ko_ai2_arc__ARC_Challenge__validation".split("__")[-2]
# Out:
# ('validation', 'ARC_Challenge')

# %%
def domain_data(col):
    cols = col.split("__")
    domain = cols[-2]
    #data_id = cols[-1]
    return domain #, data_id

def id_data(col):
    cols = col.split("__")
    #domain = cols[-2]
    data_id = cols[-1]
    return data_id

# %%
df['Domain'] = df['src'].apply(domain_data)
df['data_id'] = df['src'].apply(id_data)
df
# Out:
#                                      docid  \
# 0     42508ee0-c543-4338-878e-d98c6babee66
# 1     4a437e7f-16c1-4c62-96b9-f173d44f4339
# 2     d3c68be5-9cb1-4d6e-ba18-5f81cf89affb
# 3     910107a6-2a42-41a2-b337-fbf22d6440fe
# 4     74f22819-1a8e-4646-8a9d-13323de8cdb8
# ...                                    ...
# 1063  c9839504-a70c-4755-b933-7d71dcb800c7
# 1064  840c3bcf-3caf-43fb-b4b8-e77b450e0fee
# 1065  2d5d7d1a-79a2-4859-925c-524c5e25bbe4
# 1066  9bfc76e2-d492-42af-97eb-da5957af935f
# 1067  46e9683f-1ba0-4e93-83bc-1cde390e80e6
#
#                                         src  \
# 0                  ko_mmlu__nutrition__test
# 1         ko_mmlu__conceptual_physics__test
# 2           ko_ai2_arc__ARC_Challenge__test
# 3           ko_ai2_arc__ARC_Challenge__test
# 4     ko_ai2_arc__ARC_Challenge__validation
# ...                                     ...
# 1063  ko_ai2_arc__ARC_Challenge__validation
# 1064               ko_mmlu__astronomy__test
# ...

# %%
df1 = df[['content','docid','q1','Domain', 'data_id']]
df1.columns = ['content','id','question','Domain', 'data_id']
df1
# Out:
#                                                 content  \
# 0     건강한 사람이 에너지 균형을 평형 상태로 유지하는 것은 중요합니다. 에너지 균형은 ...
# 1     수소, 산소, 질소 가스의 혼합물에서 평균 속도가 가장 빠른 분자는 수소입니다. 수...
# 2     종이와 플라스틱은 재활용 가능한 자원입니다. 중학교 과학 수업에서 우리는 종이와 플...
# 3     마이애미파랑나비는 남부 플로리다에서 멸종 위기에 처한 종입니다. 이 나비의 개체수 ...
# 4     비버는 나무를 베고, 덤불과 관목을 모아 강과 개울에 댐을 만드는 것으로 알려져 있...
# ...                                                 ...
# 1063  식물의 성장에 철분이 미치는 영향을 연구하기 위해 한 학생이 실험을 진행했습니다. ...
# 1064  달의 바다는 어두운 용암으로 채워진 더 오래된 충돌 분지입니다. 이 용암은 달의 표...
# 1065  그레이트 베이신 국립공원은 뉴질랜드에 위치한 아름다운 자연 보호지로, 그 특징 중 ...
# 1066  물리적 변화의 예시로는 버터를 녹이는 것이 있습니다. 버터는 고체 상태에서 액체 상...
# 1067  식이 섭취 평가에서 정보 편향을 줄이는 것은 완전히 불가능하지만, 몇 가지 방법을 ...
#
#                                         id  \
# 0     42508ee0-c543-4338-878e-d98c6babee66
# 1     4a437e7f-16c1-4c62-96b9-f173d44f4339
# 2     d3c68be5-9cb1-4d6e-ba18-5f81cf89affb
# 3     910107a6-2a42-41a2-b337-fbf22d6440fe
# 4     74f22819-1a8e-4646-8a9d-13323de8cdb8
# ...

# %%
docids = []
srcs = []
contents = []
questions = []
q1_list = []
q2_list = []
q3_list = []
q4_list = []
q5_list = []

with jsonlines.open(os.path.join(os.getcwd(),"../data/generated_questions_2136.jsonl"), 'r') as f:
    for line in f.iter():
        count += 1
        docid= line['docid']
        src = line['src']
        content = line['content']
        q1 = line['q1']
        q2 = line['q2']
        q3 = line['q3']
        #q4 = line['q4']
        #q5 = line['q5']
        #print(qs, len(qs))
        #break
        docids.append(docid)
        srcs.append(src)
        contents.append(content)
        q1_list.append(q1)
        q2_list.append(q2)
        q3_list.append(q3)
        #q4_list.append(q4)
        #q5_list.append(q5)


df = pd.DataFrame({'docid': docids,
                   'src': srcs,
                   'content': contents,
                   'q1': q1_list,
                   'q2': q2_list,
                   'q3': q3_list
                   #'q4': q4_list,
                   #'q5': q5_list
                   }) 

df['Domain'] = df['src'].apply(domain_data)
df['data_id'] = df['src'].apply(id_data)
df2 = df[['content','docid','q1','Domain', 'data_id']]
df2.columns = ['content','id','question','Domain', 'data_id']
df2
# Out:
#                                                 content  \
# 0     LC 오실레이터는 파형을 생성하는 데 사용되는 주파수 범위는 1 MHz에서 500 ...
# 1     한 과학자가 공룡의 뼈를 찾기 위해 말라붙은 강바닥을 파고 있었습니다. 그러나 비가...
# 2     약물 간 상호작용으로 뇌 대사가 방해를 받았을 때, 그것은 폴리파마시를 의미합니다....
# 3     나무 블록이 테이블 위를 미끄러질 때 마찰력 f를 경험합니다. 이는 물체가 표면과 ...
# 4     화석은 고대 생물체의 흔적이며, 콜로라도와 와이오밍에서 발견된 화석은 초기 중생대부...
# ...                                                 ...
# 1063  캘리포니아의 엘 카혼 패스는 매년 거의 1센티미터씩 주변 땅보다 높아지고 있습니다....
# 1064  물의 순환 과정은 지구에서 물의 움직임을 설명합니다. 지구의 물 중 약 96%는 바...
# 1065  태양계에서 개기 월식이 발생할 때, 태양, 달, 지구는 다음과 같은 순서로 배열되어...
# 1066  사회 보장은 대부분의 은퇴자들이 가지고 있는 세 다리 의자 중 하나입니다. 사회 보...
# 1067  유전적 행동은 생물들이 부모로부터 물려받은 특정한 행동 패턴을 따르는 것을 말합니다...
#
#                                         id  \
# 0     2ab0b9fd-e94e-412f-a346-98bddaebb180
# 1     768244be-fb3f-4e8d-ac46-25f1b4030468
# 2     e9a3297d-f12b-4f25-94a2-78c5c2393ba7
# 3     cca5bead-76f2-4488-9c58-c312da2047ce
# 4     ae177d30-adb1-4401-9048-3b6efaa95880
# ...

# %%
docids = []
srcs = []
contents = []
questions = []
q1_list = []
q2_list = []
q3_list = []
q4_list = []
q5_list = []

with jsonlines.open(os.path.join(os.getcwd(),"../data/generated_questions_4272.jsonl"), 'r') as f:
    for line in f.iter():
        count += 1
        docid= line['docid']
        src = line['src']
        content = line['content']
        q1 = line['q1']
        q2 = line['q2']
        q3 = line['q3']
        q4 = line['q4']
        q5 = line['q5']
        #print(qs, len(qs))
        #break
        docids.append(docid)
        srcs.append(src)
        contents.append(content)
        q1_list.append(q1)
        q2_list.append(q2)
        q3_list.append(q3)
        q4_list.append(q4)
        q5_list.append(q5)


df = pd.DataFrame({'docid': docids,
                   'src': srcs,
                   'content': contents,
                   'q1': q1_list,
                   'q2': q2_list,
                   'q3': q3_list,
                   'q4': q4_list,
                   'q5': q5_list
                   }) 

df['Domain'] = df['src'].apply(domain_data)
df['data_id'] = df['src'].apply(id_data)
df3 = df[['content','docid','q1','Domain', 'data_id']]
df3.columns = ['content','id','question','Domain', 'data_id']
df3
# Out:
#                                                 content  \
# 0     dynamometer wattmeter의 가동 코일 내 회로의 저항은 높아야 한다....
# 1     석탄은 지구의 지질 작용이 수백만 년 동안 계속된 결과물입니다. 이 고체 바위는 습...
# 2     DNA는 생물의 유전 정보를 담고 있는 분자입니다. DNA 분자의 뉴클레오티드 서열...
# 3     인공 산호초는 침몰한 배나 객차와 같은 구조물로 구성되어 있으며, 이러한 구조물은 ...
# 4     IP 주소 스푸핑은 네트워크 보안에서 중요한 문제입니다. 스푸핑은 공격자가 자신의 ...
# ...                                                 ...
# 1063  월경은 여성의 생리주기에 따라 발생하는 현상으로, 에스트로겐과 프로게스테론 수치의 ...
# 1064  식물이 내뿜는 가스는 산소입니다. 식물은 광합성 과정을 통해 태양 에너지를 이용하여...
# 1065  버퍼 오버런은 개발자들이 만든 널리 퍼져 있는 앱의 코딩 오류로써, 공격자가 시스템...
# 1066  Elodea는 수중에서 자라는 식물로, 잎의 세포를 설탕 용액에 담가서 실험을 진행...
# 1067  힘의 상수가 k인 스프링이 특정한 길이만큼 늘어난다는 것은 스프링의 변위와 힘 사이...
#
#                                         id  \
# 0     5d2ea84a-3cc5-4f5e-849b-bc9b2d31d579
# 1     bdb60929-41cb-458c-8962-476324d49ea5
# 2     f731620e-c2fb-4fd9-b9ca-386c8445ac9a
# 3     c33695f6-a295-4e82-9d94-04876db16a7c
# 4     977ffc39-98b4-4c09-9e66-abbcc9d99d42
# ...

# %%
dft = pd.concat([df1, df2, df3], axis=0)
dft
# Out:
#                                                 content  \
# 0     건강한 사람이 에너지 균형을 평형 상태로 유지하는 것은 중요합니다. 에너지 균형은 ...
# 1     수소, 산소, 질소 가스의 혼합물에서 평균 속도가 가장 빠른 분자는 수소입니다. 수...
# 2     종이와 플라스틱은 재활용 가능한 자원입니다. 중학교 과학 수업에서 우리는 종이와 플...
# 3     마이애미파랑나비는 남부 플로리다에서 멸종 위기에 처한 종입니다. 이 나비의 개체수 ...
# 4     비버는 나무를 베고, 덤불과 관목을 모아 강과 개울에 댐을 만드는 것으로 알려져 있...
# ...                                                 ...
# 1063  월경은 여성의 생리주기에 따라 발생하는 현상으로, 에스트로겐과 프로게스테론 수치의 ...
# 1064  식물이 내뿜는 가스는 산소입니다. 식물은 광합성 과정을 통해 태양 에너지를 이용하여...
# 1065  버퍼 오버런은 개발자들이 만든 널리 퍼져 있는 앱의 코딩 오류로써, 공격자가 시스템...
# 1066  Elodea는 수중에서 자라는 식물로, 잎의 세포를 설탕 용액에 담가서 실험을 진행...
# 1067  힘의 상수가 k인 스프링이 특정한 길이만큼 늘어난다는 것은 스프링의 변위와 힘 사이...
#
#                                         id  \
# 0     42508ee0-c543-4338-878e-d98c6babee66
# 1     4a437e7f-16c1-4c62-96b9-f173d44f4339
# 2     d3c68be5-9cb1-4d6e-ba18-5f81cf89affb
# 3     910107a6-2a42-41a2-b337-fbf22d6440fe
# 4     74f22819-1a8e-4646-8a9d-13323de8cdb8
# ...

# %%
df_train = dft[dft['data_id']=='train']
df_train
# Out:
#                                                 content  \
# 8     강한 바람이 삼림 지대의 소나무를 넘어뜨렸을 때, 우거진 숲 지붕에 틈이 생겨 땅에...
# 13    겨울에 습한 공기가 차가운 표면과 접촉하면 결과적으로 서리가 생길 수 있습니다. 이...
# 28    망아지는 부모로부터 다음의 모든 형질을 유전적으로 물려받지만, 이에 해당하지 않는 ...
# 31    새의 얇은 부리는 좁은 장소에서 발견되는 먹이를 얻는 데 도움이 될 가능성이 가장 ...
# 36    지질학자들은 암석의 상대 연대를 결정하기 위해 종종 질량 분석계를 사용합니다. 이 ...
# ...                                                 ...
# 1058  음파는 암석을 통해 가장 빠르게 이동합니다. 암석은 음파의 전달에 매우 효과적인 매...
# 1059  태양과 달이 대략 같은 크기로 보이는 이유는 달이 태양보다 지름이 더 짧고 지구에서...
# 1061  비뇨기계와 순환계는 혈액이 신장을 통과하면서 폐기물과 물이 제거될 때 관여하는 두 ...
# 1062  로봇은 현대 산업에서 많은 역할을 수행할 수 있습니다. 그러나 로봇 사용의 중대한 ...
# 1064  식물이 내뿜는 가스는 산소입니다. 식물은 광합성 과정을 통해 태양 에너지를 이용하여...
#
#                                         id  \
# 8     69de4a81-3716-4195-973c-39eee3771186
# 13    284919ef-edaf-492d-9575-0a1b40416a71
# 28    fb3170e4-dd64-4716-8a18-4bf986f00702
# 31    064c460f-af5e-47f2-ad47-2f5b4a8eb3f7
# 36    814dd12b-62a4-4a79-99d2-82fa39ba76e3
# ...

# %%
df_val = dft[dft['data_id']=='validation']
df_val
# Out:
#                                                 content  \
# 4     비버는 나무를 베고, 덤불과 관목을 모아 강과 개울에 댐을 만드는 것으로 알려져 있...
# 12    아메리카 알리게이터는 플로리다 습지에서 흔하게 발견되는 동물입니다. 그들은 주로 개...
# 15    한 실험을 밀폐 용기를 이용해 실시합니다. 이 실험에서는 용기의 초기 온도가 화씨 ...
# 37    알루미늄 염화물과 마그네슘이 반응하여 마그네슘 염화물과 알루미늄이 생성되는 반응식은...
# 44    금과 탄소는 에너지를 방출하는 과정에서 서로 다른 방식을 사용합니다. 금은 핵분열을...
# ...                                                 ...
# 1033  외래 식물은 자생 식물이 이전에 서식하던 지역을 장악할 수 있습니다. 이는 생태계의...
# 1040  화석 기록은 종의 변화가 일반적으로 많은 세대에 걸쳐 발생한다는 것을 나타냅니다. ...
# 1043  평행 진화는 관련이 있거나 없을 수 있는 두 종에서 발생하는 유사한 진화적 변화를 ...
# 1048  아프리카 사바나의 생태계는 다양한 생물들이 서로 협력하여 살아가는 특별한 관계를 가...
# 1066  Elodea는 수중에서 자라는 식물로, 잎의 세포를 설탕 용액에 담가서 실험을 진행...
#
#                                         id  \
# 4     74f22819-1a8e-4646-8a9d-13323de8cdb8
# 12    6a07c17e-ec09-4383-9f77-c7baeb641bac
# 15    d9b2d729-178b-419b-8afd-2d3fc424a41b
# 37    f039886e-c38c-4ba9-a044-63028bfdf7c2
# 44    a6596127-b651-4717-bcc2-98aa06383006
# ...

# %%
df_test = dft[dft['data_id']=='test']
df_test
# Out:
#                                                 content  \
# 0     건강한 사람이 에너지 균형을 평형 상태로 유지하는 것은 중요합니다. 에너지 균형은 ...
# 1     수소, 산소, 질소 가스의 혼합물에서 평균 속도가 가장 빠른 분자는 수소입니다. 수...
# 2     종이와 플라스틱은 재활용 가능한 자원입니다. 중학교 과학 수업에서 우리는 종이와 플...
# 3     마이애미파랑나비는 남부 플로리다에서 멸종 위기에 처한 종입니다. 이 나비의 개체수 ...
# 5     AIDS에 직면한 민족문화 공동체 연구에 따르면, 한 해 동안 섹스 파트너가 한 명...
# ...                                                 ...
# 1055  DC 발전기의 정류자는 AC 암자추 전류를 DC로 변환하기 위해 사용된다. 정류자는...
# 1060  대 마젤란 운은 우리 은하를 공전하는 왜소 은하입니다. 이 은하는 1483년에 포르...
# 1063  월경은 여성의 생리주기에 따라 발생하는 현상으로, 에스트로겐과 프로게스테론 수치의 ...
# 1065  버퍼 오버런은 개발자들이 만든 널리 퍼져 있는 앱의 코딩 오류로써, 공격자가 시스템...
# 1067  힘의 상수가 k인 스프링이 특정한 길이만큼 늘어난다는 것은 스프링의 변위와 힘 사이...
#
#                                         id  \
# 0     42508ee0-c543-4338-878e-d98c6babee66
# 1     4a437e7f-16c1-4c62-96b9-f173d44f4339
# 2     d3c68be5-9cb1-4d6e-ba18-5f81cf89affb
# 3     910107a6-2a42-41a2-b337-fbf22d6440fe
# 5     80feb7f2-1b24-4a9d-87a3-4976e9304e74
# ...

# %%
dft.to_csv("../data/generated_questions_single_q_total.csv")
df_train.to_csv("../data/generated_questions_single_q_train.csv")
df_val.to_csv("../data/generated_questions_single_q_val.csv")
df_test.to_csv("../data/generated_questions_single_q_test.csv")

# %% [markdown]
# # Multiple Questions q1, q2 and q3
# dft has q1
# add q2, and q3 to dft by concat

# %%
docids = []
srcs = []
contents = []
questions = []
q1_list = []
q2_list = []
q3_list = []
q4_list = []
q5_list = []

with jsonlines.open(os.path.join(os.getcwd(),"../data/generated_questions_1068.jsonl"), 'r') as f:
    for line in f.iter():
        count += 1
        docid= line['docid']
        src = line['src']
        content = line['content']
        q1 = line['q1']
        q2 = line['q2']
        q3 = line['q3']
        q4 = line['q4']
        q5 = line['q5']
        #print(qs, len(qs))
        #break
        docids.append(docid)
        srcs.append(src)
        contents.append(content)
        q1_list.append(q1)
        q2_list.append(q2)
        q3_list.append(q3)
        q4_list.append(q4)
        q5_list.append(q5)


df = pd.DataFrame({'docid': docids,
                   'src': srcs,
                   'content': contents,
                   'q1': q1_list,
                   'q2': q2_list,
                   'q3': q3_list,
                   'q4': q4_list,
                   'q5': q5_list
                   }) 

df['Domain'] = df['src'].apply(domain_data)
df['data_id'] = df['src'].apply(id_data)

qs = ['q2', 'q3']

for q in qs:
    df_temp = df[['content','docid', q ,'Domain', 'data_id']]
    df_temp.columns = ['content','id','question','Domain', 'data_id']
    dft = pd.concat([dft, df_temp], axis=0)
    
dft
# Out:
#                                                 content  \
# 0     건강한 사람이 에너지 균형을 평형 상태로 유지하는 것은 중요합니다. 에너지 균형은 ...
# 1     수소, 산소, 질소 가스의 혼합물에서 평균 속도가 가장 빠른 분자는 수소입니다. 수...
# 2     종이와 플라스틱은 재활용 가능한 자원입니다. 중학교 과학 수업에서 우리는 종이와 플...
# 3     마이애미파랑나비는 남부 플로리다에서 멸종 위기에 처한 종입니다. 이 나비의 개체수 ...
# 4     비버는 나무를 베고, 덤불과 관목을 모아 강과 개울에 댐을 만드는 것으로 알려져 있...
# ...                                                 ...
# 1063  식물의 성장에 철분이 미치는 영향을 연구하기 위해 한 학생이 실험을 진행했습니다. ...
# 1064  달의 바다는 어두운 용암으로 채워진 더 오래된 충돌 분지입니다. 이 용암은 달의 표...
# 1065  그레이트 베이신 국립공원은 뉴질랜드에 위치한 아름다운 자연 보호지로, 그 특징 중 ...
# 1066  물리적 변화의 예시로는 버터를 녹이는 것이 있습니다. 버터는 고체 상태에서 액체 상...
# 1067  식이 섭취 평가에서 정보 편향을 줄이는 것은 완전히 불가능하지만, 몇 가지 방법을 ...
#
#                                         id  \
# 0     42508ee0-c543-4338-878e-d98c6babee66
# 1     4a437e7f-16c1-4c62-96b9-f173d44f4339
# 2     d3c68be5-9cb1-4d6e-ba18-5f81cf89affb
# 3     910107a6-2a42-41a2-b337-fbf22d6440fe
# 4     74f22819-1a8e-4646-8a9d-13323de8cdb8
# ...

# %%
docids = []
srcs = []
contents = []
questions = []
q1_list = []
q2_list = []
q3_list = []
q4_list = []
q5_list = []

with jsonlines.open(os.path.join(os.getcwd(),"../data/generated_questions_2136.jsonl"), 'r') as f:
    for line in f.iter():
        count += 1
        docid= line['docid']
        src = line['src']
        content = line['content']
        q1 = line['q1']
        q2 = line['q2']
        q3 = line['q3']
        #q4 = line['q4']
        #q5 = line['q5']
        #print(qs, len(qs))
        #break
        docids.append(docid)
        srcs.append(src)
        contents.append(content)
        q1_list.append(q1)
        q2_list.append(q2)
        q3_list.append(q3)
        #q4_list.append(q4)
        #q5_list.append(q5)


df = pd.DataFrame({'docid': docids,
                   'src': srcs,
                   'content': contents,
                   'q1': q1_list,
                   'q2': q2_list,
                   'q3': q3_list
                   #'q4': q4_list,
                   #'q5': q5_list
                   }) 

df['Domain'] = df['src'].apply(domain_data)
df['data_id'] = df['src'].apply(id_data)

qs = ['q2', 'q3']

for q in qs:
    df_temp = df[['content','docid', q ,'Domain', 'data_id']]
    df_temp.columns = ['content','id','question','Domain', 'data_id']
    dft = pd.concat([dft, df_temp], axis=0)
    
dft
# Out:
#                                                 content  \
# 0     건강한 사람이 에너지 균형을 평형 상태로 유지하는 것은 중요합니다. 에너지 균형은 ...
# 1     수소, 산소, 질소 가스의 혼합물에서 평균 속도가 가장 빠른 분자는 수소입니다. 수...
# 2     종이와 플라스틱은 재활용 가능한 자원입니다. 중학교 과학 수업에서 우리는 종이와 플...
# 3     마이애미파랑나비는 남부 플로리다에서 멸종 위기에 처한 종입니다. 이 나비의 개체수 ...
# 4     비버는 나무를 베고, 덤불과 관목을 모아 강과 개울에 댐을 만드는 것으로 알려져 있...
# ...                                                 ...
# 1063  캘리포니아의 엘 카혼 패스는 매년 거의 1센티미터씩 주변 땅보다 높아지고 있습니다....
# 1064  물의 순환 과정은 지구에서 물의 움직임을 설명합니다. 지구의 물 중 약 96%는 바...
# 1065  태양계에서 개기 월식이 발생할 때, 태양, 달, 지구는 다음과 같은 순서로 배열되어...
# 1066  사회 보장은 대부분의 은퇴자들이 가지고 있는 세 다리 의자 중 하나입니다. 사회 보...
# 1067  유전적 행동은 생물들이 부모로부터 물려받은 특정한 행동 패턴을 따르는 것을 말합니다...
#
#                                         id  \
# 0     42508ee0-c543-4338-878e-d98c6babee66
# 1     4a437e7f-16c1-4c62-96b9-f173d44f4339
# 2     d3c68be5-9cb1-4d6e-ba18-5f81cf89affb
# 3     910107a6-2a42-41a2-b337-fbf22d6440fe
# 4     74f22819-1a8e-4646-8a9d-13323de8cdb8
# ...

# %%
docids = []
srcs = []
contents = []
questions = []
q1_list = []
q2_list = []
q3_list = []
q4_list = []
q5_list = []

with jsonlines.open(os.path.join(os.getcwd(),"../data/generated_questions_4272.jsonl"), 'r') as f:
    for line in f.iter():
        count += 1
        docid= line['docid']
        src = line['src']
        content = line['content']
        q1 = line['q1']
        q2 = line['q2']
        q3 = line['q3']
        q4 = line['q4']
        q5 = line['q5']
        #print(qs, len(qs))
        #break
        docids.append(docid)
        srcs.append(src)
        contents.append(content)
        q1_list.append(q1)
        q2_list.append(q2)
        q3_list.append(q3)
        q4_list.append(q4)
        q5_list.append(q5)


df = pd.DataFrame({'docid': docids,
                   'src': srcs,
                   'content': contents,
                   'q1': q1_list,
                   'q2': q2_list,
                   'q3': q3_list,
                   'q4': q4_list,
                   'q5': q5_list
                   }) 

df['Domain'] = df['src'].apply(domain_data)
df['data_id'] = df['src'].apply(id_data)

qs = ['q2', 'q3']

for q in qs:
    df_temp = df[['content','docid', q ,'Domain', 'data_id']]
    df_temp.columns = ['content','id','question','Domain', 'data_id']
    dft = pd.concat([dft, df_temp], axis=0)
    
dft
# Out:
#                                                 content  \
# 0     건강한 사람이 에너지 균형을 평형 상태로 유지하는 것은 중요합니다. 에너지 균형은 ...
# 1     수소, 산소, 질소 가스의 혼합물에서 평균 속도가 가장 빠른 분자는 수소입니다. 수...
# 2     종이와 플라스틱은 재활용 가능한 자원입니다. 중학교 과학 수업에서 우리는 종이와 플...
# 3     마이애미파랑나비는 남부 플로리다에서 멸종 위기에 처한 종입니다. 이 나비의 개체수 ...
# 4     비버는 나무를 베고, 덤불과 관목을 모아 강과 개울에 댐을 만드는 것으로 알려져 있...
# ...                                                 ...
# 1063  월경은 여성의 생리주기에 따라 발생하는 현상으로, 에스트로겐과 프로게스테론 수치의 ...
# 1064  식물이 내뿜는 가스는 산소입니다. 식물은 광합성 과정을 통해 태양 에너지를 이용하여...
# 1065  버퍼 오버런은 개발자들이 만든 널리 퍼져 있는 앱의 코딩 오류로써, 공격자가 시스템...
# 1066  Elodea는 수중에서 자라는 식물로, 잎의 세포를 설탕 용액에 담가서 실험을 진행...
# 1067  힘의 상수가 k인 스프링이 특정한 길이만큼 늘어난다는 것은 스프링의 변위와 힘 사이...
#
#                                         id  \
# 0     42508ee0-c543-4338-878e-d98c6babee66
# 1     4a437e7f-16c1-4c62-96b9-f173d44f4339
# 2     d3c68be5-9cb1-4d6e-ba18-5f81cf89affb
# 3     910107a6-2a42-41a2-b337-fbf22d6440fe
# 4     74f22819-1a8e-4646-8a9d-13323de8cdb8
# ...

# %%
df_train = dft[dft['data_id']=='train']
df_val = dft[dft['data_id']=='validation']
df_test = dft[dft['data_id']=='test']
df_train.shape[0], df_val.shape[0], df_test.shape[0]
# Out:
# (2031, 1014, 6567)

# %%
dft.to_csv("../data/generated_questions_multiple_q_total.csv")
df_train.to_csv("../data/generated_questions_multiple_q_train.csv")
df_val.to_csv("../data/generated_questions_multiple_q_val.csv")
df_test.to_csv("../data/generated_questions_multiple_q_test.csv")
